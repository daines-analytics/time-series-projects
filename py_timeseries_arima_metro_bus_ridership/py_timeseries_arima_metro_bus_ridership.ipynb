# %% [markdown]
# # Time Series Model for Metro Bus Ridership Using Python and ARIMA
# ### David Lowe
# ### August 19, 2020
#
# Template Credit: Adapted from a template made available by Dr. Jason Brownlee of Machine Learning Mastery. https://machinelearningmastery.com/
#
# SUMMARY: The purpose of this project is to construct a time series prediction model and document the end-to-end steps using a template. The Metro Bus Ridership dataset is a time series situation where we are trying to forecast future outcomes based on past data points.
#
# INTRODUCTION: The problem is to forecast the monthly number of bus riders for the Los Angeles County Metro district. The dataset describes a time-series of bus riders between January 2009 and June 2020, and there are 138 observations. We used the first 80% of the observations for training various models while holding back the remaining observations for validating the final model.
#
# ANALYSIS: The baseline prediction (or persistence) for the dataset resulted in an RMSE of 2.480 million. After performing a grid search for the most optimal ARIMA parameters, the final ARIMA non-seasonal order was (4, 1, 2) with the seasonal order being (1, 0, 2, 12). Furthermore, the chosen model processed the validation data with an RMSE of 2.397 million, which was just slightly better than the baseline model.
#
# CONCLUSION: For this dataset, the chosen ARIMA model achieved a satisfactory result, and we should consider using the algorithm for further modeling.
#
# Dataset Used: Metro Interactive Estimated Ridership Stats
#
# Dataset ML Model: Time series forecast with numerical attribute
#
# Dataset Reference: http://isotp.metro.net/MetroRidership/Index.aspx
#
# A time series predictive modeling project generally can be broken down into about five major tasks:
#
# 1. Define Problem and Acquire Data
# 2. Inspect and Explore Data
# 3. Clean and Pre-Process Data
# 4. Fit and Evaluate Models
# 5. Finalize Model and Make Predictions

# %% [markdown]
# ## Task 1: Define Problem and Acquire Data

# %%
# Install the necessary packages for Colab
# !pip install python-dotenv PyMySQL

# %%
# Retrieve the GPU information from Colab
# gpu_info = !nvidia-smi
# gpu_info = '\n'.join(gpu_info)
# if gpu_info.find('failed') >= 0:
#     print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
#     print('and then re-execute this cell.')
# else:
#     print(gpu_info)

# %%
# Retrieve the memory configuration from Colab
# from psutil import virtual_memory
# ram_gb = virtual_memory().total / 1e9
# print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

# if ram_gb < 20:
#     print('To enable a high-RAM runtime, select the Runtime → "Change runtime type"')
#     print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
#     print('re-execute this cell.')
# else:
#     print('You are using a high-RAM runtime!')

# %%
# Retrieve the CPU information
ncpu = !nproc
print("The number of available CPUs is:", ncpu[0])
# Out:
# The number of available CPUs is: 4

# %% [markdown]
# ### 1.a) Load Libraries

# %%
# Create the random seed number for reproducible results
seedNum = 888

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pmdarima as pm
import os
import sys
import math
import boto3
from datetime import datetime
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
import pandas_datareader.data as web
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %% [markdown]
# ### 1.b) Set up the controlling parameters and functions

# %%
# Begin the timer for the script processing
startTimeScript = datetime.now()

# Set up the number of CPU cores available for multi-thread processing
n_jobs = 2

# Set up the flag to stop sending progress emails (setting to True will send status emails!)
notifyStatus = False

# Set up the parent directory location for loading the dotenv files
useGDrive = False
if useGDrive:
    # Mount Google Drive locally for storing files
    from google.colab import drive
    drive.mount('/content/gdrive')
    gdrivePrefix = '/content/gdrive/My Drive/Colab_Downloads/'
    env_path = '/content/gdrive/My Drive/Colab Notebooks/'
    dotenv_path = env_path + "python_script.env"
    load_dotenv(dotenv_path=dotenv_path)

# Set up the dotenv file for retrieving environment variables
useLocalPC = False
if useLocalPC:
    env_path = "/Users/david/PycharmProjects/"
    dotenv_path = env_path + "python_script.env"
    load_dotenv(dotenv_path=dotenv_path)

# Configure the plotting style
plt.style.use('seaborn')

# Set Pandas options
pd.set_option("display.max_rows", 500)
pd.set_option("display.width", 140)

# %%
# Set up the email notification function
def status_notify(msg_text):
    access_key = os.environ.get('SNS_ACCESS_KEY')
    secret_key = os.environ.get('SNS_SECRET_KEY')
    aws_region = os.environ.get('SNS_AWS_REGION')
    topic_arn = os.environ.get('SNS_TOPIC_ARN')
    if (access_key is None) or (secret_key is None) or (aws_region is None):
        sys.exit("Incomplete notification setup info. Script Processing Aborted!!!")
    sns = boto3.client('sns', aws_access_key_id=access_key, aws_secret_access_key=secret_key, region_name=aws_region)
    response = sns.publish(TopicArn=topic_arn, Message=msg_text)
    if response['ResponseMetadata']['HTTPStatusCode'] != 200 :
        print('Status notification not OK with HTTP status code:', response['ResponseMetadata']['HTTPStatusCode'])

# %%
if notifyStatus: status_notify("ARIMA Task 1: Define Problem and Acquire Data has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 1.c) Acquire and Load the Data
#
# Since the dataset is not current, this means that we cannot easily collect updated data to validate the model. Therefore, we will withhold a portion of the data towards the end from analysis and model selection. This very segment of data will be used to validate the final model.

# %%
# load the dataset and the necessary data structure
time_series = pd.read_csv('https://dainesanalytics.com/datasets/metro-interactive-ridership-stats/bus-estimated-ridership.csv', index_col='idx', parse_dates=True)

# Load the dataset from the Federal Reserve Bank's FRED Database
# starting = datetime(1995, 1, 1)
# ending = datetime.now()
# fred_data = 'EXPTOTCA'
# time_series = web.DataReader(fred_data, 'fred', starting, ending)
# time_series.rename(columns={fred_data: 'value'}, inplace=True)

# Sample code for subsetting the time-series data
# time_series = original_series['1986':'1990']

# %%
target_col = time_series.columns[0]
lower_bound = 'lower ' + target_col
upper_bound = 'upper ' + target_col
print('The target column of the time series is:', target_col)
print('The forecast boundary columns are:', lower_bound, '&', upper_bound)
# Out:
# The target column of the time series is: values
# The forecast boundary columns are: lower values & upper values

# %%
time_series.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 138 entries, 2009-01-01 to 2020-06-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   values  138 non-null    int64
# dtypes: int64(1)
# memory usage: 2.2 KB

# %%
time_series.head()
# Out:
#               values
# idx
# 2009-01-01  30580085
# 2009-02-01  28778916
# 2009-03-01  32963302
# 2009-04-01  31471512
# 2009-05-01  31665879

# %%
time_series.tail()
# Out:
#               values
# idx
# 2020-02-01  21767867
# 2020-03-01  15323805
# 2020-04-01   7448380
# 2020-05-01   9096081
# 2020-06-01  10679063

# %%
if notifyStatus: status_notify("ARIMA Task 1: Define Problem and Acquire Data completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Task 2: Inspect and Explore Data

# %%
if notifyStatus: status_notify("ARIMA Task 2: Inspect and Explore Data has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 2.a) Summary Statistics of the Time Series Data
#
# Summary statistics provide a quick look at the limits of observed values. It can help to get a quick idea of what we are working with.

# %%
# Summary statistics of time series
print(time_series.describe())
# Out:
#              values
# count  1.380000e+02
# mean   2.700362e+07
# std    4.368169e+06
# min    7.448380e+06
# 25%    2.414609e+07
# 50%    2.801593e+07
# 75%    3.027720e+07
# max    3.296330e+07

# %% [markdown]
# ### 2.b) Line Plot of the Time Series Data
#
# A line plot of a time series can provide a lot of insight into the problem. Some observations from the plot can include:
#
# * Whether the trend appears to be level around the mean
# * Whether there appear to be any obvious outliers
#
# The ARIMA(p,d,q) model requires three parameters and assumes that we are working with a stationary time series.
#
# The ADF results should show that the test statistic value is smaller than the critical value at 5% if the time series is stationary. This suggests that we can reject the null hypothesis (i.e. a low probability that the result is a statistical fluke).

# %%
# Line plots of time series
fig, ax = plt.subplots(figsize=(16,9))
fig.suptitle('Line Plot of the Time Series Data')
time_series.plot(ax=ax)
plt.show()

# %% [markdown]
# ### 2.c) Histogram and Density Plots of the Time Series Data
#
# Reviewing plots of the density of observations can provide further insight into the structure of the data. Some observations from the plots can include:
#
# * Whether the distribution is Gaussian
# * Whether the distribution has a long tail and may suggest the need for data transformation

# %%
# Line plots of time series
fig, ax = plt.subplots(figsize=(16,9))
fig.suptitle('Histogram of the Time Series Data')
time_series.hist(ax=ax)
plt.show()

# %%
# Line plots of time series
fig, ax = plt.subplots(figsize=(16,9))
fig.suptitle('Density Plot of the Time Series Data')
time_series.plot(kind='kde', ax=ax)
plt.show()

# %% [markdown]
# ### 2.d) Box and Whisker Plots of the Time Series Data
#
# We can group or aggregate the data and get a better idea of the spread of observations. Some observations from reviewing the plot can include:
#
# * Whether the median values for each grouping shows any significant trend
# * Whether the spread, or middle 50% of the data, shows any significant variability
# * Whether there are outliers in some grouping

# %%
# boxplots of time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Box and Whisker Plots of the Time Series Data')
squeezed = time_series.squeeze()
# sns.boxplot(squeezed.index.year, squeezed, ax=ax)
sns.boxplot(squeezed.index.year, squeezed, ax=ax)
plt.show()

# %%
if notifyStatus: status_notify("ARIMA Task 2: Inspect and Explore Data completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Task 3: Clean and Pre-Process Data

# %%
if notifyStatus: status_notify("ARIMA Task 3: Clean and Pre-Process Data has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### Section 3.a) Data Transformation

# %%
# Resampling the time series into monthly average for the ease of modeling
# original_series = time_series
# resample = original_series.resample('M')
# time_series = resample.mean()
# time_series.head(10)

# %%
# Line plots of the transformed time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Non-Seasonal Time Series Data')
time_series.plot(ax=ax)
plt.show()

# %% [markdown]
# ### Section 3.b) Test for Stationarity

# %%
# Check if stationary
result = adfuller(time_series[target_col])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Test Statistics Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: 1.622952
# p-value: 0.997925
# Critical Test Statistics Values:
# 	1%: -3.484
# 	5%: -2.885
# 	10%: -2.579

# %%
# ACF and PACF plots of the time series data
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))
plot_acf(time_series, ax=ax1)
plot_pacf(time_series, ax=ax2)
plt.show()

# %% [markdown]
# ### 3.c) Test for Stationarity of Non-Seasonal Time Series Data
#
# Occasionally a time series may look non-stationary on the first look. We can make it stationary by differencing the series and using a statistical test to confirm that the differenced result is stationary. Rejecting the null hypothesis means that the process has no unit root, and in turn that the time series is stationary or does not have time-dependent structure.

# %%
# Create a differenced series
stationary_ns = time_series.diff().dropna()

# Plot differenced data
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Stationary Time Series Data')
stationary_ns.plot(ax=ax)
plt.show()

# %%
# Check for stationarity
result = adfuller(stationary_ns[target_col])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Test Statistics Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -3.147648
# p-value: 0.023222
# Critical Test Statistics Values:
# 	1%: -3.484
# 	5%: -2.885
# 	10%: -2.579

# %%
# ACF and PACF plots of the stationary time series
lags = 25
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))
plot_acf(stationary_ns, lags=lags, ax=ax1)
plot_pacf(stationary_ns, lags=lags, ax=ax2)
plt.show()

# %% [markdown]
# ### 3.d) Seasonal Decomposition for Seasonal Time Series Data

# %%
# Set the initial seasonal frequency parameter
seasonal_freq = 12

# %%
# Perform seasonal decomposition to observe the seasonal frequency
decomp_results = seasonal_decompose(time_series, period=seasonal_freq)
decomp_results.plot()
plt.show()

# %%
# Create a seasonal series
N = seasonal_freq
seasonal_series = time_series - time_series.rolling(N).mean()
seasonal_series = seasonal_series.dropna()

# Line plots of the seasonal time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Seasonal Time Series Data')
seasonal_series.plot(ax=ax)
plt.show()

# %%
# Check for stationarity
result = adfuller(seasonal_series[target_col])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Test Statistics Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -1.369879
# p-value: 0.596628
# Critical Test Statistics Values:
# 	1%: -3.490
# 	5%: -2.887
# 	10%: -2.581

# %%
# ACF and PACF plots of the time series data
lag = seasonal_freq * 2
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))
plot_acf(seasonal_series, lags=lag, ax=ax1)
plot_pacf(seasonal_series, lags=lag, ax=ax2)
plt.show()

# %% [markdown]
# ### 3.e) Test for Stationarity of Seasonal Time Series Data
#
# Occasionally a time series may look non-stationary on the first look. We can make it stationary by differencing the series and using a statistical test to confirm that the differenced result is stationary. Rejecting the null hypothesis means that the process has no unit root, and in turn that the time series is stationary or does not have time-dependent structure.

# %%
# Create a differenced series
stationary_ss = time_series.diff(seasonal_freq).dropna()

# Plot differenced data
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Stationary Seasonal Time Series Data')
stationary_ss.plot(ax=ax)
plt.show()

# %%
# Check for stationarity
result = adfuller(stationary_ss[target_col])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Test Statistics Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -2.729303
# p-value: 0.069103
# Critical Test Statistics Values:
# 	1%: -3.484
# 	5%: -2.885
# 	10%: -2.579

# %%
# ACF and PACF plots of the stationary time series
lags = seasonal_freq * 2
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))
plot_acf(stationary_ss, lags=lags, ax=ax1)
plot_pacf(stationary_ss, lags=lags, ax=ax2)
plt.show()

# %%
if notifyStatus: status_notify("ARIMA Task 3: Clean and Pre-Process Data completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Task 4: Fit and Evaluate Models

# %%
if notifyStatus: status_notify("ARIMA Task 4: Fit and Evaluate Models has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 4.a) Establish the Persistent Model
#
# The first step before getting bogged down in data analysis and modeling is to establish a baseline of performance. This will provide both a template for evaluating models using the proposed test harness and a performance measure by which all more elaborate predictive models can be compared.
#
# The baseline prediction for time series forecasting is called the naive forecast, or persistence. This is where the observation from the previous time step is used as the prediction for the observation at the next time step.

# %% [markdown]
# #### 4.a.iii) Establish the Persistent Model as Baseline

# %%
# Prepare and evaluate a persistence model
X = time_series.values
X = X.astype('float32')
train_pct = 0.80
train_size = int(len(X) * train_pct)
test_size = len(X) - train_size
train_ts, test_ts = X[0:train_size], X[train_size:]

# walk-forward validation
history = [x for x in train_ts]
predictions = list()
for i in range(len(test_ts)):
    yhat = history[-1]
    predictions.append(yhat)
    obs = test_ts[i]
    history.append(obs)
    print('>Predicted=%.3f, Expected=%3.f' % (yhat, obs))

# Calculate performance
rmse = math.sqrt(mean_squared_error(test_ts, predictions))
print('RMSE for the persistent model is: %.3f' % rmse)
# Out:
# >Predicted=21958972.000, Expected=23214316
# >Predicted=23214316.000, Expected=23331876
# >Predicted=23331876.000, Expected=24198092
# >Predicted=24198092.000, Expected=22691252
# >Predicted=22691252.000, Expected=22105750
# >Predicted=22105750.000, Expected=24128752
# >Predicted=24128752.000, Expected=22965412
# >Predicted=22965412.000, Expected=25080292
# >Predicted=25080292.000, Expected=22438608
# >Predicted=22438608.000, Expected=20988856
# >Predicted=20988856.000, Expected=21263764
# >Predicted=21263764.000, Expected=20883716
# >Predicted=20883716.000, Expected=23562034
# >Predicted=23562034.000, Expected=23691650
# >Predicted=23691650.000, Expected=24351954
# >Predicted=24351954.000, Expected=22286620
# >Predicted=22286620.000, Expected=23735872
# >Predicted=23735872.000, Expected=24649208
# >Predicted=24649208.000, Expected=24102718
# >Predicted=24102718.000, Expected=26065766
# >Predicted=26065766.000, Expected=21760680
# >Predicted=21760680.000, Expected=20954860
# >Predicted=20954860.000, Expected=21987684
# >Predicted=21987684.000, Expected=21767868
# >Predicted=21767868.000, Expected=15323805
# >Predicted=15323805.000, Expected=7448380
# >Predicted=7448380.000, Expected=9096081
# >Predicted=9096081.000, Expected=10679063
# RMSE for the persistent model is: 2480049.043

# %% [markdown]
# ### 4.b) Grid Search of ARIMA Hyperparameters
#
# We want to find a model that can do better than the persistence model on this dataset. To confirm this analysis, we can grid search a suite of ARIMA hyperparameters.
#
# In this section, we will search values of p, d, and q for combinations (skipping those that fail to converge), and find the combination that results in the best performance. We will use a grid search to explore all combinations in a subset of integer values.

# %%
if notifyStatus: status_notify("ARIMA Hyperparameters Search has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Set the initial P, D, and Q order parameters for non-seasonal ARIMA modeling
start_p = 0
start_q = 0
max_p = 4
max_d = 2
max_q = 4

# %%
# Set the initial P, D, and Q order parameters for seasonal ARIMA modeling
start_P = 0
start_D = None
start_Q = 0
max_P = 2
max_D = 1
max_Q = 2

# %%
# Testing the time series data for suggestions on the differencing term
start_d = pm.arima.ndiffs(train_ts)
print('The suggested non-seasonal differencing term is:', start_d)
if seasonal_freq != 0:
    start_D = pm.arima.nsdiffs(train_ts, m = seasonal_freq)
    print('The suggested seasonal differencing term is:', start_D)
# Out:
# The suggested non-seasonal differencing term is: 1
# The suggested seasonal differencing term is: 0

# %%
print('The initial non-seasonal parameters are: p =', start_p, '| d =', start_d, '| q =', start_q)
print('The maximum non-seasonal parameters are: max_p =', max_p, '| max_d =', max_d, '| max_q =', max_q)
if seasonal_freq != 0:
    print('The initial seasonal parameters are: P =', start_P, '| D =', start_D, '| Q =', start_Q, '| m =', seasonal_freq)
    print('The maximum seasonal parameters are: max_P =', max_P, '| max_D =', max_D, '| max_Q =', max_Q)
# Out:
# The initial non-seasonal parameters are: p = 0 | d = 1 | q = 0
# The maximum non-seasonal parameters are: max_p = 4 | max_d = 2 | max_q = 4
# The initial seasonal parameters are: P = 0 | D = 0 | Q = 0 | m = 12
# The maximum seasonal parameters are: max_P = 2 | max_D = 1 | max_Q = 2

# %%
# Do an automated stepwise search of ARIMA parameters
if seasonal_freq == 0:
    stepwise_results = pm.auto_arima(train_ts, seasonal = False, stepwise = True, trace = True, suppress_warnings = True, random_state = seedNum, error_action="ignore")
else:
    stepwise_results = pm.auto_arima(train_ts, seasonal = True, m = seasonal_freq, stepwise = True, trace = True, suppress_warnings = True, random_state = seedNum, error_action="ignore")
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA(2,1,2)x(1,0,1,12) [intercept=True]; AIC=3398.586, BIC=3420.117, Time=1.779 seconds
# Fit ARIMA(0,1,0)x(0,0,0,12) [intercept=True]; AIC=3434.810, BIC=3440.192, Time=0.026 seconds
# Fit ARIMA(1,1,0)x(1,0,0,12) [intercept=True]; AIC=3421.377, BIC=3432.142, Time=0.201 seconds
# Fit ARIMA(0,1,1)x(0,0,1,12) [intercept=True]; AIC=3425.279, BIC=3436.044, Time=0.177 seconds
# Fit ARIMA(0,1,0)x(0,0,0,12) [intercept=False]; AIC=3433.063, BIC=3435.754, Time=0.020 seconds
# Fit ARIMA(2,1,2)x(0,0,1,12) [intercept=True]; AIC=3416.107, BIC=3434.946, Time=0.900 seconds
# Fit ARIMA(2,1,2)x(1,0,0,12) [intercept=True]; AIC=3414.375, BIC=3433.215, Time=1.127 seconds
# Fit ARIMA(2,1,2)x(2,0,1,12) [intercept=True]; AIC=3397.611, BIC=3421.834, Time=4.847 seconds
# Fit ARIMA(2,1,2)x(2,0,0,12) [intercept=True]; AIC=3403.838, BIC=3425.369, Time=4.095 seconds
# Near non-invertible roots for order (2, 1, 2)(2, 0, 0, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.991)
# Fit ARIMA(2,1,2)x(2,0,2,12) [intercept=True]; AIC=3399.797, BIC=3426.710, Time=4.894 seconds
# Near non-invertible roots for order (2, 1, 2)(2, 0, 2, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.993)
# Fit ARIMA(2,1,2)x(1,0,2,12) [intercept=True]; AIC=3397.534, BIC=3421.756, Time=4.454 seconds
# Fit ARIMA(2,1,2)x(0,0,2,12) [intercept=True]; AIC=3411.152, BIC=3432.682, Time=2.918 seconds
# Fit ARIMA(1,1,2)x(1,0,2,12) [intercept=True]; AIC=3413.566, BIC=3435.096, Time=1.456 seconds
# Fit ARIMA(2,1,1)x(1,0,2,12) [intercept=True]; AIC=3412.596, BIC=3434.127, Time=1.833 seconds
# Fit ARIMA(3,1,2)x(1,0,2,12) [intercept=True]; AIC=3398.146, BIC=3425.060, Time=4.034 seconds
# Near non-invertible roots for order (3, 1, 2)(1, 0, 2, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.993)
# Fit ARIMA(2,1,3)x(1,0,2,12) [intercept=True]; AIC=3398.534, BIC=3425.447, Time=5.148 seconds
# Fit ARIMA(1,1,1)x(1,0,2,12) [intercept=True]; AIC=3410.681, BIC=3429.520, Time=1.356 seconds
# Fit ARIMA(1,1,3)x(1,0,2,12) [intercept=True]; AIC=3413.372, BIC=3437.595, Time=3.646 seconds
# Fit ARIMA(3,1,1)x(1,0,2,12) [intercept=True]; AIC=3410.986, BIC=3435.208, Time=2.920 seconds
# Fit ARIMA(3,1,3)x(1,0,2,12) [intercept=True]; AIC=3398.188, BIC=3427.793, Time=5.926 seconds
# Near non-invertible roots for order (3, 1, 3)(1, 0, 2, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.996)
# Total fit time: 51.817 seconds

# %%
# Summarize residual errors for the automated grid search ARIMA model
print(stepwise_results.summary())
stepwise_results.plot_diagnostics(figsize=(12,12))
plt.show()
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  110
# Model:             SARIMAX(2, 1, 2)x(1, 0, 2, 12)   Log Likelihood               -1689.767
# Date:                            Sun, 09 Aug 2020   AIC                           3397.534
# Time:                                    01:47:56   BIC                           3421.756
# Sample:                                         0   HQIC                          3407.357
#                                             - 110
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept  -2.131e+05   1.02e-07   -2.1e+12      0.000   -2.13e+05   -2.13e+05
# ar.L1         -1.1390      0.027    -42.506      0.000      -1.191      -1.086
# ar.L2         -0.9683      0.025    -38.641      0.000      -1.017      -0.919
# ma.L1          1.1026      0.046     23.812      0.000       1.012       1.193
# ma.L2          0.9799      0.068     14.371      0.000       0.846       1.114
# ar.S.L12       0.7851      0.127      6.186      0.000       0.536       1.034
# ma.S.L12      -0.7312      0.136     -5.367      0.000      -0.998      -0.464
# ma.S.L24       0.0989      0.039      2.529      0.011       0.022       0.175
# sigma2      2.186e+12   1.61e-14   1.36e+26      0.000    2.19e+12    2.19e+12
# ===================================================================================
# Ljung-Box (Q):                      294.79   Jarque-Bera (JB):                 1.19
# Prob(Q):                              0.00   Prob(JB):                         0.55
# Heteroskedasticity (H):               0.41   Skew:                             0.14
# Prob(H) (two-sided):                  0.01   Kurtosis:                         3.43
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 8.12e+41. Standard errors may be unstable.

# %%
if notifyStatus: status_notify("ARIMA automated stepwise search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Do an automated random search of ARIMA parameters
n_fits = int(max_p * max_d * max_q * max_P * max_D * max_Q * 0.30)
if seasonal_freq == 0:
    randgrid_results = pm.auto_arima(train_ts, start_p = start_p, d = start_d, start_q = start_q, max_p = max_p, max_d = max_d, max_q = max_q,
                                     seasonal = False, stepwise = False, random = True, n_fits = n_fits, max_order = None,
                                     trace = True, suppress_warnings = True, random_state = seedNum, error_action="ignore")
else:
    randgrid_results = pm.auto_arima(train_ts, start_p = start_p, d = start_d, start_q = start_q, max_p = max_p, max_d = max_d, max_q = max_q,
                                     seasonal = True, m = seasonal_freq, start_P = start_P, D = start_D, start_Q = start_Q, max_P = max_P, max_D = max_D, max_Q = max_Q,
                                     stepwise = False, random = True, n_fits = n_fits, max_order = None,
                                     trace = True, suppress_warnings = True, random_state = seedNum, error_action="ignore")
# Out:
# Fit ARIMA(0,1,1)x(0,0,1,12) [intercept=True]; AIC=3425.279, BIC=3436.044, Time=0.177 seconds
# Fit ARIMA(2,1,1)x(0,0,1,12) [intercept=True]; AIC=3422.730, BIC=3438.878, Time=0.727 seconds
# Fit ARIMA(2,1,3)x(0,0,2,12) [intercept=True]; AIC=3416.924, BIC=3441.147, Time=2.224 seconds
# Fit ARIMA(1,1,0)x(1,0,2,12) [intercept=True]; AIC=3410.550, BIC=3426.698, Time=0.820 seconds
# Fit ARIMA(4,1,4)x(0,0,2,12) [intercept=True]; AIC=3403.401, BIC=3435.697, Time=6.771 seconds
# Fit ARIMA(0,1,3)x(1,0,2,12) [intercept=True]; AIC=3417.812, BIC=3439.343, Time=1.562 seconds
# Fit ARIMA(4,1,3)x(1,0,1,12) [intercept=True]; AIC=3426.907, BIC=3456.511, Time=2.883 seconds
# Fit ARIMA(0,1,1)x(1,0,1,12) [intercept=True]; AIC=3416.408, BIC=3429.865, Time=0.347 seconds
# Fit ARIMA(1,1,1)x(1,0,0,12) [intercept=True]; AIC=3420.665, BIC=3434.121, Time=0.381 seconds
# Fit ARIMA(1,1,1)x(2,0,2,12) [intercept=True]; AIC=3411.394, BIC=3432.925, Time=2.191 seconds
# Fit ARIMA(0,1,2)x(0,0,0,12) [intercept=True]; AIC=3425.582, BIC=3436.348, Time=0.135 seconds
# Fit ARIMA(3,1,0)x(1,0,1,12) [intercept=True]; AIC=3414.754, BIC=3433.594, Time=0.420 seconds
# Fit ARIMA(1,1,4)x(1,0,2,12) [intercept=True]; AIC=3412.801, BIC=3439.714, Time=3.846 seconds
# Fit ARIMA(1,1,2)x(2,0,0,12) [intercept=True]; AIC=3415.308, BIC=3434.147, Time=1.941 seconds
# Fit ARIMA(0,1,0)x(1,0,2,12) [intercept=True]; AIC=3417.783, BIC=3431.239, Time=0.669 seconds
# Fit ARIMA(1,1,3)x(2,0,1,12) [intercept=True]; AIC=3413.142, BIC=3437.364, Time=2.982 seconds
# Fit ARIMA(4,1,4)x(2,0,1,12) [intercept=True]; AIC=3424.547, BIC=3459.535, Time=6.775 seconds
# Fit ARIMA(2,1,1)x(2,0,2,12) [intercept=True]; AIC=3412.885, BIC=3437.107, Time=2.574 seconds
# Fit ARIMA(3,1,2)x(1,0,1,12) [intercept=True]; AIC=3399.091, BIC=3423.314, Time=1.833 seconds
# Fit ARIMA(1,1,3)x(1,0,2,12) [intercept=True]; AIC=3413.372, BIC=3437.595, Time=3.665 seconds
# Fit ARIMA(0,1,2)x(0,0,1,12) [intercept=True]; AIC=3421.355, BIC=3434.812, Time=0.237 seconds
# Fit ARIMA(4,1,1)x(2,0,0,12) [intercept=True]; AIC=3425.799, BIC=3450.021, Time=2.156 seconds
# Fit ARIMA(2,1,1)x(0,0,2,12) [intercept=True]; AIC=3418.494, BIC=3437.334, Time=0.984 seconds
# Fit ARIMA(3,1,4)x(2,0,2,12) [intercept=True]; AIC=3402.312, BIC=3437.299, Time=7.577 seconds
# Fit ARIMA(3,1,2)x(0,0,0,12) [intercept=True]; AIC=3421.920, BIC=3440.759, Time=1.087 seconds
# Fit ARIMA(2,1,3)x(1,0,0,12) [intercept=True]; AIC=3419.430, BIC=3440.961, Time=1.257 seconds
# Fit ARIMA(0,1,1)x(2,0,2,12) [intercept=True]; AIC=3414.064, BIC=3432.903, Time=1.708 seconds
# Fit ARIMA(4,1,3)x(2,0,2,12) [intercept=True]; AIC=3426.385, BIC=3461.373, Time=6.659 seconds
# Fit ARIMA(1,1,4)x(2,0,0,12) [intercept=True]; AIC=3414.168, BIC=3438.390, Time=2.207 seconds
# Fit ARIMA(4,1,4)x(1,0,2,12) [intercept=True]; AIC=3409.591, BIC=3444.579, Time=7.435 seconds
# Fit ARIMA(4,1,4)x(0,0,1,12) [intercept=True]; AIC=3404.040, BIC=3433.644, Time=3.003 seconds
# Fit ARIMA(1,1,2)x(1,0,1,12) [intercept=True]; AIC=3414.653, BIC=3433.492, Time=0.607 seconds
# Fit ARIMA(4,1,0)x(1,0,2,12) [intercept=True]; AIC=3427.389, BIC=3451.612, Time=1.696 seconds
# Fit ARIMA(3,1,1)x(1,0,2,12) [intercept=True]; AIC=3410.986, BIC=3435.208, Time=3.314 seconds
# Fit ARIMA(1,1,1)x(0,0,2,12) [intercept=True]; AIC=3417.804, BIC=3433.952, Time=0.930 seconds
# Fit ARIMA(1,1,3)x(0,0,1,12) [intercept=True]; AIC=3422.627, BIC=3441.466, Time=0.542 seconds
# Fit ARIMA(0,1,1)x(2,0,0,12) [intercept=True]; AIC=3416.718, BIC=3430.175, Time=0.621 seconds
# Fit ARIMA(4,1,3)x(1,0,0,12) [intercept=True]; AIC=3440.647, BIC=3467.561, Time=2.933 seconds
# Total fit time: 87.905 seconds

# %%
# Summarize residual errors for the automated grid search ARIMA model
print(randgrid_results.summary())
randgrid_results.plot_diagnostics(figsize=(12,12))
plt.show()
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  110
# Model:             SARIMAX(3, 1, 2)x(1, 0, [1], 12)   Log Likelihood               -1690.546
# Date:                              Sun, 09 Aug 2020   AIC                           3399.091
# Time:                                      01:49:25   BIC                           3423.314
# Sample:                                           0   HQIC                          3408.914
#                                               - 110
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept  -2.111e+05   1.15e-07  -1.84e+12      0.000   -2.11e+05   -2.11e+05
# ar.L1         -1.1885      0.055    -21.517      0.000      -1.297      -1.080
# ar.L2         -1.0272      0.070    -14.776      0.000      -1.163      -0.891
# ar.L3         -0.0520      0.051     -1.022      0.307      -0.152       0.048
# ma.L1          1.1075      0.055     20.275      0.000       1.000       1.215
# ma.L2          0.9883      0.086     11.442      0.000       0.819       1.158
# ar.S.L12       0.8257      0.105      7.894      0.000       0.621       1.031
# ma.S.L12      -0.7042      0.115     -6.135      0.000      -0.929      -0.479
# sigma2      2.164e+12   1.34e-14   1.61e+26      0.000    2.16e+12    2.16e+12
# ===================================================================================
# Ljung-Box (Q):                      267.76   Jarque-Bera (JB):                 8.91
# Prob(Q):                              0.00   Prob(JB):                         0.01
# Heteroskedasticity (H):               0.40   Skew:                            -0.08
# Prob(H) (two-sided):                  0.01   Kurtosis:                         4.39
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.15e+42. Standard errors may be unstable.

# %%
if notifyStatus: status_notify("ARIMA automated random search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Do an automated grid search of ARIMA parameters
if (seasonal_freq == 0):
    autogrid_results = pm.auto_arima(train_ts, start_p = start_p, d = start_d, start_q = start_q, max_p = max_p, max_d = max_d, max_q = max_q,
                                     seasonal = False, stepwise = False, max_order = None, trace = True, suppress_warnings = True, random_state = seedNum, error_action="ignore")
else:
    autogrid_results = pm.auto_arima(train_ts, start_p = start_p, d = start_d, start_q = start_q, max_p = max_p, max_d = max_d, max_q = max_q,
                                     seasonal = True, m = seasonal_freq, start_P = start_P, D = start_D, start_Q = start_Q, max_P = max_P, max_D = max_D, max_Q = max_Q,
                                     stepwise = False, max_order = None, trace = True, suppress_warnings = True, random_state = seedNum, error_action="ignore")
# Out:
# Fit ARIMA(0,1,0)x(0,0,0,12) [intercept=True]; AIC=3434.810, BIC=3440.192, Time=0.025 seconds
# Fit ARIMA(0,1,0)x(0,0,1,12) [intercept=True]; AIC=3430.201, BIC=3438.275, Time=0.118 seconds
# Fit ARIMA(0,1,0)x(0,0,2,12) [intercept=True]; AIC=3425.928, BIC=3436.694, Time=0.461 seconds
# Fit ARIMA(0,1,0)x(1,0,0,12) [intercept=True]; AIC=3428.474, BIC=3436.548, Time=0.116 seconds
# Fit ARIMA(0,1,0)x(1,0,1,12) [intercept=True]; AIC=3417.326, BIC=3428.091, Time=0.247 seconds
# Fit ARIMA(0,1,0)x(1,0,2,12) [intercept=True]; AIC=3417.783, BIC=3431.239, Time=0.648 seconds
# Fit ARIMA(0,1,0)x(2,0,0,12) [intercept=True]; AIC=3423.019, BIC=3433.784, Time=0.460 seconds
# Fit ARIMA(0,1,0)x(2,0,1,12) [intercept=True]; AIC=3417.719, BIC=3431.176, Time=1.072 seconds
# Fit ARIMA(0,1,0)x(2,0,2,12) [intercept=True]; AIC=3419.151, BIC=3435.299, Time=1.114 seconds
# Fit ARIMA(0,1,1)x(0,0,0,12) [intercept=True]; AIC=3430.981, BIC=3439.055, Time=0.083 seconds
# Fit ARIMA(0,1,1)x(0,0,1,12) [intercept=True]; AIC=3425.279, BIC=3436.044, Time=0.170 seconds
# Fit ARIMA(0,1,1)x(0,0,2,12) [intercept=True]; AIC=3419.919, BIC=3433.376, Time=0.530 seconds
# Fit ARIMA(0,1,1)x(1,0,0,12) [intercept=True]; AIC=3423.521, BIC=3434.286, Time=0.189 seconds
# Fit ARIMA(0,1,1)x(1,0,1,12) [intercept=True]; AIC=3416.408, BIC=3429.865, Time=0.335 seconds
# Fit ARIMA(0,1,1)x(1,0,2,12) [intercept=True]; AIC=3414.821, BIC=3430.969, Time=0.824 seconds
# Fit ARIMA(0,1,1)x(2,0,0,12) [intercept=True]; AIC=3416.718, BIC=3430.175, Time=0.540 seconds
# Fit ARIMA(0,1,1)x(2,0,1,12) [intercept=True]; AIC=3414.254, BIC=3430.402, Time=0.765 seconds
# Fit ARIMA(0,1,1)x(2,0,2,12) [intercept=True]; AIC=3414.064, BIC=3432.903, Time=1.515 seconds
# Fit ARIMA(0,1,2)x(0,0,0,12) [intercept=True]; AIC=3425.582, BIC=3436.348, Time=0.151 seconds
# Fit ARIMA(0,1,2)x(0,0,1,12) [intercept=True]; AIC=3421.355, BIC=3434.812, Time=0.236 seconds
# Fit ARIMA(0,1,2)x(0,0,2,12) [intercept=True]; AIC=3417.240, BIC=3433.388, Time=0.693 seconds
# Fit ARIMA(0,1,2)x(1,0,0,12) [intercept=True]; AIC=3420.092, BIC=3433.548, Time=0.276 seconds
# Fit ARIMA(0,1,2)x(1,0,1,12) [intercept=True]; AIC=3416.069, BIC=3432.217, Time=0.400 seconds
# Fit ARIMA(0,1,2)x(1,0,2,12) [intercept=True]; AIC=3414.369, BIC=3433.208, Time=0.992 seconds
# Fit ARIMA(0,1,2)x(2,0,0,12) [intercept=True]; AIC=3414.701, BIC=3430.849, Time=0.724 seconds
# Fit ARIMA(0,1,2)x(2,0,1,12) [intercept=True]; AIC=3413.751, BIC=3432.590, Time=0.949 seconds
# Fit ARIMA(0,1,2)x(2,0,2,12) [intercept=True]; AIC=3413.623, BIC=3435.154, Time=2.042 seconds
# Fit ARIMA(0,1,3)x(0,0,0,12) [intercept=True]; AIC=3424.115, BIC=3437.572, Time=0.170 seconds
# Fit ARIMA(0,1,3)x(0,0,1,12) [intercept=True]; AIC=3420.804, BIC=3436.952, Time=0.347 seconds
# Fit ARIMA(0,1,3)x(0,0,2,12) [intercept=True]; AIC=3417.297, BIC=3436.136, Time=1.041 seconds
# Fit ARIMA(0,1,3)x(1,0,0,12) [intercept=True]; AIC=3420.111, BIC=3436.259, Time=0.347 seconds
# Fit ARIMA(0,1,3)x(1,0,1,12) [intercept=True]; AIC=3420.000, BIC=3438.840, Time=0.616 seconds
# Fit ARIMA(0,1,3)x(1,0,2,12) [intercept=True]; AIC=3417.812, BIC=3439.343, Time=1.606 seconds
# Fit ARIMA(0,1,3)x(2,0,0,12) [intercept=True]; AIC=3415.603, BIC=3434.442, Time=0.827 seconds
# Fit ARIMA(0,1,3)x(2,0,1,12) [intercept=True]; AIC=3416.889, BIC=3438.420, Time=1.239 seconds
# Fit ARIMA(0,1,3)x(2,0,2,12) [intercept=True]; AIC=3416.283, BIC=3440.505, Time=2.082 seconds
# Fit ARIMA(0,1,4)x(0,0,0,12) [intercept=True]; AIC=3423.886, BIC=3440.034, Time=0.279 seconds
# Fit ARIMA(0,1,4)x(0,0,1,12) [intercept=True]; AIC=3420.966, BIC=3439.805, Time=0.339 seconds
# Fit ARIMA(0,1,4)x(0,0,2,12) [intercept=True]; AIC=3417.420, BIC=3438.951, Time=0.872 seconds
# Fit ARIMA(0,1,4)x(1,0,0,12) [intercept=True]; AIC=3420.393, BIC=3439.232, Time=0.363 seconds
# Fit ARIMA(0,1,4)x(1,0,1,12) [intercept=True]; AIC=3420.594, BIC=3442.124, Time=0.665 seconds
# Fit ARIMA(0,1,4)x(1,0,2,12) [intercept=True]; AIC=3418.144, BIC=3442.366, Time=1.540 seconds
# Fit ARIMA(0,1,4)x(2,0,0,12) [intercept=True]; AIC=3415.829, BIC=3437.360, Time=1.247 seconds
# Fit ARIMA(0,1,4)x(2,0,1,12) [intercept=True]; AIC=3417.234, BIC=3441.456, Time=1.296 seconds
# Fit ARIMA(0,1,4)x(2,0,2,12) [intercept=True]; AIC=3416.761, BIC=3443.675, Time=2.893 seconds
# Fit ARIMA(1,1,0)x(0,0,0,12) [intercept=True]; AIC=3427.936, BIC=3436.010, Time=0.075 seconds
# Fit ARIMA(1,1,0)x(0,0,1,12) [intercept=True]; AIC=3423.050, BIC=3433.815, Time=0.363 seconds
# Fit ARIMA(1,1,0)x(0,0,2,12) [intercept=True]; AIC=3418.424, BIC=3431.880, Time=0.392 seconds
# Fit ARIMA(1,1,0)x(1,0,0,12) [intercept=True]; AIC=3421.377, BIC=3432.142, Time=0.198 seconds
# Fit ARIMA(1,1,0)x(1,0,1,12) [intercept=True]; AIC=3410.838, BIC=3424.295, Time=0.305 seconds
# Fit ARIMA(1,1,0)x(1,0,2,12) [intercept=True]; AIC=3410.550, BIC=3426.698, Time=0.822 seconds
# Fit ARIMA(1,1,0)x(2,0,0,12) [intercept=True]; AIC=3415.376, BIC=3428.832, Time=0.579 seconds
# Fit ARIMA(1,1,0)x(2,0,1,12) [intercept=True]; AIC=3410.401, BIC=3426.549, Time=0.872 seconds
# Fit ARIMA(1,1,0)x(2,0,2,12) [intercept=True]; AIC=3411.475, BIC=3430.315, Time=1.566 seconds
# Fit ARIMA(1,1,1)x(0,0,0,12) [intercept=True]; AIC=3426.842, BIC=3437.608, Time=0.178 seconds
# Fit ARIMA(1,1,1)x(0,0,1,12) [intercept=True]; AIC=3422.204, BIC=3435.661, Time=0.404 seconds
# Fit ARIMA(1,1,1)x(0,0,2,12) [intercept=True]; AIC=3417.804, BIC=3433.952, Time=0.903 seconds
# Fit ARIMA(1,1,1)x(1,0,0,12) [intercept=True]; AIC=3420.665, BIC=3434.121, Time=0.375 seconds
# Fit ARIMA(1,1,1)x(1,0,1,12) [intercept=True]; AIC=3411.080, BIC=3427.228, Time=0.490 seconds
# Fit ARIMA(1,1,1)x(1,0,2,12) [intercept=True]; AIC=3410.681, BIC=3429.520, Time=1.349 seconds
# Fit ARIMA(1,1,1)x(2,0,0,12) [intercept=True]; AIC=3414.940, BIC=3431.088, Time=1.186 seconds
# Fit ARIMA(1,1,1)x(2,0,1,12) [intercept=True]; AIC=3410.494, BIC=3429.334, Time=1.425 seconds
# Fit ARIMA(1,1,1)x(2,0,2,12) [intercept=True]; AIC=3411.394, BIC=3432.925, Time=2.169 seconds
# Fit ARIMA(1,1,2)x(0,0,0,12) [intercept=True]; AIC=3425.454, BIC=3438.911, Time=0.200 seconds
# Fit ARIMA(1,1,2)x(0,0,1,12) [intercept=True]; AIC=3421.651, BIC=3437.799, Time=0.695 seconds
# Fit ARIMA(1,1,2)x(0,0,2,12) [intercept=True]; AIC=3417.813, BIC=3436.652, Time=1.159 seconds
# Fit ARIMA(1,1,2)x(1,0,0,12) [intercept=True]; AIC=3420.423, BIC=3436.571, Time=0.631 seconds
# Fit ARIMA(1,1,2)x(1,0,1,12) [intercept=True]; AIC=3414.653, BIC=3433.492, Time=0.605 seconds
# Fit ARIMA(1,1,2)x(1,0,2,12) [intercept=True]; AIC=3413.566, BIC=3435.096, Time=1.555 seconds
# Fit ARIMA(1,1,2)x(2,0,0,12) [intercept=True]; AIC=3415.308, BIC=3434.147, Time=1.918 seconds
# Fit ARIMA(1,1,2)x(2,0,1,12) [intercept=True]; AIC=3413.150, BIC=3434.681, Time=1.626 seconds
# Fit ARIMA(1,1,2)x(2,0,2,12) [intercept=True]; AIC=3413.395, BIC=3437.618, Time=2.855 seconds
# Fit ARIMA(1,1,3)x(0,0,0,12) [intercept=True]; AIC=3426.127, BIC=3442.275, Time=0.401 seconds
# Fit ARIMA(1,1,3)x(0,0,1,12) [intercept=True]; AIC=3422.627, BIC=3441.466, Time=0.544 seconds
# Fit ARIMA(1,1,3)x(0,0,2,12) [intercept=True]; AIC=3418.884, BIC=3440.415, Time=1.490 seconds
# Fit ARIMA(1,1,3)x(1,0,0,12) [intercept=True]; AIC=3421.857, BIC=3440.697, Time=0.602 seconds
# Fit ARIMA(1,1,3)x(1,0,1,12) [intercept=True]; AIC=3414.098, BIC=3435.629, Time=1.336 seconds
# Fit ARIMA(1,1,3)x(1,0,2,12) [intercept=True]; AIC=3413.372, BIC=3437.595, Time=3.656 seconds
# Fit ARIMA(1,1,3)x(2,0,0,12) [intercept=True]; AIC=3417.029, BIC=3438.560, Time=1.348 seconds
# Fit ARIMA(1,1,3)x(2,0,1,12) [intercept=True]; AIC=3413.142, BIC=3437.364, Time=3.348 seconds
# Fit ARIMA(1,1,3)x(2,0,2,12) [intercept=True]; AIC=3413.969, BIC=3440.882, Time=4.890 seconds
# Fit ARIMA(1,1,4)x(0,0,0,12) [intercept=True]; AIC=3422.105, BIC=3440.944, Time=0.494 seconds
# Fit ARIMA(1,1,4)x(0,0,1,12) [intercept=True]; AIC=3419.547, BIC=3441.078, Time=0.955 seconds
# Fit ARIMA(1,1,4)x(0,0,2,12) [intercept=True]; AIC=3416.213, BIC=3440.435, Time=2.521 seconds
# Fit ARIMA(1,1,4)x(1,0,0,12) [intercept=True]; AIC=3418.729, BIC=3440.259, Time=0.789 seconds
# Fit ARIMA(1,1,4)x(1,0,1,12) [intercept=True]; AIC=3413.871, BIC=3438.094, Time=1.483 seconds
# Fit ARIMA(1,1,4)x(1,0,2,12) [intercept=True]; AIC=3412.801, BIC=3439.714, Time=3.822 seconds
# Fit ARIMA(1,1,4)x(2,0,0,12) [intercept=True]; AIC=3414.168, BIC=3438.390, Time=2.197 seconds
# Fit ARIMA(1,1,4)x(2,0,1,12) [intercept=True]; AIC=3412.402, BIC=3439.316, Time=3.001 seconds
# Fit ARIMA(1,1,4)x(2,0,2,12) [intercept=True]; AIC=3412.570, BIC=3442.175, Time=5.669 seconds
# Fit ARIMA(2,1,0)x(0,0,0,12) [intercept=True]; AIC=3425.186, BIC=3435.951, Time=0.093 seconds
# Fit ARIMA(2,1,0)x(0,0,1,12) [intercept=True]; AIC=3420.802, BIC=3434.259, Time=0.193 seconds
# Fit ARIMA(2,1,0)x(0,0,2,12) [intercept=True]; AIC=3416.574, BIC=3432.722, Time=0.599 seconds
# Fit ARIMA(2,1,0)x(1,0,0,12) [intercept=True]; AIC=3419.376, BIC=3432.833, Time=0.299 seconds
# Fit ARIMA(2,1,0)x(1,0,1,12) [intercept=True]; AIC=3411.588, BIC=3427.736, Time=0.424 seconds
# Fit ARIMA(2,1,0)x(1,0,2,12) [intercept=True]; AIC=3410.618, BIC=3429.457, Time=1.461 seconds
# Fit ARIMA(2,1,0)x(2,0,0,12) [intercept=True]; AIC=3413.804, BIC=3429.953, Time=0.865 seconds
# Fit ARIMA(2,1,0)x(2,0,1,12) [intercept=True]; AIC=3410.301, BIC=3429.140, Time=0.960 seconds
# Fit ARIMA(2,1,0)x(2,0,2,12) [intercept=True]; AIC=3410.838, BIC=3432.369, Time=1.926 seconds
# Fit ARIMA(2,1,1)x(0,0,0,12) [intercept=True]; AIC=3427.118, BIC=3440.574, Time=0.444 seconds
# Fit ARIMA(2,1,1)x(0,0,1,12) [intercept=True]; AIC=3422.730, BIC=3438.878, Time=0.745 seconds
# Fit ARIMA(2,1,1)x(0,0,2,12) [intercept=True]; AIC=3418.494, BIC=3437.334, Time=1.029 seconds
# Fit ARIMA(2,1,1)x(1,0,0,12) [intercept=True]; AIC=3421.320, BIC=3437.468, Time=0.553 seconds
# Fit ARIMA(2,1,1)x(1,0,1,12) [intercept=True]; AIC=3413.300, BIC=3432.139, Time=0.561 seconds
# Fit ARIMA(2,1,1)x(1,0,2,12) [intercept=True]; AIC=3412.596, BIC=3434.127, Time=1.786 seconds
# Fit ARIMA(2,1,1)x(2,0,0,12) [intercept=True]; AIC=3415.758, BIC=3434.598, Time=1.350 seconds
# Fit ARIMA(2,1,1)x(2,0,1,12) [intercept=True]; AIC=3412.317, BIC=3433.848, Time=1.891 seconds
# Fit ARIMA(2,1,1)x(2,0,2,12) [intercept=True]; AIC=3412.885, BIC=3437.107, Time=2.586 seconds
# Fit ARIMA(2,1,2)x(0,0,0,12) [intercept=True]; AIC=3420.242, BIC=3436.390, Time=0.426 seconds
# Fit ARIMA(2,1,2)x(0,0,1,12) [intercept=True]; AIC=3416.107, BIC=3434.946, Time=0.870 seconds
# Fit ARIMA(2,1,2)x(0,0,2,12) [intercept=True]; AIC=3411.152, BIC=3432.682, Time=2.917 seconds
# Fit ARIMA(2,1,2)x(1,0,0,12) [intercept=True]; AIC=3414.375, BIC=3433.215, Time=1.176 seconds
# Fit ARIMA(2,1,2)x(1,0,1,12) [intercept=True]; AIC=3398.586, BIC=3420.117, Time=1.834 seconds
# Fit ARIMA(2,1,2)x(1,0,2,12) [intercept=True]; AIC=3397.534, BIC=3421.756, Time=4.563 seconds
# Fit ARIMA(2,1,2)x(2,0,0,12) [intercept=True]; AIC=3403.838, BIC=3425.369, Time=4.168 seconds
# Fit ARIMA(2,1,2)x(2,0,1,12) [intercept=True]; AIC=3397.611, BIC=3421.834, Time=4.881 seconds
# Fit ARIMA(2,1,2)x(2,0,2,12) [intercept=True]; AIC=3399.797, BIC=3426.710, Time=4.987 seconds
# Fit ARIMA(2,1,3)x(0,0,0,12) [intercept=True]; AIC=3422.686, BIC=3441.526, Time=0.521 seconds
# Fit ARIMA(2,1,3)x(0,0,1,12) [intercept=True]; AIC=3420.293, BIC=3441.824, Time=0.997 seconds
# Fit ARIMA(2,1,3)x(0,0,2,12) [intercept=True]; AIC=3416.924, BIC=3441.147, Time=2.192 seconds
# Fit ARIMA(2,1,3)x(1,0,0,12) [intercept=True]; AIC=3419.430, BIC=3440.961, Time=1.173 seconds
# Fit ARIMA(2,1,3)x(1,0,1,12) [intercept=True]; AIC=3399.820, BIC=3424.042, Time=2.211 seconds
# Fit ARIMA(2,1,3)x(1,0,2,12) [intercept=True]; AIC=3398.534, BIC=3425.447, Time=5.492 seconds
# Fit ARIMA(2,1,3)x(2,0,0,12) [intercept=True]; AIC=3414.772, BIC=3438.994, Time=3.417 seconds
# Fit ARIMA(2,1,3)x(2,0,1,12) [intercept=True]; AIC=3398.449, BIC=3425.362, Time=5.065 seconds
# Fit ARIMA(2,1,3)x(2,0,2,12) [intercept=True]; AIC=3400.412, BIC=3430.017, Time=5.871 seconds
# Fit ARIMA(2,1,4)x(0,0,0,12) [intercept=True]; AIC=3423.464, BIC=3444.995, Time=0.636 seconds
# Fit ARIMA(2,1,4)x(0,0,1,12) [intercept=True]; AIC=3421.223, BIC=3445.445, Time=1.436 seconds
# Fit ARIMA(2,1,4)x(0,0,2,12) [intercept=True]; AIC=3417.842, BIC=3444.755, Time=3.218 seconds
# Fit ARIMA(2,1,4)x(1,0,0,12) [intercept=True]; AIC=3420.421, BIC=3444.644, Time=1.215 seconds
# Fit ARIMA(2,1,4)x(1,0,1,12) [intercept=True]; AIC=3397.408, BIC=3424.321, Time=2.618 seconds
# Fit ARIMA(2,1,4)x(1,0,2,12) [intercept=True]; AIC=3400.888, BIC=3430.493, Time=5.488 seconds
# Fit ARIMA(2,1,4)x(2,0,0,12) [intercept=True]; AIC=3403.289, BIC=3430.203, Time=5.217 seconds
# Fit ARIMA(2,1,4)x(2,0,1,12) [intercept=True]; AIC=3395.816, BIC=3425.421, Time=5.809 seconds
# Fit ARIMA(2,1,4)x(2,0,2,12) [intercept=True]; AIC=3399.340, BIC=3431.636, Time=6.677 seconds
# Fit ARIMA(3,1,0)x(0,0,0,12) [intercept=True]; AIC=3426.949, BIC=3440.406, Time=0.113 seconds
# Fit ARIMA(3,1,0)x(0,0,1,12) [intercept=True]; AIC=3422.577, BIC=3438.725, Time=0.224 seconds
# Fit ARIMA(3,1,0)x(0,0,2,12) [intercept=True]; AIC=3418.337, BIC=3437.176, Time=0.670 seconds
# Fit ARIMA(3,1,0)x(1,0,0,12) [intercept=True]; AIC=3421.218, BIC=3437.366, Time=0.286 seconds
# Fit ARIMA(3,1,0)x(1,0,1,12) [intercept=True]; AIC=3414.754, BIC=3433.594, Time=0.416 seconds
# Fit ARIMA(3,1,0)x(1,0,2,12) [intercept=True]; AIC=3413.455, BIC=3434.986, Time=1.119 seconds
# Fit ARIMA(3,1,0)x(2,0,0,12) [intercept=True]; AIC=3415.672, BIC=3434.512, Time=0.753 seconds
# Fit ARIMA(3,1,0)x(2,0,1,12) [intercept=True]; AIC=3413.025, BIC=3434.556, Time=1.047 seconds
# Fit ARIMA(3,1,0)x(2,0,2,12) [intercept=True]; AIC=3413.230, BIC=3437.452, Time=2.294 seconds
# Fit ARIMA(3,1,1)x(0,0,0,12) [intercept=True]; AIC=3428.402, BIC=3444.550, Time=0.276 seconds
# Fit ARIMA(3,1,1)x(0,0,1,12) [intercept=True]; AIC=3424.183, BIC=3443.022, Time=0.523 seconds
# Fit ARIMA(3,1,1)x(0,0,2,12) [intercept=True]; AIC=3420.025, BIC=3441.556, Time=1.277 seconds
# Fit ARIMA(3,1,1)x(1,0,0,12) [intercept=True]; AIC=3422.984, BIC=3441.824, Time=0.500 seconds
# Fit ARIMA(3,1,1)x(1,0,1,12) [intercept=True]; AIC=3410.779, BIC=3432.310, Time=0.929 seconds
# Fit ARIMA(3,1,1)x(1,0,2,12) [intercept=True]; AIC=3410.986, BIC=3435.208, Time=2.965 seconds
# Fit ARIMA(3,1,1)x(2,0,0,12) [intercept=True]; AIC=3417.605, BIC=3439.135, Time=1.617 seconds
# Fit ARIMA(3,1,1)x(2,0,1,12) [intercept=True]; AIC=3410.916, BIC=3435.138, Time=2.408 seconds
# Fit ARIMA(3,1,1)x(2,0,2,12) [intercept=True]; AIC=3412.313, BIC=3439.227, Time=2.392 seconds
# Fit ARIMA(3,1,2)x(0,0,0,12) [intercept=True]; AIC=3421.920, BIC=3440.759, Time=1.097 seconds
# Fit ARIMA(3,1,2)x(0,0,1,12) [intercept=True]; AIC=3420.271, BIC=3441.802, Time=1.135 seconds
# Fit ARIMA(3,1,2)x(0,0,2,12) [intercept=True]; AIC=3416.939, BIC=3441.161, Time=2.389 seconds
# Fit ARIMA(3,1,2)x(1,0,0,12) [intercept=True]; AIC=3419.209, BIC=3440.739, Time=0.826 seconds
# Fit ARIMA(3,1,2)x(1,0,1,12) [intercept=True]; AIC=3399.091, BIC=3423.314, Time=1.819 seconds
# Fit ARIMA(3,1,2)x(1,0,2,12) [intercept=True]; AIC=3398.146, BIC=3425.060, Time=4.081 seconds
# Fit ARIMA(3,1,2)x(2,0,0,12) [intercept=True]; AIC=3414.459, BIC=3438.681, Time=3.010 seconds
# Fit ARIMA(3,1,2)x(2,0,1,12) [intercept=True]; AIC=3398.246, BIC=3425.159, Time=4.849 seconds
# Fit ARIMA(3,1,2)x(2,0,2,12) [intercept=True]; AIC=3400.764, BIC=3430.369, Time=5.436 seconds
# Fit ARIMA(3,1,3)x(0,0,0,12) [intercept=True]; AIC=3423.170, BIC=3444.701, Time=1.220 seconds
# Fit ARIMA(3,1,3)x(0,0,1,12) [intercept=True]; AIC=3418.740, BIC=3442.962, Time=2.291 seconds
# Fit ARIMA(3,1,3)x(0,0,2,12) [intercept=True]; AIC=3413.768, BIC=3440.681, Time=5.472 seconds
# Fit ARIMA(3,1,3)x(1,0,0,12) [intercept=True]; AIC=3416.747, BIC=3440.969, Time=1.948 seconds
# Fit ARIMA(3,1,3)x(1,0,1,12) [intercept=True]; AIC=3399.503, BIC=3426.416, Time=2.786 seconds
# Fit ARIMA(3,1,3)x(1,0,2,12) [intercept=True]; AIC=3398.188, BIC=3427.793, Time=6.396 seconds
# Fit ARIMA(3,1,3)x(2,0,0,12) [intercept=True]; AIC=3406.964, BIC=3433.877, Time=4.989 seconds
# Fit ARIMA(3,1,3)x(2,0,1,12) [intercept=True]; AIC=3399.913, BIC=3429.518, Time=5.390 seconds
# Fit ARIMA(3,1,3)x(2,0,2,12) [intercept=True]; AIC=3401.026, BIC=3433.322, Time=6.588 seconds
# Fit ARIMA(3,1,4)x(0,0,0,12) [intercept=True]; AIC=3425.769, BIC=3449.991, Time=0.886 seconds
# Fit ARIMA(3,1,4)x(0,0,1,12) [intercept=True]; AIC=3423.213, BIC=3450.126, Time=1.553 seconds
# Fit ARIMA(3,1,4)x(0,0,2,12) [intercept=True]; AIC=3419.629, BIC=3449.234, Time=3.989 seconds
# Fit ARIMA(3,1,4)x(1,0,0,12) [intercept=True]; AIC=3422.244, BIC=3449.157, Time=1.336 seconds
# Fit ARIMA(3,1,4)x(1,0,1,12) [intercept=True]; AIC=3402.376, BIC=3431.981, Time=2.932 seconds
# Fit ARIMA(3,1,4)x(1,0,2,12) [intercept=True]; AIC=3402.528, BIC=3434.824, Time=5.987 seconds
# Fit ARIMA(3,1,4)x(2,0,0,12) [intercept=True]; AIC=3417.251, BIC=3446.855, Time=3.930 seconds
# Fit ARIMA(3,1,4)x(2,0,1,12) [intercept=True]; AIC=3402.365, BIC=3434.661, Time=6.782 seconds
# Fit ARIMA(3,1,4)x(2,0,2,12) [intercept=True]; AIC=3402.312, BIC=3437.299, Time=7.531 seconds
# Fit ARIMA(4,1,0)x(0,0,0,12) [intercept=True]; AIC=3442.670, BIC=3458.818, Time=0.183 seconds
# Fit ARIMA(4,1,0)x(0,0,1,12) [intercept=True]; AIC=3436.850, BIC=3455.690, Time=0.276 seconds
# Fit ARIMA(4,1,0)x(0,0,2,12) [intercept=True]; AIC=3429.823, BIC=3451.353, Time=0.706 seconds
# Fit ARIMA(4,1,0)x(1,0,0,12) [intercept=True]; AIC=3435.663, BIC=3454.502, Time=0.574 seconds
# Fit ARIMA(4,1,0)x(1,0,1,12) [intercept=True]; AIC=3432.525, BIC=3454.056, Time=0.693 seconds
# Fit ARIMA(4,1,0)x(1,0,2,12) [intercept=True]; AIC=3427.389, BIC=3451.612, Time=1.698 seconds
# Fit ARIMA(4,1,0)x(2,0,0,12) [intercept=True]; AIC=3426.696, BIC=3448.226, Time=1.332 seconds
# Fit ARIMA(4,1,0)x(2,0,1,12) [intercept=True]; AIC=3426.134, BIC=3450.356, Time=1.595 seconds
# Fit ARIMA(4,1,0)x(2,0,2,12) [intercept=True]; AIC=3424.269, BIC=3451.182, Time=3.215 seconds
# Fit ARIMA(4,1,1)x(0,0,0,12) [intercept=True]; AIC=3438.595, BIC=3457.435, Time=0.574 seconds
# Fit ARIMA(4,1,1)x(0,0,1,12) [intercept=True]; AIC=3434.694, BIC=3456.225, Time=0.638 seconds
# Fit ARIMA(4,1,1)x(0,0,2,12) [intercept=True]; AIC=3428.870, BIC=3453.093, Time=1.823 seconds
# Fit ARIMA(4,1,1)x(1,0,0,12) [intercept=True]; AIC=3433.572, BIC=3455.103, Time=0.997 seconds
# Fit ARIMA(4,1,1)x(1,0,1,12) [intercept=True]; AIC=3424.023, BIC=3448.245, Time=1.326 seconds
# Fit ARIMA(4,1,1)x(1,0,2,12) [intercept=True]; AIC=3421.674, BIC=3448.587, Time=2.793 seconds
# Fit ARIMA(4,1,1)x(2,0,0,12) [intercept=True]; AIC=3425.799, BIC=3450.021, Time=2.175 seconds
# Fit ARIMA(4,1,1)x(2,0,1,12) [intercept=True]; AIC=3421.187, BIC=3448.100, Time=2.711 seconds
# Fit ARIMA(4,1,1)x(2,0,2,12) [intercept=True]; AIC=3420.763, BIC=3450.368, Time=4.253 seconds
# Fit ARIMA(4,1,2)x(0,0,0,12) [intercept=True]; AIC=3442.181, BIC=3463.712, Time=0.706 seconds
# Fit ARIMA(4,1,2)x(0,0,1,12) [intercept=True]; AIC=3437.311, BIC=3461.533, Time=0.965 seconds
# Fit ARIMA(4,1,2)x(0,0,2,12) [intercept=True]; AIC=3430.775, BIC=3457.689, Time=2.816 seconds
# Fit ARIMA(4,1,2)x(1,0,0,12) [intercept=True]; AIC=3435.941, BIC=3460.163, Time=1.298 seconds
# Fit ARIMA(4,1,2)x(1,0,1,12) [intercept=True]; AIC=3399.425, BIC=3426.339, Time=2.590 seconds
# Fit ARIMA(4,1,2)x(1,0,2,12) [intercept=True]; AIC=3394.304, BIC=3423.909, Time=4.715 seconds
# Fit ARIMA(4,1,2)x(2,0,0,12) [intercept=True]; AIC=3427.155, BIC=3454.068, Time=3.315 seconds
# Fit ARIMA(4,1,2)x(2,0,1,12) [intercept=True]; AIC=3394.641, BIC=3424.246, Time=5.672 seconds
# Fit ARIMA(4,1,2)x(2,0,2,12) [intercept=True]; AIC=3398.884, BIC=3431.180, Time=6.286 seconds
# Fit ARIMA(4,1,3)x(0,0,0,12) [intercept=True]; AIC=3439.352, BIC=3463.574, Time=1.645 seconds
# Fit ARIMA(4,1,3)x(0,0,1,12) [intercept=True]; AIC=3439.226, BIC=3466.139, Time=2.710 seconds
# Fit ARIMA(4,1,3)x(0,0,2,12) [intercept=True]; AIC=3432.645, BIC=3462.250, Time=6.253 seconds
# Fit ARIMA(4,1,3)x(1,0,0,12) [intercept=True]; AIC=3440.647, BIC=3467.561, Time=2.967 seconds
# Fit ARIMA(4,1,3)x(1,0,1,12) [intercept=True]; AIC=3426.907, BIC=3456.511, Time=2.880 seconds
# Fit ARIMA(4,1,3)x(1,0,2,12) [intercept=True]; AIC=3424.760, BIC=3457.056, Time=6.014 seconds
# Fit ARIMA(4,1,3)x(2,0,0,12) [intercept=True]; AIC=3433.726, BIC=3463.331, Time=7.276 seconds
# Fit ARIMA(4,1,3)x(2,0,1,12) [intercept=True]; AIC=3423.807, BIC=3456.103, Time=6.708 seconds
# Fit ARIMA(4,1,3)x(2,0,2,12) [intercept=True]; AIC=3426.385, BIC=3461.373, Time=6.636 seconds
# Fit ARIMA(4,1,4)x(0,0,0,12) [intercept=True]; AIC=3395.400, BIC=3422.313, Time=1.578 seconds
# Fit ARIMA(4,1,4)x(0,0,1,12) [intercept=True]; AIC=3404.040, BIC=3433.644, Time=3.073 seconds
# Fit ARIMA(4,1,4)x(0,0,2,12) [intercept=True]; AIC=3403.401, BIC=3435.697, Time=6.671 seconds
# Fit ARIMA(4,1,4)x(1,0,0,12) [intercept=True]; AIC=3444.099, BIC=3473.703, Time=3.164 seconds
# Fit ARIMA(4,1,4)x(1,0,1,12) [intercept=True]; AIC=3422.769, BIC=3455.065, Time=3.334 seconds
# Fit ARIMA(4,1,4)x(1,0,2,12) [intercept=True]; AIC=3409.591, BIC=3444.579, Time=7.490 seconds
# Fit ARIMA(4,1,4)x(2,0,0,12) [intercept=True]; AIC=3416.924, BIC=3449.220, Time=6.930 seconds
# Fit ARIMA(4,1,4)x(2,0,1,12) [intercept=True]; AIC=3424.547, BIC=3459.535, Time=7.085 seconds
# Fit ARIMA(4,1,4)x(2,0,2,12) [intercept=True]; AIC=3423.619, BIC=3461.298, Time=8.328 seconds
# Total fit time: 462.995 seconds

# %%
# Summarize residual errors for the automated grid search ARIMA model
print(autogrid_results.summary())
autogrid_results.plot_diagnostics(figsize=(12,12))
plt.show()
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  110
# Model:             SARIMAX(4, 1, 2)x(1, 0, 2, 12)   Log Likelihood               -1686.152
# Date:                            Sun, 09 Aug 2020   AIC                           3394.304
# Time:                                    01:57:10   BIC                           3423.909
# Sample:                                         0   HQIC                          3406.310
#                                             - 110
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept  -2.652e+05   8.21e-08  -3.23e+12      0.000   -2.65e+05   -2.65e+05
# ar.L1         -1.1891      0.037    -31.971      0.000      -1.262      -1.116
# ar.L2         -0.9511      0.055    -17.431      0.000      -1.058      -0.844
# ar.L3          0.0484      0.051      0.949      0.343      -0.052       0.148
# ar.L4          0.0758      0.032      2.371      0.018       0.013       0.138
# ma.L1          1.1213      0.038     29.540      0.000       1.047       1.196
# ma.L2          0.9896      0.059     16.758      0.000       0.874       1.105
# ar.S.L12       0.7634      0.092      8.292      0.000       0.583       0.944
# ma.S.L12      -0.7184      0.098     -7.323      0.000      -0.911      -0.526
# ma.S.L24       0.1089      0.023      4.726      0.000       0.064       0.154
# sigma2      1.281e+12   2.91e-14   4.39e+25      0.000    1.28e+12    1.28e+12
# ===================================================================================
# Ljung-Box (Q):                      313.55   Jarque-Bera (JB):                 2.59
# Prob(Q):                              0.00   Prob(JB):                         0.27
# Heteroskedasticity (H):               0.45   Skew:                             0.14
# Prob(H) (two-sided):                  0.02   Kurtosis:                         3.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.96e+41. Standard errors may be unstable.

# %%
if notifyStatus: status_notify("ARIMA automated grid search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Not applicable for this iteration of the project

# Set up the function to handle the ARIMA calculation
# def Calculate_ARIMA(ns_order, ss_order):
#     startTimeModel = datetime.now()
#     aic_score, bic_score = float("inf"), float("inf")
#     if (verbose): print('Trying to fit the model with parameters:', ns_order, ss_order)
#     try:
#         if (ss_order[3] == 0): grid_model = SARIMAX(train_ts, order=ns_order)
#         else: grid_model = SARIMAX(train_ts, order=ns_order, seasonal_order=ss_order)
#         with warnings.catch_warnings():
#             warnings.simplefilter("ignore")
#             grid_results = grid_model.fit(disp = False)
#         aic_score = grid_results.aic
#         bic_score = grid_results.bic
#         if (verbose): print('Fit ARIMA: order=%s seasonal_order=%s; AIC=%.3f, BIC=%.3f, Fit time=%s' % 
#               (ns_order, ss_order, aic_score, bic_score, (datetime.now() - startTimeModel)))
#         return(aic_score, bic_score)
#     except:
#         return(float("inf"), float("inf"))

# %%
# Not applicable for this iteration of the project

# Do a manual grid search of ARIMA parameters
# best_score, best_ns_cfg, best_ss_cfg = float("inf"), None, None
# for p in range(start_p, max_p+1):
#     for d in range(start_d, max_d+1):
#         for q in range(start_q, max_q+1):
#             for P in range(start_P, max_P+1):
#                 for D in range(start_D, max_D+1):
#                     for Q in range(start_Q, max_Q+1):
#                         ns_order = (p, d, q)
#                         ss_order = (P, D, Q, seasonal_freq)
#                         aic_score, bic_score = Calculate_ARIMA(ns_order, ss_order)
#                         if (aic_score < best_score):
#                             best_ns_cfg, best_ss_cfg, best_score = ns_order, ss_order, aic_score
#                             print('A better model found: order=%s seasonal_order=%s; AIC=%.3f, BIC=%.3f' % (ns_order, ss_order, aic_score, bic_score))
# print('Best ARIMA model via manual search: order=%s seasonal_order=%s; AIC=%f' % (best_ns_cfg, best_ss_cfg, best_score))

# %%
# Summarize residual errors for the manual ARIMA model
# manual_model = SARIMAX(train_ts, order=best_ns_cfg, seasonal_order=best_ss_cfg)
# manual_results = manual_model.fit(disp = False)
# print(manual_results.summary())
# manual_results.plot_diagnostics(figsize=(12,12))
# plt.show()

# %%
if notifyStatus: status_notify("ARIMA Hyperparameters Search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 4.c) Evaluate the Residual Errors
#
# A good final check of a model is to review residual forecast errors. Ideally, the distribution of residual errors should be a Gaussian with a zero mean.

# %%
# Set the ARIMA order parameters for validation and forecasting
# final_ns_order = stepwise_results.order
# final_ns_order = randgrid_results.order
final_ns_order = autogrid_results.order
# final_ns_order = best_ns_cfg
if seasonal_freq != 0:
#     final_ss_order = stepwise_results.seasonal_order
#     final_ss_order = randgrid_results.seasonal_order
    final_ss_order = autogrid_results.seasonal_order
#     final_ss_order = best_ss_cfg
    print("Final Non-season order:", final_ns_order, 'Final Seasonal Order:', final_ss_order)
else:
    print("Final Non-season order:", final_ns_order)
# Out:
# Final Non-season order: (4, 1, 2) Final Seasonal Order: (1, 0, 2, 12)

# %%
# Summarize residual errors for the final ARIMA model
if seasonal_freq != 0:
    final_model = SARIMAX(time_series, order=final_ns_order, seasonal_order=final_ss_order)
else:
    final_model = SARIMAX(time_series, order=final_ns_order)
final_results = final_model.fit(disp = False)
print(final_results.summary())
final_results.plot_diagnostics(figsize=(12,12))
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /opt/conda/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                             values   No. Observations:                  138
# Model:             SARIMAX(4, 1, 2)x(1, 0, 2, 12)   Log Likelihood               -2153.785
# Date:                            Sun, 09 Aug 2020   AIC                           4327.569
# Time:                                    01:57:18   BIC                           4356.769
# Sample:                                01-01-2009   HQIC                          4339.435
#                                      - 06-01-2020
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.0005      0.111     -9.004      0.000      -1.218      -0.783
# ar.L2         -0.9034      0.104     -8.704      0.000      -1.107      -0.700
# ar.L3         -0.0289      0.081     -0.356      0.722      -0.188       0.130
# ar.L4         -0.0127      0.045     -0.286      0.775      -0.100       0.075
# ma.L1          0.9419      0.095      9.881      0.000       0.755       1.129
# ma.L2          0.9138      0.087     10.533      0.000       0.744       1.084
# ar.S.L12       0.9944      0.053     18.775      0.000       0.891       1.098
# ma.S.L12      -0.9543      0.136     -6.991      0.000      -1.222      -0.687
# ma.S.L24      -0.0136      0.050     -0.269      0.788      -0.112       0.085
# sigma2      2.513e+12   9.14e-14   2.75e+25      0.000    2.51e+12    2.51e+12
# ===================================================================================
# Ljung-Box (Q):                      117.11   Jarque-Bera (JB):               264.92
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.87   Skew:                            -1.46
# Prob(H) (two-sided):                  0.04   Kurtosis:                         9.16
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.64e+40. Standard errors may be unstable.

# %%
if notifyStatus: status_notify("ARIMA Task 4: Fit and Evaluate Models completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 5. Finalize Model and Make Predictions

# %%
if notifyStatus: status_notify("ARIMA Task 5: Finalize Model and Make Predictions has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 5.a) Validation via In-sample Data

# %%
validate_forecast = final_results.get_prediction(start = -test_size)
mean_validate_forecast = validate_forecast.predicted_mean
validate_confidence_intervals = validate_forecast.conf_int()

# %%
# Occasionally some predicted values turned out to be < 0 but they should not be (e.g. rainfall, disease cases, etc.)
# If we have those values, we will need to set them to 0
# print(mean_validate_forecast[mean_validate_forecast < 0])
# mean_validate_forecast[mean_validate_forecast < 0] = 0

# %%
plt.figure(figsize=(12,9))
plt.plot(time_series.index, time_series[target_col], label='observed')
plt.plot(mean_validate_forecast.index, mean_validate_forecast.values, color='red', label='forecast')
plt.fill_between(validate_confidence_intervals.index, validate_confidence_intervals[lower_bound], 
                 validate_confidence_intervals[upper_bound], color='pink')
plt.show()

# %%
# Evaluate RMSE for the validation data
y_test = time_series[-test_size:]
predictions = mean_validate_forecast.values
for i in range(y_test.shape[0]):
    print(y_test.index[i], ' | ', y_test.iloc[i,0], ' | ', predictions[i])
print('RMSE from the validation data is: %.3f' % math.sqrt(mean_squared_error(y_test, predictions)))
# Out:
# 2018-03-01 00:00:00  |  23214316  |  23140115.403798416
# 2018-04-01 00:00:00  |  23331877  |  22648112.174598742
# 2018-05-01 00:00:00  |  24198091  |  23825776.857102532
# 2018-06-01 00:00:00  |  22691252  |  23362268.371065836
# 2018-07-01 00:00:00  |  22105750  |  22545966.884989552
# 2018-08-01 00:00:00  |  24128752  |  22720715.32028126
# 2018-09-01 00:00:00  |  22965413  |  23746430.357882243
# 2018-10-01 00:00:00  |  25080291  |  23721169.826589666
# 2018-11-01 00:00:00  |  22438608  |  23866098.079763416
# 2018-12-01 00:00:00  |  20988857  |  22056067.581624873
# 2019-01-01 00:00:00  |  21263765  |  22485098.903093595
# 2019-02-01 00:00:00  |  20883716  |  21041072.35398187
# 2019-03-01 00:00:00  |  23562034  |  22247319.179274544
# 2019-04-01 00:00:00  |  23691650  |  23004247.24191927
# 2019-05-01 00:00:00  |  24351954  |  24051071.867648266
# 2019-06-01 00:00:00  |  22286620  |  23638652.31520072
# 2019-07-01 00:00:00  |  23735873  |  22121679.49758027
# 2019-08-01 00:00:00  |  24649209  |  24160442.41556769
# 2019-09-01 00:00:00  |  24102718  |  24572295.81878038
# 2019-10-01 00:00:00  |  26065766  |  24742823.65760818
# 2019-11-01 00:00:00  |  21760680  |  24662759.501265965
# 2019-12-01 00:00:00  |  20954860  |  21700483.429188572
# 2020-01-01 00:00:00  |  21987685  |  22077125.512188468
# 2020-02-01 00:00:00  |  21767867  |  21718723.787003856
# 2020-03-01 00:00:00  |  15323805  |  23527996.673355017
# 2020-04-01 00:00:00  |  7448380  |  15048935.121012414
# 2020-05-01 00:00:00  |  9096081  |  7658099.719605606
# 2020-06-01 00:00:00  |  10679063  |  8362732.64269302
# RMSE from the validation data is: 2396590.463

# %% [markdown]
# ### 5.b) Forecasting Out-of-Sample Data

# %%
if seasonal_freq != 0:
    forecast_size = seasonal_freq
else:
    forecast_size = 1
final_forecast = final_results.get_forecast(steps = forecast_size)
mean_final_forecast = final_forecast.predicted_mean
final_confidence_intervals = final_forecast.conf_int()
print("The forecasted values are:\n\n", mean_final_forecast)
# Out:
# The forecasted values are:
#
#  2020-07-01    1.086233e+07
# 2020-08-01    1.120508e+07
# 2020-09-01    1.087677e+07
# 2020-10-01    1.185063e+07
# 2020-11-01    1.034422e+07
# 2020-12-01    9.785477e+06
# 2021-01-01    1.134622e+07
# 2021-02-01    1.100422e+07
# 2021-03-01    1.189877e+07
# 2021-04-01    1.111837e+07
# 2021-05-01    1.142649e+07
# 2021-06-01    1.081681e+07
# Freq: MS, dtype: float64

# %%
# Occasionally some predicted values turned out to be < 0 but they should not be (e.g. rainfall, disease cases, etc.)
# If we have those values, we will need to set them to 0
# print(mean_final_forecast[mean_final_forecast < 0])
# mean_final_forecast[mean_final_forecast < 0] = 0

# %%
plt.figure(figsize=(12,9))
halfway_point = int(time_series.index.size / 2)
plt.plot(time_series.index[halfway_point:], time_series[target_col][halfway_point:], label='observed')
plt.plot(mean_final_forecast.index, mean_final_forecast.values, color='red', label='forecast')
plt.fill_between(final_confidence_intervals.index, final_confidence_intervals[lower_bound], 
                 final_confidence_intervals[upper_bound], color='pink')
plt.show()

# %%
if notifyStatus: status_notify("ARIMA Task 5: Finalize Model and Make Predictions completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
print ('Total time for the script:',(datetime.now() - startTimeScript))
# Out:
# Total time for the script: 0:10:31.518188
