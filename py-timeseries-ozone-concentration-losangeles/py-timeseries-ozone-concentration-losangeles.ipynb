# %% [markdown]
# # Time Series Model for Ozone Concentration in Los Angeles Using Python
# ### David Lowe
# ### February 5, 2020
#
# Template Credit: Adapted from a template made available by Dr. Jason Brownlee of Machine Learning Mastery. https://machinelearningmastery.com/
#
# SUMMARY: The purpose of this project is to construct a time series prediction model and document the end-to-end steps using a template. The Ozone Concentration in Los Angeles dataset is a time series situation where we are trying to forecast future outcomes based on past data points.
#
# INTRODUCTION: The problem is to forecast the monthly number of ozone concentration in Downtown Los Angeles. The dataset describes a time-series of ozone concentration (in part per million) over 18 years (1955-1972), and there are 216 observations. We used the first 80% of the observations for training and testing various models while holding back the remaining observations for validating the final model.
#
# ANALYSIS: The baseline prediction (or persistence) for the dataset resulted in an RMSE of 0.772. After performing a grid search for the most optimal ARIMA parameters, the final ARIMA non-seasonal order was (1, 1, 1) with the seasonal order being (1, 0, 1, 12). Furthermore, the chosen model processed the validation data with an RMSE of 0.569, which was better than the baseline model as expected.
#
# CONCLUSION: For this dataset, the chosen ARIMA model achieved a satisfactory result and should be considered for further modeling.
#
# Dataset Used: Ozon Concentration, Downtown Los Angeles, 1955-1972
#
# Dataset ML Model: Time series forecast with numerical attributes
#
# Dataset Reference: Rob Hyndman and Yangzhuoran Yang (2018). tsdl: Time Series Data Library. v0.1.0. https://pkg.yangzhuoranyang./tsdl/.
#
# The project aims to touch on the following areas:
#
# * Document a predictive modeling problem end-to-end
# * Explore data cleaning and transformation options
# * Explore various algorithms for baselining the model performance
# * Explore tuning techniques for improving the model performance
#
# A time series predictive modeling project genrally can be broken down into about five major tasks:
#
# 1. Define Problem and Acquire Data
# 2. Inspect and Explore Data
# 3. Clean and Pre-Process Data
# 4. Fit and Evaluate Models
# 5. Finalize Model

# %% [markdown]
# ## Section 1. Define Problem and Acquire Data

# %% [markdown]
# ### 1.a) Load Libraries

# %%
# Set the warning message filter
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import math
import smtplib
import pmdarima as pm
from datetime import datetime
from email.message import EmailMessage
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %% [markdown]
# ### 1.b) Set up the controlling parameters and functions

# %%
# Create the random seed number for reproducible results
seedNum = 888

# Set up the number of CPU cores available for multi-thread processing
n_jobs = -1

# Set up the verbose flag to print detailed messages for debugging (setting True will activate!)
verbose = False

# Set up the flag to stop sending progress emails (setting to True will send status emails!)
notifyStatus = False

# %%
# Set up the email notification function
def email_notify(msg_text):
    sender = os.environ.get('MAIL_SENDER')
    receiver = os.environ.get('MAIL_RECEIVER')
    gateway = os.environ.get('SMTP_GATEWAY')
    smtpuser = os.environ.get('SMTP_USERNAME')
    password = os.environ.get('SMTP_PASSWORD')
    if sender==None or receiver==None or gateway==None or smtpuser==None or password==None:
        sys.exit("Incomplete email setup info. Script Processing Aborted!!!")
    msg = EmailMessage()
    msg.set_content(msg_text)
    msg['Subject'] = 'Notification from Python ARIMA Time Series Script'
    msg['From'] = sender
    msg['To'] = receiver
    server = smtplib.SMTP(gateway, 587)
    server.starttls()
    server.login(smtpuser, password)
    server.send_message(msg)
    server.quit()

# %%
if (notifyStatus): email_notify("Library and Data Loading has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 1.c) Acquire and Load the Data
#
# Since the dataset is not current, this means that we cannot easily collect updated data to validate the model. Therefore, we will withhold a portion of the data towards the end from analysis and model selection. This very segment of data will be used to validate the final model.

# %%
startTimeScript = datetime.now()

# %%
# load the dataset and the necessary data structure
time_series = pd.read_csv('https://dainesanalytics.com/datasets/time-series-data-library/tsdl334.csv', index_col='idx', parse_dates=True)

# Sample code for subsetting the time-series data
# time_series = original_series['1986':'1990']

# %%
target_col = time_series.columns[0]
lower_bound = 'lower ' + target_col
upper_bound = 'upper ' + target_col
print('The target column of the time series is:', target_col)
print('The forecast boundary columns are:', lower_bound, '&', upper_bound)
# Out:
# The target column of the time series is: values
# The forecast boundary columns are: lower values & upper values

# %%
time_series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 216 entries, 1955-01-01 to 1972-12-01
# Data columns (total 1 columns):
# values    216 non-null float64
# dtypes: float64(1)
# memory usage: 3.4 KB

# %%
time_series.head(10)
# Out:
#             values
# idx
# 1955-01-01     2.7
# 1955-02-01     2.0
# 1955-03-01     3.6
# 1955-04-01     5.0
# 1955-05-01     6.5
# 1955-06-01     6.1
# 1955-07-01     5.9
# 1955-08-01     5.0
# 1955-09-01     6.4
# 1955-10-01     7.4

# %%
time_series.tail(10)
# Out:
#             values
# idx
# 1972-03-01     3.1
# 1972-04-01     3.0
# 1972-05-01     3.5
# 1972-06-01     3.4
# 1972-07-01     4.0
# 1972-08-01     3.8
# 1972-09-01     3.1
# 1972-10-01     2.1
# 1972-11-01     1.6
# 1972-12-01     1.3

# %%
if (notifyStatus): email_notify("Library and Data Loading completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 2. Inspect and Explore Data

# %%
if (notifyStatus): email_notify("Data Inspection and Exploration has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 2.a) Summary Statistics of the Time Series Data
#
# Summary statistics provide a quick look at the limits of observed values. It can help to get a quick idea of what we are working with.

# %%
# Summary statistics of time series
print(time_series.describe())
# Out:
#            values
# count  216.000000
# mean     3.772685
# std      1.491634
# min      1.200000
# 25%      2.575000
# 50%      3.700000
# 75%      4.800000
# max      8.700000

# %% [markdown]
# ### 2.b) Line Plot of the Time Series Data
#
# A line plot of a time series can provide a lot of insight into the problem. Some observations from the plot can include:
#
# * Whether the trend appears to be level around the mean
# * Whether there appear to be any obvious outliers
#
# The ARIMA(p,d,q) model requires three parameters and assumes that we are working with a stationary time series.
#
# The ADF results should show that the test statistic value is smaller than the critical value at 5% if the time series is stationary. This suggests that we can reject the null hypothesis (i.e. a low probability that the result is a statistical fluke).

# %%
# Line plots of time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Time Series Data')
time_series.plot(ax=ax)
plt.show()

# %% [markdown]
# ### 2.c) Histogram and Density Plots of the Time Series Data
#
# Reviewing plots of the density of observations can provide further insight into the structure of the data. Some observations from the plots can include:
#
# * Whether the distribution is Gaussian
# * Whether the distribution has a long tail and may suggest the need for data transformation

# %%
# Line plots of time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Histogram of the Time Series Data')
time_series.hist(ax=ax)
plt.show()

# %%
# Line plots of time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Density Plot of the Time Series Data')
time_series.plot(kind='kde', ax=ax)
plt.show()

# %% [markdown]
# ### 2.d) Box and Whisker Plots of the Time Series Data
#
# We can group or aggregate the data and get a better idea of the spread of observations. Some observations from reviewing the plot can include:
#
# * Whether the median values for each grouping shows any significant trend
# * Whether the spread, or middle 50% of the data, shows any significant variability
# * Whether there are outliers in some grouping

# %%
# boxplots of time series
fig, ax = plt.subplots(figsize=(12,9))
squeezed = time_series.squeeze()
sns.boxplot(squeezed.index.year, squeezed, ax=ax)
plt.show()

# %%
if (notifyStatus): email_notify("Data Inspection and Exploration completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 3. Data Transformation and Stationarity Tests

# %%
if (notifyStatus): email_notify("Data Cleaning and Pre-Processing has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### Section 3.a) Data Transformation

# %%
# Resampling the time series into monthly average for the ease of modeling
# original_series = time_series
# resample = original_series.resample('M')
# time_series = resample.mean()
# time_series.head(10)

# %%
# Line plots of the transformed time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Non-Seasonal Time Series Data')
time_series.plot(ax=ax)
plt.show()

# %% [markdown]
# ### Section 3.b) Test for Stationarity

# %%
# Check if stationary
result = adfuller(time_series[target_col])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Test Statistics Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -2.193446
# p-value: 0.208633
# Critical Test Statistics Values:
# 	1%: -3.463
# 	5%: -2.876
# 	10%: -2.574

# %%
# ACF and PACF plots of the time series data
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))
plot_acf(time_series, ax=ax1)
plot_pacf(time_series, ax=ax2)
plt.show()

# %% [markdown]
# ### 3.c) Test for Stationarity of Non-Seasonal Time Series Data
#
# Occasionally a time series may look non-stationary on the first look. We can make it stationary by differencing the series and using a statistical test to confirm that the differenced result is stationary. Rejecting the null hypothesis means that the process has no unit root, and in turn that the time series is stationary or does not have time-dependent structure.

# %%
# Create a differenced series
stationary_ns = time_series.diff().dropna()

# Plot differenced data
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Stationary Time Series Data')
stationary_ns.plot(ax=ax)
plt.show()

# %%
# Check for stationarity
result = adfuller(stationary_ns[target_col])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Test Statistics Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -5.518311
# p-value: 0.000002
# Critical Test Statistics Values:
# 	1%: -3.463
# 	5%: -2.876
# 	10%: -2.574

# %%
# ACF and PACF plots of the stationary time series
lags = 25
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))
plot_acf(stationary_ns, lags=lags, ax=ax1)
plot_pacf(stationary_ns, lags=lags, ax=ax2)
plt.show()

# %% [markdown]
# ### 3.d) Seasonal Decomposition for Seasonal Time Series Data

# %%
# Set the initial seasonal frequency parameter
seasonal_freq = 12

# %%
# Perform seasonal decomposition to observe the seasonal frequency
decomp_results = seasonal_decompose(time_series, freq=seasonal_freq)
decomp_results.plot()
plt.show()

# %%
# Create a seasonal series
N = seasonal_freq
seasonal_series = time_series - time_series.rolling(N).mean()
seasonal_series = seasonal_series.dropna()

# Line plots of the seasonal time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Seasonal Time Series Data')
seasonal_series.plot(ax=ax)
plt.show()

# %%
# Check for stationarity
result = adfuller(seasonal_series[target_col])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Test Statistics Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -5.539819
# p-value: 0.000002
# Critical Test Statistics Values:
# 	1%: -3.465
# 	5%: -2.877
# 	10%: -2.575

# %%
# ACF and PACF plots of the time series data
lag = seasonal_freq * 2
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))
plot_acf(seasonal_series, lags=lag, ax=ax1)
plot_pacf(seasonal_series, lags=lag, ax=ax2)
plt.show()

# %% [markdown]
# ### 3.e) Test for Stationarity of Seasonal Time Series Data
#
# Occasionally a time series may look non-stationary on the first look. We can make it stationary by differencing the series and using a statistical test to confirm that the differenced result is stationary. Rejecting the null hypothesis means that the process has no unit root, and in turn that the time series is stationary or does not have time-dependent structure.

# %%
# Create a differenced series
stationary_ss = time_series.diff(seasonal_freq).dropna()

# Plot differenced data
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Stationary Seasonal Time Series Data')
stationary_ss.plot(ax=ax)
plt.show()

# %%
# Check for stationarity
result = adfuller(stationary_ss[target_col])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Test Statistics Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -3.639342
# p-value: 0.005052
# Critical Test Statistics Values:
# 	1%: -3.466
# 	5%: -2.877
# 	10%: -2.575

# %%
# ACF and PACF plots of the stationary time series
lags = seasonal_freq * 2
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))
plot_acf(stationary_ss, lags=lags, ax=ax1)
plot_pacf(stationary_ss, lags=lags, ax=ax2)
plt.show()

# %%
if (notifyStatus): email_notify("Data Cleaning and Pre-Processing completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 4. Fit and Evaluate Models
#
# In this section, we will develop Autoregressive Integrated Moving Average or ARIMA models for the problem. We will first establish a persistent model. Next we will use a grid search approach to look for an optimal ARIMA model. This will be followed by a third step of investigating the residual errors of the chosen model.
#
# * Establish the Persistent Model
# * Automatically Configure the ARIMA
# * Review Residual Errors

# %%
if (notifyStatus): email_notify("Model Fitting and Evaluation has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 4.a) Establish the Persistent Model
#
# The first step before getting bogged down in data analysis and modeling is to establish a baseline of performance. This will provide both a template for evaluating models using the proposed test harness and a performance measure by which all more elaborate predictive models can be compared.
#
# The baseline prediction for time series forecasting is called the naive forecast, or persistence. This is where the observation from the previous time step is used as the prediction for the observation at the next time step.

# %% [markdown]
# #### 4.a.iii) Establish the Persistent Model as Baseline

# %%
# Prepare and evaluate a persistence model
X = time_series.values
X = X.astype('float32')
train_pct = 0.80
train_size = int(len(X) * train_pct)
test_size = len(X) - train_size
train_ts, test_ts = X[0:train_size], X[train_size:]

# walk-forward validation
history = [x for x in train_ts]
predictions = list()
for i in range(len(test_ts)):
    yhat = history[-1]
    predictions.append(yhat)
    obs = test_ts[i]
    history.append(obs)
    print('>Predicted=%.3f, Expected=%3.f' % (yhat, obs))

# Calculate performance
rmse = math.sqrt(mean_squared_error(test_ts, predictions))
print('RMSE for the persistent model is: %.3f' % rmse)
# Out:
# >Predicted=3.200, Expected=  4
# >Predicted=4.400, Expected=  3
# >Predicted=3.400, Expected=  4
# >Predicted=3.900, Expected=  6
# >Predicted=5.500, Expected=  4
# >Predicted=3.800, Expected=  3
# >Predicted=3.200, Expected=  2
# >Predicted=2.300, Expected=  2
# >Predicted=2.200, Expected=  1
# >Predicted=1.300, Expected=  2
# >Predicted=2.300, Expected=  3
# >Predicted=2.700, Expected=  3
# >Predicted=3.300, Expected=  4
# >Predicted=3.700, Expected=  3
# >Predicted=3.000, Expected=  4
# >Predicted=3.800, Expected=  5
# >Predicted=4.700, Expected=  5
# >Predicted=4.600, Expected=  3
# >Predicted=2.900, Expected=  2
# >Predicted=1.700, Expected=  1
# >Predicted=1.300, Expected=  2
# >Predicted=1.800, Expected=  2
# >Predicted=2.000, Expected=  2
# >Predicted=2.200, Expected=  3
# >Predicted=3.000, Expected=  2
# >Predicted=2.400, Expected=  4
# >Predicted=3.500, Expected=  4
# >Predicted=3.500, Expected=  3
# >Predicted=3.300, Expected=  3
# >Predicted=2.700, Expected=  2
# >Predicted=2.500, Expected=  2
# >Predicted=1.600, Expected=  1
# >Predicted=1.200, Expected=  2
# >Predicted=1.500, Expected=  2
# >Predicted=2.000, Expected=  3
# >Predicted=3.100, Expected=  3
# >Predicted=3.000, Expected=  4
# >Predicted=3.500, Expected=  3
# >Predicted=3.400, Expected=  4
# >Predicted=4.000, Expected=  4
# >Predicted=3.800, Expected=  3
# >Predicted=3.100, Expected=  2
# >Predicted=2.100, Expected=  2
# >Predicted=1.600, Expected=  1
# RMSE for the persistent model is: 0.772

# %% [markdown]
# ### 4.b) Grid Search of ARIMA Hyperparameters
#
# We want to find a model that can do better than the persistence model on this dataset. To confirm this analysis, we can grid search a suite of ARIMA hyperparameters.
#
# In this section, we will search values of p, d, and q for combinations (skipping those that fail to converge), and find the combination that results in the best performance. We will use a grid search to explore all combinations in a subset of integer values.

# %%
if (notifyStatus): email_notify("ARIMA Hyperparameters Search has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Set the initial P, D, and Q order parameters for non-seasonal ARIMA modeling
start_p = 0
start_d = 0
start_q = 0
max_p = 4
max_d = 2
max_q = 3

# %%
# Set the initial P, D, and Q order parameters for seasonal ARIMA modeling
start_P = 0
start_D = 0
start_Q = 0
max_P = 4
max_D = 1
max_Q = 3

# %%
# Testing the time series data for suggestions on the differencing term
start_d = pm.arima.ndiffs(train_ts)
print('The suggested non-seasonal differencing term is:', start_d)
if (seasonal_freq != 0):
    start_D = pm.arima.nsdiffs(train_ts, m = seasonal_freq)
    print('The suggested seasonal differencing term is:', start_D)
# Out:
# The suggested non-seasonal differencing term is: 1
# The suggested seasonal differencing term is: 0

# %%
print('The initial non-seasonal parameters are: p =', start_p, '| d =', start_d, '| q =', start_q)
print('The maximum non-seasonal parameters are: max_p =', max_p, '| max_d =', max_d, '| max_q =', max_q)
if (seasonal_freq != 0):
    print('The initial seasonal parameters are: P =', start_P, '| D =', start_D, '| Q =', start_Q, '| m =', seasonal_freq)
    print('The maximum seasonal parameters are: max_P =', max_P, '| max_D =', max_D, '| max_Q =', max_Q)
# Out:
# The initial non-seasonal parameters are: p = 0 | d = 1 | q = 0
# The maximum non-seasonal parameters are: max_p = 4 | max_d = 2 | max_q = 3
# The initial seasonal parameters are: P = 0 | D = 0 | Q = 0 | m = 12
# The maximum seasonal parameters are: max_P = 4 | max_D = 1 | max_Q = 3

# %%
# Do an automated stepwise search of ARIMA parameters
if (seasonal_freq == 0):
    stepwise_results = pm.auto_arima(train_ts, seasonal = False, stepwise = True, trace = True, suppress_warnings = True, random_state = seedNum)
else:
    stepwise_results = pm.auto_arima(train_ts, seasonal = True, m = seasonal_freq, stepwise = True, trace = True, suppress_warnings = True, random_state = seedNum)
# Out:
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 0, 1, 12); AIC=462.678, BIC=487.811, Fit time=2.169 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 0, 0, 12); AIC=537.001, BIC=543.284, Fit time=0.068 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 0, 0, 12); AIC=513.452, BIC=526.018, Fit time=0.234 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 0, 1, 12); AIC=520.633, BIC=533.200, Fit time=0.252 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 0, 0, 12); AIC=535.002, BIC=538.143, Fit time=0.031 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 0, 1, 12); AIC=497.894, BIC=519.886, Fit time=1.833 seconds
# Near non-invertible roots for order (2, 1, 2)(0, 0, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.997)
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 0, 0, 12); AIC=484.384, BIC=506.376, Fit time=2.305 seconds
# Near non-invertible roots for order (2, 1, 2)(1, 0, 0, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(2, 0, 1, 12); AIC=463.260, BIC=491.535, Fit time=6.843 seconds
# Near non-invertible roots for order (2, 1, 2)(2, 0, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.997)
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 0, 2, 12); AIC=463.636, BIC=491.911, Fit time=6.189 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 0, 0, 12); AIC=515.128, BIC=533.978, Fit time=1.803 seconds
# Near non-invertible roots for order (2, 1, 2)(0, 0, 0, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.997)
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 0, 2, 12); AIC=491.541, BIC=516.674, Fit time=4.196 seconds
# Near non-invertible roots for order (2, 1, 2)(0, 0, 2, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.998)
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(2, 0, 0, 12); AIC=472.591, BIC=497.725, Fit time=5.678 seconds
# Near non-invertible roots for order (2, 1, 2)(2, 0, 0, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.999)
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(2, 0, 2, 12); AIC=467.340, BIC=498.756, Fit time=7.122 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 0, 1, 12); AIC=461.155, BIC=483.146, Fit time=1.955 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 0, 1, 12); AIC=495.948, BIC=514.798, Fit time=1.546 seconds
# Near non-invertible roots for order (1, 1, 2)(0, 0, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.999)
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 0, 0, 12); AIC=483.141, BIC=501.991, Fit time=1.740 seconds
# Near non-invertible roots for order (1, 1, 2)(1, 0, 0, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.999)
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 0, 1, 12); AIC=463.518, BIC=488.652, Fit time=5.240 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 0, 2, 12); AIC=463.374, BIC=488.508, Fit time=5.221 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 0, 0, 12); AIC=513.550, BIC=529.258, Fit time=1.070 seconds
# Near non-invertible roots for order (1, 1, 2)(0, 0, 0, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 0, 2, 12); AIC=489.498, BIC=511.489, Fit time=4.551 seconds
# Near non-invertible roots for order (1, 1, 2)(0, 0, 2, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 0, 0, 12); AIC=470.625, BIC=492.616, Fit time=4.917 seconds
# Near non-invertible roots for order (1, 1, 2)(2, 0, 0, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.998)
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 0, 2, 12); AIC=468.510, BIC=496.785, Fit time=6.521 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 0, 1, 12); AIC=461.394, BIC=480.244, Fit time=2.209 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 0, 1, 12); AIC=459.331, BIC=478.181, Fit time=3.016 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 0, 1, 12); AIC=494.186, BIC=509.894, Fit time=1.578 seconds
# Near non-invertible roots for order (1, 1, 1)(0, 0, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 0, 0, 12); AIC=481.147, BIC=496.855, Fit time=1.869 seconds
# Near non-invertible roots for order (1, 1, 1)(1, 0, 0, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 0, 1, 12); AIC=460.379, BIC=482.371, Fit time=5.105 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 0, 2, 12); AIC=460.285, BIC=482.277, Fit time=4.112 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 0, 0, 12); AIC=512.774, BIC=525.341, Fit time=0.816 seconds
# Near non-invertible roots for order (1, 1, 1)(0, 0, 0, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.999)
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 0, 2, 12); AIC=487.694, BIC=506.544, Fit time=4.422 seconds
# Near non-invertible roots for order (1, 1, 1)(0, 0, 2, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 0, 0, 12); AIC=468.631, BIC=487.481, Fit time=4.217 seconds
# Near non-invertible roots for order (1, 1, 1)(2, 0, 0, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.999)
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 0, 2, 12); AIC=465.104, BIC=490.237, Fit time=6.075 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 0, 1, 12); AIC=469.521, BIC=485.229, Fit time=2.130 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 0, 1, 12); AIC=492.138, BIC=507.847, Fit time=0.748 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(1, 0, 1, 12); AIC=462.207, BIC=484.199, Fit time=2.257 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 0, 1, 12); AIC=507.494, BIC=520.061, Fit time=0.428 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(1, 0, 1, 12); AIC=480.141, BIC=498.991, Fit time=0.860 seconds
# Total fit time: 111.409 seconds

# %%
# Summarize residual errors for the automated grid search ARIMA model
print(stepwise_results.summary())
stepwise_results.plot_diagnostics(figsize=(12,12))
plt.show()
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  172
# Model:             SARIMAX(1, 1, 1)x(1, 0, 1, 12)   Log Likelihood                -223.666
# Date:                            Tue, 28 Jan 2020   AIC                            459.331
# Time:                                    03:30:27   BIC                            478.181
# Sample:                                         0   HQIC                           466.980
#                                             - 172
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -0.0002      0.000     -0.564      0.573      -0.001       0.001
# ar.L1          0.3628      0.080      4.512      0.000       0.205       0.520
# ma.L1         -0.9503      0.032    -29.959      0.000      -1.012      -0.888
# ar.S.L12       0.9703      0.027     36.370      0.000       0.918       1.023
# ma.S.L12      -0.7560      0.103     -7.369      0.000      -0.957      -0.555
# sigma2         0.7406      0.081      9.094      0.000       0.581       0.900
# ===================================================================================
# Ljung-Box (Q):                       35.36   Jarque-Bera (JB):                 2.12
# Prob(Q):                              0.68   Prob(JB):                         0.35
# Heteroskedasticity (H):               0.44   Skew:                             0.25
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.22
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
if (notifyStatus): email_notify("ARIMA automated stepwise search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Do an automated random search of ARIMA parameters
n_fits = int(max_p * max_d * max_q * max_P * max_D * max_Q * 0.30)
if (seasonal_freq == 0):
    randgrid_results = pm.auto_arima(train_ts, start_p = start_p, d = start_d, start_q = start_q, max_p = max_p, max_d = max_d, max_q = max_q,
                                     seasonal = False, stepwise = False, random = True, n_fits = n_fits, max_order = None,
                                     trace = True, suppress_warnings = True, random_state = seedNum)
else:
    randgrid_results = pm.auto_arima(train_ts, start_p = start_p, d = start_d, start_q = start_q, max_p = max_p, max_d = max_d, max_q = max_q,
                                     seasonal = True, m = seasonal_freq, start_P = start_P, D = start_D, start_Q = start_Q, max_P = max_P, max_D = max_D, max_Q = max_Q,
                                     stepwise = False, random = True, n_fits = n_fits, max_order = None,
                                     trace = True, suppress_warnings = True, random_state = seedNum)
# Out:
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(4, 0, 3, 12); AIC=470.174, BIC=507.874, Fit time=22.452 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(1, 0, 3, 12); AIC=479.999, BIC=505.132, Fit time=3.961 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(2, 0, 3, 12); AIC=477.593, BIC=509.010, Fit time=11.887 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 0, 2, 12); AIC=492.971, BIC=511.821, Fit time=1.621 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(2, 0, 3, 12); AIC=465.769, BIC=500.327, Fit time=15.589 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(4, 0, 1, 12); AIC=468.200, BIC=505.900, Fit time=23.173 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(0, 0, 1, 12); AIC=497.147, BIC=519.139, Fit time=2.449 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 0, 3, 12); AIC=506.462, BIC=525.312, Fit time=2.773 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(0, 0, 0, 12); AIC=542.901, BIC=561.750, Fit time=0.174 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(3, 0, 3, 12); AIC=482.702, BIC=514.119, Fit time=14.132 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(4, 0, 3, 12); AIC=483.160, BIC=524.002, Fit time=28.873 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(3, 0, 1, 12); AIC=463.871, BIC=501.571, Fit time=16.941 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(2, 0, 2, 12); AIC=483.817, BIC=508.950, Fit time=5.205 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(2, 0, 0, 12); AIC=474.546, BIC=502.821, Fit time=6.419 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(2, 0, 2, 12); AIC=505.237, BIC=524.087, Fit time=3.306 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 0, 3, 12); AIC=491.785, BIC=513.777, Fit time=3.589 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(1, 0, 0, 12); AIC=484.756, BIC=506.747, Fit time=2.026 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(0, 0, 0, 12); AIC=519.618, BIC=535.326, Fit time=0.996 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(0, 0, 3, 12); AIC=482.719, BIC=514.136, Fit time=11.863 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(1, 0, 3, 12); AIC=477.525, BIC=508.941, Fit time=5.872 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(4, 0, 3, 12); AIC=497.375, BIC=528.792, Fit time=11.565 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(2, 0, 3, 12); AIC=493.620, BIC=518.753, Fit time=6.918 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 0, 0, 12); AIC=513.550, BIC=529.258, Fit time=1.150 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(2, 0, 2, 12); AIC=472.330, BIC=506.889, Fit time=8.586 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(0, 0, 2, 12); AIC=491.349, BIC=516.483, Fit time=5.554 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 0, 3, 12); AIC=464.672, BIC=496.089, Fit time=12.498 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 0, 3, 12); AIC=470.876, BIC=492.867, Fit time=9.727 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(3, 0, 3, 12); AIC=468.481, BIC=506.181, Fit time=16.409 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 0, 1, 12); AIC=492.138, BIC=507.847, Fit time=0.666 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(0, 0, 3, 12); AIC=505.751, BIC=530.885, Fit time=3.163 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(3, 0, 1, 12); AIC=463.215, BIC=491.490, Fit time=12.072 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(4, 0, 1, 12); AIC=464.586, BIC=496.003, Fit time=19.696 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(2, 0, 2, 12); AIC=467.903, BIC=496.178, Fit time=7.189 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 0, 2, 12); AIC=498.343, BIC=517.193, Fit time=6.275 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(2, 0, 1, 12); AIC=477.624, BIC=505.899, Fit time=3.597 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(3, 0, 1, 12); AIC=492.784, BIC=514.776, Fit time=3.221 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(4, 0, 3, 12); AIC=471.560, BIC=512.402, Fit time=22.849 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(3, 0, 3, 12); AIC=468.172, BIC=505.872, Fit time=15.825 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(4, 0, 0, 12); AIC=465.472, BIC=500.030, Fit time=22.667 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(1, 0, 0, 12); AIC=507.347, BIC=529.338, Fit time=0.605 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(2, 0, 1, 12); AIC=462.561, BIC=487.694, Fit time=6.083 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(2, 0, 2, 12); AIC=467.340, BIC=498.756, Fit time=7.532 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(3, 0, 0, 12); AIC=508.039, BIC=523.748, Fit time=1.567 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(1, 0, 2, 12); AIC=465.653, BIC=503.353, Fit time=8.890 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(2, 0, 3, 12); AIC=467.019, BIC=507.860, Fit time=17.301 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(2, 0, 0, 12); AIC=473.897, BIC=508.455, Fit time=8.753 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(4, 0, 1, 12); AIC=464.780, BIC=493.055, Fit time=15.931 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(1, 0, 3, 12); AIC=467.699, BIC=499.115, Fit time=15.730 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 0, 1, 12); AIC=522.303, BIC=534.869, Fit time=0.233 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(1, 0, 3, 12); AIC=475.719, BIC=503.994, Fit time=4.279 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(0, 0, 3, 12); AIC=483.829, BIC=521.529, Fit time=17.136 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(3, 0, 2, 12); AIC=468.929, BIC=506.629, Fit time=16.482 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(3, 0, 3, 12); AIC=479.662, BIC=514.220, Fit time=14.249 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(2, 0, 3, 12); AIC=466.247, BIC=500.805, Fit time=14.481 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(0, 0, 0, 12); AIC=539.426, BIC=551.993, Fit time=0.121 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(3, 0, 3, 12); AIC=466.473, BIC=497.889, Fit time=13.356 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(2, 0, 1, 12); AIC=465.168, BIC=496.585, Fit time=6.865 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(4, 0, 1, 12); AIC=462.688, BIC=490.963, Fit time=16.421 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 0, 2, 12); AIC=465.104, BIC=490.237, Fit time=6.295 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(4, 0, 0, 12); AIC=463.029, BIC=488.162, Fit time=9.076 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(0, 0, 1, 12); AIC=499.184, BIC=524.317, Fit time=1.939 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(0, 0, 3, 12); AIC=482.605, BIC=514.022, Fit time=13.354 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(3, 0, 1, 12); AIC=508.328, BIC=527.178, Fit time=2.164 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(3, 0, 1, 12); AIC=471.235, BIC=493.226, Fit time=7.268 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(4, 0, 2, 12); AIC=466.772, BIC=501.330, Fit time=22.509 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(4, 0, 2, 12); AIC=467.901, BIC=511.884, Fit time=27.770 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(2, 0, 1, 12); AIC=465.681, BIC=500.239, Fit time=7.384 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(4, 0, 2, 12); AIC=496.338, BIC=524.613, Fit time=8.347 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(4, 0, 1, 12); AIC=465.980, BIC=500.538, Fit time=24.629 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(2, 0, 1, 12); AIC=463.755, BIC=498.314, Fit time=8.600 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(4, 0, 1, 12); AIC=479.970, BIC=514.528, Fit time=11.083 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(4, 0, 1, 12); AIC=466.601, BIC=501.160, Fit time=19.493 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(0, 0, 2, 12); AIC=489.483, BIC=511.474, Fit time=5.067 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 0, 1, 12); AIC=525.370, BIC=534.795, Fit time=0.179 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(4, 0, 2, 12); AIC=474.987, BIC=503.262, Fit time=17.475 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(0, 0, 0, 12); AIC=541.389, BIC=557.097, Fit time=0.146 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(1, 0, 1, 12); AIC=464.216, BIC=492.491, Fit time=3.340 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(3, 0, 0, 12); AIC=461.938, BIC=487.071, Fit time=11.123 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 0, 1, 12); AIC=497.894, BIC=519.886, Fit time=1.961 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(1, 0, 1, 12); AIC=474.695, BIC=496.687, Fit time=1.135 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(4, 0, 2, 12); AIC=466.759, BIC=498.176, Fit time=18.224 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(2, 0, 3, 12); AIC=471.832, BIC=509.532, Fit time=16.542 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(3, 0, 1, 12); AIC=463.543, BIC=491.818, Fit time=11.273 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 0, 3, 12); AIC=481.187, BIC=509.462, Fit time=14.461 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(2, 0, 1, 12); AIC=475.996, BIC=501.129, Fit time=3.007 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(4, 0, 0, 12); AIC=478.395, BIC=509.812, Fit time=6.199 seconds
# Total fit time: 839.040 seconds

# %%
# Summarize residual errors for the automated grid search ARIMA model
print(randgrid_results.summary())
randgrid_results.plot_diagnostics(figsize=(12,12))
plt.show()
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  172
# Model:             SARIMAX(2, 1, 1)x(3, 0, 0, 12)   Log Likelihood                -222.969
# Date:                            Tue, 28 Jan 2020   AIC                            461.938
# Time:                                    03:44:29   BIC                            487.071
# Sample:                                         0   HQIC                           472.136
#                                             - 172
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -0.0016      0.001     -2.115      0.034      -0.003      -0.000
# ar.L1          0.4123      0.077      5.387      0.000       0.262       0.562
# ar.L2          0.0354      0.084      0.421      0.673      -0.129       0.200
# ma.L1         -0.9977      0.057    -17.641      0.000      -1.109      -0.887
# ar.S.L12       0.2349      0.081      2.898      0.004       0.076       0.394
# ar.S.L24       0.2398      0.096      2.493      0.013       0.051       0.428
# ar.S.L36       0.2994      0.086      3.465      0.001       0.130       0.469
# sigma2         0.7438      0.090      8.249      0.000       0.567       0.921
# ===================================================================================
# Ljung-Box (Q):                       43.86   Jarque-Bera (JB):                 1.09
# Prob(Q):                              0.31   Prob(JB):                         0.58
# Heteroskedasticity (H):               0.41   Skew:                             0.19
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.06
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
if (notifyStatus): email_notify("ARIMA automated random search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Do an automated grid search of ARIMA parameters
if (seasonal_freq == 0):
    autogrid_results = pm.auto_arima(train_ts, start_p = start_p, d = start_d, start_q = start_q, max_p = max_p, max_d = max_d, max_q = max_q,
                                     seasonal = False, stepwise = False, max_order = None, trace = True, suppress_warnings = True, random_state = seedNum)
else:
    autogrid_results = pm.auto_arima(train_ts, start_p = start_p, d = start_d, start_q = start_q, max_p = max_p, max_d = max_d, max_q = max_q,
                                     seasonal = True, m = seasonal_freq, start_P = start_P, D = start_D, start_Q = start_Q, max_P = max_P, max_D = max_D, max_Q = max_Q,
                                     stepwise = False, max_order = None, trace = True, suppress_warnings = True, random_state = seedNum)
# Out:
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 0, 0, 12); AIC=537.001, BIC=543.284, Fit time=0.034 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 0, 1, 12); AIC=525.370, BIC=534.795, Fit time=0.170 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 0, 2, 12); AIC=522.563, BIC=535.130, Fit time=0.521 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 0, 3, 12); AIC=516.223, BIC=531.931, Fit time=2.030 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 0, 0, 12); AIC=520.009, BIC=529.434, Fit time=0.168 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 0, 1, 12); AIC=507.494, BIC=520.061, Fit time=0.407 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 0, 2, 12); AIC=507.690, BIC=523.398, Fit time=0.917 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 0, 3, 12); AIC=506.462, BIC=525.312, Fit time=2.740 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(2, 0, 0, 12); AIC=513.922, BIC=526.488, Fit time=0.563 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(2, 0, 1, 12); AIC=508.412, BIC=524.120, Fit time=1.242 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(2, 0, 2, 12); AIC=505.237, BIC=524.087, Fit time=3.400 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(2, 0, 3, 12); AIC=506.323, BIC=528.314, Fit time=6.845 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(3, 0, 0, 12); AIC=508.039, BIC=523.748, Fit time=1.560 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(3, 0, 1, 12); AIC=508.328, BIC=527.178, Fit time=2.240 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(3, 0, 2, 12); AIC=506.186, BIC=528.178, Fit time=9.489 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(3, 0, 3, 12); AIC=508.495, BIC=533.628, Fit time=10.418 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(4, 0, 0, 12); AIC=507.579, BIC=526.429, Fit time=2.876 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(4, 0, 1, 12); AIC=509.568, BIC=531.559, Fit time=4.987 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(4, 0, 2, 12); AIC=511.311, BIC=536.444, Fit time=7.850 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(4, 0, 3, 12); AIC=510.169, BIC=538.444, Fit time=15.445 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 0, 0, 12); AIC=537.495, BIC=546.920, Fit time=0.090 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 0, 1, 12); AIC=520.633, BIC=533.200, Fit time=0.259 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 0, 2, 12); AIC=514.975, BIC=530.684, Fit time=0.688 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 0, 3, 12); AIC=505.379, BIC=524.229, Fit time=2.274 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 0, 0, 12); AIC=504.833, BIC=517.400, Fit time=0.314 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 0, 1, 12); AIC=469.521, BIC=485.229, Fit time=2.026 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 0, 2, 12); AIC=470.659, BIC=489.509, Fit time=4.014 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 0, 3, 12); AIC=470.876, BIC=492.867, Fit time=9.566 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(2, 0, 0, 12); AIC=488.208, BIC=503.916, Fit time=1.186 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(2, 0, 1, 12); AIC=470.925, BIC=489.775, Fit time=3.042 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(2, 0, 2, 12); AIC=473.323, BIC=495.315, Fit time=5.620 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(2, 0, 3, 12); AIC=472.945, BIC=498.079, Fit time=8.226 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(3, 0, 0, 12); AIC=474.938, BIC=493.788, Fit time=3.267 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(3, 0, 1, 12); AIC=471.235, BIC=493.226, Fit time=7.304 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(3, 0, 2, 12); AIC=473.433, BIC=498.566, Fit time=10.220 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(3, 0, 3, 12); AIC=474.716, BIC=502.991, Fit time=12.285 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(4, 0, 0, 12); AIC=472.305, BIC=494.297, Fit time=5.041 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(4, 0, 1, 12); AIC=473.156, BIC=498.289, Fit time=14.312 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(4, 0, 2, 12); AIC=474.987, BIC=503.262, Fit time=17.110 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(4, 0, 3, 12); AIC=476.567, BIC=507.984, Fit time=18.299 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 0, 0, 12); AIC=539.339, BIC=551.906, Fit time=0.124 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 0, 1, 12); AIC=508.313, BIC=524.022, Fit time=1.176 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 0, 2, 12); AIC=498.343, BIC=517.193, Fit time=6.345 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 0, 3, 12); AIC=483.967, BIC=505.959, Fit time=8.263 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 0, 0, 12); AIC=487.085, BIC=502.793, Fit time=1.541 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 0, 1, 12); AIC=461.394, BIC=480.244, Fit time=2.318 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 0, 2, 12); AIC=462.173, BIC=484.165, Fit time=5.282 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 0, 3, 12); AIC=463.062, BIC=488.196, Fit time=9.895 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(2, 0, 0, 12); AIC=472.628, BIC=491.478, Fit time=4.071 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(2, 0, 1, 12); AIC=463.671, BIC=485.663, Fit time=4.908 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(2, 0, 2, 12); AIC=465.347, BIC=490.480, Fit time=5.642 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(2, 0, 3, 12); AIC=464.441, BIC=492.716, Fit time=7.506 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(3, 0, 0, 12); AIC=462.981, BIC=484.973, Fit time=6.256 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(3, 0, 1, 12); AIC=462.771, BIC=487.905, Fit time=10.614 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(3, 0, 2, 12); AIC=464.905, BIC=493.180, Fit time=9.478 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(3, 0, 3, 12); AIC=466.473, BIC=497.889, Fit time=12.873 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(4, 0, 0, 12); AIC=463.029, BIC=488.162, Fit time=8.592 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(4, 0, 1, 12); AIC=464.780, BIC=493.055, Fit time=15.212 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(4, 0, 2, 12); AIC=466.759, BIC=498.176, Fit time=17.435 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(4, 0, 3, 12); AIC=468.728, BIC=503.287, Fit time=18.720 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(0, 0, 0, 12); AIC=519.618, BIC=535.326, Fit time=0.987 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(0, 0, 1, 12); AIC=500.634, BIC=519.484, Fit time=2.058 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(0, 0, 2, 12); AIC=492.351, BIC=514.342, Fit time=4.127 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(0, 0, 3, 12); AIC=480.625, BIC=505.758, Fit time=10.096 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(1, 0, 0, 12); AIC=485.609, BIC=504.459, Fit time=1.485 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(1, 0, 1, 12); AIC=462.977, BIC=484.969, Fit time=2.300 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(1, 0, 2, 12); AIC=463.632, BIC=488.766, Fit time=5.893 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(1, 0, 3, 12); AIC=463.772, BIC=492.047, Fit time=12.603 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(2, 0, 0, 12); AIC=471.716, BIC=493.708, Fit time=4.088 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(2, 0, 1, 12); AIC=464.374, BIC=489.507, Fit time=4.848 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(2, 0, 2, 12); AIC=466.072, BIC=494.347, Fit time=6.489 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(2, 0, 3, 12); AIC=465.298, BIC=496.715, Fit time=12.831 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(3, 0, 0, 12); AIC=463.597, BIC=488.731, Fit time=7.851 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(3, 0, 1, 12); AIC=463.543, BIC=491.818, Fit time=10.889 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(3, 0, 2, 12); AIC=465.719, BIC=497.136, Fit time=11.796 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(3, 0, 3, 12); AIC=467.554, BIC=502.112, Fit time=14.681 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(4, 0, 0, 12); AIC=463.707, BIC=491.982, Fit time=16.051 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(4, 0, 1, 12); AIC=465.529, BIC=496.946, Fit time=17.291 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(4, 0, 2, 12); AIC=467.526, BIC=502.084, Fit time=19.801 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(4, 0, 3, 12); AIC=469.381, BIC=507.081, Fit time=21.128 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 0, 0, 12); AIC=537.577, BIC=547.002, Fit time=0.082 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 0, 1, 12); AIC=522.303, BIC=534.869, Fit time=0.232 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 0, 2, 12); AIC=518.260, BIC=533.968, Fit time=0.634 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 0, 3, 12); AIC=510.223, BIC=529.073, Fit time=2.064 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 0, 0, 12); AIC=513.452, BIC=526.018, Fit time=0.230 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 0, 1, 12); AIC=492.138, BIC=507.847, Fit time=0.655 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 0, 2, 12); AIC=492.971, BIC=511.821, Fit time=1.501 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 0, 3, 12); AIC=491.785, BIC=513.777, Fit time=3.361 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(2, 0, 0, 12); AIC=504.908, BIC=520.616, Fit time=0.748 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(2, 0, 1, 12); AIC=493.443, BIC=512.293, Fit time=1.626 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(2, 0, 2, 12); AIC=496.028, BIC=518.019, Fit time=3.880 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(2, 0, 3, 12); AIC=493.620, BIC=518.753, Fit time=6.660 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(3, 0, 0, 12); AIC=495.011, BIC=513.861, Fit time=1.812 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(3, 0, 1, 12); AIC=492.784, BIC=514.776, Fit time=3.131 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(3, 0, 2, 12); AIC=493.524, BIC=518.657, Fit time=6.139 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(3, 0, 3, 12); AIC=495.473, BIC=523.748, Fit time=11.054 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(4, 0, 0, 12); AIC=492.531, BIC=514.523, Fit time=3.316 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(4, 0, 1, 12); AIC=494.338, BIC=519.471, Fit time=6.572 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(4, 0, 2, 12); AIC=496.338, BIC=524.613, Fit time=8.104 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(4, 0, 3, 12); AIC=497.375, BIC=528.792, Fit time=11.283 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 0, 0, 12); AIC=512.774, BIC=525.341, Fit time=0.791 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 0, 1, 12); AIC=494.186, BIC=509.894, Fit time=1.490 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 0, 2, 12); AIC=487.694, BIC=506.544, Fit time=4.219 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 0, 3, 12); AIC=477.382, BIC=499.373, Fit time=9.887 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 0, 0, 12); AIC=481.147, BIC=496.855, Fit time=1.748 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 0, 1, 12); AIC=459.331, BIC=478.181, Fit time=2.917 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 0, 2, 12); AIC=460.285, BIC=482.277, Fit time=3.974 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 0, 3, 12); AIC=461.658, BIC=486.791, Fit time=10.410 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 0, 0, 12); AIC=468.631, BIC=487.481, Fit time=4.210 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 0, 1, 12); AIC=460.379, BIC=482.371, Fit time=4.887 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 0, 2, 12); AIC=465.104, BIC=490.237, Fit time=6.054 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 0, 3, 12); AIC=462.792, BIC=491.067, Fit time=12.520 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(3, 0, 0, 12); AIC=460.266, BIC=482.257, Fit time=8.810 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(3, 0, 1, 12); AIC=460.734, BIC=485.867, Fit time=10.069 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(3, 0, 2, 12); AIC=463.257, BIC=491.532, Fit time=12.055 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(3, 0, 3, 12); AIC=465.986, BIC=497.402, Fit time=13.057 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(4, 0, 0, 12); AIC=460.788, BIC=485.922, Fit time=15.077 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(4, 0, 1, 12); AIC=462.688, BIC=490.963, Fit time=16.318 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(4, 0, 2, 12); AIC=464.709, BIC=496.125, Fit time=16.654 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(4, 0, 3, 12); AIC=466.683, BIC=501.241, Fit time=19.365 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 0, 0, 12); AIC=513.550, BIC=529.258, Fit time=1.073 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 0, 1, 12); AIC=495.948, BIC=514.798, Fit time=1.587 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 0, 2, 12); AIC=489.498, BIC=511.489, Fit time=4.607 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 0, 3, 12); AIC=479.256, BIC=504.389, Fit time=8.821 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 0, 0, 12); AIC=483.141, BIC=501.991, Fit time=1.741 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 0, 1, 12); AIC=461.155, BIC=483.146, Fit time=1.974 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 0, 2, 12); AIC=463.374, BIC=488.508, Fit time=5.279 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 0, 3, 12); AIC=464.190, BIC=492.465, Fit time=11.365 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 0, 0, 12); AIC=470.625, BIC=492.616, Fit time=4.865 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 0, 1, 12); AIC=463.518, BIC=488.652, Fit time=5.274 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 0, 2, 12); AIC=468.510, BIC=496.785, Fit time=6.335 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 0, 3, 12); AIC=464.672, BIC=496.089, Fit time=11.824 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(3, 0, 0, 12); AIC=462.162, BIC=487.295, Fit time=9.447 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(3, 0, 1, 12); AIC=463.215, BIC=491.490, Fit time=11.596 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(3, 0, 2, 12); AIC=466.471, BIC=497.887, Fit time=12.392 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(3, 0, 3, 12); AIC=467.478, BIC=502.037, Fit time=12.847 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(4, 0, 0, 12); AIC=462.503, BIC=490.778, Fit time=17.432 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(4, 0, 1, 12); AIC=464.473, BIC=495.889, Fit time=18.076 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(4, 0, 2, 12); AIC=467.180, BIC=501.738, Fit time=18.887 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(4, 0, 3, 12); AIC=470.174, BIC=507.874, Fit time=21.627 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(0, 0, 0, 12); AIC=513.884, BIC=532.734, Fit time=1.282 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(0, 0, 1, 12); AIC=497.791, BIC=519.783, Fit time=2.699 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(0, 0, 2, 12); AIC=491.514, BIC=516.648, Fit time=5.753 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(0, 0, 3, 12); AIC=483.291, BIC=511.566, Fit time=12.357 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(1, 0, 0, 12); AIC=488.664, BIC=510.656, Fit time=2.140 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(1, 0, 1, 12); AIC=464.963, BIC=490.096, Fit time=3.345 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(1, 0, 2, 12); AIC=465.904, BIC=494.179, Fit time=6.604 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(1, 0, 3, 12); AIC=467.699, BIC=499.115, Fit time=14.895 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(2, 0, 0, 12); AIC=473.629, BIC=498.762, Fit time=5.293 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(2, 0, 1, 12); AIC=466.186, BIC=494.461, Fit time=6.068 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(2, 0, 2, 12); AIC=469.439, BIC=500.856, Fit time=7.757 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(2, 0, 3, 12); AIC=466.922, BIC=501.481, Fit time=15.615 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(3, 0, 0, 12); AIC=465.437, BIC=493.712, Fit time=12.147 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(3, 0, 1, 12); AIC=465.597, BIC=497.013, Fit time=11.754 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(3, 0, 2, 12); AIC=467.614, BIC=502.172, Fit time=13.797 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(3, 0, 3, 12); AIC=469.657, BIC=507.357, Fit time=16.774 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(4, 0, 0, 12); AIC=465.497, BIC=496.914, Fit time=18.959 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(4, 0, 1, 12); AIC=466.601, BIC=501.160, Fit time=18.938 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(4, 0, 2, 12); AIC=469.408, BIC=507.108, Fit time=22.011 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(4, 0, 3, 12); AIC=471.560, BIC=512.402, Fit time=21.811 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(0, 0, 0, 12); AIC=539.426, BIC=551.993, Fit time=0.106 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(0, 0, 1, 12); AIC=521.102, BIC=536.810, Fit time=0.310 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(0, 0, 2, 12); AIC=515.068, BIC=533.918, Fit time=0.868 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(0, 0, 3, 12); AIC=505.489, BIC=527.481, Fit time=3.054 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(1, 0, 0, 12); AIC=505.486, BIC=521.194, Fit time=0.373 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(1, 0, 1, 12); AIC=480.141, BIC=498.991, Fit time=0.840 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(1, 0, 2, 12); AIC=481.687, BIC=503.679, Fit time=2.090 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(1, 0, 3, 12); AIC=479.999, BIC=505.132, Fit time=3.783 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(2, 0, 0, 12); AIC=494.153, BIC=513.003, Fit time=0.983 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(2, 0, 1, 12); AIC=481.881, BIC=503.873, Fit time=2.103 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(2, 0, 2, 12); AIC=483.817, BIC=508.950, Fit time=4.904 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(2, 0, 3, 12); AIC=481.756, BIC=510.031, Fit time=8.280 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(3, 0, 0, 12); AIC=482.739, BIC=504.730, Fit time=2.552 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(3, 0, 1, 12); AIC=481.047, BIC=506.181, Fit time=4.817 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(3, 0, 2, 12); AIC=481.490, BIC=509.765, Fit time=9.625 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(3, 0, 3, 12); AIC=482.702, BIC=514.119, Fit time=13.403 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(4, 0, 0, 12); AIC=480.904, BIC=506.038, Fit time=4.468 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(4, 0, 1, 12); AIC=482.713, BIC=510.988, Fit time=7.893 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(4, 0, 2, 12); AIC=483.358, BIC=514.775, Fit time=19.415 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(4, 0, 3, 12); AIC=485.330, BIC=519.888, Fit time=21.480 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(0, 0, 0, 12); AIC=512.949, BIC=528.658, Fit time=1.201 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(0, 0, 1, 12); AIC=495.900, BIC=514.750, Fit time=1.957 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(0, 0, 2, 12); AIC=489.483, BIC=511.474, Fit time=4.733 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(0, 0, 3, 12); AIC=479.213, BIC=504.346, Fit time=10.647 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(1, 0, 0, 12); AIC=483.140, BIC=501.990, Fit time=1.822 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(1, 0, 1, 12); AIC=462.207, BIC=484.199, Fit time=2.117 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(1, 0, 2, 12); AIC=462.751, BIC=487.884, Fit time=5.625 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(1, 0, 3, 12); AIC=463.618, BIC=491.893, Fit time=10.794 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(2, 0, 0, 12); AIC=470.616, BIC=492.607, Fit time=4.980 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(2, 0, 1, 12); AIC=462.561, BIC=487.694, Fit time=5.968 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(2, 0, 2, 12); AIC=467.903, BIC=496.178, Fit time=6.665 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(2, 0, 3, 12); AIC=464.619, BIC=496.036, Fit time=13.285 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(3, 0, 0, 12); AIC=461.938, BIC=487.071, Fit time=10.490 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(3, 0, 1, 12); AIC=462.787, BIC=491.062, Fit time=11.211 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(3, 0, 2, 12); AIC=464.964, BIC=496.381, Fit time=13.319 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(3, 0, 3, 12); AIC=467.561, BIC=502.120, Fit time=15.568 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(4, 0, 0, 12); AIC=462.655, BIC=490.929, Fit time=18.659 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(4, 0, 1, 12); AIC=464.586, BIC=496.003, Fit time=18.868 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(4, 0, 2, 12); AIC=466.772, BIC=501.330, Fit time=22.370 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(4, 0, 3, 12); AIC=469.329, BIC=507.029, Fit time=23.333 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 0, 0, 12); AIC=515.128, BIC=533.978, Fit time=1.833 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 0, 1, 12); AIC=497.894, BIC=519.886, Fit time=1.837 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 0, 2, 12); AIC=491.541, BIC=516.674, Fit time=4.120 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 0, 3, 12); AIC=481.187, BIC=509.462, Fit time=13.598 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 0, 0, 12); AIC=484.384, BIC=506.376, Fit time=2.274 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 0, 1, 12); AIC=462.678, BIC=487.811, Fit time=2.175 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 0, 2, 12); AIC=463.636, BIC=491.911, Fit time=6.061 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 0, 3, 12); AIC=464.345, BIC=495.762, Fit time=12.262 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(2, 0, 0, 12); AIC=472.591, BIC=497.725, Fit time=5.675 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(2, 0, 1, 12); AIC=463.260, BIC=491.535, Fit time=6.692 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(2, 0, 2, 12); AIC=467.340, BIC=498.756, Fit time=7.076 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(2, 0, 3, 12); AIC=466.247, BIC=500.805, Fit time=13.726 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(3, 0, 0, 12); AIC=463.399, BIC=491.674, Fit time=12.439 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(3, 0, 1, 12); AIC=463.772, BIC=495.188, Fit time=13.468 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(3, 0, 2, 12); AIC=466.769, BIC=501.327, Fit time=14.122 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(3, 0, 3, 12); AIC=468.481, BIC=506.181, Fit time=15.600 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(4, 0, 0, 12); AIC=463.403, BIC=494.820, Fit time=18.909 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(4, 0, 1, 12); AIC=465.980, BIC=500.538, Fit time=23.624 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(4, 0, 2, 12); AIC=467.454, BIC=505.153, Fit time=23.918 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(4, 0, 3, 12); AIC=470.386, BIC=511.227, Fit time=24.465 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(0, 0, 0, 12); AIC=513.828, BIC=535.820, Fit time=1.462 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(0, 0, 1, 12); AIC=499.233, BIC=524.366, Fit time=2.358 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(0, 0, 2, 12); AIC=493.040, BIC=521.315, Fit time=6.812 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(0, 0, 3, 12); AIC=482.605, BIC=514.022, Fit time=12.840 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(1, 0, 0, 12); AIC=487.131, BIC=512.265, Fit time=2.636 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(1, 0, 1, 12); AIC=464.216, BIC=492.491, Fit time=3.130 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(1, 0, 2, 12); AIC=465.217, BIC=496.633, Fit time=7.277 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(1, 0, 3, 12); AIC=466.239, BIC=500.797, Fit time=14.622 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(2, 0, 0, 12); AIC=474.517, BIC=502.792, Fit time=6.597 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(2, 0, 1, 12); AIC=465.376, BIC=496.793, Fit time=10.376 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(2, 0, 2, 12); AIC=469.412, BIC=503.970, Fit time=7.797 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(2, 0, 3, 12); AIC=468.401, BIC=506.101, Fit time=14.298 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(3, 0, 0, 12); AIC=465.586, BIC=497.003, Fit time=14.332 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(3, 0, 1, 12); AIC=465.845, BIC=500.403, Fit time=13.958 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(3, 0, 2, 12); AIC=468.929, BIC=506.629, Fit time=15.923 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(3, 0, 3, 12); AIC=469.911, BIC=510.752, Fit time=17.688 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(4, 0, 0, 12); AIC=465.472, BIC=500.030, Fit time=22.165 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(4, 0, 1, 12); AIC=467.653, BIC=505.353, Fit time=24.293 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(4, 0, 2, 12); AIC=469.736, BIC=510.578, Fit time=26.670 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(4, 0, 3, 12); AIC=471.758, BIC=515.741, Fit time=27.046 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(0, 0, 0, 12); AIC=541.389, BIC=557.097, Fit time=0.143 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(0, 0, 1, 12); AIC=523.074, BIC=541.924, Fit time=0.335 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(0, 0, 2, 12); AIC=516.191, BIC=538.183, Fit time=0.974 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(0, 0, 3, 12); AIC=505.751, BIC=530.885, Fit time=2.952 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(1, 0, 0, 12); AIC=505.612, BIC=524.462, Fit time=0.403 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(1, 0, 1, 12); AIC=474.695, BIC=496.687, Fit time=1.048 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(1, 0, 2, 12); AIC=475.658, BIC=500.791, Fit time=2.638 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(1, 0, 3, 12); AIC=475.719, BIC=503.994, Fit time=4.031 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(2, 0, 0, 12); AIC=489.316, BIC=511.308, Fit time=1.144 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(2, 0, 1, 12); AIC=475.996, BIC=501.129, Fit time=2.869 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(2, 0, 2, 12); AIC=478.638, BIC=506.913, Fit time=6.093 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(2, 0, 3, 12); AIC=477.593, BIC=509.010, Fit time=11.372 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(3, 0, 0, 12); AIC=478.288, BIC=503.421, Fit time=2.645 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(3, 0, 1, 12); AIC=476.333, BIC=504.608, Fit time=5.134 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(3, 0, 2, 12); AIC=477.497, BIC=508.914, Fit time=11.724 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(3, 0, 3, 12); AIC=479.662, BIC=514.220, Fit time=12.758 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(4, 0, 0, 12); AIC=476.574, BIC=504.849, Fit time=4.846 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(4, 0, 1, 12); AIC=478.179, BIC=509.596, Fit time=9.198 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(4, 0, 2, 12); AIC=479.508, BIC=514.066, Fit time=20.881 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(4, 0, 3, 12); AIC=481.495, BIC=519.195, Fit time=20.334 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(0, 0, 0, 12); AIC=509.494, BIC=528.344, Fit time=1.172 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(0, 0, 1, 12); AIC=497.147, BIC=519.139, Fit time=2.177 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(0, 0, 2, 12); AIC=491.349, BIC=516.483, Fit time=5.212 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(0, 0, 3, 12); AIC=481.225, BIC=509.500, Fit time=11.375 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(1, 0, 0, 12); AIC=484.756, BIC=506.747, Fit time=1.811 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(1, 0, 1, 12); AIC=471.050, BIC=496.183, Fit time=2.140 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(1, 0, 2, 12); AIC=472.592, BIC=500.867, Fit time=6.025 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(1, 0, 3, 12); AIC=470.865, BIC=502.282, Fit time=12.624 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(2, 0, 0, 12); AIC=471.914, BIC=497.047, Fit time=5.012 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(2, 0, 1, 12); AIC=467.901, BIC=496.176, Fit time=8.138 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(2, 0, 2, 12); AIC=467.981, BIC=499.397, Fit time=6.656 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(2, 0, 3, 12); AIC=465.769, BIC=500.327, Fit time=14.064 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(3, 0, 0, 12); AIC=462.438, BIC=490.713, Fit time=11.138 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(3, 0, 1, 12); AIC=467.159, BIC=498.575, Fit time=12.698 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(3, 0, 2, 12); AIC=472.505, BIC=507.063, Fit time=13.367 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(3, 0, 3, 12); AIC=468.172, BIC=505.872, Fit time=14.397 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(4, 0, 0, 12); AIC=463.305, BIC=494.722, Fit time=17.891 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(4, 0, 1, 12); AIC=465.530, BIC=500.089, Fit time=19.246 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(4, 0, 2, 12); AIC=470.093, BIC=507.793, Fit time=21.892 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(4, 0, 3, 12); AIC=474.811, BIC=515.652, Fit time=23.718 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(0, 0, 0, 12); AIC=512.923, BIC=534.915, Fit time=1.262 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(0, 0, 1, 12); AIC=499.184, BIC=524.317, Fit time=1.728 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(0, 0, 2, 12); AIC=493.073, BIC=521.348, Fit time=5.526 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(0, 0, 3, 12); AIC=482.719, BIC=514.136, Fit time=10.646 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(1, 0, 0, 12); AIC=487.152, BIC=512.285, Fit time=2.058 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(1, 0, 1, 12); AIC=464.607, BIC=492.882, Fit time=1.759 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(1, 0, 2, 12); AIC=465.444, BIC=496.861, Fit time=6.292 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(1, 0, 3, 12); AIC=466.298, BIC=500.856, Fit time=11.673 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(2, 0, 0, 12); AIC=474.546, BIC=502.821, Fit time=5.849 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(2, 0, 1, 12); AIC=465.168, BIC=496.585, Fit time=6.356 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(2, 0, 2, 12); AIC=470.197, BIC=504.755, Fit time=6.200 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(2, 0, 3, 12); AIC=468.127, BIC=505.827, Fit time=13.863 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(3, 0, 0, 12); AIC=465.504, BIC=496.921, Fit time=11.830 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(3, 0, 1, 12); AIC=465.536, BIC=500.094, Fit time=15.287 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(3, 0, 2, 12); AIC=468.764, BIC=506.464, Fit time=14.867 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(3, 0, 3, 12); AIC=470.097, BIC=510.938, Fit time=15.027 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(4, 0, 0, 12); AIC=465.993, BIC=500.551, Fit time=19.797 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(4, 0, 1, 12); AIC=468.200, BIC=505.900, Fit time=21.204 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(4, 0, 2, 12); AIC=470.161, BIC=511.002, Fit time=21.057 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(4, 0, 3, 12); AIC=472.054, BIC=516.037, Fit time=24.919 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(0, 0, 0, 12); AIC=517.156, BIC=542.289, Fit time=1.586 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(0, 0, 1, 12); AIC=497.378, BIC=525.653, Fit time=3.082 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(0, 0, 2, 12); AIC=492.054, BIC=523.471, Fit time=7.235 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(0, 0, 3, 12); AIC=481.832, BIC=516.390, Fit time=13.556 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(1, 0, 0, 12); AIC=483.670, BIC=511.945, Fit time=2.259 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(1, 0, 1, 12); AIC=464.671, BIC=496.088, Fit time=2.909 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(1, 0, 2, 12); AIC=465.996, BIC=500.555, Fit time=7.706 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(1, 0, 3, 12); AIC=467.654, BIC=505.354, Fit time=16.290 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(2, 0, 0, 12); AIC=471.797, BIC=503.213, Fit time=6.152 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(2, 0, 1, 12); AIC=465.681, BIC=500.239, Fit time=6.610 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(2, 0, 2, 12); AIC=470.627, BIC=508.327, Fit time=8.204 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(2, 0, 3, 12); AIC=470.075, BIC=510.916, Fit time=15.631 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(3, 0, 0, 12); AIC=464.774, BIC=499.333, Fit time=13.753 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(3, 0, 1, 12); AIC=466.856, BIC=504.556, Fit time=14.569 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(3, 0, 2, 12); AIC=470.551, BIC=511.393, Fit time=14.461 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(3, 0, 3, 12); AIC=472.040, BIC=516.023, Fit time=18.471 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(4, 0, 0, 12); AIC=465.761, BIC=503.461, Fit time=23.484 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(4, 0, 1, 12); AIC=468.411, BIC=509.253, Fit time=25.987 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(4, 0, 2, 12); AIC=471.401, BIC=515.384, Fit time=27.732 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(4, 0, 3, 12); AIC=474.198, BIC=521.322, Fit time=28.002 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(0, 0, 0, 12); AIC=542.901, BIC=561.750, Fit time=0.184 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(0, 0, 1, 12); AIC=524.982, BIC=546.974, Fit time=0.407 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(0, 0, 2, 12); AIC=518.080, BIC=543.214, Fit time=1.104 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(0, 0, 3, 12); AIC=507.743, BIC=536.018, Fit time=3.395 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(1, 0, 0, 12); AIC=507.347, BIC=529.338, Fit time=0.643 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(1, 0, 1, 12); AIC=476.260, BIC=501.393, Fit time=1.497 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(1, 0, 2, 12); AIC=477.334, BIC=505.609, Fit time=3.218 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(1, 0, 3, 12); AIC=477.525, BIC=508.941, Fit time=5.791 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(2, 0, 0, 12); AIC=490.658, BIC=515.792, Fit time=1.617 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(2, 0, 1, 12); AIC=477.624, BIC=505.899, Fit time=3.488 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(2, 0, 2, 12); AIC=480.167, BIC=511.584, Fit time=7.334 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(2, 0, 3, 12); AIC=479.381, BIC=513.940, Fit time=12.594 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(3, 0, 0, 12); AIC=480.096, BIC=508.371, Fit time=3.370 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(3, 0, 1, 12); AIC=478.132, BIC=509.548, Fit time=6.828 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(3, 0, 2, 12); AIC=479.258, BIC=513.816, Fit time=15.913 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(3, 0, 3, 12); AIC=481.418, BIC=519.118, Fit time=16.781 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(4, 0, 0, 12); AIC=478.395, BIC=509.812, Fit time=6.251 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(4, 0, 1, 12); AIC=479.970, BIC=514.528, Fit time=11.123 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(4, 0, 2, 12); AIC=481.049, BIC=518.749, Fit time=25.739 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(4, 0, 3, 12); AIC=483.160, BIC=524.002, Fit time=36.904 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(0, 0, 0, 12); AIC=502.139, BIC=524.130, Fit time=3.643 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(0, 0, 1, 12); AIC=492.877, BIC=518.011, Fit time=3.286 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(0, 0, 2, 12); AIC=490.641, BIC=518.916, Fit time=6.400 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(0, 0, 3, 12); AIC=481.932, BIC=513.349, Fit time=13.987 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(1, 0, 0, 12); AIC=485.804, BIC=510.937, Fit time=2.648 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(1, 0, 1, 12); AIC=471.706, BIC=499.981, Fit time=3.760 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(1, 0, 2, 12); AIC=474.907, BIC=506.324, Fit time=6.775 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(1, 0, 3, 12); AIC=473.297, BIC=507.855, Fit time=15.430 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(2, 0, 0, 12); AIC=473.425, BIC=501.700, Fit time=7.026 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(2, 0, 1, 12); AIC=470.409, BIC=501.825, Fit time=7.716 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(2, 0, 2, 12); AIC=472.330, BIC=506.889, Fit time=8.333 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(2, 0, 3, 12); AIC=471.832, BIC=509.532, Fit time=17.231 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(3, 0, 0, 12); AIC=464.734, BIC=496.150, Fit time=17.125 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(3, 0, 1, 12); AIC=469.225, BIC=503.783, Fit time=17.087 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(3, 0, 2, 12); AIC=473.878, BIC=511.578, Fit time=19.046 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(3, 0, 3, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(4, 0, 0, 12); AIC=464.741, BIC=499.299, Fit time=24.624 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(4, 0, 1, 12); AIC=467.238, BIC=504.938, Fit time=25.359 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(4, 0, 2, 12); AIC=472.189, BIC=513.030, Fit time=28.942 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(4, 0, 3, 12); AIC=476.859, BIC=520.842, Fit time=28.678 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(0, 0, 0, 12); AIC=512.144, BIC=537.277, Fit time=1.565 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(0, 0, 1, 12); AIC=500.795, BIC=529.070, Fit time=2.591 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(0, 0, 2, 12); AIC=494.998, BIC=526.414, Fit time=6.639 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(0, 0, 3, 12); AIC=484.647, BIC=519.205, Fit time=12.399 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(1, 0, 0, 12); AIC=488.757, BIC=517.032, Fit time=3.339 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(1, 0, 1, 12); AIC=462.318, BIC=493.734, Fit time=5.162 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(1, 0, 2, 12); AIC=463.145, BIC=497.704, Fit time=8.582 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(1, 0, 3, 12); AIC=463.965, BIC=501.665, Fit time=28.374 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(2, 0, 0, 12); AIC=475.151, BIC=506.567, Fit time=7.510 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(2, 0, 1, 12); AIC=463.755, BIC=498.314, Fit time=8.206 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(2, 0, 2, 12); AIC=468.075, BIC=505.775, Fit time=9.850 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(2, 0, 3, 12); AIC=467.019, BIC=507.860, Fit time=16.704 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(3, 0, 0, 12); AIC=464.663, BIC=499.221, Fit time=14.456 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(3, 0, 1, 12); AIC=463.871, BIC=501.571, Fit time=15.797 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(3, 0, 2, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(3, 0, 3, 12); AIC=468.586, BIC=512.569, Fit time=19.617 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(4, 0, 0, 12); AIC=463.634, BIC=501.333, Fit time=25.148 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(4, 0, 1, 12); AIC=465.304, BIC=506.146, Fit time=26.389 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(4, 0, 2, 12); AIC=467.901, BIC=511.884, Fit time=26.251 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(4, 0, 3, 12); AIC=470.007, BIC=517.132, Fit time=28.049 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(0, 0, 0, 12); AIC=519.704, BIC=547.979, Fit time=1.995 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(0, 0, 1, 12); AIC=499.231, BIC=530.648, Fit time=3.463 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(0, 0, 2, 12); AIC=493.764, BIC=528.322, Fit time=7.655 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(0, 0, 3, 12); AIC=483.829, BIC=521.529, Fit time=17.098 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(1, 0, 0, 12); AIC=484.191, BIC=515.608, Fit time=3.495 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(1, 0, 1, 12); AIC=463.628, BIC=498.186, Fit time=3.761 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(1, 0, 2, 12); AIC=465.653, BIC=503.353, Fit time=8.573 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(1, 0, 3, 12); AIC=466.356, BIC=507.198, Fit time=17.039 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(2, 0, 0, 12); AIC=473.897, BIC=508.455, Fit time=8.149 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(2, 0, 1, 12); AIC=465.584, BIC=503.284, Fit time=9.326 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(2, 0, 2, 12); AIC=468.934, BIC=509.776, Fit time=10.197 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(2, 0, 3, 12); AIC=468.709, BIC=512.692, Fit time=20.170 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(3, 0, 0, 12); AIC=465.963, BIC=503.663, Fit time=16.553 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(3, 0, 1, 12); AIC=465.952, BIC=506.793, Fit time=19.258 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(3, 0, 2, 12); AIC=468.509, BIC=512.492, Fit time=20.456 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(3, 0, 3, 12); AIC=470.411, BIC=517.536, Fit time=21.261 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(4, 0, 0, 12); AIC=465.925, BIC=506.767, Fit time=26.436 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(4, 0, 1, 12); AIC=467.895, BIC=511.878, Fit time=28.275 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(4, 0, 2, 12); AIC=469.817, BIC=516.942, Fit time=31.529 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(4, 0, 3, 12); AIC=471.988, BIC=522.255, Fit time=32.226 seconds
# Total fit time: 3821.424 seconds

# %%
# Summarize residual errors for the automated grid search ARIMA model
print(autogrid_results.summary())
autogrid_results.plot_diagnostics(figsize=(12,12))
plt.show()
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  172
# Model:             SARIMAX(1, 1, 1)x(1, 0, 1, 12)   Log Likelihood                -223.666
# Date:                            Tue, 28 Jan 2020   AIC                            459.331
# Time:                                    04:48:20   BIC                            478.181
# Sample:                                         0   HQIC                           466.980
#                                             - 172
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -0.0002      0.000     -0.564      0.573      -0.001       0.001
# ar.L1          0.3628      0.080      4.512      0.000       0.205       0.520
# ma.L1         -0.9503      0.032    -29.959      0.000      -1.012      -0.888
# ar.S.L12       0.9703      0.027     36.370      0.000       0.918       1.023
# ma.S.L12      -0.7560      0.103     -7.369      0.000      -0.957      -0.555
# sigma2         0.7406      0.081      9.094      0.000       0.581       0.900
# ===================================================================================
# Ljung-Box (Q):                       35.36   Jarque-Bera (JB):                 2.12
# Prob(Q):                              0.68   Prob(JB):                         0.35
# Heteroskedasticity (H):               0.44   Skew:                             0.25
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.22
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
if (notifyStatus): email_notify("ARIMA automated grid search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Not applicable for this iteration of the project

# Set up the function to handle the ARIMA calculation
# def Calculate_ARIMA(ns_order, ss_order):
#     startTimeModel = datetime.now()
#     aic_score, bic_score = float("inf"), float("inf")
#     if (verbose): print('Trying to fit the model with parameters:', ns_order, ss_order)
#     try:
#         if (ss_order[3] == 0): grid_model = SARIMAX(train_ts, order=ns_order)
#         else: grid_model = SARIMAX(train_ts, order=ns_order, seasonal_order=ss_order)
#         with warnings.catch_warnings():
#             warnings.simplefilter("ignore")
#             grid_results = grid_model.fit(disp = False)
#         aic_score = grid_results.aic
#         bic_score = grid_results.bic
#         if (verbose): print('Fit ARIMA: order=%s seasonal_order=%s; AIC=%.3f, BIC=%.3f, Fit time=%s' % 
#               (ns_order, ss_order, aic_score, bic_score, (datetime.now() - startTimeModel)))
#         return(aic_score, bic_score)
#     except:
#         return(float("inf"), float("inf"))

# %%
# Not applicable for this iteration of the project

# Do a manual grid search of ARIMA parameters
# best_score, best_ns_cfg, best_ss_cfg = float("inf"), None, None
# for p in range(start_p, max_p+1):
#     for d in range(start_d, max_d+1):
#         for q in range(start_q, max_q+1):
#             for P in range(start_P, max_P+1):
#                 for D in range(start_D, max_D+1):
#                     for Q in range(start_Q, max_Q+1):
#                         ns_order = (p, d, q)
#                         ss_order = (P, D, Q, seasonal_freq)
#                         aic_score, bic_score = Calculate_ARIMA(ns_order, ss_order)
#                         if (aic_score < best_score):
#                             best_ns_cfg, best_ss_cfg, best_score = ns_order, ss_order, aic_score
#                             print('A better model found: order=%s seasonal_order=%s; AIC=%.3f, BIC=%.3f' % (ns_order, ss_order, aic_score, bic_score))
# print('Best ARIMA model via manual search: order=%s seasonal_order=%s; AIC=%f' % (best_ns_cfg, best_ss_cfg, best_score))

# %%
# Summarize residual errors for the manual ARIMA model
# manual_model = SARIMAX(train_ts, order=best_ns_cfg, seasonal_order=best_ss_cfg)
# manual_results = manual_model.fit(disp = False)
# print(manual_results.summary())
# manual_results.plot_diagnostics(figsize=(12,12))
# plt.show()

# %%
if (notifyStatus): email_notify("ARIMA Hyperparameters Search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 4.c) Evaluate the Residual Errors
#
# A good final check of a model is to review residual forecast errors. Ideally, the distribution of residual errors should be a Gaussian with a zero mean.

# %%
# Set the ARIMA order parameters for validation and forecasting
final_ns_order = stepwise_results.order
# final_ns_order = randgrid_results.order
# final_ns_order = autogrid_results.order
# final_ns_order = best_ns_cfg
if (seasonal_freq != 0):
    final_ss_order = stepwise_results.seasonal_order
#     final_ss_order = randgrid_results.seasonal_order
#     final_ss_order = autogrid_results.seasonal_order
#     final_ss_order = best_ss_cfg
    print("Final Non-season order:", final_ns_order, 'Final Seasonal Order:', final_ss_order)
else:
    print("Final Non-season order:", final_ns_order)
# Out:
# Final Non-season order: (1, 1, 1) Final Seasonal Order: (1, 0, 1, 12)

# %%
# Summarize residual errors for the final ARIMA model
if (seasonal_freq != 0):
    final_model = SARIMAX(time_series, order=final_ns_order, seasonal_order=final_ss_order)
else:
    final_model = SARIMAX(time_series, order=final_ns_order)
final_results = final_model.fit(disp = False)
print(final_results.summary())
final_results.plot_diagnostics(figsize=(12,12))
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                             values   No. Observations:                  216
# Model:             SARIMAX(1, 1, 1)x(1, 0, 1, 12)   Log Likelihood                -266.545
# Date:                            Tue, 28 Jan 2020   AIC                            543.090
# Time:                                    04:48:27   BIC                            559.943
# Sample:                                01-01-1955   HQIC                           549.899
#                                      - 12-01-1972
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3536      0.069      5.111      0.000       0.218       0.489
# ma.L1         -0.9491      0.026    -36.495      0.000      -1.000      -0.898
# ar.S.L12       0.9633      0.025     38.216      0.000       0.914       1.013
# ma.S.L12      -0.7279      0.088     -8.271      0.000      -0.900      -0.555
# sigma2         0.6584      0.061     10.774      0.000       0.539       0.778
# ===================================================================================
# Ljung-Box (Q):                       39.81   Jarque-Bera (JB):                 4.54
# Prob(Q):                              0.48   Prob(JB):                         0.10
# Heteroskedasticity (H):               0.33   Skew:                             0.28
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.43
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
if (notifyStatus): email_notify("Model Fitting and Evaluation completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 5. Finalize Model
#
# After models have been developed and a final model selected, it must be validated and finalized. Validation is an optional part of the process, but one that provides a ‘last check’ to ensure we have not fooled or lied to ourselves.

# %%
if (notifyStatus): email_notify("Model Finalization has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 5.a) Validation via In-sample Data

# %%
validate_forecast = final_results.get_prediction(start = -test_size)
mean_validate_forecast = validate_forecast.predicted_mean
validate_confidence_intervals = validate_forecast.conf_int()

# Because some predicted values turned out to be negative, we will need to set those values to 0
print(mean_validate_forecast[mean_validate_forecast < 0])
mean_validate_forecast[mean_validate_forecast < 0] = 0
# Out:
# Series([], Freq: MS, dtype: float64)

# %%
plt.figure(figsize=(12,9))
plt.plot(time_series.index, time_series[target_col], label='observed')
plt.plot(mean_validate_forecast.index, mean_validate_forecast.values, color='red', label='forecast')
plt.fill_between(validate_confidence_intervals.index, validate_confidence_intervals[lower_bound], 
                 validate_confidence_intervals[upper_bound], color='pink')
plt.show()

# %%
# Evaluate RMSE for the validation data
y_test = time_series[-test_size:]
predictions = mean_validate_forecast.values
for i in range(y_test.shape[0]):
    print(y_test.index[i], ' | ', y_test.iloc[i,0], ' | ', predictions[i])
print('RMSE from the validation data is: %.3f' % math.sqrt(mean_squared_error(y_test, predictions)))
# Out:
# 1969-05-01 00:00:00  |  4.4  |  3.4060570400690997
# 1969-06-01 00:00:00  |  3.4  |  4.2316800036663285
# 1969-07-01 00:00:00  |  3.9  |  4.447011091814389
# 1969-08-01 00:00:00  |  5.5  |  4.194336565823847
# 1969-09-01 00:00:00  |  3.8  |  4.6617241831355445
# 1969-10-01 00:00:00  |  3.2  |  4.083811906336923
# 1969-11-01 00:00:00  |  2.3  |  2.399809158205223
# 1969-12-01 00:00:00  |  2.2  |  1.6499771278565931
# 1970-01-01 00:00:00  |  1.3  |  2.0185246434729476
# 1970-02-01 00:00:00  |  2.3  |  1.8867299865280485
# 1970-03-01 00:00:00  |  2.7  |  2.691136691093577
# 1970-04-01 00:00:00  |  3.3  |  3.010431644325967
# 1970-05-01 00:00:00  |  3.7  |  3.604014010389928
# 1970-06-01 00:00:00  |  3.0  |  3.6702947663371868
# 1970-07-01 00:00:00  |  3.8  |  4.034564716243273
# 1970-08-01 00:00:00  |  4.7  |  4.348220660529833
# 1970-09-01 00:00:00  |  4.6  |  4.030952769521691
# 1970-10-01 00:00:00  |  2.9  |  4.0736189985505815
# 1970-11-01 00:00:00  |  1.7  |  2.212231631602487
# 1970-12-01 00:00:00  |  1.3  |  1.5027654537296806
# 1971-01-01 00:00:00  |  1.8  |  1.4210704019017404
# 1971-02-01 00:00:00  |  2.0  |  2.0898210209171753
# 1971-03-01 00:00:00  |  2.2  |  2.4797438926180706
# 1971-04-01 00:00:00  |  3.0  |  2.7733167059946497
# 1971-05-01 00:00:00  |  2.4  |  3.3788655317005363
# 1971-06-01 00:00:00  |  3.5  |  2.860541324248958
# 1971-07-01 00:00:00  |  3.5  |  3.9987914919953873
# 1971-08-01 00:00:00  |  3.3  |  4.149795779753339
# 1971-09-01 00:00:00  |  2.7  |  3.461746810749648
# 1971-10-01 00:00:00  |  2.5  |  2.854645818160402
# 1971-11-01 00:00:00  |  1.6  |  1.7509663946729437
# 1971-12-01 00:00:00  |  1.2  |  1.2421765894819634
# 1972-01-01 00:00:00  |  1.5  |  1.3005947722099553
# 1972-02-01 00:00:00  |  2.0  |  1.7663539055501802
# 1972-03-01 00:00:00  |  3.1  |  2.2211591485309303
# 1972-04-01 00:00:00  |  3.0  |  2.9991011441014344
# 1972-05-01 00:00:00  |  3.5  |  2.9824468993424804
# 1972-06-01 00:00:00  |  3.4  |  3.307870255116848
# 1972-07-01 00:00:00  |  4.0  |  3.7073954691439086
# 1972-08-01 00:00:00  |  3.8  |  4.015755473114687
# 1972-09-01 00:00:00  |  3.1  |  3.3915723646763007
# 1972-10-01 00:00:00  |  2.1  |  2.8728136741060384
# 1972-11-01 00:00:00  |  1.6  |  1.5458954197766293
# 1972-12-01 00:00:00  |  1.3  |  1.2194810767272495
# RMSE from the validation data is: 0.569

# %% [markdown]
# ### 5.b) Forecasting Out-of-Sample Data

# %%
final_forecast = final_results.get_forecast(steps = test_size)
mean_final_forecast = final_forecast.predicted_mean
final_confidence_intervals = final_forecast.conf_int()

# Because some predicted values turned out to be negative, we will need to set those values to 0
print(mean_final_forecast[mean_final_forecast < 0])
mean_final_forecast[mean_final_forecast < 0] = 0
print("The forecasted values are:\n\n", mean_final_forecast)
# Out:
# Series([], Freq: MS, dtype: float64)
# The forecasted values are:
#
#  1973-01-01    1.368464
# 1973-02-01    1.739841
# 1973-03-01    2.282203
# 1973-04-01    2.609477
# 1973-05-01    2.864802
# 1973-06-01    2.978941
# 1973-07-01    3.482016
# 1973-08-01    3.622066
# 1973-09-01    3.128553
# 1973-10-01    2.590263
# 1973-11-01    1.685575
# 1973-12-01    1.225771
# 1974-01-01    1.286963
# 1974-02-01    1.643041
# 1974-03-01    2.164924
# 1974-04-01    2.479990
# 1974-05-01    2.725880
# 1974-06-01    2.835808
# 1974-07-01    3.320431
# 1974-08-01    3.455342
# 1974-09-01    2.979921
# 1974-10-01    2.461365
# 1974-11-01    1.589844
# 1974-12-01    1.146897
# 1975-01-01    1.205844
# 1975-02-01    1.548869
# 1975-03-01    2.051619
# 1975-04-01    2.355134
# 1975-05-01    2.592010
# 1975-06-01    2.697907
# 1975-07-01    3.164764
# 1975-08-01    3.294730
# 1975-09-01    2.836738
# 1975-10-01    2.337192
# 1975-11-01    1.497621
# 1975-12-01    1.070913
# 1976-01-01    1.127700
# 1976-02-01    1.458149
# 1976-03-01    1.942468
# 1976-04-01    2.234856
# 1976-05-01    2.463048
# 1976-06-01    2.565063
# 1976-07-01    3.014804
# 1976-08-01    3.140005
# Freq: MS, dtype: float64

# %%
plt.figure(figsize=(12,9))
plt.plot(time_series.index, time_series[target_col], label='observed')
plt.plot(mean_final_forecast.index, mean_final_forecast.values, color='red', label='forecast')
plt.fill_between(final_confidence_intervals.index, final_confidence_intervals[lower_bound], 
                 final_confidence_intervals[upper_bound], color='pink')
plt.show()

# %%
if (notifyStatus): email_notify("Model Finalization completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
print ('Total time for the script:',(datetime.now() - startTimeScript))
# Out:
# Total time for the script: 1:20:11.543648
