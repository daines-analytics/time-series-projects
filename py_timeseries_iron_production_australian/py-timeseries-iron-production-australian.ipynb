# %% [markdown]
# # Time Series Model for Iron Production in Australia Using Python
# ### David Lowe
# ### November 20, 2019
#
# Template Credit: Adapted from a template made available by Dr. Jason Brownlee of Machine Learning Mastery. https://machinelearningmastery.com/
#
# SUMMARY: The purpose of this project is to construct a time series prediction model and document the end-to-end steps using a template. The Iron Production in Australia dataset is a time series situation where we are trying to forecast future outcomes based on past data points.
#
# INTRODUCTION: The problem is to forecast the monthly basic iron production in Australia. The dataset describes a time-series of weight (in thousand tons) over 40 years (1956-1995), and there are 476 observations. We used the first 80% of the observations for training and testing various models while holding back the remaining observations for validating the final model.
#
# ANALYSIS: The baseline prediction (or persistence) for the dataset resulted in an RMSE of 41.096. After performing a grid search for the most optimal ARIMA parameters, the final ARIMA non-seasonal order was (1, 1, 1) with the seasonal order being (1, 0, 1, 12). Furthermore, the chosen model processed the validation data with an RMSE of 34.639, which was better than the baseline model as expected.
#
# CONCLUSION: For this dataset, the chosen ARIMA model achieved a satisfactory result and should be considered for further modeling.
#
# Dataset Used: Monthly basic iron production in Australia January 1956 through August 1995
#
# Dataset ML Model: Time series forecast with numerical attributes
#
# Dataset Reference: Rob Hyndman and Yangzhuoran Yang (2018). tsdl: Time Series Data Library. v0.1.0. https://pkg.yangzhuoranyang./tsdl/.
#
# The project aims to touch on the following areas:
#
# * Document a predictive modeling problem end-to-end
# * Explore data cleaning and transformation options
# * Explore various algorithms for baselining the model performance
# * Explore tuning techniques for improving the model performance
#
# A time series predictive modeling project genrally can be broken down into about five major tasks:
#
# 1. Define Problem and Acquire Data
# 2. Inspect and Explore Data
# 3. Clean and Pre-Process Data
# 4. Fit and Evaluate Models
# 5. Finalize Model

# %% [markdown]
# ## Section 1. Define Problem and Acquire Data

# %% [markdown]
# ### 1.a) Load Libraries

# %%
# Set the warning message filter
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import math
import smtplib
import pmdarima as pm
from datetime import datetime
from email.message import EmailMessage
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %% [markdown]
# ### 1.b) Set up the controlling parameters and functions

# %%
# Create the random seed number for reproducible results
seedNum = 888

# Set up the number of CPU cores available for multi-thread processing
n_jobs = 1

# Set up the verbose flag to print detailed messages for debugging (setting True will activate!)
verbose = False

# Set up the flag to stop sending progress emails (setting to True will send status emails!)
notifyStatus = False

# %%
# Set up the email notification function
def email_notify(msg_text):
    sender = os.environ.get('MAIL_SENDER')
    receiver = os.environ.get('MAIL_RECEIVER')
    gateway = os.environ.get('SMTP_GATEWAY')
    smtpuser = os.environ.get('SMTP_USERNAME')
    password = os.environ.get('SMTP_PASSWORD')
    if sender==None or receiver==None or gateway==None or smtpuser==None or password==None:
        sys.exit("Incomplete email setup info. Script Processing Aborted!!!")
    msg = EmailMessage()
    msg.set_content(msg_text)
    msg['Subject'] = 'Notification from Python ARIMA Time Series Script'
    msg['From'] = sender
    msg['To'] = receiver
    server = smtplib.SMTP(gateway, 587)
    server.starttls()
    server.login(smtpuser, password)
    server.send_message(msg)
    server.quit()

# %%
if (notifyStatus): email_notify("Library and Data Loading has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 1.c) Acquire and Load the Data
#
# Since the dataset is not current, this means that we cannot easily collect updated data to validate the model. Therefore, we will withhold a portion of the data towards the end from analysis and model selection. This very segment of data will be used to validate the final model.

# %%
startTimeScript = datetime.now()

# %%
# load the dataset and the necessary data structure
time_series = pd.read_csv('https://github.com/daines-analytics/datasets-public/raw/master/time-series-data-library/tsdl096.csv', index_col='idx', parse_dates=True)

# Sample code for subsetting the time-series data
# time_series = original_series['1986':'1990']

# %%
target_col = time_series.columns[0]
lower_bound = 'lower ' + target_col
upper_bound = 'upper ' + target_col
print('The target column of the time series is:', target_col)
print('The forecast boundary columns are:', lower_bound, '&', upper_bound)
# Out:
# The target column of the time series is: values
# The forecast boundary columns are: lower values & upper values

# %%
time_series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 476 entries, 1956-01-01 to 1995-08-01
# Data columns (total 1 columns):
# values    476 non-null int64
# dtypes: int64(1)
# memory usage: 7.4 KB

# %%
time_series.head(10)
# Out:
#             values
# idx
# 1956-01-01     172
# 1956-02-01     166
# 1956-03-01     175
# 1956-04-01     171
# 1956-05-01     184
# 1956-06-01     175
# 1956-07-01     183
# 1956-08-01     154
# 1956-09-01     182
# 1956-10-01     161

# %%
time_series.tail(10)
# Out:
#             values
# idx
# 1994-11-01     627
# 1994-12-01     590
# 1995-01-01     637
# 1995-02-01     563
# 1995-03-01     634
# 1995-04-01     605
# 1995-05-01     619
# 1995-06-01     595
# 1995-07-01     625
# 1995-08-01     657

# %%
if (notifyStatus): email_notify("Library and Data Loading completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 2. Inspect and Explore Data

# %%
if (notifyStatus): email_notify("Data Inspection and Exploration has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 2.a) Summary Statistics of the Time Series Data
#
# Summary statistics provide a quick look at the limits of observed values. It can help to get a quick idea of what we are working with.

# %%
# Summary statistics of time series
print(time_series.describe())
# Out:
#            values
# count  476.000000
# mean   460.313025
# std    142.790921
# min    154.000000
# 25%    363.250000
# 50%    489.500000
# 75%    567.000000
# max    711.000000

# %% [markdown]
# ### 2.b) Line Plot of the Time Series Data
#
# A line plot of a time series can provide a lot of insight into the problem. Some observations from the plot can include:
#
# * Whether the trend appears to be level around the mean
# * Whether there appear to be any obvious outliers
#
# The ARIMA(p,d,q) model requires three parameters and assumes that we are working with a stationary time series.
#
# The ADF results should show that the test statistic value is smaller than the critical value at 5% if the time series is stationary. This suggests that we can reject the null hypothesis (i.e. a low probability that the result is a statistical fluke).

# %%
# Line plots of time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Time Series Data')
time_series.plot(ax=ax)
plt.show()

# %% [markdown]
# ### 2.c) Histogram and Density Plots of the Time Series Data
#
# Reviewing plots of the density of observations can provide further insight into the structure of the data. Some observations from the plots can include:
#
# * Whether the distribution is Gaussian
# * Whether the distribution has a long tail and may suggest the need for data transformation

# %%
# Line plots of time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Histogram of the Time Series Data')
time_series.hist(ax=ax)
plt.show()

# %%
# Line plots of time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Density Plot of the Time Series Data')
time_series.plot(kind='kde', ax=ax)
plt.show()

# %% [markdown]
# ### 2.d) Box and Whisker Plots of the Time Series Data
#
# We can group or aggregate the data and get a better idea of the spread of observations. Some observations from reviewing the plot can include:
#
# * Whether the median values for each grouping shows any significant trend
# * Whether the spread, or middle 50% of the data, shows any significant variability
# * Whether there are outliers in some grouping

# %%
# boxplots of time series
fig, ax = plt.subplots(figsize=(12,9))
squeezed = time_series.squeeze()
sns.boxplot(squeezed.index.year, squeezed, ax=ax)
plt.show()

# %%
if (notifyStatus): email_notify("Data Inspection and Exploration completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 3. Data Transformation and Stationarity Tests

# %%
if (notifyStatus): email_notify("Data Cleaning and Pre-Processing has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### Section 3.a) Data Transformation

# %%
# Resampling the time series into monthly average for the ease of modeling
# original_series = time_series
# resample = original_series.resample('M')
# time_series = resample.mean()
# time_series.head(10)

# %%
# Line plots of the transformed time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Non-Seasonal Time Series Data')
time_series.plot(ax=ax)
plt.show()

# %% [markdown]
# ### Section 3.b) Test for Stationarity

# %%
# Check if stationary
result = adfuller(time_series[target_col])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Test Statistics Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -1.773329
# p-value: 0.393781
# Critical Test Statistics Values:
# 	1%: -3.445
# 	5%: -2.868
# 	10%: -2.570

# %%
# ACF and PACF plots of the time series data
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))
plot_acf(time_series, ax=ax1)
plot_pacf(time_series, ax=ax2)
plt.show()

# %% [markdown]
# ### 3.c) Test for Stationarity of Non-Seasonal Time Series Data
#
# Occasionally a time series may look non-stationary on the first look. We can make it stationary by differencing the series and using a statistical test to confirm that the differenced result is stationary. Rejecting the null hypothesis means that the process has no unit root, and in turn that the time series is stationary or does not have time-dependent structure.

# %%
# Create a differenced series
stationary_ns = time_series.diff().dropna()

# Plot differenced data
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Stationary Time Series Data')
stationary_ns.plot(ax=ax)
plt.show()

# %%
# Check for stationarity
result = adfuller(stationary_ns[target_col])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Test Statistics Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -8.620878
# p-value: 0.000000
# Critical Test Statistics Values:
# 	1%: -3.445
# 	5%: -2.868
# 	10%: -2.570

# %%
# ACF and PACF plots of the stationary time series
lags = 25
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))
plot_acf(stationary_ns, lags=lags, ax=ax1)
plot_pacf(stationary_ns, lags=lags, ax=ax2)
plt.show()

# %% [markdown]
# ### 3.d) Seasonal Decomposition for Seasonal Time Series Data

# %%
# Set the initial seasonal frequency parameter
seasonal_freq = 12

# %%
# Perform seasonal decomposition to observe the seasonal frequency
decomp_results = seasonal_decompose(time_series, freq=seasonal_freq)
decomp_results.plot()
plt.show()

# %%
# Create a seasonal series
N = seasonal_freq
seasonal_series = time_series - time_series.rolling(N).mean()
seasonal_series = seasonal_series.dropna()

# Line plots of the seasonal time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Seasonal Time Series Data')
seasonal_series.plot(ax=ax)
plt.show()

# %%
# Check for stationarity
result = adfuller(seasonal_series[target_col])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Test Statistics Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -5.234041
# p-value: 0.000007
# Critical Test Statistics Values:
# 	1%: -3.445
# 	5%: -2.868
# 	10%: -2.570

# %%
# ACF and PACF plots of the time series data
lag = seasonal_freq * 2
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))
plot_acf(seasonal_series, lags=lag, ax=ax1)
plot_pacf(seasonal_series, lags=lag, ax=ax2)
plt.show()

# %% [markdown]
# ### 3.e) Test for Stationarity of Seasonal Time Series Data
#
# Occasionally a time series may look non-stationary on the first look. We can make it stationary by differencing the series and using a statistical test to confirm that the differenced result is stationary. Rejecting the null hypothesis means that the process has no unit root, and in turn that the time series is stationary or does not have time-dependent structure.

# %%
# Create a differenced series
stationary_ss = time_series.diff(seasonal_freq).dropna()

# Plot differenced data
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Stationary Seasonal Time Series Data')
stationary_ss.plot(ax=ax)
plt.show()

# %%
# Check for stationarity
result = adfuller(stationary_ss[target_col])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Test Statistics Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -4.685303
# p-value: 0.000090
# Critical Test Statistics Values:
# 	1%: -3.445
# 	5%: -2.868
# 	10%: -2.570

# %%
# ACF and PACF plots of the stationary time series
lags = seasonal_freq * 2
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))
plot_acf(stationary_ss, lags=lags, ax=ax1)
plot_pacf(stationary_ss, lags=lags, ax=ax2)
plt.show()

# %%
if (notifyStatus): email_notify("Data Cleaning and Pre-Processing completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 4. Fit and Evaluate Models
#
# In this section, we will develop Autoregressive Integrated Moving Average or ARIMA models for the problem. We will first establish a persistent model. Next we will use a grid search approach to look for an optimal ARIMA model. This will be followed by a third step of investigating the residual errors of the chosen model.
#
# * Establish the Persistent Model
# * Automatically Configure the ARIMA
# * Review Residual Errors

# %%
if (notifyStatus): email_notify("Model Fitting and Evaluation has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 4.a) Establish the Persistent Model
#
# The first step before getting bogged down in data analysis and modeling is to establish a baseline of performance. This will provide both a template for evaluating models using the proposed test harness and a performance measure by which all more elaborate predictive models can be compared.
#
# The baseline prediction for time series forecasting is called the naive forecast, or persistence. This is where the observation from the previous time step is used as the prediction for the observation at the next time step.

# %% [markdown]
# #### 4.a.iii) Establish the Persistent Model as Baseline

# %%
# Prepare and evaluate a persistence model
X = time_series.values
X = X.astype('float32')
train_pct = 0.80
train_size = int(len(X) * train_pct)
test_size = len(X) - train_size
train_ts, test_ts = X[0:train_size], X[train_size:]

# walk-forward validation
history = [x for x in train_ts]
predictions = list()
for i in range(len(test_ts)):
    yhat = history[-1]
    predictions.append(yhat)
    obs = test_ts[i]
    history.append(obs)
    print('>Predicted=%.3f, Expected=%3.f' % (yhat, obs))

# Calculate performance
rmse = math.sqrt(mean_squared_error(test_ts, predictions))
print('RMSE for the persistent model is: %.3f' % rmse)
# Out:
# >Predicted=577.000, Expected=514
# >Predicted=514.000, Expected=440
# >Predicted=440.000, Expected=417
# >Predicted=417.000, Expected=389
# >Predicted=389.000, Expected=366
# >Predicted=366.000, Expected=449
# >Predicted=449.000, Expected=518
# >Predicted=518.000, Expected=447
# >Predicted=447.000, Expected=466
# >Predicted=466.000, Expected=469
# >Predicted=469.000, Expected=493
# >Predicted=493.000, Expected=498
# >Predicted=498.000, Expected=500
# >Predicted=500.000, Expected=519
# >Predicted=519.000, Expected=489
# >Predicted=489.000, Expected=518
# >Predicted=518.000, Expected=499
# >Predicted=499.000, Expected=454
# >Predicted=454.000, Expected=488
# >Predicted=488.000, Expected=486
# >Predicted=486.000, Expected=457
# >Predicted=457.000, Expected=473
# >Predicted=473.000, Expected=528
# >Predicted=528.000, Expected=513
# >Predicted=513.000, Expected=546
# >Predicted=546.000, Expected=558
# >Predicted=558.000, Expected=521
# >Predicted=521.000, Expected=553
# >Predicted=553.000, Expected=534
# >Predicted=534.000, Expected=440
# >Predicted=440.000, Expected=484
# >Predicted=484.000, Expected=498
# >Predicted=498.000, Expected=518
# >Predicted=518.000, Expected=476
# >Predicted=476.000, Expected=515
# >Predicted=515.000, Expected=551
# >Predicted=551.000, Expected=526
# >Predicted=526.000, Expected=521
# >Predicted=521.000, Expected=539
# >Predicted=539.000, Expected=523
# >Predicted=523.000, Expected=454
# >Predicted=454.000, Expected=413
# >Predicted=413.000, Expected=384
# >Predicted=384.000, Expected=356
# >Predicted=356.000, Expected=397
# >Predicted=397.000, Expected=420
# >Predicted=420.000, Expected=535
# >Predicted=535.000, Expected=587
# >Predicted=587.000, Expected=522
# >Predicted=522.000, Expected=558
# >Predicted=558.000, Expected=454
# >Predicted=454.000, Expected=567
# >Predicted=567.000, Expected=552
# >Predicted=552.000, Expected=502
# >Predicted=502.000, Expected=557
# >Predicted=557.000, Expected=533
# >Predicted=533.000, Expected=510
# >Predicted=510.000, Expected=517
# >Predicted=517.000, Expected=572
# >Predicted=572.000, Expected=537
# >Predicted=537.000, Expected=543
# >Predicted=543.000, Expected=532
# >Predicted=532.000, Expected=533
# >Predicted=533.000, Expected=500
# >Predicted=500.000, Expected=531
# >Predicted=531.000, Expected=466
# >Predicted=466.000, Expected=526
# >Predicted=526.000, Expected=550
# >Predicted=550.000, Expected=567
# >Predicted=567.000, Expected=568
# >Predicted=568.000, Expected=572
# >Predicted=572.000, Expected=588
# >Predicted=588.000, Expected=574
# >Predicted=574.000, Expected=613
# >Predicted=613.000, Expected=600
# >Predicted=600.000, Expected=591
# >Predicted=591.000, Expected=582
# >Predicted=582.000, Expected=556
# >Predicted=556.000, Expected=607
# >Predicted=607.000, Expected=628
# >Predicted=628.000, Expected=652
# >Predicted=652.000, Expected=646
# >Predicted=646.000, Expected=643
# >Predicted=643.000, Expected=649
# >Predicted=649.000, Expected=643
# >Predicted=643.000, Expected=644
# >Predicted=644.000, Expected=627
# >Predicted=627.000, Expected=590
# >Predicted=590.000, Expected=637
# >Predicted=637.000, Expected=563
# >Predicted=563.000, Expected=634
# >Predicted=634.000, Expected=605
# >Predicted=605.000, Expected=619
# >Predicted=619.000, Expected=595
# >Predicted=595.000, Expected=625
# >Predicted=625.000, Expected=657
# RMSE for the persistent model is: 41.096

# %% [markdown]
# ### 4.b) Grid Search of ARIMA Hyperparameters
#
# We want to find a model that can do better than the persistence model on this dataset. To confirm this analysis, we can grid search a suite of ARIMA hyperparameters.
#
# In this section, we will search values of p, d, and q for combinations (skipping those that fail to converge), and find the combination that results in the best performance. We will use a grid search to explore all combinations in a subset of integer values.

# %%
if (notifyStatus): email_notify("ARIMA Hyperparameters Search has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Set the initial P, D, and Q order parameters for non-seasonal ARIMA modeling
start_p = 0
start_d = None
start_q = 0
max_p = 5
max_d = 2
max_q = 5

# %%
# Set the initial P, D, and Q order parameters for seasonal ARIMA modeling
start_P = 0
start_D = None
start_Q = 0
max_P = 2
max_D = 1
max_Q = 2

# %%
# Testing the time series data for suggestions on the differencing term
start_d = pm.arima.ndiffs(train_ts)
print('The suggested non-seasonal differencing term is:', start_d)
if (seasonal_freq != 0):
    start_D = pm.arima.nsdiffs(train_ts, m = seasonal_freq)
    print('The suggested seasonal differencing term is:', start_D)
# Out:
# The suggested non-seasonal differencing term is: 1
# The suggested seasonal differencing term is: 0

# %%
print('The initial non-seasonal parameters are: p =', start_p, '| d =', start_d, '| q =', start_q)
print('The maximum non-seasonal parameters are: max_p =', max_p, '| max_d =', max_d, '| max_q =', max_q)
print('The initial seasonal parameters are: P =', start_P, '| D =', start_D, '| Q =', start_Q, '| m =', seasonal_freq)
print('The maximum seasonal parameters are: max_P =', max_P, '| max_D =', max_D, '| max_Q =', max_Q)
# Out:
# The initial non-seasonal parameters are: p = 0 | d = 1 | q = 0
# The maximum non-seasonal parameters are: max_p = 5 | max_d = 2 | max_q = 5
# The initial seasonal parameters are: P = 0 | D = 0 | Q = 0 | m = 12
# The maximum seasonal parameters are: max_P = 2 | max_D = 1 | max_Q = 2

# %%
# Do an automated stepwise search of ARIMA parameters
if (seasonal_freq == 0):
    stepwise_results = pm.auto_arima(train_ts, seasonal = False, stepwise = True, trace = True, suppress_warnings = True, random_state = seedNum)
else:
    stepwise_results = pm.auto_arima(train_ts, seasonal = True, m = seasonal_freq, stepwise = True, trace = True, suppress_warnings = True, random_state = seedNum)
# Out:
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 0, 1, 12); AIC=3776.483, BIC=3807.984, Fit time=1.548 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 0, 0, 12); AIC=3916.850, BIC=3924.725, Fit time=0.019 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 0, 0, 12); AIC=3841.034, BIC=3856.784, Fit time=0.453 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 0, 1, 12); AIC=3842.513, BIC=3858.263, Fit time=0.401 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 0, 1, 12); AIC=3830.353, BIC=3857.916, Fit time=1.581 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(2, 0, 1, 12); AIC=3778.218, BIC=3813.656, Fit time=5.902 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 0, 0, 12); AIC=3819.309, BIC=3846.872, Fit time=2.059 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 0, 2, 12); AIC=3778.239, BIC=3813.677, Fit time=5.827 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 0, 0, 12); AIC=3851.519, BIC=3875.145, Fit time=0.537 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(2, 0, 2, 12); AIC=3779.855, BIC=3819.230, Fit time=6.567 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 0, 1, 12); AIC=3774.599, BIC=3802.162, Fit time=1.921 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 0, 1, 12); AIC=3772.614, BIC=3796.239, Fit time=1.728 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 0, 1, 12); AIC=3805.465, BIC=3821.215, Fit time=0.514 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 0, 1, 12); AIC=3832.869, BIC=3852.556, Fit time=0.828 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 0, 1, 12); AIC=3774.346, BIC=3801.909, Fit time=4.502 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 0, 0, 12); AIC=3819.746, BIC=3839.433, Fit time=0.856 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 0, 2, 12); AIC=3774.364, BIC=3801.927, Fit time=4.848 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 0, 0, 12); AIC=3856.861, BIC=3872.611, Fit time=0.244 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 0, 2, 12); AIC=3775.982, BIC=3807.483, Fit time=5.885 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 0, 1, 12); AIC=3793.268, BIC=3812.955, Fit time=1.121 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(1, 0, 1, 12); AIC=3774.652, BIC=3802.215, Fit time=2.316 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 0, 1, 12); AIC=3796.627, BIC=3816.315, Fit time=0.903 seconds
# Total fit time: 50.599 seconds

# %%
# Summarize residual errors for the automated grid search ARIMA model
print(stepwise_results.summary())
stepwise_results.plot_diagnostics(figsize=(12,12))
plt.show()
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  380
# Model:             SARIMAX(1, 1, 1)x(1, 0, 1, 12)   Log Likelihood               -1880.307
# Date:                            Tue, 12 Nov 2019   AIC                           3772.614
# Time:                                    13:34:00   BIC                           3796.239
# Sample:                                         0   HQIC                          3781.989
#                                             - 380
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0069      0.028      0.245      0.807      -0.048       0.062
# ar.L1          0.6393      0.053     12.048      0.000       0.535       0.743
# ma.L1         -0.8875      0.038    -23.156      0.000      -0.963      -0.812
# ar.S.L12       0.9768      0.026     37.030      0.000       0.925       1.028
# ma.S.L12      -0.8609      0.055    -15.584      0.000      -0.969      -0.753
# sigma2      1164.1777     51.948     22.410      0.000    1062.361    1265.995
# ===================================================================================
# Ljung-Box (Q):                       62.32   Jarque-Bera (JB):               278.18
# Prob(Q):                              0.01   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.73   Skew:                            -0.42
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.11
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
if (notifyStatus): email_notify("ARIMA automated stepwise search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Do an automated random search of ARIMA parameters
n_fits = int(max_p * max_d * max_q * max_P * max_D * max_Q * 0.30)
if (seasonal_freq == 0):
    randgrid_results = pm.auto_arima(train_ts, start_p = start_p, d = start_d, start_q = start_q, max_p = max_p, max_d = max_d, max_q = max_q,
                                     seasonal = False, stepwise = False, random = True, n_fits = n_fits, max_order = None,
                                     trace = True, suppress_warnings = True, random_state = seedNum)
else:
    randgrid_results = pm.auto_arima(train_ts, start_p = start_p, d = start_d, start_q = start_q, max_p = max_p, max_d = max_d, max_q = max_q,
                                     seasonal = True, m = seasonal_freq, start_P = start_P, D = start_D, start_Q = start_Q, max_P = max_P, max_D = max_D, max_Q = max_Q,
                                     stepwise = False, random = True, n_fits = n_fits, max_order = None,
                                     trace = True, suppress_warnings = True, random_state = seedNum)
# Out:
# Fit ARIMA: order=(3, 1, 4) seasonal_order=(1, 0, 1, 12); AIC=3771.551, BIC=3814.864, Fit time=4.061 seconds
# Fit ARIMA: order=(5, 1, 0) seasonal_order=(2, 0, 1, 12); AIC=3791.518, BIC=3830.893, Fit time=6.869 seconds
# Fit ARIMA: order=(5, 1, 5) seasonal_order=(2, 0, 0, 12); AIC=3781.633, BIC=3836.759, Fit time=10.484 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 0, 2, 12); AIC=3833.677, BIC=3853.365, Fit time=1.180 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(1, 0, 1, 12); AIC=3778.519, BIC=3813.956, Fit time=2.767 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 0, 0, 12); AIC=3866.444, BIC=3878.256, Fit time=0.094 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 0, 1, 12); AIC=3850.230, BIC=3865.980, Fit time=0.366 seconds
# Fit ARIMA: order=(3, 1, 5) seasonal_order=(2, 0, 2, 12); AIC=3777.404, BIC=3832.530, Fit time=11.527 seconds
# Fit ARIMA: order=(1, 1, 4) seasonal_order=(0, 0, 1, 12); AIC=3830.330, BIC=3861.831, Fit time=1.614 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 0, 1, 12); AIC=3796.627, BIC=3816.315, Fit time=0.902 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(2, 0, 0, 12); AIC=3801.220, BIC=3828.783, Fit time=3.907 seconds
# Fit ARIMA: order=(1, 1, 5) seasonal_order=(2, 0, 2, 12); AIC=3783.156, BIC=3830.406, Fit time=10.465 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(0, 0, 1, 12); AIC=3824.463, BIC=3859.901, Fit time=2.652 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 0, 2, 12); AIC=3778.239, BIC=3813.677, Fit time=5.771 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(0, 0, 2, 12); AIC=3813.105, BIC=3844.605, Fit time=5.451 seconds
# Fit ARIMA: order=(1, 1, 5) seasonal_order=(1, 0, 1, 12); AIC=3779.987, BIC=3819.363, Fit time=3.814 seconds
# Fit ARIMA: order=(5, 1, 5) seasonal_order=(0, 0, 1, 12); AIC=3787.967, BIC=3839.155, Fit time=5.232 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(0, 0, 0, 12); AIC=3855.767, BIC=3891.205, Fit time=1.325 seconds
# Fit ARIMA: order=(1, 1, 4) seasonal_order=(1, 0, 2, 12); AIC=3780.243, BIC=3819.618, Fit time=6.653 seconds
# Fit ARIMA: order=(4, 1, 4) seasonal_order=(2, 0, 0, 12); AIC=3783.300, BIC=3830.550, Fit time=8.619 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 0, 1, 12); AIC=3844.901, BIC=3868.526, Fit time=0.654 seconds
# Fit ARIMA: order=(4, 1, 4) seasonal_order=(1, 0, 0, 12); AIC=3786.019, BIC=3829.332, Fit time=3.312 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(2, 0, 2, 12); AIC=3796.326, BIC=3831.764, Fit time=4.259 seconds
# Fit ARIMA: order=(2, 1, 5) seasonal_order=(1, 0, 1, 12); AIC=3772.112, BIC=3815.425, Fit time=3.996 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(1, 0, 1, 12); AIC=3776.255, BIC=3807.755, Fit time=1.833 seconds
# Fit ARIMA: order=(3, 1, 4) seasonal_order=(1, 0, 2, 12); AIC=3775.191, BIC=3822.441, Fit time=9.215 seconds
# Fit ARIMA: order=(3, 1, 5) seasonal_order=(1, 0, 2, 12); AIC=3774.272, BIC=3825.460, Fit time=11.408 seconds
# Fit ARIMA: order=(4, 1, 4) seasonal_order=(1, 0, 1, 12); AIC=3779.367, BIC=3826.618, Fit time=4.028 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(0, 0, 2, 12); AIC=3834.532, BIC=3862.095, Fit time=1.360 seconds
# Fit ARIMA: order=(3, 1, 5) seasonal_order=(0, 0, 2, 12); AIC=3782.970, BIC=3830.221, Fit time=10.232 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(1, 0, 0, 12); AIC=3820.030, BIC=3847.593, Fit time=1.218 seconds
# Fit ARIMA: order=(4, 1, 4) seasonal_order=(0, 0, 0, 12); AIC=3790.609, BIC=3829.985, Fit time=1.611 seconds
# Fit ARIMA: order=(1, 1, 5) seasonal_order=(0, 0, 2, 12); AIC=3817.174, BIC=3856.549, Fit time=5.885 seconds
# Fit ARIMA: order=(3, 1, 5) seasonal_order=(2, 0, 1, 12); AIC=3781.262, BIC=3832.450, Fit time=7.928 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 0, 2, 12); AIC=3774.364, BIC=3801.927, Fit time=4.783 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 0, 0, 12); AIC=3851.519, BIC=3875.145, Fit time=0.510 seconds
# Fit ARIMA: order=(0, 1, 4) seasonal_order=(2, 0, 0, 12); AIC=3803.483, BIC=3834.983, Fit time=2.077 seconds
# Fit ARIMA: order=(1, 1, 5) seasonal_order=(0, 0, 0, 12); AIC=3847.338, BIC=3878.838, Fit time=0.963 seconds
# Fit ARIMA: order=(4, 1, 4) seasonal_order=(0, 0, 2, 12); AIC=3783.725, BIC=3830.976, Fit time=9.233 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(1, 0, 0, 12); AIC=3830.524, BIC=3858.087, Fit time=1.191 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(0, 0, 2, 12); AIC=3813.442, BIC=3841.005, Fit time=3.546 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(2, 0, 0, 12); AIC=3801.641, BIC=3833.142, Fit time=3.202 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(2, 0, 0, 12); AIC=3801.246, BIC=3840.621, Fit time=6.425 seconds
# Fit ARIMA: order=(5, 1, 4) seasonal_order=(0, 0, 0, 12); AIC=3790.416, BIC=3833.729, Fit time=1.455 seconds
# Fit ARIMA: order=(5, 1, 3) seasonal_order=(0, 0, 2, 12); AIC=3779.882, BIC=3827.133, Fit time=8.217 seconds
# Fit ARIMA: order=(5, 1, 2) seasonal_order=(1, 0, 2, 12); AIC=3783.841, BIC=3831.092, Fit time=7.282 seconds
# Fit ARIMA: order=(2, 1, 4) seasonal_order=(2, 0, 1, 12); AIC=3781.537, BIC=3824.850, Fit time=6.945 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(0, 0, 0, 12); AIC=3847.659, BIC=3871.285, Fit time=0.555 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(2, 0, 0, 12); AIC=3823.078, BIC=3842.766, Fit time=1.451 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(1, 0, 0, 12); AIC=3811.500, BIC=3846.938, Fit time=2.047 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(0, 0, 1, 12); AIC=3834.631, BIC=3866.131, Fit time=2.015 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(0, 0, 0, 12); AIC=3842.442, BIC=3873.942, Fit time=0.787 seconds
# Fit ARIMA: order=(0, 1, 5) seasonal_order=(1, 0, 2, 12); AIC=3780.359, BIC=3819.734, Fit time=8.798 seconds
# Fit ARIMA: order=(5, 1, 2) seasonal_order=(2, 0, 1, 12); AIC=3784.052, BIC=3831.303, Fit time=8.085 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(0, 0, 2, 12); AIC=3816.428, BIC=3851.866, Fit time=5.261 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(2, 0, 1, 12); AIC=3779.619, BIC=3818.994, Fit time=7.064 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(0, 0, 1, 12); AIC=3838.026, BIC=3865.589, Fit time=0.645 seconds
# Fit ARIMA: order=(5, 1, 4) seasonal_order=(1, 0, 1, 12); AIC=3781.104, BIC=3832.292, Fit time=4.060 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 0, 2, 12); AIC=3859.932, BIC=3875.682, Fit time=0.881 seconds
# Fit ARIMA: order=(1, 1, 4) seasonal_order=(2, 0, 1, 12); AIC=3780.239, BIC=3819.615, Fit time=5.618 seconds
# Total fit time: 263.885 seconds

# %%
# Summarize residual errors for the automated grid search ARIMA model
print(randgrid_results.summary())
randgrid_results.plot_diagnostics(figsize=(12,12))
plt.show()
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  380
# Model:             SARIMAX(3, 1, 4)x(1, 0, 1, 12)   Log Likelihood               -1874.776
# Date:                            Tue, 12 Nov 2019   AIC                           3771.551
# Time:                                    13:38:25   BIC                           3814.864
# Sample:                                         0   HQIC                          3788.740
#                                             - 380
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0116      0.040      0.288      0.774      -0.068       0.091
# ar.L1         -1.0069      0.100    -10.062      0.000      -1.203      -0.811
# ar.L2          0.2457      0.174      1.408      0.159      -0.096       0.588
# ar.L3          0.7031      0.100      7.007      0.000       0.506       0.900
# ma.L1          0.7712      0.105      7.364      0.000       0.566       0.977
# ma.L2         -0.6358      0.133     -4.787      0.000      -0.896      -0.375
# ma.L3         -0.8488      0.048    -17.682      0.000      -0.943      -0.755
# ma.L4          0.0545      0.060      0.911      0.362      -0.063       0.172
# ar.S.L12       0.9899      0.022     45.972      0.000       0.948       1.032
# ma.S.L12      -0.9310      0.058    -15.980      0.000      -1.045      -0.817
# sigma2      1131.6568     54.219     20.872      0.000    1025.389    1237.925
# ===================================================================================
# Ljung-Box (Q):                       60.57   Jarque-Bera (JB):               285.97
# Prob(Q):                              0.02   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.44   Skew:                            -0.35
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.20
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
if (notifyStatus): email_notify("ARIMA automated random search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Do an automated grid search of ARIMA parameters
if (seasonal_freq == 0):
    autogrid_results = pm.auto_arima(train_ts, start_p = start_p, d = start_d, start_q = start_q, max_p = max_p, max_d = max_d, max_q = max_q,
                                     seasonal = False, stepwise = False, max_order = None, trace = True, suppress_warnings = True, random_state = seedNum)
else:
    autogrid_results = pm.auto_arima(train_ts, start_p = start_p, d = start_d, start_q = start_q, max_p = max_p, max_d = max_d, max_q = max_q,
                                     seasonal = True, m = seasonal_freq, start_P = start_P, D = start_D, start_Q = start_Q, max_P = max_P, max_D = max_D, max_Q = max_Q,
                                     stepwise = False, max_order = None, trace = True, suppress_warnings = True, random_state = seedNum)
# Out:
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 0, 0, 12); AIC=3916.850, BIC=3924.725, Fit time=0.021 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 0, 1, 12); AIC=3886.700, BIC=3898.513, Fit time=0.259 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 0, 2, 12); AIC=3859.932, BIC=3875.682, Fit time=0.814 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 0, 0, 12); AIC=3867.354, BIC=3879.167, Fit time=0.333 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 0, 1, 12); AIC=3805.465, BIC=3821.215, Fit time=0.542 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 0, 2, 12); AIC=3807.465, BIC=3827.153, Fit time=2.151 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(2, 0, 0, 12); AIC=3838.127, BIC=3853.877, Fit time=1.093 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(2, 0, 1, 12); AIC=3807.465, BIC=3827.153, Fit time=2.297 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(2, 0, 2, 12); AIC=3808.045, BIC=3831.670, Fit time=1.893 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 0, 0, 12); AIC=3861.649, BIC=3873.462, Fit time=0.181 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 0, 1, 12); AIC=3842.513, BIC=3858.263, Fit time=0.424 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 0, 2, 12); AIC=3830.225, BIC=3849.913, Fit time=1.470 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 0, 0, 12); AIC=3833.945, BIC=3849.695, Fit time=0.432 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 0, 1, 12); AIC=3793.268, BIC=3812.955, Fit time=1.008 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 0, 2, 12); AIC=3794.974, BIC=3818.599, Fit time=3.417 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(2, 0, 0, 12); AIC=3820.465, BIC=3840.152, Fit time=1.510 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(2, 0, 1, 12); AIC=3794.946, BIC=3818.571, Fit time=2.934 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(2, 0, 2, 12); AIC=3796.270, BIC=3823.833, Fit time=3.340 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 0, 0, 12); AIC=3863.020, BIC=3878.770, Fit time=0.222 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 0, 1, 12); AIC=3841.757, BIC=3861.444, Fit time=0.566 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 0, 2, 12); AIC=3830.627, BIC=3854.252, Fit time=1.929 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 0, 0, 12); AIC=3832.123, BIC=3851.811, Fit time=0.541 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 0, 1, 12); AIC=3787.804, BIC=3811.429, Fit time=1.136 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 0, 2, 12); AIC=3789.243, BIC=3816.806, Fit time=3.659 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(2, 0, 0, 12); AIC=3820.124, BIC=3843.749, Fit time=1.520 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(2, 0, 1, 12); AIC=3789.244, BIC=3816.806, Fit time=3.258 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(2, 0, 2, 12); AIC=3791.516, BIC=3823.016, Fit time=4.722 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(0, 0, 0, 12); AIC=3847.082, BIC=3866.770, Fit time=0.310 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(0, 0, 1, 12); AIC=3832.583, BIC=3856.208, Fit time=0.806 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(0, 0, 2, 12); AIC=3819.977, BIC=3847.540, Fit time=2.549 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(1, 0, 0, 12); AIC=3824.974, BIC=3848.599, Fit time=0.599 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(1, 0, 1, 12); AIC=3781.480, BIC=3809.043, Fit time=1.696 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(1, 0, 2, 12); AIC=3783.371, BIC=3814.871, Fit time=5.153 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(2, 0, 0, 12); AIC=3811.076, BIC=3838.639, Fit time=2.028 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(2, 0, 1, 12); AIC=3783.367, BIC=3814.867, Fit time=4.203 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(2, 0, 2, 12); AIC=3785.142, BIC=3820.580, Fit time=4.495 seconds
# Fit ARIMA: order=(0, 1, 4) seasonal_order=(0, 0, 0, 12); AIC=3847.926, BIC=3871.551, Fit time=0.356 seconds
# Fit ARIMA: order=(0, 1, 4) seasonal_order=(0, 0, 1, 12); AIC=3831.537, BIC=3859.100, Fit time=1.142 seconds
# Fit ARIMA: order=(0, 1, 4) seasonal_order=(0, 0, 2, 12); AIC=3814.484, BIC=3845.984, Fit time=2.973 seconds
# Fit ARIMA: order=(0, 1, 4) seasonal_order=(1, 0, 0, 12); AIC=3821.750, BIC=3849.313, Fit time=0.719 seconds
# Fit ARIMA: order=(0, 1, 4) seasonal_order=(1, 0, 1, 12); AIC=3776.389, BIC=3807.889, Fit time=2.488 seconds
# Fit ARIMA: order=(0, 1, 4) seasonal_order=(1, 0, 2, 12); AIC=3778.273, BIC=3813.710, Fit time=6.787 seconds
# Fit ARIMA: order=(0, 1, 4) seasonal_order=(2, 0, 0, 12); AIC=3803.483, BIC=3834.983, Fit time=2.080 seconds
# Fit ARIMA: order=(0, 1, 4) seasonal_order=(2, 0, 1, 12); AIC=3778.262, BIC=3813.700, Fit time=5.077 seconds
# Fit ARIMA: order=(0, 1, 4) seasonal_order=(2, 0, 2, 12); AIC=3779.663, BIC=3819.038, Fit time=7.435 seconds
# Fit ARIMA: order=(0, 1, 5) seasonal_order=(0, 0, 0, 12); AIC=3849.831, BIC=3877.394, Fit time=0.564 seconds
# Fit ARIMA: order=(0, 1, 5) seasonal_order=(0, 0, 1, 12); AIC=3833.375, BIC=3864.875, Fit time=1.418 seconds
# Fit ARIMA: order=(0, 1, 5) seasonal_order=(0, 0, 2, 12); AIC=3816.441, BIC=3851.879, Fit time=4.612 seconds
# Fit ARIMA: order=(0, 1, 5) seasonal_order=(1, 0, 0, 12); AIC=3823.727, BIC=3855.228, Fit time=0.955 seconds
# Fit ARIMA: order=(0, 1, 5) seasonal_order=(1, 0, 1, 12); AIC=3778.955, BIC=3814.393, Fit time=3.305 seconds
# Fit ARIMA: order=(0, 1, 5) seasonal_order=(1, 0, 2, 12); AIC=3780.359, BIC=3819.734, Fit time=8.711 seconds
# Fit ARIMA: order=(0, 1, 5) seasonal_order=(2, 0, 0, 12); AIC=3805.242, BIC=3840.680, Fit time=2.674 seconds
# Fit ARIMA: order=(0, 1, 5) seasonal_order=(2, 0, 1, 12); AIC=3780.257, BIC=3819.632, Fit time=5.246 seconds
# Fit ARIMA: order=(0, 1, 5) seasonal_order=(2, 0, 2, 12); AIC=3784.084, BIC=3827.397, Fit time=9.916 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 0, 0, 12); AIC=3866.444, BIC=3878.256, Fit time=0.107 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 0, 1, 12); AIC=3850.230, BIC=3865.980, Fit time=0.385 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 0, 2, 12); AIC=3833.677, BIC=3853.365, Fit time=1.173 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 0, 0, 12); AIC=3841.034, BIC=3856.784, Fit time=0.484 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 0, 1, 12); AIC=3796.627, BIC=3816.315, Fit time=0.855 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 0, 2, 12); AIC=3798.512, BIC=3822.137, Fit time=2.865 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(2, 0, 0, 12); AIC=3823.078, BIC=3842.766, Fit time=1.394 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(2, 0, 1, 12); AIC=3798.498, BIC=3822.123, Fit time=2.852 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(2, 0, 2, 12); AIC=3799.268, BIC=3826.831, Fit time=2.904 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 0, 0, 12); AIC=3856.861, BIC=3872.611, Fit time=0.319 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 0, 1, 12); AIC=3832.869, BIC=3852.556, Fit time=0.814 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 0, 2, 12); AIC=3816.364, BIC=3839.989, Fit time=2.807 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 0, 0, 12); AIC=3819.746, BIC=3839.433, Fit time=0.811 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 0, 1, 12); AIC=3772.614, BIC=3796.239, Fit time=1.702 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 0, 2, 12); AIC=3774.364, BIC=3801.927, Fit time=4.781 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 0, 0, 12); AIC=3801.123, BIC=3824.748, Fit time=2.422 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 0, 1, 12); AIC=3774.346, BIC=3801.909, Fit time=4.455 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 0, 2, 12); AIC=3775.982, BIC=3807.483, Fit time=5.750 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 0, 0, 12); AIC=3859.024, BIC=3878.712, Fit time=0.621 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 0, 1, 12); AIC=3844.901, BIC=3868.526, Fit time=0.718 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 0, 2, 12); AIC=3833.130, BIC=3860.692, Fit time=2.209 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 0, 0, 12); AIC=3835.597, BIC=3859.222, Fit time=0.900 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 0, 1, 12); AIC=3774.599, BIC=3802.162, Fit time=1.786 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 0, 2, 12); AIC=3776.505, BIC=3808.005, Fit time=5.432 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 0, 0, 12); AIC=3822.890, BIC=3850.453, Fit time=2.688 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 0, 1, 12); AIC=3791.198, BIC=3822.698, Fit time=3.915 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 0, 2, 12); AIC=3777.956, BIC=3813.394, Fit time=6.161 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(0, 0, 0, 12); AIC=3847.659, BIC=3871.285, Fit time=0.558 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(0, 0, 1, 12); AIC=3830.589, BIC=3858.152, Fit time=1.825 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(0, 0, 2, 12); AIC=3813.105, BIC=3844.605, Fit time=5.458 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(1, 0, 0, 12); AIC=3819.907, BIC=3847.470, Fit time=1.260 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(1, 0, 1, 12); AIC=3791.755, BIC=3823.255, Fit time=2.301 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(1, 0, 2, 12); AIC=3793.161, BIC=3828.599, Fit time=6.473 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(2, 0, 0, 12); AIC=3801.641, BIC=3833.142, Fit time=3.208 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(2, 0, 1, 12); AIC=3793.160, BIC=3828.598, Fit time=5.782 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(2, 0, 2, 12); AIC=3795.464, BIC=3834.839, Fit time=6.275 seconds
# Fit ARIMA: order=(1, 1, 4) seasonal_order=(0, 0, 0, 12); AIC=3845.675, BIC=3873.238, Fit time=0.590 seconds
# Fit ARIMA: order=(1, 1, 4) seasonal_order=(0, 0, 1, 12); AIC=3830.330, BIC=3861.831, Fit time=1.555 seconds
# Fit ARIMA: order=(1, 1, 4) seasonal_order=(0, 0, 2, 12); AIC=3815.048, BIC=3850.486, Fit time=5.370 seconds
# Fit ARIMA: order=(1, 1, 4) seasonal_order=(1, 0, 0, 12); AIC=3821.997, BIC=3853.497, Fit time=1.337 seconds
# Fit ARIMA: order=(1, 1, 4) seasonal_order=(1, 0, 1, 12); AIC=3778.232, BIC=3813.669, Fit time=3.044 seconds
# Fit ARIMA: order=(1, 1, 4) seasonal_order=(1, 0, 2, 12); AIC=3780.243, BIC=3819.618, Fit time=6.612 seconds
# Fit ARIMA: order=(1, 1, 4) seasonal_order=(2, 0, 0, 12); AIC=3803.321, BIC=3838.759, Fit time=4.137 seconds
# Fit ARIMA: order=(1, 1, 4) seasonal_order=(2, 0, 1, 12); AIC=3780.239, BIC=3819.615, Fit time=5.660 seconds
# Fit ARIMA: order=(1, 1, 4) seasonal_order=(2, 0, 2, 12); AIC=3781.035, BIC=3824.348, Fit time=8.185 seconds
# Fit ARIMA: order=(1, 1, 5) seasonal_order=(0, 0, 0, 12); AIC=3847.338, BIC=3878.838, Fit time=0.994 seconds
# Fit ARIMA: order=(1, 1, 5) seasonal_order=(0, 0, 1, 12); AIC=3832.328, BIC=3867.766, Fit time=2.740 seconds
# Fit ARIMA: order=(1, 1, 5) seasonal_order=(0, 0, 2, 12); AIC=3817.174, BIC=3856.549, Fit time=5.788 seconds
# Fit ARIMA: order=(1, 1, 5) seasonal_order=(1, 0, 0, 12); AIC=3823.807, BIC=3859.245, Fit time=1.437 seconds
# Fit ARIMA: order=(1, 1, 5) seasonal_order=(1, 0, 1, 12); AIC=3779.987, BIC=3819.363, Fit time=3.786 seconds
# Fit ARIMA: order=(1, 1, 5) seasonal_order=(1, 0, 2, 12); AIC=3782.123, BIC=3825.436, Fit time=8.719 seconds
# Fit ARIMA: order=(1, 1, 5) seasonal_order=(2, 0, 0, 12); AIC=3806.845, BIC=3846.220, Fit time=5.195 seconds
# Fit ARIMA: order=(1, 1, 5) seasonal_order=(2, 0, 1, 12); AIC=3782.194, BIC=3825.507, Fit time=6.230 seconds
# Fit ARIMA: order=(1, 1, 5) seasonal_order=(2, 0, 2, 12); AIC=3783.156, BIC=3830.406, Fit time=10.861 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(0, 0, 0, 12); AIC=3866.926, BIC=3882.676, Fit time=0.172 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(0, 0, 1, 12); AIC=3848.784, BIC=3868.472, Fit time=0.433 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(0, 0, 2, 12); AIC=3834.291, BIC=3857.917, Fit time=1.359 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(1, 0, 0, 12); AIC=3838.951, BIC=3858.639, Fit time=0.748 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(1, 0, 1, 12); AIC=3794.160, BIC=3817.785, Fit time=1.378 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(1, 0, 2, 12); AIC=3795.811, BIC=3823.374, Fit time=3.795 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(2, 0, 0, 12); AIC=3823.602, BIC=3847.227, Fit time=2.193 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(2, 0, 1, 12); AIC=3795.791, BIC=3823.353, Fit time=4.521 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(2, 0, 2, 12); AIC=3797.408, BIC=3828.908, Fit time=4.816 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(0, 0, 0, 12); AIC=3849.156, BIC=3868.844, Fit time=0.345 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(0, 0, 1, 12); AIC=3829.279, BIC=3852.904, Fit time=1.097 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(0, 0, 2, 12); AIC=3813.442, BIC=3841.005, Fit time=3.381 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(1, 0, 0, 12); AIC=3818.160, BIC=3841.786, Fit time=1.375 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(1, 0, 1, 12); AIC=3774.652, BIC=3802.215, Fit time=2.317 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(1, 0, 2, 12); AIC=3776.352, BIC=3807.852, Fit time=5.553 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(2, 0, 0, 12); AIC=3801.220, BIC=3828.783, Fit time=3.667 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(2, 0, 1, 12); AIC=3777.170, BIC=3808.671, Fit time=5.385 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(2, 0, 2, 12); AIC=3777.941, BIC=3813.379, Fit time=5.215 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 0, 0, 12); AIC=3851.519, BIC=3875.145, Fit time=0.508 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 0, 1, 12); AIC=3830.353, BIC=3857.916, Fit time=1.544 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 0, 2, 12); AIC=3815.526, BIC=3847.026, Fit time=5.094 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 0, 0, 12); AIC=3819.309, BIC=3846.872, Fit time=1.989 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 0, 1, 12); AIC=3776.483, BIC=3807.984, Fit time=1.456 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 0, 2, 12); AIC=3778.239, BIC=3813.677, Fit time=5.730 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(2, 0, 0, 12); AIC=3802.886, BIC=3834.386, Fit time=5.378 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(2, 0, 1, 12); AIC=3778.218, BIC=3813.656, Fit time=5.715 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(2, 0, 2, 12); AIC=3779.855, BIC=3819.230, Fit time=6.366 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(0, 0, 0, 12); AIC=3849.485, BIC=3877.048, Fit time=0.858 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(0, 0, 1, 12); AIC=3832.510, BIC=3864.010, Fit time=2.382 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(0, 0, 2, 12); AIC=3815.235, BIC=3850.673, Fit time=6.510 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(1, 0, 0, 12); AIC=3821.893, BIC=3853.394, Fit time=2.441 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(1, 0, 1, 12); AIC=3778.519, BIC=3813.956, Fit time=2.841 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(1, 0, 2, 12); AIC=3780.867, BIC=3820.242, Fit time=7.380 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(2, 0, 0, 12); AIC=3805.089, BIC=3840.526, Fit time=5.503 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(2, 0, 1, 12); AIC=3779.749, BIC=3819.124, Fit time=6.478 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(2, 0, 2, 12); AIC=3781.855, BIC=3825.168, Fit time=8.044 seconds
# Fit ARIMA: order=(2, 1, 4) seasonal_order=(0, 0, 0, 12); AIC=3800.894, BIC=3832.395, Fit time=1.120 seconds
# Fit ARIMA: order=(2, 1, 4) seasonal_order=(0, 0, 1, 12); AIC=3795.442, BIC=3830.880, Fit time=3.028 seconds
# Fit ARIMA: order=(2, 1, 4) seasonal_order=(0, 0, 2, 12); AIC=3816.829, BIC=3856.205, Fit time=7.161 seconds
# Fit ARIMA: order=(2, 1, 4) seasonal_order=(1, 0, 0, 12); AIC=3822.155, BIC=3857.593, Fit time=2.098 seconds
# Fit ARIMA: order=(2, 1, 4) seasonal_order=(1, 0, 1, 12); AIC=3779.360, BIC=3818.735, Fit time=3.276 seconds
# Fit ARIMA: order=(2, 1, 4) seasonal_order=(1, 0, 2, 12); AIC=3780.340, BIC=3823.653, Fit time=8.308 seconds
# Fit ARIMA: order=(2, 1, 4) seasonal_order=(2, 0, 0, 12); AIC=3804.937, BIC=3844.312, Fit time=6.281 seconds
# Fit ARIMA: order=(2, 1, 4) seasonal_order=(2, 0, 1, 12); AIC=3781.537, BIC=3824.850, Fit time=6.872 seconds
# Fit ARIMA: order=(2, 1, 4) seasonal_order=(2, 0, 2, 12); AIC=3787.116, BIC=3834.366, Fit time=9.497 seconds
# Fit ARIMA: order=(2, 1, 5) seasonal_order=(0, 0, 0, 12); AIC=3789.589, BIC=3825.027, Fit time=1.640 seconds
# Fit ARIMA: order=(2, 1, 5) seasonal_order=(0, 0, 1, 12); AIC=3787.301, BIC=3826.676, Fit time=3.902 seconds
# Fit ARIMA: order=(2, 1, 5) seasonal_order=(0, 0, 2, 12); AIC=3787.908, BIC=3831.221, Fit time=9.021 seconds
# Fit ARIMA: order=(2, 1, 5) seasonal_order=(1, 0, 0, 12); AIC=3786.082, BIC=3825.457, Fit time=2.998 seconds
# Fit ARIMA: order=(2, 1, 5) seasonal_order=(1, 0, 1, 12); AIC=3772.112, BIC=3815.425, Fit time=4.126 seconds
# Fit ARIMA: order=(2, 1, 5) seasonal_order=(1, 0, 2, 12); AIC=3774.937, BIC=3822.187, Fit time=9.376 seconds
# Fit ARIMA: order=(2, 1, 5) seasonal_order=(2, 0, 0, 12); AIC=3786.728, BIC=3830.041, Fit time=7.078 seconds
# Fit ARIMA: order=(2, 1, 5) seasonal_order=(2, 0, 1, 12); AIC=3775.080, BIC=3822.330, Fit time=7.376 seconds
# Fit ARIMA: order=(2, 1, 5) seasonal_order=(2, 0, 2, 12); AIC=3777.649, BIC=3828.837, Fit time=10.931 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(0, 0, 0, 12); AIC=3866.722, BIC=3886.410, Fit time=0.181 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(0, 0, 1, 12); AIC=3847.594, BIC=3871.219, Fit time=0.475 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(0, 0, 2, 12); AIC=3834.532, BIC=3862.095, Fit time=1.301 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(1, 0, 0, 12); AIC=3837.994, BIC=3861.619, Fit time=0.709 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(1, 0, 1, 12); AIC=3792.760, BIC=3820.323, Fit time=1.431 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(1, 0, 2, 12); AIC=3794.480, BIC=3825.981, Fit time=4.040 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(2, 0, 0, 12); AIC=3823.786, BIC=3851.349, Fit time=2.499 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(2, 0, 1, 12); AIC=3794.472, BIC=3825.972, Fit time=4.626 seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(2, 0, 2, 12); AIC=3796.326, BIC=3831.764, Fit time=4.172 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(0, 0, 0, 12); AIC=3849.077, BIC=3872.702, Fit time=0.416 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(0, 0, 1, 12); AIC=3830.831, BIC=3858.394, Fit time=1.608 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(0, 0, 2, 12); AIC=3813.965, BIC=3845.466, Fit time=3.749 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(1, 0, 0, 12); AIC=3820.030, BIC=3847.593, Fit time=1.255 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(1, 0, 1, 12); AIC=3776.255, BIC=3807.755, Fit time=1.834 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(1, 0, 2, 12); AIC=3779.000, BIC=3814.438, Fit time=6.151 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(2, 0, 0, 12); AIC=3802.084, BIC=3833.584, Fit time=4.598 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(2, 0, 1, 12); AIC=3778.148, BIC=3813.586, Fit time=6.606 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(2, 0, 2, 12); AIC=3779.470, BIC=3818.845, Fit time=6.602 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(0, 0, 0, 12); AIC=3847.010, BIC=3874.573, Fit time=0.815 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(0, 0, 1, 12); AIC=3831.693, BIC=3863.193, Fit time=1.365 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(0, 0, 2, 12); AIC=3816.428, BIC=3851.866, Fit time=5.131 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(1, 0, 0, 12); AIC=3820.546, BIC=3852.046, Fit time=1.472 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(1, 0, 1, 12); AIC=3778.012, BIC=3813.450, Fit time=2.155 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(1, 0, 2, 12); AIC=3779.695, BIC=3819.070, Fit time=6.167 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(2, 0, 0, 12); AIC=3804.309, BIC=3839.746, Fit time=6.110 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(2, 0, 1, 12); AIC=3779.619, BIC=3818.994, Fit time=6.921 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(2, 0, 2, 12); AIC=3781.355, BIC=3824.668, Fit time=6.906 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(0, 0, 0, 12); AIC=3790.004, BIC=3821.504, Fit time=1.095 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(0, 0, 1, 12); AIC=3824.463, BIC=3859.901, Fit time=2.668 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(0, 0, 2, 12); AIC=3809.273, BIC=3848.648, Fit time=6.688 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(1, 0, 0, 12); AIC=3811.500, BIC=3846.938, Fit time=1.985 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(1, 0, 1, 12); AIC=3777.267, BIC=3816.642, Fit time=3.006 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(1, 0, 2, 12); AIC=3781.088, BIC=3824.401, Fit time=7.809 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(2, 0, 0, 12); AIC=3797.560, BIC=3836.935, Fit time=6.525 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(2, 0, 1, 12); AIC=3790.187, BIC=3833.500, Fit time=7.587 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(2, 0, 2, 12); AIC=3779.927, BIC=3827.177, Fit time=8.581 seconds
# Fit ARIMA: order=(3, 1, 4) seasonal_order=(0, 0, 0, 12); AIC=3787.825, BIC=3823.263, Fit time=1.205 seconds
# Fit ARIMA: order=(3, 1, 4) seasonal_order=(0, 0, 1, 12); AIC=3786.589, BIC=3825.965, Fit time=3.419 seconds
# Fit ARIMA: order=(3, 1, 4) seasonal_order=(0, 0, 2, 12); AIC=3782.219, BIC=3825.531, Fit time=7.954 seconds
# Fit ARIMA: order=(3, 1, 4) seasonal_order=(1, 0, 0, 12); AIC=3784.985, BIC=3824.361, Fit time=2.349 seconds
# Fit ARIMA: order=(3, 1, 4) seasonal_order=(1, 0, 1, 12); AIC=3771.551, BIC=3814.864, Fit time=4.044 seconds
# Fit ARIMA: order=(3, 1, 4) seasonal_order=(1, 0, 2, 12); AIC=3775.191, BIC=3822.441, Fit time=9.088 seconds
# Fit ARIMA: order=(3, 1, 4) seasonal_order=(2, 0, 0, 12); AIC=3780.015, BIC=3823.328, Fit time=7.031 seconds
# Fit ARIMA: order=(3, 1, 4) seasonal_order=(2, 0, 1, 12); AIC=3774.471, BIC=3821.721, Fit time=8.278 seconds
# Fit ARIMA: order=(3, 1, 4) seasonal_order=(2, 0, 2, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(3, 1, 5) seasonal_order=(0, 0, 0, 12); AIC=3792.622, BIC=3831.998, Fit time=1.751 seconds
# Fit ARIMA: order=(3, 1, 5) seasonal_order=(0, 0, 1, 12); AIC=3787.791, BIC=3831.104, Fit time=4.364 seconds
# Fit ARIMA: order=(3, 1, 5) seasonal_order=(0, 0, 2, 12); AIC=3782.970, BIC=3830.221, Fit time=10.121 seconds
# Fit ARIMA: order=(3, 1, 5) seasonal_order=(1, 0, 0, 12); AIC=3788.668, BIC=3831.981, Fit time=2.698 seconds
# Fit ARIMA: order=(3, 1, 5) seasonal_order=(1, 0, 1, 12); AIC=3775.541, BIC=3822.792, Fit time=4.651 seconds
# Fit ARIMA: order=(3, 1, 5) seasonal_order=(1, 0, 2, 12); AIC=3774.272, BIC=3825.460, Fit time=10.657 seconds
# Fit ARIMA: order=(3, 1, 5) seasonal_order=(2, 0, 0, 12); AIC=3780.663, BIC=3827.914, Fit time=7.722 seconds
# Fit ARIMA: order=(3, 1, 5) seasonal_order=(2, 0, 1, 12); AIC=3781.262, BIC=3832.450, Fit time=7.891 seconds
# Fit ARIMA: order=(3, 1, 5) seasonal_order=(2, 0, 2, 12); AIC=3777.404, BIC=3832.530, Fit time=11.417 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(0, 0, 0, 12); AIC=3852.310, BIC=3875.935, Fit time=0.304 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(0, 0, 1, 12); AIC=3838.026, BIC=3865.589, Fit time=0.620 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(0, 0, 2, 12); AIC=3825.176, BIC=3856.676, Fit time=1.676 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(1, 0, 0, 12); AIC=3830.524, BIC=3858.087, Fit time=1.116 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(1, 0, 1, 12); AIC=3787.762, BIC=3819.262, Fit time=2.017 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(1, 0, 2, 12); AIC=3789.534, BIC=3824.972, Fit time=4.859 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(2, 0, 0, 12); AIC=3816.476, BIC=3847.977, Fit time=3.379 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(2, 0, 1, 12); AIC=3789.521, BIC=3824.959, Fit time=6.551 seconds
# Fit ARIMA: order=(4, 1, 0) seasonal_order=(2, 0, 2, 12); AIC=3791.159, BIC=3830.534, Fit time=5.396 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(0, 0, 0, 12); AIC=3846.933, BIC=3874.496, Fit time=0.684 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(0, 0, 1, 12); AIC=3834.631, BIC=3866.131, Fit time=1.996 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(0, 0, 2, 12); AIC=3814.226, BIC=3849.664, Fit time=4.046 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(1, 0, 0, 12); AIC=3828.639, BIC=3860.139, Fit time=2.080 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(1, 0, 1, 12); AIC=3789.046, BIC=3824.484, Fit time=2.391 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(1, 0, 2, 12); AIC=3781.399, BIC=3820.775, Fit time=7.396 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(2, 0, 0, 12); AIC=3802.650, BIC=3838.088, Fit time=4.135 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(2, 0, 1, 12); AIC=3790.842, BIC=3830.217, Fit time=6.580 seconds
# Fit ARIMA: order=(4, 1, 1) seasonal_order=(2, 0, 2, 12); AIC=3780.667, BIC=3823.980, Fit time=8.140 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(0, 0, 0, 12); AIC=3842.442, BIC=3873.942, Fit time=0.798 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(0, 0, 1, 12); AIC=3828.770, BIC=3864.208, Fit time=1.495 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(0, 0, 2, 12); AIC=3811.417, BIC=3850.792, Fit time=5.369 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(1, 0, 0, 12); AIC=3819.701, BIC=3855.138, Fit time=1.877 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(1, 0, 1, 12); AIC=3780.330, BIC=3819.705, Fit time=2.860 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(1, 0, 2, 12); AIC=3782.110, BIC=3825.423, Fit time=6.791 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(2, 0, 0, 12); AIC=3801.246, BIC=3840.621, Fit time=6.127 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(2, 0, 1, 12); AIC=3782.167, BIC=3825.480, Fit time=7.509 seconds
# Fit ARIMA: order=(4, 1, 2) seasonal_order=(2, 0, 2, 12); AIC=3783.470, BIC=3830.720, Fit time=8.345 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(0, 0, 0, 12); AIC=3855.767, BIC=3891.205, Fit time=1.333 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(0, 0, 1, 12); AIC=3823.321, BIC=3862.697, Fit time=2.717 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(0, 0, 2, 12); AIC=3782.118, BIC=3825.431, Fit time=7.846 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(1, 0, 0, 12); AIC=3818.075, BIC=3857.450, Fit time=2.903 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(1, 0, 1, 12); AIC=3778.649, BIC=3821.962, Fit time=3.708 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(1, 0, 2, 12); AIC=3787.791, BIC=3835.042, Fit time=8.723 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(2, 0, 0, 12); AIC=3782.407, BIC=3825.720, Fit time=7.352 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(2, 0, 1, 12); AIC=3787.987, BIC=3835.238, Fit time=8.246 seconds
# Fit ARIMA: order=(4, 1, 3) seasonal_order=(2, 0, 2, 12); AIC=3785.304, BIC=3836.492, Fit time=9.628 seconds
# Fit ARIMA: order=(4, 1, 4) seasonal_order=(0, 0, 0, 12); AIC=3790.609, BIC=3829.985, Fit time=1.602 seconds
# Fit ARIMA: order=(4, 1, 4) seasonal_order=(0, 0, 1, 12); AIC=3787.820, BIC=3831.133, Fit time=3.725 seconds
# Fit ARIMA: order=(4, 1, 4) seasonal_order=(0, 0, 2, 12); AIC=3783.725, BIC=3830.976, Fit time=9.041 seconds
# Fit ARIMA: order=(4, 1, 4) seasonal_order=(1, 0, 0, 12); AIC=3786.019, BIC=3829.332, Fit time=3.313 seconds
# Fit ARIMA: order=(4, 1, 4) seasonal_order=(1, 0, 1, 12); AIC=3779.367, BIC=3826.618, Fit time=3.907 seconds
# Fit ARIMA: order=(4, 1, 4) seasonal_order=(1, 0, 2, 12); AIC=3779.591, BIC=3830.779, Fit time=8.745 seconds
# Fit ARIMA: order=(4, 1, 4) seasonal_order=(2, 0, 0, 12); AIC=3783.300, BIC=3830.550, Fit time=8.200 seconds
# Fit ARIMA: order=(4, 1, 4) seasonal_order=(2, 0, 1, 12); AIC=3774.075, BIC=3825.263, Fit time=9.332 seconds
# Fit ARIMA: order=(4, 1, 4) seasonal_order=(2, 0, 2, 12); AIC=3781.606, BIC=3836.732, Fit time=10.451 seconds
# Fit ARIMA: order=(4, 1, 5) seasonal_order=(0, 0, 0, 12); AIC=3792.376, BIC=3835.689, Fit time=1.771 seconds
# Fit ARIMA: order=(4, 1, 5) seasonal_order=(0, 0, 1, 12); AIC=3793.840, BIC=3841.090, Fit time=4.214 seconds
# Fit ARIMA: order=(4, 1, 5) seasonal_order=(0, 0, 2, 12); AIC=3785.442, BIC=3836.630, Fit time=10.357 seconds
# Fit ARIMA: order=(4, 1, 5) seasonal_order=(1, 0, 0, 12); AIC=3792.352, BIC=3839.602, Fit time=3.475 seconds
# Fit ARIMA: order=(4, 1, 5) seasonal_order=(1, 0, 1, 12); AIC=3779.326, BIC=3830.514, Fit time=5.004 seconds
# Fit ARIMA: order=(4, 1, 5) seasonal_order=(1, 0, 2, 12); AIC=3786.709, BIC=3841.834, Fit time=11.596 seconds
# Fit ARIMA: order=(4, 1, 5) seasonal_order=(2, 0, 0, 12); AIC=3782.260, BIC=3833.448, Fit time=8.952 seconds
# Fit ARIMA: order=(4, 1, 5) seasonal_order=(2, 0, 1, 12); AIC=3786.583, BIC=3841.708, Fit time=9.674 seconds
# Fit ARIMA: order=(4, 1, 5) seasonal_order=(2, 0, 2, 12); AIC=3778.671, BIC=3837.734, Fit time=11.325 seconds
# Fit ARIMA: order=(5, 1, 0) seasonal_order=(0, 0, 0, 12); AIC=3851.660, BIC=3879.223, Fit time=0.281 seconds
# Fit ARIMA: order=(5, 1, 0) seasonal_order=(0, 0, 1, 12); AIC=3838.357, BIC=3869.857, Fit time=0.634 seconds
# Fit ARIMA: order=(5, 1, 0) seasonal_order=(0, 0, 2, 12); AIC=3826.964, BIC=3862.402, Fit time=1.854 seconds
# Fit ARIMA: order=(5, 1, 0) seasonal_order=(1, 0, 0, 12); AIC=3831.683, BIC=3863.183, Fit time=1.379 seconds
# Fit ARIMA: order=(5, 1, 0) seasonal_order=(1, 0, 1, 12); AIC=3789.759, BIC=3825.197, Fit time=2.869 seconds
# Fit ARIMA: order=(5, 1, 0) seasonal_order=(1, 0, 2, 12); AIC=3791.530, BIC=3830.906, Fit time=5.328 seconds
# Fit ARIMA: order=(5, 1, 0) seasonal_order=(2, 0, 0, 12); AIC=3818.472, BIC=3853.910, Fit time=3.458 seconds
# Fit ARIMA: order=(5, 1, 0) seasonal_order=(2, 0, 1, 12); AIC=3791.518, BIC=3830.893, Fit time=6.709 seconds
# Fit ARIMA: order=(5, 1, 0) seasonal_order=(2, 0, 2, 12); AIC=3793.154, BIC=3836.466, Fit time=6.376 seconds
# Fit ARIMA: order=(5, 1, 1) seasonal_order=(0, 0, 0, 12); AIC=3848.645, BIC=3880.145, Fit time=0.735 seconds
# Fit ARIMA: order=(5, 1, 1) seasonal_order=(0, 0, 1, 12); AIC=3836.509, BIC=3871.947, Fit time=2.090 seconds
# Fit ARIMA: order=(5, 1, 1) seasonal_order=(0, 0, 2, 12); AIC=3814.961, BIC=3854.336, Fit time=5.057 seconds
# Fit ARIMA: order=(5, 1, 1) seasonal_order=(1, 0, 0, 12); AIC=3830.623, BIC=3866.061, Fit time=2.198 seconds
# Fit ARIMA: order=(5, 1, 1) seasonal_order=(1, 0, 1, 12); AIC=3790.819, BIC=3830.194, Fit time=2.911 seconds
# Fit ARIMA: order=(5, 1, 1) seasonal_order=(1, 0, 2, 12); AIC=3792.627, BIC=3835.940, Fit time=6.783 seconds
# Fit ARIMA: order=(5, 1, 1) seasonal_order=(2, 0, 0, 12); AIC=3804.083, BIC=3843.459, Fit time=5.367 seconds
# Fit ARIMA: order=(5, 1, 1) seasonal_order=(2, 0, 1, 12); AIC=3792.600, BIC=3835.912, Fit time=7.781 seconds
# Fit ARIMA: order=(5, 1, 1) seasonal_order=(2, 0, 2, 12); AIC=3794.330, BIC=3841.581, Fit time=8.575 seconds
# Fit ARIMA: order=(5, 1, 2) seasonal_order=(0, 0, 0, 12); AIC=3846.376, BIC=3881.814, Fit time=1.076 seconds
# Fit ARIMA: order=(5, 1, 2) seasonal_order=(0, 0, 1, 12); AIC=3831.990, BIC=3871.365, Fit time=2.028 seconds
# Fit ARIMA: order=(5, 1, 2) seasonal_order=(0, 0, 2, 12); AIC=3815.920, BIC=3859.233, Fit time=6.180 seconds
# Fit ARIMA: order=(5, 1, 2) seasonal_order=(1, 0, 0, 12); AIC=3822.432, BIC=3861.808, Fit time=2.872 seconds
# Fit ARIMA: order=(5, 1, 2) seasonal_order=(1, 0, 1, 12); AIC=3781.682, BIC=3824.995, Fit time=3.288 seconds
# Fit ARIMA: order=(5, 1, 2) seasonal_order=(1, 0, 2, 12); AIC=3783.841, BIC=3831.092, Fit time=7.192 seconds
# Fit ARIMA: order=(5, 1, 2) seasonal_order=(2, 0, 0, 12); AIC=3806.650, BIC=3849.963, Fit time=5.172 seconds
# Fit ARIMA: order=(5, 1, 2) seasonal_order=(2, 0, 1, 12); AIC=3784.052, BIC=3831.303, Fit time=8.132 seconds
# Fit ARIMA: order=(5, 1, 2) seasonal_order=(2, 0, 2, 12); AIC=3784.520, BIC=3835.708, Fit time=9.485 seconds
# Fit ARIMA: order=(5, 1, 3) seasonal_order=(0, 0, 0, 12); AIC=3792.108, BIC=3831.483, Fit time=1.233 seconds
# Fit ARIMA: order=(5, 1, 3) seasonal_order=(0, 0, 1, 12); AIC=3786.933, BIC=3830.245, Fit time=3.013 seconds
# Fit ARIMA: order=(5, 1, 3) seasonal_order=(0, 0, 2, 12); AIC=3779.882, BIC=3827.133, Fit time=8.114 seconds
# Fit ARIMA: order=(5, 1, 3) seasonal_order=(1, 0, 0, 12); AIC=3785.096, BIC=3828.408, Fit time=3.607 seconds
# Fit ARIMA: order=(5, 1, 3) seasonal_order=(1, 0, 1, 12); AIC=3773.732, BIC=3820.982, Fit time=3.712 seconds
# Fit ARIMA: order=(5, 1, 3) seasonal_order=(1, 0, 2, 12); AIC=3776.109, BIC=3827.297, Fit time=8.610 seconds
# Fit ARIMA: order=(5, 1, 3) seasonal_order=(2, 0, 0, 12); AIC=3778.211, BIC=3825.462, Fit time=9.297 seconds
# Fit ARIMA: order=(5, 1, 3) seasonal_order=(2, 0, 1, 12); AIC=3773.499, BIC=3824.686, Fit time=10.417 seconds
# Fit ARIMA: order=(5, 1, 3) seasonal_order=(2, 0, 2, 12); AIC=3774.506, BIC=3829.632, Fit time=10.957 seconds
# Fit ARIMA: order=(5, 1, 4) seasonal_order=(0, 0, 0, 12); AIC=3790.416, BIC=3833.729, Fit time=1.329 seconds
# Fit ARIMA: order=(5, 1, 4) seasonal_order=(0, 0, 1, 12); AIC=3787.702, BIC=3834.952, Fit time=3.924 seconds
# Fit ARIMA: order=(5, 1, 4) seasonal_order=(0, 0, 2, 12); AIC=3781.205, BIC=3832.393, Fit time=9.777 seconds
# Fit ARIMA: order=(5, 1, 4) seasonal_order=(1, 0, 0, 12); AIC=3786.303, BIC=3833.553, Fit time=3.855 seconds
# Fit ARIMA: order=(5, 1, 4) seasonal_order=(1, 0, 1, 12); AIC=3781.104, BIC=3832.292, Fit time=4.479 seconds
# Fit ARIMA: order=(5, 1, 4) seasonal_order=(1, 0, 2, 12); AIC=3782.705, BIC=3837.830, Fit time=11.517 seconds
# Fit ARIMA: order=(5, 1, 4) seasonal_order=(2, 0, 0, 12); AIC=3781.456, BIC=3832.644, Fit time=11.381 seconds
# Fit ARIMA: order=(5, 1, 4) seasonal_order=(2, 0, 1, 12); AIC=3775.109, BIC=3830.234, Fit time=11.052 seconds
# Fit ARIMA: order=(5, 1, 4) seasonal_order=(2, 0, 2, 12); AIC=3783.048, BIC=3842.111, Fit time=10.970 seconds
# Fit ARIMA: order=(5, 1, 5) seasonal_order=(0, 0, 0, 12); AIC=3795.049, BIC=3842.299, Fit time=2.092 seconds
# Fit ARIMA: order=(5, 1, 5) seasonal_order=(0, 0, 1, 12); AIC=3787.967, BIC=3839.155, Fit time=5.148 seconds
# Fit ARIMA: order=(5, 1, 5) seasonal_order=(0, 0, 2, 12); AIC=3785.925, BIC=3841.051, Fit time=12.258 seconds
# Fit ARIMA: order=(5, 1, 5) seasonal_order=(1, 0, 0, 12); AIC=3784.579, BIC=3835.767, Fit time=4.298 seconds
# Fit ARIMA: order=(5, 1, 5) seasonal_order=(1, 0, 1, 12); AIC=3785.440, BIC=3840.566, Fit time=5.727 seconds
# Fit ARIMA: order=(5, 1, 5) seasonal_order=(1, 0, 2, 12); AIC=3786.437, BIC=3845.500, Fit time=13.659 seconds
# Fit ARIMA: order=(5, 1, 5) seasonal_order=(2, 0, 0, 12); AIC=3781.633, BIC=3836.759, Fit time=10.298 seconds
# Fit ARIMA: order=(5, 1, 5) seasonal_order=(2, 0, 1, 12); AIC=3788.847, BIC=3847.910, Fit time=10.750 seconds
# Fit ARIMA: order=(5, 1, 5) seasonal_order=(2, 0, 2, 12); AIC=3784.881, BIC=3847.881, Fit time=13.763 seconds
# Total fit time: 1383.530 seconds

# %%
# Summarize residual errors for the automated grid search ARIMA model
print(autogrid_results.summary())
autogrid_results.plot_diagnostics(figsize=(12,12))
plt.show()
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  380
# Model:             SARIMAX(3, 1, 4)x(1, 0, 1, 12)   Log Likelihood               -1874.776
# Date:                            Tue, 12 Nov 2019   AIC                           3771.551
# Time:                                    14:01:30   BIC                           3814.864
# Sample:                                         0   HQIC                          3788.740
#                                             - 380
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0116      0.040      0.288      0.774      -0.068       0.091
# ar.L1         -1.0069      0.100    -10.062      0.000      -1.203      -0.811
# ar.L2          0.2457      0.174      1.408      0.159      -0.096       0.588
# ar.L3          0.7031      0.100      7.007      0.000       0.506       0.900
# ma.L1          0.7712      0.105      7.364      0.000       0.566       0.977
# ma.L2         -0.6358      0.133     -4.787      0.000      -0.896      -0.375
# ma.L3         -0.8488      0.048    -17.682      0.000      -0.943      -0.755
# ma.L4          0.0545      0.060      0.911      0.362      -0.063       0.172
# ar.S.L12       0.9899      0.022     45.972      0.000       0.948       1.032
# ma.S.L12      -0.9310      0.058    -15.980      0.000      -1.045      -0.817
# sigma2      1131.6568     54.219     20.872      0.000    1025.389    1237.925
# ===================================================================================
# Ljung-Box (Q):                       60.57   Jarque-Bera (JB):               285.97
# Prob(Q):                              0.02   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.44   Skew:                            -0.35
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.20
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
if (notifyStatus): email_notify("ARIMA automated grid search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Not applicable for this iteration of the project

# Set up the function to handle the ARIMA calculation
# def Calculate_ARIMA(ns_order, ss_order):
#     startTimeModel = datetime.now()
#     aic_score, bic_score = float("inf"), float("inf")
#     if (verbose): print('Trying to fit the model with parameters:', ns_order, ss_order)
#     try:
#         if (ss_order[3] == 0): grid_model = SARIMAX(train_ts, order=ns_order)
#         else: grid_model = SARIMAX(train_ts, order=ns_order, seasonal_order=ss_order)
#         with warnings.catch_warnings():
#             warnings.simplefilter("ignore")
#             grid_results = grid_model.fit(disp = False)
#         aic_score = grid_results.aic
#         bic_score = grid_results.bic
#         if (verbose): print('Fit ARIMA: order=%s seasonal_order=%s; AIC=%.3f, BIC=%.3f, Fit time=%s' % 
#               (ns_order, ss_order, aic_score, bic_score, (datetime.now() - startTimeModel)))
#         return(aic_score, bic_score)
#     except:
#         return(float("inf"), float("inf"))

# %%
# Not applicable for this iteration of the project

# Do a manual grid search of ARIMA parameters
# best_score, best_ns_cfg, best_ss_cfg = float("inf"), None, None
# for p in range(start_p, max_p+1):
#     for d in range(start_d, max_d+1):
#         for q in range(start_q, max_q+1):
#             for P in range(start_P, max_P+1):
#                 for D in range(start_D, max_D+1):
#                     for Q in range(start_Q, max_Q+1):
#                         ns_order = (p, d, q)
#                         ss_order = (P, D, Q, seasonal_freq)
#                         aic_score, bic_score = Calculate_ARIMA(ns_order, ss_order)
#                         if (aic_score < best_score):
#                             best_ns_cfg, best_ss_cfg, best_score = ns_order, ss_order, aic_score
#                             print('A better model found: order=%s seasonal_order=%s; AIC=%.3f, BIC=%.3f' % (ns_order, ss_order, aic_score, bic_score))
# print('Best ARIMA model via manual search: order=%s seasonal_order=%s; AIC=%f' % (best_ns_cfg, best_ss_cfg, best_score))

# %%
# Summarize residual errors for the manual ARIMA model
# manual_model = SARIMAX(train_ts, order=best_ns_cfg, seasonal_order=best_ss_cfg)
# manual_results = manual_model.fit(disp = False)
# print(manual_results.summary())
# manual_results.plot_diagnostics(figsize=(12,12))
# plt.show()

# %%
if (notifyStatus): email_notify("ARIMA Hyperparameters Search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 4.c) Evaluate the Residual Errors
#
# A good final check of a model is to review residual forecast errors. Ideally, the distribution of residual errors should be a Gaussian with a zero mean.

# %%
# Set the ARIMA order parameters for validation and forecasting
final_ns_order = stepwise_results.order
final_ss_order = stepwise_results.seasonal_order
# final_ns_order = randgrid_results.order
# final_ss_order = randgrid_results.seasonal_order
# final_ns_order = autogrid_results.order
# final_ss_order = autogrid_results.seasonal_order
# final_ns_order = best_ns_cfg
# final_ss_order = best_ss_cfg
print("Final Non-season order:", final_ns_order, 'Final Seasonal Order:', final_ss_order)
# Out:
# Final Non-season order: (1, 1, 1) Final Seasonal Order: (1, 0, 1, 12)

# %%
# Summarize residual errors for the final ARIMA model
final_model = SARIMAX(time_series, order=final_ns_order, seasonal_order=final_ss_order)
final_results = final_model.fit(disp = False)
print(final_results.summary())
final_results.plot_diagnostics(figsize=(12,12))
plt.show()
# Out:
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                             values   No. Observations:                  476
# Model:             SARIMAX(1, 1, 1)x(1, 0, 1, 12)   Log Likelihood               -2357.335
# Date:                            Tue, 12 Nov 2019   AIC                           4724.671
# Time:                                    14:01:32   BIC                           4745.487
# Sample:                                01-01-1956   HQIC                          4732.857
#                                      - 08-01-1995
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6298      0.047     13.357      0.000       0.537       0.722
# ma.L1         -0.8857      0.035    -25.465      0.000      -0.954      -0.818
# ar.S.L12       0.9837      0.015     63.826      0.000       0.953       1.014
# ma.S.L12      -0.8926      0.039    -23.082      0.000      -0.968      -0.817
# sigma2      1171.9330     48.427     24.200      0.000    1077.018    1266.848
# ===================================================================================
# Ljung-Box (Q):                       52.02   Jarque-Bera (JB):               230.83
# Prob(Q):                              0.10   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.02   Skew:                            -0.37
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.33
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
if (notifyStatus): email_notify("Model Fitting and Evaluation completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 5. Finalize Model
#
# After models have been developed and a final model selected, it must be validated and finalized. Validation is an optional part of the process, but one that provides a ‘last check’ to ensure we have not fooled or lied to ourselves.

# %%
if (notifyStatus): email_notify("Model Finalization has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 5.a) Validation via In-sample Data

# %%
forecast = final_results.get_prediction(start = -test_size)
mean_forecast = forecast.predicted_mean
confidence_intervals = forecast.conf_int()

# %%
plt.figure(figsize=(12,9))
plt.plot(time_series.index, time_series[target_col], label='observed')
plt.plot(mean_forecast.index, mean_forecast.values, color='red', label='forecast')
plt.fill_between(confidence_intervals.index, confidence_intervals[lower_bound], confidence_intervals[upper_bound], color='pink')
plt.show()

# %%
# Evaluate RMSE for the validation data
y = time_series[-test_size:]
predictions = mean_forecast.values
rmse = math.sqrt(mean_squared_error(y, predictions))
print('RMSE from the validation data is: %.3f' % rmse)
# Out:
# RMSE from the validation data is: 34.639

# %% [markdown]
# ### 5.b) Forecasting Out-of-Sample Data

# %%
forecast = final_results.get_forecast(steps = test_size)
mean_forecast = forecast.predicted_mean
confidence_intervals = forecast.conf_int()

# %%
plt.figure(figsize=(12,9))
plt.plot(time_series.index, time_series[target_col], label='observed')
plt.plot(mean_forecast.index, mean_forecast.values, color='red', label='forecast')
plt.fill_between(confidence_intervals.index, confidence_intervals[lower_bound], confidence_intervals[upper_bound], color='pink')
plt.show()

# %%
if (notifyStatus): email_notify("Model Finalization completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
print ('Total time for the script:',(datetime.now() - startTimeScript))
# Out:
# Total time for the script: 0:28:31.321268
