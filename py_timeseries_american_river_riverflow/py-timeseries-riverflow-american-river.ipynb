# %% [markdown]
# # Time Series Model for American River Riverflow Using Python
# ### David Lowe
# ### November 27, 2019
#
# Template Credit: Adapted from a template made available by Dr. Jason Brownlee of Machine Learning Mastery. https://machinelearningmastery.com/
#
# SUMMARY: The purpose of this project is to construct a time series prediction model and document the end-to-end steps using a template. The American River Riverflow dataset is a time series situation where we are trying to forecast future outcomes based on past data points.
#
# INTRODUCTION: The problem is to forecast the monthly riverflow for American River at Fair Oaks, California. The dataset describes a time-series of flow volume (in cms) over 55 years (1906-1960), and there are 660 observations. We used the first 80% of the observations for training and testing various models while holding back the remaining observations for validating the final model.
#
# ANALYSIS: The baseline prediction (or persistence) for the dataset resulted in an RMSE of 90.012. After performing a grid search for the most optimal ARIMA parameters, the final ARIMA non-seasonal order was (1, 0, 0) with the seasonal order being (1, 0, 1, 12). Furthermore, the chosen model processed the validation data with an RMSE of 78.413, which was better than the baseline model as expected.
#
# CONCLUSION: For this dataset, the chosen ARIMA model achieved a satisfactory result and should be considered for further modeling.
#
# Dataset Used: Monthly riverflow in cms, American River at Fair Oaks, California, October 1906 through September 1960
#
# Dataset ML Model: Time series forecast with numerical attributes
#
# Dataset Reference: Rob Hyndman and Yangzhuoran Yang (2018). tsdl: Time Series Data Library. v0.1.0. https://pkg.yangzhuoranyang./tsdl/.
#
# The project aims to touch on the following areas:
#
# * Document a predictive modeling problem end-to-end
# * Explore data cleaning and transformation options
# * Explore various algorithms for baselining the model performance
# * Explore tuning techniques for improving the model performance
#
# A time series predictive modeling project genrally can be broken down into about five major tasks:
#
# 1. Define Problem and Acquire Data
# 2. Inspect and Explore Data
# 3. Clean and Pre-Process Data
# 4. Fit and Evaluate Models
# 5. Finalize Model

# %% [markdown]
# ## Section 1. Define Problem and Acquire Data

# %% [markdown]
# ### 1.a) Load Libraries

# %%
# Set the warning message filter
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import math
import smtplib
import pmdarima as pm
from datetime import datetime
from email.message import EmailMessage
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %% [markdown]
# ### 1.b) Set up the controlling parameters and functions

# %%
# Create the random seed number for reproducible results
seedNum = 888

# Set up the number of CPU cores available for multi-thread processing
n_jobs = 1

# Set up the verbose flag to print detailed messages for debugging (setting True will activate!)
verbose = False

# Set up the flag to stop sending progress emails (setting to True will send status emails!)
notifyStatus = False

# %%
# Set up the email notification function
def email_notify(msg_text):
    sender = os.environ.get('MAIL_SENDER')
    receiver = os.environ.get('MAIL_RECEIVER')
    gateway = os.environ.get('SMTP_GATEWAY')
    smtpuser = os.environ.get('SMTP_USERNAME')
    password = os.environ.get('SMTP_PASSWORD')
    if sender==None or receiver==None or gateway==None or smtpuser==None or password==None:
        sys.exit("Incomplete email setup info. Script Processing Aborted!!!")
    msg = EmailMessage()
    msg.set_content(msg_text)
    msg['Subject'] = 'Notification from Python ARIMA Time Series Script'
    msg['From'] = sender
    msg['To'] = receiver
    server = smtplib.SMTP(gateway, 587)
    server.starttls()
    server.login(smtpuser, password)
    server.send_message(msg)
    server.quit()

# %%
if (notifyStatus): email_notify("Library and Data Loading has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 1.c) Acquire and Load the Data
#
# Since the dataset is not current, this means that we cannot easily collect updated data to validate the model. Therefore, we will withhold a portion of the data towards the end from analysis and model selection. This very segment of data will be used to validate the final model.

# %%
startTimeScript = datetime.now()

# %%
# load the dataset and the necessary data structure
time_series = pd.read_csv('https://github.com/daines-analytics/datasets-public/raw/master/time-series-data-library/tsdl228.csv', index_col='idx', parse_dates=True)

# Sample code for subsetting the time-series data
# time_series = original_series['1986':'1990']

# %%
target_col = time_series.columns[0]
lower_bound = 'lower ' + target_col
upper_bound = 'upper ' + target_col
print('The target column of the time series is:', target_col)
print('The forecast boundary columns are:', lower_bound, '&', upper_bound)
# Out:
# The target column of the time series is: values
# The forecast boundary columns are: lower values & upper values

# %%
time_series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 660 entries, 1906-10-01 to 1961-09-01
# Data columns (total 1 columns):
# values    660 non-null float64
# dtypes: float64(1)
# memory usage: 10.3 KB

# %%
time_series.head(10)
# Out:
#               values
# idx
# 1906-10-01    4.1626
# 1906-11-01    5.4935
# 1906-12-01    7.1925
# 1907-01-01  205.5237
# 1907-02-01  168.0322
# 1907-03-01  400.6834
# 1907-04-01  342.6339
# 1907-05-01  427.0181
# 1907-06-01  454.4854
# 1907-07-01  179.4156

# %%
time_series.tail(10)
# Out:
#               values
# idx
# 1960-12-01   17.4715
# 1961-01-01   16.6220
# 1961-02-01   76.3139
# 1961-03-01  107.1510
# 1961-04-01   89.2264
# 1961-05-01   53.8303
# 1961-06-01   81.8074
# 1961-07-01   95.3428
# 1961-08-01   67.0543
# 1961-09-01   34.9713

# %%
if (notifyStatus): email_notify("Library and Data Loading completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 2. Inspect and Explore Data

# %%
if (notifyStatus): email_notify("Data Inspection and Exploration has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 2.a) Summary Statistics of the Time Series Data
#
# Summary statistics provide a quick look at the limits of observed values. It can help to get a quick idea of what we are working with.

# %%
# Summary statistics of time series
print(time_series.describe())
# Out:
#            values
# count  660.000000
# mean   106.186175
# std    119.789848
# min      0.447400
# 25%     15.453900
# 50%     54.694000
# 75%    167.671150
# max    699.709400

# %% [markdown]
# ### 2.b) Line Plot of the Time Series Data
#
# A line plot of a time series can provide a lot of insight into the problem. Some observations from the plot can include:
#
# * Whether the trend appears to be level around the mean
# * Whether there appear to be any obvious outliers
#
# The ARIMA(p,d,q) model requires three parameters and assumes that we are working with a stationary time series.
#
# The ADF results should show that the test statistic value is smaller than the critical value at 5% if the time series is stationary. This suggests that we can reject the null hypothesis (i.e. a low probability that the result is a statistical fluke).

# %%
# Line plots of time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Time Series Data')
time_series.plot(ax=ax)
plt.show()

# %% [markdown]
# ### 2.c) Histogram and Density Plots of the Time Series Data
#
# Reviewing plots of the density of observations can provide further insight into the structure of the data. Some observations from the plots can include:
#
# * Whether the distribution is Gaussian
# * Whether the distribution has a long tail and may suggest the need for data transformation

# %%
# Line plots of time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Histogram of the Time Series Data')
time_series.hist(ax=ax)
plt.show()

# %%
# Line plots of time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Density Plot of the Time Series Data')
time_series.plot(kind='kde', ax=ax)
plt.show()

# %% [markdown]
# ### 2.d) Box and Whisker Plots of the Time Series Data
#
# We can group or aggregate the data and get a better idea of the spread of observations. Some observations from reviewing the plot can include:
#
# * Whether the median values for each grouping shows any significant trend
# * Whether the spread, or middle 50% of the data, shows any significant variability
# * Whether there are outliers in some grouping

# %%
# boxplots of time series
fig, ax = plt.subplots(figsize=(12,9))
squeezed = time_series.squeeze()
sns.boxplot(squeezed.index.year, squeezed, ax=ax)
plt.show()

# %%
if (notifyStatus): email_notify("Data Inspection and Exploration completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 3. Data Transformation and Stationarity Tests

# %%
if (notifyStatus): email_notify("Data Cleaning and Pre-Processing has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### Section 3.a) Data Transformation

# %%
# Resampling the time series into monthly average for the ease of modeling
# original_series = time_series
# resample = original_series.resample('M')
# time_series = resample.mean()
# time_series.head(10)

# %%
# Line plots of the transformed time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Non-Seasonal Time Series Data')
time_series.plot(ax=ax)
plt.show()

# %% [markdown]
# ### Section 3.b) Test for Stationarity

# %%
# Check if stationary
result = adfuller(time_series[target_col])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Test Statistics Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -6.209850
# p-value: 0.000000
# Critical Test Statistics Values:
# 	1%: -3.441
# 	5%: -2.866
# 	10%: -2.569

# %%
# ACF and PACF plots of the time series data
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))
plot_acf(time_series, ax=ax1)
plot_pacf(time_series, ax=ax2)
plt.show()

# %% [markdown]
# ### 3.c) Test for Stationarity of Non-Seasonal Time Series Data
#
# Occasionally a time series may look non-stationary on the first look. We can make it stationary by differencing the series and using a statistical test to confirm that the differenced result is stationary. Rejecting the null hypothesis means that the process has no unit root, and in turn that the time series is stationary or does not have time-dependent structure.

# %%
# Create a differenced series
stationary_ns = time_series.diff().dropna()

# Plot differenced data
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Stationary Time Series Data')
stationary_ns.plot(ax=ax)
plt.show()

# %%
# Check for stationarity
result = adfuller(stationary_ns[target_col])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Test Statistics Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -10.556154
# p-value: 0.000000
# Critical Test Statistics Values:
# 	1%: -3.441
# 	5%: -2.866
# 	10%: -2.569

# %%
# ACF and PACF plots of the stationary time series
lags = 25
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))
plot_acf(stationary_ns, lags=lags, ax=ax1)
plot_pacf(stationary_ns, lags=lags, ax=ax2)
plt.show()

# %% [markdown]
# ### 3.d) Seasonal Decomposition for Seasonal Time Series Data

# %%
# Set the initial seasonal frequency parameter
seasonal_freq = 12

# %%
# Perform seasonal decomposition to observe the seasonal frequency
decomp_results = seasonal_decompose(time_series, freq=seasonal_freq)
decomp_results.plot()
plt.show()

# %%
# Create a seasonal series
N = seasonal_freq
seasonal_series = time_series - time_series.rolling(N).mean()
seasonal_series = seasonal_series.dropna()

# Line plots of the seasonal time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Seasonal Time Series Data')
seasonal_series.plot(ax=ax)
plt.show()

# %%
# Check for stationarity
result = adfuller(seasonal_series[target_col])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Test Statistics Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -10.610308
# p-value: 0.000000
# Critical Test Statistics Values:
# 	1%: -3.441
# 	5%: -2.866
# 	10%: -2.569

# %%
# ACF and PACF plots of the time series data
lag = seasonal_freq * 2
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))
plot_acf(seasonal_series, lags=lag, ax=ax1)
plot_pacf(seasonal_series, lags=lag, ax=ax2)
plt.show()

# %% [markdown]
# ### 3.e) Test for Stationarity of Seasonal Time Series Data
#
# Occasionally a time series may look non-stationary on the first look. We can make it stationary by differencing the series and using a statistical test to confirm that the differenced result is stationary. Rejecting the null hypothesis means that the process has no unit root, and in turn that the time series is stationary or does not have time-dependent structure.

# %%
# Create a differenced series
stationary_ss = time_series.diff(seasonal_freq).dropna()

# Plot differenced data
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Stationary Seasonal Time Series Data')
stationary_ss.plot(ax=ax)
plt.show()

# %%
# Check for stationarity
result = adfuller(stationary_ss[target_col])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Test Statistics Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -9.414151
# p-value: 0.000000
# Critical Test Statistics Values:
# 	1%: -3.441
# 	5%: -2.866
# 	10%: -2.569

# %%
# ACF and PACF plots of the stationary time series
lags = seasonal_freq * 2
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))
plot_acf(stationary_ss, lags=lags, ax=ax1)
plot_pacf(stationary_ss, lags=lags, ax=ax2)
plt.show()

# %%
if (notifyStatus): email_notify("Data Cleaning and Pre-Processing completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 4. Fit and Evaluate Models
#
# In this section, we will develop Autoregressive Integrated Moving Average or ARIMA models for the problem. We will first establish a persistent model. Next we will use a grid search approach to look for an optimal ARIMA model. This will be followed by a third step of investigating the residual errors of the chosen model.
#
# * Establish the Persistent Model
# * Automatically Configure the ARIMA
# * Review Residual Errors

# %%
if (notifyStatus): email_notify("Model Fitting and Evaluation has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 4.a) Establish the Persistent Model
#
# The first step before getting bogged down in data analysis and modeling is to establish a baseline of performance. This will provide both a template for evaluating models using the proposed test harness and a performance measure by which all more elaborate predictive models can be compared.
#
# The baseline prediction for time series forecasting is called the naive forecast, or persistence. This is where the observation from the previous time step is used as the prediction for the observation at the next time step.

# %% [markdown]
# #### 4.a.iii) Establish the Persistent Model as Baseline

# %%
# Prepare and evaluate a persistence model
X = time_series.values
X = X.astype('float32')
train_pct = 0.80
train_size = int(len(X) * train_pct)
test_size = len(X) - train_size
train_ts, test_ts = X[0:train_size], X[train_size:]

# walk-forward validation
history = [x for x in train_ts]
predictions = list()
for i in range(len(test_ts)):
    yhat = history[-1]
    predictions.append(yhat)
    obs = test_ts[i]
    history.append(obs)
    print('>Predicted=%.3f, Expected=%3.f' % (yhat, obs))

# Calculate performance
rmse = math.sqrt(mean_squared_error(test_ts, predictions))
print('RMSE for the persistent model is: %.3f' % rmse)
# Out:
# >Predicted=4.672, Expected=  7
# >Predicted=6.994, Expected= 17
# >Predicted=16.735, Expected= 18
# >Predicted=17.811, Expected=146
# >Predicted=145.803, Expected=178
# >Predicted=177.773, Expected=160
# >Predicted=159.566, Expected=279
# >Predicted=278.978, Expected=271
# >Predicted=270.964, Expected=152
# >Predicted=151.665, Expected= 34
# >Predicted=33.810, Expected=  8
# >Predicted=7.929, Expected= 10
# >Predicted=9.599, Expected= 26
# >Predicted=26.108, Expected=466
# >Predicted=465.812, Expected=492
# >Predicted=491.581, Expected=274
# >Predicted=273.739, Expected=221
# >Predicted=221.410, Expected=199
# >Predicted=199.322, Expected=202
# >Predicted=202.211, Expected=210
# >Predicted=210.423, Expected= 71
# >Predicted=71.047, Expected= 18
# >Predicted=17.641, Expected=  8
# >Predicted=8.325, Expected=  8
# >Predicted=7.702, Expected= 19
# >Predicted=19.425, Expected= 54
# >Predicted=53.830, Expected=154
# >Predicted=153.959, Expected=256
# >Predicted=256.013, Expected=275
# >Predicted=275.410, Expected=231
# >Predicted=231.122, Expected=389
# >Predicted=389.357, Expected=515
# >Predicted=515.367, Expected=314
# >Predicted=314.317, Expected=110
# >Predicted=109.813, Expected= 26
# >Predicted=26.023, Expected= 15
# >Predicted=14.895, Expected= 13
# >Predicted=12.969, Expected= 16
# >Predicted=15.716, Expected= 55
# >Predicted=55.275, Expected=216
# >Predicted=216.284, Expected= 80
# >Predicted=80.080, Expected=107
# >Predicted=106.811, Expected=222
# >Predicted=222.457, Expected=225
# >Predicted=225.289, Expected=238
# >Predicted=237.918, Expected= 73
# >Predicted=72.944, Expected= 13
# >Predicted=12.658, Expected= 11
# >Predicted=11.440, Expected= 16
# >Predicted=15.829, Expected= 30
# >Predicted=30.044, Expected= 40
# >Predicted=39.870, Expected= 65
# >Predicted=64.704, Expected=112
# >Predicted=112.276, Expected=208
# >Predicted=207.902, Expected=260
# >Predicted=260.119, Expected=165
# >Predicted=165.031, Expected= 49
# >Predicted=49.300, Expected= 13
# >Predicted=12.601, Expected=  7
# >Predicted=6.881, Expected= 10
# >Predicted=9.854, Expected= 12
# >Predicted=12.233, Expected= 22
# >Predicted=22.059, Expected= 61
# >Predicted=60.853, Expected= 76
# >Predicted=75.578, Expected= 52
# >Predicted=51.848, Expected= 47
# >Predicted=46.836, Expected= 31
# >Predicted=31.432, Expected=120
# >Predicted=119.950, Expected=107
# >Predicted=106.670, Expected= 50
# >Predicted=50.376, Expected= 61
# >Predicted=61.108, Expected= 30
# >Predicted=29.931, Expected= 23
# >Predicted=22.710, Expected= 16
# >Predicted=15.574, Expected=416
# >Predicted=415.974, Expected=463
# >Predicted=463.264, Expected=158
# >Predicted=157.527, Expected=153
# >Predicted=152.968, Expected=113
# >Predicted=112.758, Expected=181
# >Predicted=180.661, Expected=191
# >Predicted=191.450, Expected=121
# >Predicted=120.856, Expected=112
# >Predicted=112.361, Expected= 66
# >Predicted=66.346, Expected= 38
# >Predicted=38.001, Expected= 56
# >Predicted=55.699, Expected= 46
# >Predicted=46.015, Expected= 33
# >Predicted=32.536, Expected= 48
# >Predicted=47.629, Expected=193
# >Predicted=193.121, Expected= 93
# >Predicted=93.332, Expected=148
# >Predicted=147.814, Expected=124
# >Predicted=123.858, Expected= 86
# >Predicted=85.942, Expected= 93
# >Predicted=92.681, Expected= 70
# >Predicted=70.367, Expected= 52
# >Predicted=52.245, Expected= 63
# >Predicted=62.609, Expected= 33
# >Predicted=32.734, Expected= 57
# >Predicted=56.549, Expected=248
# >Predicted=247.659, Expected=236
# >Predicted=235.936, Expected=425
# >Predicted=425.319, Expected=313
# >Predicted=312.901, Expected=234
# >Predicted=233.501, Expected=106
# >Predicted=105.735, Expected=103
# >Predicted=103.187, Expected= 89
# >Predicted=89.255, Expected= 46
# >Predicted=45.703, Expected= 44
# >Predicted=44.316, Expected= 43
# >Predicted=43.325, Expected= 31
# >Predicted=30.639, Expected= 75
# >Predicted=75.464, Expected= 85
# >Predicted=84.979, Expected= 34
# >Predicted=33.556, Expected= 30
# >Predicted=29.874, Expected= 61
# >Predicted=60.541, Expected=116
# >Predicted=115.504, Expected= 95
# >Predicted=94.691, Expected= 35
# >Predicted=35.481, Expected= 18
# >Predicted=17.896, Expected= 19
# >Predicted=19.454, Expected= 17
# >Predicted=17.472, Expected= 17
# >Predicted=16.622, Expected= 76
# >Predicted=76.314, Expected=107
# >Predicted=107.151, Expected= 89
# >Predicted=89.226, Expected= 54
# >Predicted=53.830, Expected= 82
# >Predicted=81.807, Expected= 95
# >Predicted=95.343, Expected= 67
# >Predicted=67.054, Expected= 35
# RMSE for the persistent model is: 90.012

# %% [markdown]
# ### 4.b) Grid Search of ARIMA Hyperparameters
#
# We want to find a model that can do better than the persistence model on this dataset. To confirm this analysis, we can grid search a suite of ARIMA hyperparameters.
#
# In this section, we will search values of p, d, and q for combinations (skipping those that fail to converge), and find the combination that results in the best performance. We will use a grid search to explore all combinations in a subset of integer values.

# %%
if (notifyStatus): email_notify("ARIMA Hyperparameters Search has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Set the initial P, D, and Q order parameters for non-seasonal ARIMA modeling
start_p = 0
start_d = None
start_q = 0
max_p = 5
max_d = 2
max_q = 5

# %%
# Set the initial P, D, and Q order parameters for seasonal ARIMA modeling
start_P = 0
start_D = None
start_Q = 0
max_P = 2
max_D = 1
max_Q = 2

# %%
# Testing the time series data for suggestions on the differencing term
start_d = pm.arima.ndiffs(train_ts)
print('The suggested non-seasonal differencing term is:', start_d)
if (seasonal_freq != 0):
    start_D = pm.arima.nsdiffs(train_ts, m = seasonal_freq)
    print('The suggested seasonal differencing term is:', start_D)
# Out:
# The suggested non-seasonal differencing term is: 0
# The suggested seasonal differencing term is: 0

# %%
print('The initial non-seasonal parameters are: p =', start_p, '| d =', start_d, '| q =', start_q)
print('The maximum non-seasonal parameters are: max_p =', max_p, '| max_d =', max_d, '| max_q =', max_q)
print('The initial seasonal parameters are: P =', start_P, '| D =', start_D, '| Q =', start_Q, '| m =', seasonal_freq)
print('The maximum seasonal parameters are: max_P =', max_P, '| max_D =', max_D, '| max_Q =', max_Q)
# Out:
# The initial non-seasonal parameters are: p = 0 | d = 0 | q = 0
# The maximum non-seasonal parameters are: max_p = 5 | max_d = 2 | max_q = 5
# The initial seasonal parameters are: P = 0 | D = 0 | Q = 0 | m = 12
# The maximum seasonal parameters are: max_P = 2 | max_D = 1 | max_Q = 2

# %%
# Do an automated stepwise search of ARIMA parameters
if (seasonal_freq == 0):
    stepwise_results = pm.auto_arima(train_ts, seasonal = False, stepwise = True, trace = True, suppress_warnings = True, random_state = seedNum)
else:
    stepwise_results = pm.auto_arima(train_ts, seasonal = True, m = seasonal_freq, stepwise = True, trace = True, suppress_warnings = True, random_state = seedNum)
# Out:
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=6076.832, BIC=6110.985, Fit time=8.204 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=6568.866, BIC=6577.404, Fit time=0.053 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=6189.987, BIC=6207.063, Fit time=1.565 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=6274.867, BIC=6291.943, Fit time=1.628 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(0, 0, 1, 12); AIC=6180.715, BIC=6210.598, Fit time=5.257 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=6104.925, BIC=6143.347, Fit time=14.103 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=6191.091, BIC=6220.974, Fit time=4.481 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 0, 2, 12); AIC=6110.834, BIC=6149.256, Fit time=15.312 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=6189.335, BIC=6214.949, Fit time=2.866 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(2, 0, 2, 12); AIC=6100.261, BIC=6142.952, Fit time=16.916 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=6083.049, BIC=6112.933, Fit time=4.832 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=6141.533, BIC=6179.955, Fit time=6.159 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=6074.207, BIC=6104.090, Fit time=4.988 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=6071.340, BIC=6092.685, Fit time=3.260 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 0, 1, 12); AIC=6208.196, BIC=6225.272, Fit time=1.565 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=6072.259, BIC=6097.874, Fit time=10.512 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 2, 12); AIC=6074.787, BIC=6100.402, Fit time=9.967 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=6240.321, BIC=6253.128, Fit time=0.153 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 0, 2, 12); AIC=6075.407, BIC=6105.291, Fit time=12.743 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=6573.024, BIC=6590.101, Fit time=1.201 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=6074.479, BIC=6100.094, Fit time=4.914 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=6071.692, BIC=6097.307, Fit time=4.309 seconds
# Total fit time: 135.019 seconds

# %%
# Summarize residual errors for the automated grid search ARIMA model
print(stepwise_results.summary())
stepwise_results.plot_diagnostics(figsize=(12,12))
plt.show()
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  528
# Model:             SARIMAX(1, 0, 0)x(1, 0, 1, 12)   Log Likelihood               -3030.670
# Date:                            Mon, 18 Nov 2019   AIC                           6071.340
# Time:                                    19:22:07   BIC                           6092.685
# Sample:                                         0   HQIC                          6079.696
#                                             - 528
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.2775      0.239      1.162      0.245      -0.191       0.746
# ar.L1          0.5544      0.030     18.265      0.000       0.495       0.614
# ar.S.L12       0.9943      0.004    275.899      0.000       0.987       1.001
# ma.S.L12      -0.9181      0.024    -38.747      0.000      -0.965      -0.872
# sigma2      5476.8560    209.564     26.135      0.000    5066.119    5887.593
# ===================================================================================
# Ljung-Box (Q):                       35.37   Jarque-Bera (JB):              1988.40
# Prob(Q):                              0.68   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.48   Skew:                             1.75
# Prob(H) (two-sided):                  0.00   Kurtosis:                        11.84
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
if (notifyStatus): email_notify("ARIMA automated stepwise search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Do an automated random search of ARIMA parameters
n_fits = int(max_p * max_d * max_q * max_P * max_D * max_Q * 0.30)
if (seasonal_freq == 0):
    randgrid_results = pm.auto_arima(train_ts, start_p = start_p, d = start_d, start_q = start_q, max_p = max_p, max_d = max_d, max_q = max_q,
                                     seasonal = False, stepwise = False, random = True, n_fits = n_fits, max_order = None,
                                     trace = True, suppress_warnings = True, random_state = seedNum)
else:
    randgrid_results = pm.auto_arima(train_ts, start_p = start_p, d = start_d, start_q = start_q, max_p = max_p, max_d = max_d, max_q = max_q,
                                     seasonal = True, m = seasonal_freq, start_P = start_P, D = start_D, start_Q = start_Q, max_P = max_P, max_D = max_D, max_Q = max_Q,
                                     stepwise = False, random = True, n_fits = n_fits, max_order = None,
                                     trace = True, suppress_warnings = True, random_state = seedNum)
# Out:
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(1, 0, 1, 12); AIC=6113.598, BIC=6160.558, Fit time=8.586 seconds
# Fit ARIMA: order=(5, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=6140.305, BIC=6182.996, Fit time=18.371 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(2, 0, 0, 12); AIC=6098.977, BIC=6158.745, Fit time=29.563 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 0, 2, 12); AIC=6183.370, BIC=6204.716, Fit time=5.437 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(1, 0, 1, 12); AIC=6145.557, BIC=6183.979, Fit time=5.117 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=6240.321, BIC=6253.128, Fit time=0.149 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 0, 1, 12); AIC=6208.196, BIC=6225.272, Fit time=1.549 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(2, 0, 2, 12); AIC=6108.040, BIC=6167.807, Fit time=25.728 seconds
# Fit ARIMA: order=(1, 0, 4) seasonal_order=(0, 0, 1, 12); AIC=6210.606, BIC=6244.759, Fit time=5.397 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=6071.340, BIC=6092.685, Fit time=3.227 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 0, 0, 12); AIC=6148.309, BIC=6178.193, Fit time=10.729 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(2, 0, 2, 12); AIC=6089.704, BIC=6140.933, Fit time=22.500 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=6160.468, BIC=6198.890, Fit time=5.925 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 0, 2, 12); AIC=6110.834, BIC=6149.256, Fit time=15.103 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(0, 0, 2, 12); AIC=6183.226, BIC=6217.379, Fit time=10.682 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(1, 0, 1, 12); AIC=6086.698, BIC=6129.389, Fit time=8.027 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(0, 0, 1, 12); AIC=6104.579, BIC=6160.078, Fit time=10.280 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=6204.171, BIC=6242.593, Fit time=3.626 seconds
# Fit ARIMA: order=(1, 0, 4) seasonal_order=(1, 0, 2, 12); AIC=6086.690, BIC=6129.381, Fit time=19.712 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(2, 0, 0, 12); AIC=6106.522, BIC=6157.751, Fit time=21.200 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(0, 0, 1, 12); AIC=6206.114, BIC=6231.729, Fit time=2.981 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(1, 0, 0, 12); AIC=6113.318, BIC=6160.278, Fit time=7.105 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(2, 0, 2, 12); AIC=6082.437, BIC=6120.859, Fit time=16.466 seconds
# Fit ARIMA: order=(2, 0, 5) seasonal_order=(1, 0, 1, 12); AIC=6118.689, BIC=6165.650, Fit time=10.057 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=6086.445, BIC=6120.598, Fit time=5.551 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(1, 0, 2, 12); AIC=6106.549, BIC=6157.778, Fit time=21.603 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(1, 0, 2, 12); AIC=6152.994, BIC=6208.492, Fit time=24.029 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(1, 0, 1, 12); AIC=6102.366, BIC=6153.595, Fit time=9.126 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(0, 0, 2, 12); AIC=6183.360, BIC=6213.243, Fit time=4.189 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(0, 0, 2, 12); AIC=6105.576, BIC=6156.805, Fit time=19.894 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 0, 0, 12); AIC=6191.031, BIC=6220.914, Fit time=5.194 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=6111.148, BIC=6153.839, Fit time=4.748 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(0, 0, 2, 12); AIC=6184.579, BIC=6227.270, Fit time=8.331 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(2, 0, 1, 12); AIC=6138.345, BIC=6193.843, Fit time=23.270 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 0, 2, 12); AIC=6074.999, BIC=6104.883, Fit time=11.475 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=6189.335, BIC=6214.949, Fit time=2.882 seconds
# Fit ARIMA: order=(0, 0, 4) seasonal_order=(2, 0, 0, 12); AIC=6153.005, BIC=6187.158, Fit time=9.267 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=6225.562, BIC=6259.714, Fit time=3.084 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(0, 0, 2, 12); AIC=6157.946, BIC=6209.176, Fit time=12.037 seconds
# Fit ARIMA: order=(4, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=6181.622, BIC=6211.506, Fit time=3.752 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(0, 0, 2, 12); AIC=6172.203, BIC=6202.087, Fit time=11.871 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(2, 0, 0, 12); AIC=6151.634, BIC=6185.787, Fit time=12.901 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(2, 0, 0, 12); AIC=6151.274, BIC=6193.965, Fit time=17.548 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=6106.929, BIC=6153.889, Fit time=5.043 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(0, 0, 2, 12); AIC=6137.989, BIC=6189.218, Fit time=20.290 seconds
# Fit ARIMA: order=(5, 0, 2) seasonal_order=(1, 0, 2, 12); AIC=6143.818, BIC=6195.047, Fit time=20.464 seconds
# Fit ARIMA: order=(2, 0, 4) seasonal_order=(2, 0, 1, 12); AIC=6104.358, BIC=6151.318, Fit time=17.676 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=6227.109, BIC=6252.723, Fit time=1.802 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 0, 0, 12); AIC=6148.896, BIC=6170.241, Fit time=7.214 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(1, 0, 0, 12); AIC=6160.545, BIC=6198.967, Fit time=6.932 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=6178.223, BIC=6212.376, Fit time=4.009 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=6188.944, BIC=6223.096, Fit time=3.342 seconds
# Fit ARIMA: order=(0, 0, 5) seasonal_order=(1, 0, 2, 12); AIC=6087.031, BIC=6129.722, Fit time=19.763 seconds
# Fit ARIMA: order=(5, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=6136.255, BIC=6187.484, Fit time=24.315 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(0, 0, 2, 12); AIC=6185.315, BIC=6223.737, Fit time=15.151 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=6135.149, BIC=6177.840, Fit time=17.285 seconds
# Fit ARIMA: order=(4, 0, 0) seasonal_order=(0, 0, 1, 12); AIC=6188.544, BIC=6218.428, Fit time=1.637 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(1, 0, 1, 12); AIC=6107.579, BIC=6163.077, Fit time=9.694 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 2, 12); AIC=6417.069, BIC=6434.145, Fit time=2.819 seconds
# Fit ARIMA: order=(1, 0, 4) seasonal_order=(2, 0, 1, 12); AIC=6087.191, BIC=6129.882, Fit time=15.783 seconds
# Total fit time: 671.526 seconds

# %%
# Summarize residual errors for the automated grid search ARIMA model
print(randgrid_results.summary())
randgrid_results.plot_diagnostics(figsize=(12,12))
plt.show()
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  528
# Model:             SARIMAX(1, 0, 0)x(1, 0, 1, 12)   Log Likelihood               -3030.670
# Date:                            Mon, 18 Nov 2019   AIC                           6071.340
# Time:                                    19:40:00   BIC                           6092.685
# Sample:                                         0   HQIC                          6079.696
#                                             - 528
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.2775      0.239      1.162      0.245      -0.191       0.746
# ar.L1          0.5544      0.030     18.265      0.000       0.495       0.614
# ar.S.L12       0.9943      0.004    275.899      0.000       0.987       1.001
# ma.S.L12      -0.9181      0.024    -38.747      0.000      -0.965      -0.872
# sigma2      5476.8560    209.564     26.135      0.000    5066.119    5887.593
# ===================================================================================
# Ljung-Box (Q):                       35.37   Jarque-Bera (JB):              1988.40
# Prob(Q):                              0.68   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.48   Skew:                             1.75
# Prob(H) (two-sided):                  0.00   Kurtosis:                        11.84
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
if (notifyStatus): email_notify("ARIMA automated random search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Do an automated grid search of ARIMA parameters
if (seasonal_freq == 0):
    autogrid_results = pm.auto_arima(train_ts, start_p = start_p, d = start_d, start_q = start_q, max_p = max_p, max_d = max_d, max_q = max_q,
                                     seasonal = False, stepwise = False, max_order = None, trace = True, suppress_warnings = True, random_state = seedNum)
else:
    autogrid_results = pm.auto_arima(train_ts, start_p = start_p, d = start_d, start_q = start_q, max_p = max_p, max_d = max_d, max_q = max_q,
                                     seasonal = True, m = seasonal_freq, start_P = start_P, D = start_D, start_Q = start_Q, max_P = max_P, max_D = max_D, max_Q = max_Q,
                                     stepwise = False, max_order = None, trace = True, suppress_warnings = True, random_state = seedNum)
# Out:
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=6568.866, BIC=6577.404, Fit time=0.059 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 1, 12); AIC=6487.435, BIC=6500.242, Fit time=0.695 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 2, 12); AIC=6417.069, BIC=6434.145, Fit time=2.717 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=6422.525, BIC=6435.332, Fit time=1.412 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=6573.024, BIC=6590.101, Fit time=1.194 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(1, 0, 2, 12); AIC=6276.597, BIC=6297.942, Fit time=8.841 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(2, 0, 0, 12); AIC=6339.584, BIC=6356.661, Fit time=5.219 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=6297.943, BIC=6319.289, Fit time=7.698 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(2, 0, 2, 12); AIC=6267.016, BIC=6292.631, Fit time=10.896 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 0, 12); AIC=6316.725, BIC=6329.532, Fit time=0.647 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=6274.867, BIC=6291.943, Fit time=1.652 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 2, 12); AIC=6239.254, BIC=6260.600, Fit time=4.921 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(1, 0, 0, 12); AIC=6247.017, BIC=6264.093, Fit time=1.663 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=6117.806, BIC=6139.152, Fit time=3.756 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(1, 0, 2, 12); AIC=6118.628, BIC=6144.243, Fit time=10.226 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(2, 0, 0, 12); AIC=6193.841, BIC=6215.187, Fit time=6.468 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=6131.826, BIC=6157.440, Fit time=9.564 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(2, 0, 2, 12); AIC=6122.559, BIC=6152.442, Fit time=11.026 seconds
# Fit ARIMA: order=(0, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=6253.684, BIC=6270.761, Fit time=1.040 seconds
# Fit ARIMA: order=(0, 0, 2) seasonal_order=(0, 0, 1, 12); AIC=6225.758, BIC=6247.104, Fit time=2.726 seconds
# Fit ARIMA: order=(0, 0, 2) seasonal_order=(0, 0, 2, 12); AIC=6202.436, BIC=6228.051, Fit time=7.487 seconds
# Fit ARIMA: order=(0, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=6209.376, BIC=6230.722, Fit time=1.993 seconds
# Fit ARIMA: order=(0, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=6095.521, BIC=6121.136, Fit time=4.856 seconds
# Fit ARIMA: order=(0, 0, 2) seasonal_order=(1, 0, 2, 12); AIC=6095.338, BIC=6125.222, Fit time=13.037 seconds
# Fit ARIMA: order=(0, 0, 2) seasonal_order=(2, 0, 0, 12); AIC=6169.640, BIC=6195.255, Fit time=7.558 seconds
# Fit ARIMA: order=(0, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=6095.020, BIC=6124.904, Fit time=10.606 seconds
# Fit ARIMA: order=(0, 0, 2) seasonal_order=(2, 0, 2, 12); AIC=6101.593, BIC=6135.745, Fit time=15.007 seconds
# Fit ARIMA: order=(0, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=6231.806, BIC=6253.152, Fit time=1.453 seconds
# Fit ARIMA: order=(0, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=6208.001, BIC=6233.615, Fit time=2.568 seconds
# Fit ARIMA: order=(0, 0, 3) seasonal_order=(0, 0, 2, 12); AIC=6186.804, BIC=6216.688, Fit time=8.941 seconds
# Fit ARIMA: order=(0, 0, 3) seasonal_order=(1, 0, 0, 12); AIC=6194.291, BIC=6219.906, Fit time=2.425 seconds
# Fit ARIMA: order=(0, 0, 3) seasonal_order=(1, 0, 1, 12); AIC=6084.385, BIC=6114.268, Fit time=4.746 seconds
# Fit ARIMA: order=(0, 0, 3) seasonal_order=(1, 0, 2, 12); AIC=6083.318, BIC=6117.470, Fit time=14.102 seconds
# Fit ARIMA: order=(0, 0, 3) seasonal_order=(2, 0, 0, 12); AIC=6156.237, BIC=6186.121, Fit time=7.161 seconds
# Fit ARIMA: order=(0, 0, 3) seasonal_order=(2, 0, 1, 12); AIC=6089.307, BIC=6123.460, Fit time=11.876 seconds
# Fit ARIMA: order=(0, 0, 3) seasonal_order=(2, 0, 2, 12); AIC=6090.344, BIC=6128.766, Fit time=14.411 seconds
# Fit ARIMA: order=(0, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=6226.685, BIC=6252.300, Fit time=1.844 seconds
# Fit ARIMA: order=(0, 0, 4) seasonal_order=(0, 0, 1, 12); AIC=6204.727, BIC=6234.611, Fit time=3.740 seconds
# Fit ARIMA: order=(0, 0, 4) seasonal_order=(0, 0, 2, 12); AIC=6183.266, BIC=6217.419, Fit time=11.023 seconds
# Fit ARIMA: order=(0, 0, 4) seasonal_order=(1, 0, 0, 12); AIC=6191.925, BIC=6221.808, Fit time=1.641 seconds
# Fit ARIMA: order=(0, 0, 4) seasonal_order=(1, 0, 1, 12); AIC=6085.216, BIC=6119.369, Fit time=6.599 seconds
# Fit ARIMA: order=(0, 0, 4) seasonal_order=(1, 0, 2, 12); AIC=6085.293, BIC=6123.714, Fit time=17.804 seconds
# Fit ARIMA: order=(0, 0, 4) seasonal_order=(2, 0, 0, 12); AIC=6153.005, BIC=6187.158, Fit time=9.129 seconds
# Fit ARIMA: order=(0, 0, 4) seasonal_order=(2, 0, 1, 12); AIC=6096.179, BIC=6134.601, Fit time=12.034 seconds
# Fit ARIMA: order=(0, 0, 4) seasonal_order=(2, 0, 2, 12); AIC=6084.312, BIC=6127.003, Fit time=17.913 seconds
# Fit ARIMA: order=(0, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=6222.940, BIC=6252.824, Fit time=2.005 seconds
# Fit ARIMA: order=(0, 0, 5) seasonal_order=(0, 0, 1, 12); AIC=6200.498, BIC=6234.651, Fit time=4.919 seconds
# Fit ARIMA: order=(0, 0, 5) seasonal_order=(0, 0, 2, 12); AIC=6180.372, BIC=6218.794, Fit time=12.904 seconds
# Fit ARIMA: order=(0, 0, 5) seasonal_order=(1, 0, 0, 12); AIC=6186.846, BIC=6220.999, Fit time=3.279 seconds
# Fit ARIMA: order=(0, 0, 5) seasonal_order=(1, 0, 1, 12); AIC=6097.897, BIC=6136.319, Fit time=7.653 seconds
# Fit ARIMA: order=(0, 0, 5) seasonal_order=(1, 0, 2, 12); AIC=6087.031, BIC=6129.722, Fit time=19.851 seconds
# Fit ARIMA: order=(0, 0, 5) seasonal_order=(2, 0, 0, 12); AIC=6149.699, BIC=6188.121, Fit time=10.550 seconds
# Fit ARIMA: order=(0, 0, 5) seasonal_order=(2, 0, 1, 12); AIC=6087.732, BIC=6130.423, Fit time=13.813 seconds
# Fit ARIMA: order=(0, 0, 5) seasonal_order=(2, 0, 2, 12); AIC=6087.120, BIC=6134.080, Fit time=22.383 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=6240.321, BIC=6253.128, Fit time=0.146 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 0, 1, 12); AIC=6208.196, BIC=6225.272, Fit time=1.560 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 0, 2, 12); AIC=6183.370, BIC=6204.716, Fit time=5.243 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=6189.987, BIC=6207.063, Fit time=1.589 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=6071.340, BIC=6092.685, Fit time=3.292 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 2, 12); AIC=6074.787, BIC=6100.402, Fit time=9.818 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 0, 0, 12); AIC=6148.896, BIC=6170.241, Fit time=7.164 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=6072.259, BIC=6097.874, Fit time=10.404 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 0, 2, 12); AIC=6075.407, BIC=6105.291, Fit time=12.708 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 0, 0, 12); AIC=6231.685, BIC=6248.761, Fit time=0.988 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=6205.728, BIC=6227.073, Fit time=2.299 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 0, 2, 12); AIC=6183.543, BIC=6209.158, Fit time=6.814 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 0, 0, 12); AIC=6190.435, BIC=6211.780, Fit time=2.339 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=6071.692, BIC=6097.307, Fit time=4.185 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 0, 2, 12); AIC=6074.999, BIC=6104.883, Fit time=11.485 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(2, 0, 0, 12); AIC=6150.894, BIC=6176.508, Fit time=8.389 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=6077.138, BIC=6107.022, Fit time=11.789 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(2, 0, 2, 12); AIC=6077.458, BIC=6111.611, Fit time=13.337 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=6230.085, BIC=6251.431, Fit time=1.398 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(0, 0, 1, 12); AIC=6206.114, BIC=6231.729, Fit time=2.947 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(0, 0, 2, 12); AIC=6185.073, BIC=6214.957, Fit time=9.544 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=6191.973, BIC=6217.587, Fit time=2.810 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=6083.049, BIC=6112.933, Fit time=4.816 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(1, 0, 2, 12); AIC=6095.379, BIC=6129.532, Fit time=14.575 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(2, 0, 0, 12); AIC=6152.768, BIC=6182.652, Fit time=10.328 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=6122.427, BIC=6156.580, Fit time=13.337 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(2, 0, 2, 12); AIC=6100.691, BIC=6139.112, Fit time=16.854 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=6227.109, BIC=6252.723, Fit time=1.845 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=6204.479, BIC=6234.362, Fit time=3.193 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(0, 0, 2, 12); AIC=6183.226, BIC=6217.379, Fit time=10.772 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(1, 0, 0, 12); AIC=6191.036, BIC=6220.920, Fit time=3.610 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(1, 0, 1, 12); AIC=6097.478, BIC=6131.631, Fit time=5.215 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(1, 0, 2, 12); AIC=6097.821, BIC=6136.243, Fit time=16.433 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(2, 0, 0, 12); AIC=6151.634, BIC=6185.787, Fit time=13.066 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(2, 0, 1, 12); AIC=6118.944, BIC=6157.366, Fit time=14.500 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(2, 0, 2, 12); AIC=6120.773, BIC=6163.464, Fit time=15.825 seconds
# Fit ARIMA: order=(1, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=6234.323, BIC=6264.207, Fit time=2.965 seconds
# Fit ARIMA: order=(1, 0, 4) seasonal_order=(0, 0, 1, 12); AIC=6210.606, BIC=6244.759, Fit time=5.343 seconds
# Fit ARIMA: order=(1, 0, 4) seasonal_order=(0, 0, 2, 12); AIC=6190.707, BIC=6229.129, Fit time=8.074 seconds
# Fit ARIMA: order=(1, 0, 4) seasonal_order=(1, 0, 0, 12); AIC=6191.614, BIC=6225.767, Fit time=4.650 seconds
# Fit ARIMA: order=(1, 0, 4) seasonal_order=(1, 0, 1, 12); AIC=6086.163, BIC=6124.585, Fit time=7.023 seconds
# Fit ARIMA: order=(1, 0, 4) seasonal_order=(1, 0, 2, 12); AIC=6086.690, BIC=6129.381, Fit time=19.665 seconds
# Fit ARIMA: order=(1, 0, 4) seasonal_order=(2, 0, 0, 12); AIC=6152.089, BIC=6190.511, Fit time=14.386 seconds
# Fit ARIMA: order=(1, 0, 4) seasonal_order=(2, 0, 1, 12); AIC=6087.191, BIC=6129.882, Fit time=15.754 seconds
# Fit ARIMA: order=(1, 0, 4) seasonal_order=(2, 0, 2, 12); AIC=6091.440, BIC=6138.400, Fit time=20.604 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=6225.562, BIC=6259.714, Fit time=3.082 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(0, 0, 1, 12); AIC=6204.680, BIC=6243.102, Fit time=3.414 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(0, 0, 2, 12); AIC=6184.579, BIC=6227.270, Fit time=8.569 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(1, 0, 0, 12); AIC=6192.469, BIC=6230.891, Fit time=5.295 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(1, 0, 1, 12); AIC=6086.698, BIC=6129.389, Fit time=8.054 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(1, 0, 2, 12); AIC=6083.835, BIC=6130.795, Fit time=22.333 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(2, 0, 0, 12); AIC=6151.702, BIC=6194.393, Fit time=15.425 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(2, 0, 1, 12); AIC=6084.620, BIC=6131.580, Fit time=15.821 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(2, 0, 2, 12); AIC=6089.704, BIC=6140.933, Fit time=22.660 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=6227.818, BIC=6244.895, Fit time=0.293 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 0, 1, 12); AIC=6204.561, BIC=6225.906, Fit time=1.082 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 0, 2, 12); AIC=6183.248, BIC=6208.862, Fit time=6.481 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=6190.189, BIC=6211.534, Fit time=2.273 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=6074.479, BIC=6100.094, Fit time=4.915 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 0, 2, 12); AIC=6073.401, BIC=6103.284, Fit time=11.308 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 0, 0, 12); AIC=6150.894, BIC=6176.508, Fit time=8.259 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=6074.027, BIC=6103.911, Fit time=12.534 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 0, 2, 12); AIC=6078.844, BIC=6112.997, Fit time=12.996 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(0, 0, 0, 12); AIC=6199.426, BIC=6220.771, Fit time=1.887 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=6186.322, BIC=6211.937, Fit time=3.824 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(0, 0, 2, 12); AIC=6172.203, BIC=6202.087, Fit time=11.899 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(1, 0, 0, 12); AIC=6189.236, BIC=6214.851, Fit time=3.717 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=6074.207, BIC=6104.090, Fit time=4.909 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(1, 0, 2, 12); AIC=6078.169, BIC=6112.322, Fit time=12.197 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 0, 0, 12); AIC=6148.309, BIC=6178.193, Fit time=10.884 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=6077.642, BIC=6111.795, Fit time=15.412 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 0, 2, 12); AIC=6077.191, BIC=6115.613, Fit time=15.802 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=6189.335, BIC=6214.949, Fit time=2.967 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(0, 0, 1, 12); AIC=6180.715, BIC=6210.598, Fit time=5.531 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(0, 0, 2, 12); AIC=6187.503, BIC=6221.656, Fit time=5.377 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=6191.091, BIC=6220.974, Fit time=4.523 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=6076.832, BIC=6110.985, Fit time=8.246 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 0, 2, 12); AIC=6110.834, BIC=6149.256, Fit time=15.338 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(2, 0, 0, 12); AIC=6151.494, BIC=6185.647, Fit time=13.370 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=6104.925, BIC=6143.347, Fit time=13.913 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(2, 0, 2, 12); AIC=6100.261, BIC=6142.952, Fit time=17.158 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=6124.613, BIC=6154.496, Fit time=2.834 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=6117.850, BIC=6152.003, Fit time=5.059 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(0, 0, 2, 12); AIC=6104.157, BIC=6142.579, Fit time=16.047 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(1, 0, 0, 12); AIC=6152.554, BIC=6186.707, Fit time=5.780 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(1, 0, 1, 12); AIC=6145.557, BIC=6183.979, Fit time=4.921 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(1, 0, 2, 12); AIC=6141.653, BIC=6184.344, Fit time=17.568 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(2, 0, 0, 12); AIC=6152.280, BIC=6190.702, Fit time=14.772 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(2, 0, 1, 12); AIC=6136.268, BIC=6178.959, Fit time=14.931 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(2, 0, 2, 12); AIC=6125.380, BIC=6172.340, Fit time=17.729 seconds
# Fit ARIMA: order=(2, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=6108.606, BIC=6142.759, Fit time=3.868 seconds
# Fit ARIMA: order=(2, 0, 4) seasonal_order=(0, 0, 1, 12); AIC=6109.060, BIC=6147.482, Fit time=7.563 seconds
# Fit ARIMA: order=(2, 0, 4) seasonal_order=(0, 0, 2, 12); AIC=6104.813, BIC=6147.503, Fit time=18.026 seconds
# Fit ARIMA: order=(2, 0, 4) seasonal_order=(1, 0, 0, 12); AIC=6108.152, BIC=6146.574, Fit time=6.896 seconds
# Fit ARIMA: order=(2, 0, 4) seasonal_order=(1, 0, 1, 12); AIC=6125.438, BIC=6168.129, Fit time=9.519 seconds
# Fit ARIMA: order=(2, 0, 4) seasonal_order=(1, 0, 2, 12); AIC=6108.035, BIC=6154.996, Fit time=19.701 seconds
# Fit ARIMA: order=(2, 0, 4) seasonal_order=(2, 0, 0, 12); AIC=6103.075, BIC=6145.766, Fit time=16.392 seconds
# Fit ARIMA: order=(2, 0, 4) seasonal_order=(2, 0, 1, 12); AIC=6104.358, BIC=6151.318, Fit time=18.016 seconds
# Fit ARIMA: order=(2, 0, 4) seasonal_order=(2, 0, 2, 12); AIC=6110.396, BIC=6161.625, Fit time=22.264 seconds
# Fit ARIMA: order=(2, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=6105.054, BIC=6143.476, Fit time=4.113 seconds
# Fit ARIMA: order=(2, 0, 5) seasonal_order=(0, 0, 1, 12); AIC=6104.362, BIC=6147.053, Fit time=7.806 seconds
# Fit ARIMA: order=(2, 0, 5) seasonal_order=(0, 0, 2, 12); AIC=6098.730, BIC=6145.690, Fit time=22.171 seconds
# Fit ARIMA: order=(2, 0, 5) seasonal_order=(1, 0, 0, 12); AIC=6103.535, BIC=6146.226, Fit time=6.422 seconds
# Fit ARIMA: order=(2, 0, 5) seasonal_order=(1, 0, 1, 12); AIC=6118.689, BIC=6165.650, Fit time=10.077 seconds
# Fit ARIMA: order=(2, 0, 5) seasonal_order=(1, 0, 2, 12); AIC=6100.495, BIC=6151.724, Fit time=24.339 seconds
# Fit ARIMA: order=(2, 0, 5) seasonal_order=(2, 0, 0, 12); AIC=6097.729, BIC=6144.689, Fit time=17.834 seconds
# Fit ARIMA: order=(2, 0, 5) seasonal_order=(2, 0, 1, 12); AIC=6114.368, BIC=6165.598, Fit time=19.808 seconds
# Fit ARIMA: order=(2, 0, 5) seasonal_order=(2, 0, 2, 12); AIC=6107.610, BIC=6163.108, Fit time=27.030 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=6219.001, BIC=6240.346, Fit time=0.320 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(0, 0, 1, 12); AIC=6201.407, BIC=6227.021, Fit time=1.411 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(0, 0, 2, 12); AIC=6183.360, BIC=6213.243, Fit time=4.255 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=6190.462, BIC=6216.076, Fit time=3.972 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=6072.646, BIC=6102.530, Fit time=5.524 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(1, 0, 2, 12); AIC=6079.385, BIC=6113.537, Fit time=11.908 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(2, 0, 0, 12); AIC=6152.659, BIC=6182.543, Fit time=11.930 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=6080.366, BIC=6114.519, Fit time=14.949 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(2, 0, 2, 12); AIC=6082.437, BIC=6120.859, Fit time=16.463 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(0, 0, 0, 12); AIC=6196.504, BIC=6222.118, Fit time=2.100 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=6184.785, BIC=6214.668, Fit time=4.250 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(0, 0, 2, 12); AIC=6171.062, BIC=6205.215, Fit time=12.152 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 0, 0, 12); AIC=6191.031, BIC=6220.914, Fit time=5.221 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=6086.445, BIC=6120.598, Fit time=5.668 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 0, 2, 12); AIC=6080.520, BIC=6118.942, Fit time=13.356 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(2, 0, 0, 12); AIC=6150.110, BIC=6184.263, Fit time=14.742 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=6076.099, BIC=6114.521, Fit time=16.991 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(2, 0, 2, 12); AIC=6083.070, BIC=6125.761, Fit time=17.147 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=6208.048, BIC=6237.932, Fit time=3.143 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(0, 0, 1, 12); AIC=6202.063, BIC=6236.215, Fit time=6.120 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(0, 0, 2, 12); AIC=6185.315, BIC=6223.737, Fit time=15.288 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=6193.237, BIC=6227.390, Fit time=5.024 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=6141.533, BIC=6179.955, Fit time=6.165 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 0, 2, 12); AIC=6141.534, BIC=6184.225, Fit time=18.275 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(2, 0, 0, 12); AIC=6149.856, BIC=6188.278, Fit time=17.859 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=6135.149, BIC=6177.840, Fit time=17.494 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(2, 0, 2, 12); AIC=6124.186, BIC=6171.146, Fit time=18.572 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=6166.885, BIC=6201.038, Fit time=3.465 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=6160.468, BIC=6198.890, Fit time=5.974 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(0, 0, 2, 12); AIC=6156.148, BIC=6198.839, Fit time=17.428 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(1, 0, 0, 12); AIC=6160.545, BIC=6198.967, Fit time=6.947 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(1, 0, 1, 12); AIC=6133.877, BIC=6176.568, Fit time=6.330 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(1, 0, 2, 12); AIC=6129.444, BIC=6176.404, Fit time=18.313 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(2, 0, 0, 12); AIC=6151.997, BIC=6194.688, Fit time=18.558 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(2, 0, 1, 12); AIC=6125.593, BIC=6172.553, Fit time=19.601 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(2, 0, 2, 12); AIC=6114.467, BIC=6165.696, Fit time=19.853 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=6111.408, BIC=6149.830, Fit time=3.965 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(0, 0, 1, 12); AIC=6111.959, BIC=6154.650, Fit time=7.674 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(0, 0, 2, 12); AIC=6105.818, BIC=6152.778, Fit time=19.556 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(1, 0, 0, 12); AIC=6113.682, BIC=6156.373, Fit time=6.888 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(1, 0, 1, 12); AIC=6113.598, BIC=6160.558, Fit time=8.778 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(1, 0, 2, 12); AIC=6106.549, BIC=6157.778, Fit time=21.578 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(2, 0, 0, 12); AIC=6105.612, BIC=6152.572, Fit time=19.571 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(2, 0, 1, 12); AIC=6105.517, BIC=6156.746, Fit time=22.055 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(2, 0, 2, 12); AIC=6109.152, BIC=6164.650, Fit time=24.121 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=6109.390, BIC=6152.081, Fit time=4.269 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(0, 0, 1, 12); AIC=6109.145, BIC=6156.105, Fit time=8.439 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(0, 0, 2, 12); AIC=6105.576, BIC=6156.805, Fit time=19.891 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(1, 0, 0, 12); AIC=6110.996, BIC=6157.956, Fit time=7.544 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(1, 0, 1, 12); AIC=6146.236, BIC=6197.465, Fit time=10.251 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(1, 0, 2, 12); AIC=6152.994, BIC=6208.492, Fit time=24.406 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(2, 0, 0, 12); AIC=6103.882, BIC=6155.112, Fit time=19.761 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(2, 0, 1, 12); AIC=6138.345, BIC=6193.843, Fit time=23.328 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(2, 0, 2, 12); AIC=6108.040, BIC=6167.807, Fit time=25.955 seconds
# Fit ARIMA: order=(4, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=6200.217, BIC=6225.832, Fit time=0.382 seconds
# Fit ARIMA: order=(4, 0, 0) seasonal_order=(0, 0, 1, 12); AIC=6188.544, BIC=6218.428, Fit time=1.629 seconds
# Fit ARIMA: order=(4, 0, 0) seasonal_order=(0, 0, 2, 12); AIC=6172.834, BIC=6206.987, Fit time=5.228 seconds
# Fit ARIMA: order=(4, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=6181.622, BIC=6211.506, Fit time=3.770 seconds
# Fit ARIMA: order=(4, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=6099.513, BIC=6133.666, Fit time=5.415 seconds
# Fit ARIMA: order=(4, 0, 0) seasonal_order=(1, 0, 2, 12); AIC=6088.454, BIC=6126.876, Fit time=14.059 seconds
# Fit ARIMA: order=(4, 0, 0) seasonal_order=(2, 0, 0, 12); AIC=6150.265, BIC=6184.417, Fit time=14.270 seconds
# Fit ARIMA: order=(4, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=6094.568, BIC=6132.990, Fit time=15.193 seconds
# Fit ARIMA: order=(4, 0, 0) seasonal_order=(2, 0, 2, 12); AIC=6109.311, BIC=6152.002, Fit time=17.657 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(0, 0, 0, 12); AIC=6188.123, BIC=6218.007, Fit time=2.378 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=6178.223, BIC=6212.376, Fit time=4.062 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(0, 0, 2, 12); AIC=6163.913, BIC=6202.335, Fit time=14.182 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(1, 0, 0, 12); AIC=6172.635, BIC=6206.788, Fit time=5.289 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=6156.264, BIC=6194.686, Fit time=5.830 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(1, 0, 2, 12); AIC=6143.387, BIC=6186.078, Fit time=15.795 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(2, 0, 0, 12); AIC=6152.095, BIC=6190.517, Fit time=15.826 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=6147.272, BIC=6189.963, Fit time=18.673 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(2, 0, 2, 12); AIC=6092.400, BIC=6139.360, Fit time=18.384 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=6188.944, BIC=6223.096, Fit time=3.337 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(0, 0, 1, 12); AIC=6190.913, BIC=6229.335, Fit time=6.076 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(0, 0, 2, 12); AIC=6171.902, BIC=6214.593, Fit time=16.417 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=6191.109, BIC=6229.530, Fit time=5.550 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=6153.622, BIC=6196.313, Fit time=6.355 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(1, 0, 2, 12); AIC=6143.808, BIC=6190.768, Fit time=17.944 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(2, 0, 0, 12); AIC=6151.274, BIC=6193.965, Fit time=17.763 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=6137.203, BIC=6184.164, Fit time=17.765 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(2, 0, 2, 12); AIC=6126.455, BIC=6177.684, Fit time=19.841 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=6204.171, BIC=6242.593, Fit time=3.619 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=6189.738, BIC=6232.429, Fit time=5.916 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(0, 0, 2, 12); AIC=6177.324, BIC=6224.284, Fit time=18.163 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(1, 0, 0, 12); AIC=6188.280, BIC=6230.971, Fit time=5.798 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(1, 0, 1, 12); AIC=6122.767, BIC=6169.728, Fit time=7.758 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(1, 0, 2, 12); AIC=6115.621, BIC=6166.850, Fit time=21.981 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(2, 0, 0, 12); AIC=6147.791, BIC=6194.752, Fit time=20.594 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(2, 0, 1, 12); AIC=6110.179, BIC=6161.408, Fit time=20.245 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(2, 0, 2, 12); AIC=6103.800, BIC=6159.299, Fit time=21.606 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=6111.148, BIC=6153.839, Fit time=4.644 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(0, 0, 1, 12); AIC=6111.377, BIC=6158.337, Fit time=9.025 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(0, 0, 2, 12); AIC=6157.946, BIC=6209.176, Fit time=12.091 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(1, 0, 0, 12); AIC=6113.318, BIC=6160.278, Fit time=7.293 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(1, 0, 1, 12); AIC=6102.366, BIC=6153.595, Fit time=9.260 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(1, 0, 2, 12); AIC=6105.742, BIC=6161.241, Fit time=26.465 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(2, 0, 0, 12); AIC=6106.522, BIC=6157.751, Fit time=21.184 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(2, 0, 1, 12); AIC=6100.516, BIC=6156.014, Fit time=21.199 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(2, 0, 2, 12); AIC=6092.973, BIC=6152.741, Fit time=24.443 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=6113.462, BIC=6160.422, Fit time=4.574 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(0, 0, 1, 12); AIC=6113.555, BIC=6164.784, Fit time=9.374 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(0, 0, 2, 12); AIC=6107.516, BIC=6163.014, Fit time=23.580 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(1, 0, 0, 12); AIC=6113.088, BIC=6164.318, Fit time=7.421 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(1, 0, 1, 12); AIC=6156.322, BIC=6211.820, Fit time=11.333 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(1, 0, 2, 12); AIC=6172.295, BIC=6232.063, Fit time=27.768 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(2, 0, 0, 12); AIC=6105.670, BIC=6161.168, Fit time=22.221 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(2, 0, 1, 12); AIC=6167.813, BIC=6227.580, Fit time=23.568 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(2, 0, 2, 12); AIC=6109.573, BIC=6173.609, Fit time=30.367 seconds
# Fit ARIMA: order=(5, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=6187.273, BIC=6217.157, Fit time=0.596 seconds
# Fit ARIMA: order=(5, 0, 0) seasonal_order=(0, 0, 1, 12); AIC=6178.318, BIC=6212.470, Fit time=3.017 seconds
# Fit ARIMA: order=(5, 0, 0) seasonal_order=(0, 0, 2, 12); AIC=6164.406, BIC=6202.828, Fit time=10.413 seconds
# Fit ARIMA: order=(5, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=6173.324, BIC=6207.476, Fit time=5.677 seconds
# Fit ARIMA: order=(5, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=6109.244, BIC=6147.666, Fit time=7.016 seconds
# Fit ARIMA: order=(5, 0, 0) seasonal_order=(1, 0, 2, 12); AIC=6129.627, BIC=6172.318, Fit time=15.191 seconds
# Fit ARIMA: order=(5, 0, 0) seasonal_order=(2, 0, 0, 12); AIC=6147.024, BIC=6185.446, Fit time=16.701 seconds
# Fit ARIMA: order=(5, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=6140.305, BIC=6182.996, Fit time=18.455 seconds
# Fit ARIMA: order=(5, 0, 0) seasonal_order=(2, 0, 2, 12); AIC=6160.246, BIC=6207.206, Fit time=22.063 seconds
# Fit ARIMA: order=(5, 0, 1) seasonal_order=(0, 0, 0, 12); AIC=6185.343, BIC=6219.495, Fit time=3.203 seconds
# Fit ARIMA: order=(5, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=6176.247, BIC=6214.668, Fit time=5.048 seconds
# Fit ARIMA: order=(5, 0, 1) seasonal_order=(0, 0, 2, 12); AIC=6162.631, BIC=6205.321, Fit time=14.500 seconds
# Fit ARIMA: order=(5, 0, 1) seasonal_order=(1, 0, 0, 12); AIC=6171.223, BIC=6209.645, Fit time=7.818 seconds
# Fit ARIMA: order=(5, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=6116.001, BIC=6158.692, Fit time=8.539 seconds
# Fit ARIMA: order=(5, 0, 1) seasonal_order=(1, 0, 2, 12); AIC=6136.923, BIC=6183.883, Fit time=16.586 seconds
# Fit ARIMA: order=(5, 0, 1) seasonal_order=(2, 0, 0, 12); AIC=6151.780, BIC=6194.471, Fit time=22.214 seconds
# Fit ARIMA: order=(5, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=6109.614, BIC=6156.574, Fit time=19.876 seconds
# Fit ARIMA: order=(5, 0, 1) seasonal_order=(2, 0, 2, 12); AIC=6115.380, BIC=6166.609, Fit time=23.580 seconds
# Fit ARIMA: order=(5, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=6192.055, BIC=6230.477, Fit time=3.627 seconds
# Fit ARIMA: order=(5, 0, 2) seasonal_order=(0, 0, 1, 12); AIC=6182.230, BIC=6224.921, Fit time=6.652 seconds
# Fit ARIMA: order=(5, 0, 2) seasonal_order=(0, 0, 2, 12); AIC=6167.607, BIC=6214.567, Fit time=18.648 seconds
# Fit ARIMA: order=(5, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=6179.146, BIC=6221.837, Fit time=8.652 seconds
# Fit ARIMA: order=(5, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=6145.913, BIC=6192.873, Fit time=10.960 seconds
# Fit ARIMA: order=(5, 0, 2) seasonal_order=(1, 0, 2, 12); AIC=6143.818, BIC=6195.047, Fit time=22.587 seconds
# Fit ARIMA: order=(5, 0, 2) seasonal_order=(2, 0, 0, 12); AIC=6152.745, BIC=6199.705, Fit time=22.630 seconds
# Fit ARIMA: order=(5, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=6136.255, BIC=6187.484, Fit time=25.053 seconds
# Fit ARIMA: order=(5, 0, 2) seasonal_order=(2, 0, 2, 12); AIC=6126.143, BIC=6181.641, Fit time=25.214 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=6136.058, BIC=6178.748, Fit time=4.542 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=6147.136, BIC=6194.096, Fit time=6.584 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(0, 0, 2, 12); AIC=6137.989, BIC=6189.218, Fit time=20.217 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(1, 0, 0, 12); AIC=6142.479, BIC=6189.439, Fit time=9.648 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(1, 0, 1, 12); AIC=6125.056, BIC=6176.286, Fit time=10.381 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(1, 0, 2, 12); AIC=6120.499, BIC=6175.997, Fit time=20.751 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(2, 0, 0, 12); AIC=6151.443, BIC=6202.673, Fit time=26.622 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(2, 0, 1, 12); AIC=6110.531, BIC=6166.030, Fit time=23.449 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(2, 0, 2, 12); AIC=6103.109, BIC=6162.877, Fit time=24.234 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=6106.929, BIC=6153.889, Fit time=5.054 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(0, 0, 1, 12); AIC=6106.740, BIC=6157.970, Fit time=9.784 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(0, 0, 2, 12); AIC=6101.695, BIC=6157.194, Fit time=29.221 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(1, 0, 0, 12); AIC=6107.026, BIC=6158.256, Fit time=10.977 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(1, 0, 1, 12); AIC=6107.579, BIC=6163.077, Fit time=9.559 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(1, 0, 2, 12); AIC=6092.694, BIC=6152.462, Fit time=27.392 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(2, 0, 0, 12); AIC=6100.169, BIC=6155.667, Fit time=29.087 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(2, 0, 1, 12); AIC=6091.181, BIC=6150.948, Fit time=28.436 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(2, 0, 2, 12); AIC=6094.087, BIC=6158.123, Fit time=28.007 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=6103.224, BIC=6154.453, Fit time=5.506 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(0, 0, 1, 12); AIC=6104.579, BIC=6160.078, Fit time=10.541 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(0, 0, 2, 12); AIC=6099.124, BIC=6158.891, Fit time=27.893 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(1, 0, 0, 12); AIC=6104.262, BIC=6159.760, Fit time=10.843 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(1, 0, 1, 12); AIC=6152.590, BIC=6212.357, Fit time=11.445 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(1, 0, 2, 12); AIC=6103.294, BIC=6167.330, Fit time=30.056 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(2, 0, 0, 12); AIC=6098.977, BIC=6158.745, Fit time=30.101 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(2, 0, 1, 12); AIC=6163.283, BIC=6227.319, Fit time=27.742 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(2, 0, 2, 12); AIC=6107.159, BIC=6175.465, Fit time=34.887 seconds
# Total fit time: 3720.546 seconds

# %%
# Summarize residual errors for the automated grid search ARIMA model
print(autogrid_results.summary())
autogrid_results.plot_diagnostics(figsize=(12,12))
plt.show()
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  528
# Model:             SARIMAX(1, 0, 0)x(1, 0, 1, 12)   Log Likelihood               -3030.670
# Date:                            Mon, 18 Nov 2019   AIC                           6071.340
# Time:                                    20:44:34   BIC                           6092.685
# Sample:                                         0   HQIC                          6079.696
#                                             - 528
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.2775      0.239      1.162      0.245      -0.191       0.746
# ar.L1          0.5544      0.030     18.265      0.000       0.495       0.614
# ar.S.L12       0.9943      0.004    275.899      0.000       0.987       1.001
# ma.S.L12      -0.9181      0.024    -38.747      0.000      -0.965      -0.872
# sigma2      5476.8560    209.564     26.135      0.000    5066.119    5887.593
# ===================================================================================
# Ljung-Box (Q):                       35.37   Jarque-Bera (JB):              1988.40
# Prob(Q):                              0.68   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.48   Skew:                             1.75
# Prob(H) (two-sided):                  0.00   Kurtosis:                        11.84
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
if (notifyStatus): email_notify("ARIMA automated grid search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Not applicable for this iteration of the project

# Set up the function to handle the ARIMA calculation
# def Calculate_ARIMA(ns_order, ss_order):
#     startTimeModel = datetime.now()
#     aic_score, bic_score = float("inf"), float("inf")
#     if (verbose): print('Trying to fit the model with parameters:', ns_order, ss_order)
#     try:
#         if (ss_order[3] == 0): grid_model = SARIMAX(train_ts, order=ns_order)
#         else: grid_model = SARIMAX(train_ts, order=ns_order, seasonal_order=ss_order)
#         with warnings.catch_warnings():
#             warnings.simplefilter("ignore")
#             grid_results = grid_model.fit(disp = False)
#         aic_score = grid_results.aic
#         bic_score = grid_results.bic
#         if (verbose): print('Fit ARIMA: order=%s seasonal_order=%s; AIC=%.3f, BIC=%.3f, Fit time=%s' % 
#               (ns_order, ss_order, aic_score, bic_score, (datetime.now() - startTimeModel)))
#         return(aic_score, bic_score)
#     except:
#         return(float("inf"), float("inf"))

# %%
# Not applicable for this iteration of the project

# Do a manual grid search of ARIMA parameters
# best_score, best_ns_cfg, best_ss_cfg = float("inf"), None, None
# for p in range(start_p, max_p+1):
#     for d in range(start_d, max_d+1):
#         for q in range(start_q, max_q+1):
#             for P in range(start_P, max_P+1):
#                 for D in range(start_D, max_D+1):
#                     for Q in range(start_Q, max_Q+1):
#                         ns_order = (p, d, q)
#                         ss_order = (P, D, Q, seasonal_freq)
#                         aic_score, bic_score = Calculate_ARIMA(ns_order, ss_order)
#                         if (aic_score < best_score):
#                             best_ns_cfg, best_ss_cfg, best_score = ns_order, ss_order, aic_score
#                             print('A better model found: order=%s seasonal_order=%s; AIC=%.3f, BIC=%.3f' % (ns_order, ss_order, aic_score, bic_score))
# print('Best ARIMA model via manual search: order=%s seasonal_order=%s; AIC=%f' % (best_ns_cfg, best_ss_cfg, best_score))

# %%
# Summarize residual errors for the manual ARIMA model
# manual_model = SARIMAX(train_ts, order=best_ns_cfg, seasonal_order=best_ss_cfg)
# manual_results = manual_model.fit(disp = False)
# print(manual_results.summary())
# manual_results.plot_diagnostics(figsize=(12,12))
# plt.show()

# %%
if (notifyStatus): email_notify("ARIMA Hyperparameters Search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 4.c) Evaluate the Residual Errors
#
# A good final check of a model is to review residual forecast errors. Ideally, the distribution of residual errors should be a Gaussian with a zero mean.

# %%
# Set the ARIMA order parameters for validation and forecasting
final_ns_order = stepwise_results.order
final_ss_order = stepwise_results.seasonal_order
# final_ns_order = randgrid_results.order
# final_ss_order = randgrid_results.seasonal_order
# final_ns_order = autogrid_results.order
# final_ss_order = autogrid_results.seasonal_order
# final_ns_order = best_ns_cfg
# final_ss_order = best_ss_cfg
print("Final Non-season order:", final_ns_order, 'Final Seasonal Order:', final_ss_order)
# Out:
# Final Non-season order: (1, 0, 0) Final Seasonal Order: (1, 0, 1, 12)

# %%
# Summarize residual errors for the final ARIMA model
final_model = SARIMAX(time_series, order=final_ns_order, seasonal_order=final_ss_order)
final_results = final_model.fit(disp = False)
print(final_results.summary())
final_results.plot_diagnostics(figsize=(12,12))
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                             values   No. Observations:                  660
# Model:             SARIMAX(1, 0, 0)x(1, 0, 1, 12)   Log Likelihood               -3797.754
# Date:                            Mon, 18 Nov 2019   AIC                           7603.508
# Time:                                    20:44:55   BIC                           7621.477
# Sample:                                10-01-1906   HQIC                          7610.473
#                                      - 09-01-1961
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5892      0.025     23.983      0.000       0.541       0.637
# ar.S.L12       0.9970      0.002    624.244      0.000       0.994       1.000
# ma.S.L12      -0.9304      0.018    -50.523      0.000      -0.967      -0.894
# sigma2      5627.6664    167.796     33.539      0.000    5298.793    5956.540
# ===================================================================================
# Ljung-Box (Q):                       26.38   Jarque-Bera (JB):              2262.83
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.67   Skew:                             1.70
# Prob(H) (two-sided):                  0.00   Kurtosis:                        11.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
if (notifyStatus): email_notify("Model Fitting and Evaluation completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 5. Finalize Model
#
# After models have been developed and a final model selected, it must be validated and finalized. Validation is an optional part of the process, but one that provides a ‘last check’ to ensure we have not fooled or lied to ourselves.

# %%
if (notifyStatus): email_notify("Model Finalization has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 5.a) Validation via In-sample Data

# %%
forecast = final_results.get_prediction(start = -test_size)
mean_forecast = forecast.predicted_mean
confidence_intervals = forecast.conf_int()

# %%
plt.figure(figsize=(12,9))
plt.plot(time_series.index, time_series[target_col], label='observed')
plt.plot(mean_forecast.index, mean_forecast.values, color='red', label='forecast')
plt.fill_between(confidence_intervals.index, confidence_intervals[lower_bound], confidence_intervals[upper_bound], color='pink')
plt.show()

# %%
# Evaluate RMSE for the validation data
y = time_series[-test_size:]
predictions = mean_forecast.values
rmse = math.sqrt(mean_squared_error(y, predictions))
print('RMSE from the validation data is: %.3f' % rmse)
# Out:
# RMSE from the validation data is: 78.413

# %% [markdown]
# ### 5.b) Forecasting Out-of-Sample Data

# %%
forecast = final_results.get_forecast(steps = test_size)
mean_forecast = forecast.predicted_mean
confidence_intervals = forecast.conf_int()

# %%
plt.figure(figsize=(12,9))
plt.plot(time_series.index, time_series[target_col], label='observed')
plt.plot(mean_forecast.index, mean_forecast.values, color='red', label='forecast')
plt.fill_between(confidence_intervals.index, confidence_intervals[lower_bound], confidence_intervals[upper_bound], color='pink')
plt.show()

# %%
if (notifyStatus): email_notify("Model Finalization completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
print ('Total time for the script:',(datetime.now() - startTimeScript))
# Out:
# Total time for the script: 1:29:44.545206
