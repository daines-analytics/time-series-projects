# %% [markdown]
# # Time Series Model for Fisher River Flow Using Python
# ### David Lowe
# ### January 15, 2020
#
# Template Credit: Adapted from a template made available by Dr. Jason Brownlee of Machine Learning Mastery. https://machinelearningmastery.com/
#
# SUMMARY: The purpose of this project is to construct a time series prediction model and document the end-to-end steps using a template. The Fisher River Flow dataset is a time series situation where we are trying to forecast future outcomes based on past data points.
#
# INTRODUCTION: The problem is to forecast the daily river flow volume for Fisher River near Dallas, Texas. The dataset describes a time-series of daily volume (in cms) over 4 years (1988-1991), and there are 1,461 observations in the dataset. We used the first 80% of the observations for training and testing various models while holding back the remaining observations for validating the final model.
#
# ANALYSIS: The baseline prediction (or persistence) for the dataset resulted in an RMSE of 0.693. After performing a grid search for the most optimal ARIMA parameters, the final ARIMA non-seasonal order was (1, 0, 2) with the seasonal order being (0, 1, 0, 365). Furthermore, the chosen model processed the validation data with an RMSE of 0.987, which was no better than the baseline model.
#
# CONCLUSION: For this dataset, the chosen ARIMA model did not achieve a satisfactory result. We should explore different sets of ARIMA parameters and conduct further modeling activities.
#
# Dataset Used: Mean daily flow, Fisher River near Dallas, January 1, 1988 to December 31, 1991
#
# Dataset ML Model: Time series forecast with numerical attributes
#
# Dataset Reference: Rob Hyndman and Yangzhuoran Yang (2018). tsdl: Time Series Data Library. v0.1.0. https://pkg.yangzhuoranyang./tsdl/.
#
# The project aims to touch on the following areas:
#
# * Document a predictive modeling problem end-to-end
# * Explore data cleaning and transformation options
# * Explore various algorithms for baselining the model performance
# * Explore tuning techniques for improving the model performance
#
# A time series predictive modeling project genrally can be broken down into about five major tasks:
#
# 1. Define Problem and Acquire Data
# 2. Inspect and Explore Data
# 3. Clean and Pre-Process Data
# 4. Fit and Evaluate Models
# 5. Finalize Model

# %% [markdown]
# ## Section 1. Define Problem and Acquire Data

# %% [markdown]
# ### 1.a) Load Libraries

# %%
# Set the warning message filter
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import math
import smtplib
import pmdarima as pm
from datetime import datetime
from random import randint
from email.message import EmailMessage
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %% [markdown]
# ### 1.b) Set up the controlling parameters and functions

# %%
# Create the random seed number for reproducible results
seedNum = 888

# Set up the number of CPU cores available for multi-thread processing
n_jobs = 1

# Set up the verbose flag to print detailed messages for debugging (setting True will activate!)
verbose = True

# Set up the flag to stop sending progress emails (setting to True will send status emails!)
notifyStatus = True

# %%
# Set up the email notification function
def email_notify(msg_text):
    sender = os.environ.get('MAIL_SENDER')
    receiver = os.environ.get('MAIL_RECEIVER')
    gateway = os.environ.get('SMTP_GATEWAY')
    smtpuser = os.environ.get('SMTP_USERNAME')
    password = os.environ.get('SMTP_PASSWORD')
    if sender==None or receiver==None or gateway==None or smtpuser==None or password==None:
        sys.exit("Incomplete email setup info. Script Processing Aborted!!!")
    msg = EmailMessage()
    msg.set_content(msg_text)
    msg['Subject'] = 'Notification from Python ARIMA Time Series Script'
    msg['From'] = sender
    msg['To'] = receiver
    server = smtplib.SMTP(gateway, 587)
    server.starttls()
    server.login(smtpuser, password)
    server.send_message(msg)
    server.quit()

# %%
if (notifyStatus): email_notify("Library and Data Loading has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 1.c) Acquire and Load the Data
#
# Since the dataset is not current, this means that we cannot easily collect updated data to validate the model. Therefore, we will withhold a portion of the data towards the end from analysis and model selection. This very segment of data will be used to validate the final model.

# %%
startTimeScript = datetime.now()

# %%
# load the dataset and the necessary data structure
time_series = pd.read_csv('https://dainesanalytics.com/datasets/time-series-data-library/tsdl269.csv')

import netCDF4
time_series['date_idx'] = ((time_series.idx - 1988) * 365).round()
time_series['idx'] = netCDF4.num2date(time_series['date_idx'], "day since 1988-01-01")
time_series.drop(columns=['date_idx'], inplace=True)
time_series.set_index('idx', inplace=True)

# %%
target_col = time_series.columns[0]
lower_bound = 'lower ' + target_col
upper_bound = 'upper ' + target_col
print('The target column of the time series is:', target_col)
print('The forecast boundary columns are:', lower_bound, '&', upper_bound)
# Out:
# The target column of the time series is: values
# The forecast boundary columns are: lower values & upper values

# %%
time_series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1461 entries, 1988-01-01 to 1991-12-31
# Data columns (total 1 columns):
# values    1461 non-null float64
# dtypes: float64(1)
# memory usage: 22.8 KB

# %%
time_series.head(10)
# Out:
#             values
# idx
# 1988-01-01   0.190
# 1988-01-02   0.167
# 1988-01-03   0.157
# 1988-01-04   0.132
# 1988-01-05   0.106
# 1988-01-06   0.100
# 1988-01-07   0.098
# 1988-01-08   0.103
# 1988-01-09   0.097
# 1988-01-10   0.095

# %%
time_series.tail(10)
# Out:
#             values
# idx
# 1991-12-22   0.177
# 1991-12-23   0.181
# 1991-12-24   0.180
# 1991-12-25   0.180
# 1991-12-26   0.182
# 1991-12-27   0.181
# 1991-12-28   0.182
# 1991-12-29   0.183
# 1991-12-30   0.184
# 1991-12-31   0.189

# %%
if (notifyStatus): email_notify("Library and Data Loading completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 2. Inspect and Explore Data

# %%
if (notifyStatus): email_notify("Data Inspection and Exploration has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 2.a) Summary Statistics of the Time Series Data
#
# Summary statistics provide a quick look at the limits of observed values. It can help to get a quick idea of what we are working with.

# %%
# Summary statistics of time series
print(time_series.describe())
# Out:
#             values
# count  1461.000000
# mean      0.590552
# std       1.791947
# min       0.034000
# 25%       0.103000
# 50%       0.178000
# 75%       0.333000
# max      24.300000

# %% [markdown]
# ### 2.b) Line Plot of the Time Series Data
#
# A line plot of a time series can provide a lot of insight into the problem. Some observations from the plot can include:
#
# * Whether the trend appears to be level around the mean
# * Whether there appear to be any obvious outliers
#
# The ARIMA(p,d,q) model requires three parameters and assumes that we are working with a stationary time series.
#
# The ADF results should show that the test statistic value is smaller than the critical value at 5% if the time series is stationary. This suggests that we can reject the null hypothesis (i.e. a low probability that the result is a statistical fluke).

# %%
# Line plots of time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Time Series Data')
time_series.plot(ax=ax)
plt.show()

# %% [markdown]
# ### 2.c) Histogram and Density Plots of the Time Series Data
#
# Reviewing plots of the density of observations can provide further insight into the structure of the data. Some observations from the plots can include:
#
# * Whether the distribution is Gaussian
# * Whether the distribution has a long tail and may suggest the need for data transformation

# %%
# Line plots of time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Histogram of the Time Series Data')
time_series.hist(ax=ax)
plt.show()

# %%
# Line plots of time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Density Plot of the Time Series Data')
time_series.plot(kind='kde', ax=ax)
plt.show()

# %% [markdown]
# ### 2.d) Box and Whisker Plots of the Time Series Data
#
# We can group or aggregate the data and get a better idea of the spread of observations. Some observations from reviewing the plot can include:
#
# * Whether the median values for each grouping shows any significant trend
# * Whether the spread, or middle 50% of the data, shows any significant variability
# * Whether there are outliers in some grouping

# %%
# boxplots of time series
fig, ax = plt.subplots(figsize=(12,9))
squeezed = time_series.squeeze()
sns.boxplot(squeezed.index.year, squeezed, ax=ax)
plt.show()

# %%
if (notifyStatus): email_notify("Data Inspection and Exploration completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 3. Data Transformation and Stationarity Tests

# %%
if (notifyStatus): email_notify("Data Cleaning and Pre-Processing has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### Section 3.a) Data Transformation

# %%
# Resampling the time series into monthly average for the ease of modeling
# original_series = time_series
# resample = original_series.resample('M')
# time_series = resample.mean()
# time_series.head(10)

# %%
# Line plots of the transformed time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Non-Seasonal Time Series Data')
time_series.plot(ax=ax)
plt.show()

# %% [markdown]
# ### Section 3.b) Test for Stationarity

# %%
# Check if stationary
result = adfuller(time_series[target_col])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Test Statistics Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -10.758131
# p-value: 0.000000
# Critical Test Statistics Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568

# %%
# ACF and PACF plots of the time series data
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))
plot_acf(time_series, ax=ax1)
plot_pacf(time_series, ax=ax2)
plt.show()

# %% [markdown]
# ### 3.c) Test for Stationarity of Non-Seasonal Time Series Data
#
# Occasionally a time series may look non-stationary on the first look. We can make it stationary by differencing the series and using a statistical test to confirm that the differenced result is stationary. Rejecting the null hypothesis means that the process has no unit root, and in turn that the time series is stationary or does not have time-dependent structure.

# %%
# Create a differenced series
stationary_ns = time_series.diff().dropna()

# Plot differenced data
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Stationary Time Series Data')
stationary_ns.plot(ax=ax)
plt.show()

# %%
# Check for stationarity
result = adfuller(stationary_ns[target_col])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Test Statistics Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -14.264454
# p-value: 0.000000
# Critical Test Statistics Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568

# %%
# ACF and PACF plots of the stationary time series
lags = 25
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))
plot_acf(stationary_ns, lags=lags, ax=ax1)
plot_pacf(stationary_ns, lags=lags, ax=ax2)
plt.show()

# %% [markdown]
# ### 3.d) Seasonal Decomposition for Seasonal Time Series Data

# %%
# Set the initial seasonal frequency parameter
seasonal_freq = 365

# %%
# Perform seasonal decomposition to observe the seasonal frequency
decomp_results = seasonal_decompose(time_series, freq=seasonal_freq)
decomp_results.plot()
plt.show()

# %%
# Create a seasonal series
N = seasonal_freq
seasonal_series = time_series - time_series.rolling(N).mean()
seasonal_series = seasonal_series.dropna()

# Line plots of the seasonal time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Seasonal Time Series Data')
seasonal_series.plot(ax=ax)
plt.show()

# %%
# Check for stationarity
result = adfuller(seasonal_series[target_col])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Test Statistics Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -8.782706
# p-value: 0.000000
# Critical Test Statistics Values:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568

# %%
# ACF and PACF plots of the time series data
lag = seasonal_freq * 2
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))
plot_acf(seasonal_series, lags=lag, ax=ax1)
plot_pacf(seasonal_series, lags=lag, ax=ax2)
plt.show()
# Out:
# /usr/local/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1358: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %% [markdown]
# ### 3.e) Test for Stationarity of Seasonal Time Series Data
#
# Occasionally a time series may look non-stationary on the first look. We can make it stationary by differencing the series and using a statistical test to confirm that the differenced result is stationary. Rejecting the null hypothesis means that the process has no unit root, and in turn that the time series is stationary or does not have time-dependent structure.

# %%
# Create a differenced series
stationary_ss = time_series.diff(seasonal_freq).dropna()

# Plot differenced data
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Stationary Seasonal Time Series Data')
stationary_ss.plot(ax=ax)
plt.show()

# %%
# Check for stationarity
result = adfuller(stationary_ss[target_col])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Test Statistics Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -9.207645
# p-value: 0.000000
# Critical Test Statistics Values:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568

# %%
# ACF and PACF plots of the stationary time series
lags = seasonal_freq
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))
plot_acf(stationary_ss, lags=lags, ax=ax1)
plot_pacf(stationary_ss, lags=lags, ax=ax2)
plt.show()

# %%
if (notifyStatus): email_notify("Data Cleaning and Pre-Processing completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 4. Fit and Evaluate Models
#
# In this section, we will develop Autoregressive Integrated Moving Average or ARIMA models for the problem. We will first establish a persistent model. Next we will use a grid search approach to look for an optimal ARIMA model. This will be followed by a third step of investigating the residual errors of the chosen model.
#
# * Establish the Persistent Model
# * Automatically Configure the ARIMA
# * Review Residual Errors

# %%
if (notifyStatus): email_notify("Model Fitting and Evaluation has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 4.a) Establish the Persistent Model
#
# The first step before getting bogged down in data analysis and modeling is to establish a baseline of performance. This will provide both a template for evaluating models using the proposed test harness and a performance measure by which all more elaborate predictive models can be compared.
#
# The baseline prediction for time series forecasting is called the naive forecast, or persistence. This is where the observation from the previous time step is used as the prediction for the observation at the next time step.

# %% [markdown]
# #### 4.a.iii) Establish the Persistent Model as Baseline

# %%
# Prepare and evaluate a persistence model
X = time_series.values
X = X.astype('float32')
train_pct = 0.75
train_size = int(len(X) * train_pct)
test_size = len(X) - train_size
train_ts, test_ts = X[0:train_size], X[train_size:]

# walk-forward validation
history = [x for x in train_ts]
predictions = list()
for i in range(len(test_ts)):
    yhat = history[-1]
    predictions.append(yhat)
    obs = test_ts[i]
    history.append(obs)
    print('>Predicted=%.3f, Expected=%3.f' % (yhat, obs))

# Calculate performance
rmse = math.sqrt(mean_squared_error(test_ts, predictions))
print('RMSE for the persistent model is: %.3f' % rmse)
# Out:
# >Predicted=0.088, Expected=  0
# >Predicted=0.084, Expected=  0
# >Predicted=0.078, Expected=  0
# >Predicted=0.075, Expected=  0
# >Predicted=0.071, Expected=  0
# >Predicted=0.067, Expected=  0
# >Predicted=0.064, Expected=  0
# >Predicted=0.062, Expected=  0
# >Predicted=0.059, Expected=  0
# >Predicted=0.053, Expected=  0
# >Predicted=0.053, Expected=  0
# >Predicted=0.052, Expected=  0
# >Predicted=0.054, Expected=  0
# >Predicted=0.054, Expected=  0
# >Predicted=0.053, Expected=  0
# >Predicted=0.055, Expected=  0
# >Predicted=0.058, Expected=  0
# >Predicted=0.058, Expected=  0
# >Predicted=0.060, Expected=  0
# >Predicted=0.060, Expected=  0
# >Predicted=0.061, Expected=  0
# >Predicted=0.061, Expected=  0
# >Predicted=0.059, Expected=  0
# >Predicted=0.061, Expected=  0
# >Predicted=0.061, Expected=  0
# >Predicted=0.061, Expected=  0
# >Predicted=0.060, Expected=  0
# >Predicted=0.057, Expected=  0
# >Predicted=0.056, Expected=  0
# >Predicted=0.054, Expected=  0
# >Predicted=0.049, Expected=  0
# >Predicted=0.043, Expected=  0
# >Predicted=0.041, Expected=  0
# >Predicted=0.038, Expected=  0
# >Predicted=0.038, Expected=  0
# >Predicted=0.039, Expected=  0
# >Predicted=0.041, Expected=  0
# >Predicted=0.044, Expected=  0
# >Predicted=0.045, Expected=  0
# >Predicted=0.045, Expected=  0
# >Predicted=0.050, Expected=  0
# >Predicted=0.062, Expected=  0
# >Predicted=0.078, Expected=  0
# >Predicted=0.083, Expected=  0
# >Predicted=0.082, Expected=  0
# >Predicted=0.081, Expected=  0
# >Predicted=0.080, Expected=  0
# >Predicted=0.078, Expected=  0
# >Predicted=0.077, Expected=  0
# >Predicted=0.076, Expected=  0
# >Predicted=0.076, Expected=  0
# >Predicted=0.075, Expected=  0
# >Predicted=0.073, Expected=  0
# >Predicted=0.073, Expected=  0
# >Predicted=0.072, Expected=  0
# >Predicted=0.071, Expected=  0
# >Predicted=0.070, Expected=  0
# >Predicted=0.069, Expected=  0
# >Predicted=0.068, Expected=  0
# >Predicted=0.066, Expected=  0
# >Predicted=0.063, Expected=  0
# >Predicted=0.060, Expected=  0
# >Predicted=0.059, Expected=  0
# >Predicted=0.055, Expected=  0
# >Predicted=0.054, Expected=  0
# >Predicted=0.058, Expected=  0
# >Predicted=0.060, Expected=  0
# >Predicted=0.054, Expected=  0
# >Predicted=0.051, Expected=  0
# >Predicted=0.051, Expected=  0
# >Predicted=0.052, Expected=  0
# >Predicted=0.054, Expected=  0
# >Predicted=0.055, Expected=  0
# >Predicted=0.057, Expected=  0
# >Predicted=0.062, Expected=  0
# >Predicted=0.065, Expected=  0
# >Predicted=0.065, Expected=  0
# >Predicted=0.065, Expected=  0
# >Predicted=0.068, Expected=  0
# >Predicted=0.077, Expected=  0
# >Predicted=0.107, Expected=  0
# >Predicted=0.217, Expected=  0
# >Predicted=0.384, Expected=  1
# >Predicted=0.653, Expected=  1
# >Predicted=0.879, Expected=  1
# >Predicted=0.861, Expected=  1
# >Predicted=0.740, Expected=  1
# >Predicted=0.607, Expected=  1
# >Predicted=0.548, Expected=  0
# >Predicted=0.465, Expected=  0
# >Predicted=0.397, Expected=  0
# >Predicted=0.430, Expected=  1
# >Predicted=0.595, Expected=  1
# >Predicted=1.000, Expected=  3
# >Predicted=3.420, Expected= 10
# >Predicted=9.670, Expected=  8
# >Predicted=7.520, Expected=  7
# >Predicted=6.670, Expected=  6
# >Predicted=6.150, Expected=  4
# >Predicted=4.240, Expected=  3
# >Predicted=2.890, Expected=  2
# >Predicted=1.860, Expected=  1
# >Predicted=1.300, Expected=  1
# >Predicted=0.954, Expected=  1
# >Predicted=0.721, Expected=  1
# >Predicted=0.613, Expected=  1
# >Predicted=0.676, Expected=  1
# >Predicted=0.718, Expected=  1
# >Predicted=0.648, Expected=  1
# >Predicted=0.587, Expected=  1
# >Predicted=0.535, Expected=  0
# >Predicted=0.442, Expected=  0
# >Predicted=0.381, Expected=  0
# >Predicted=0.378, Expected=  0
# >Predicted=0.424, Expected=  0
# >Predicted=0.424, Expected=  0
# >Predicted=0.390, Expected=  0
# >Predicted=0.328, Expected=  0
# >Predicted=0.307, Expected=  0
# >Predicted=0.355, Expected=  0
# >Predicted=0.358, Expected=  0
# >Predicted=0.373, Expected=  0
# >Predicted=0.394, Expected=  0
# >Predicted=0.397, Expected=  0
# >Predicted=0.397, Expected=  0
# >Predicted=0.471, Expected=  1
# >Predicted=0.607, Expected=  1
# >Predicted=0.964, Expected=  2
# >Predicted=1.600, Expected=  2
# >Predicted=1.850, Expected=  2
# >Predicted=1.740, Expected=  2
# >Predicted=1.780, Expected=  3
# >Predicted=3.130, Expected= 11
# >Predicted=11.200, Expected=  5
# >Predicted=4.610, Expected=  2
# >Predicted=2.390, Expected=  1
# >Predicted=1.440, Expected=  1
# >Predicted=0.948, Expected=  1
# >Predicted=0.705, Expected=  1
# >Predicted=0.581, Expected=  0
# >Predicted=0.500, Expected=  1
# >Predicted=0.510, Expected=  1
# >Predicted=0.507, Expected=  1
# >Predicted=0.503, Expected=  1
# >Predicted=0.598, Expected=  1
# >Predicted=0.826, Expected=  1
# >Predicted=0.792, Expected=  1
# >Predicted=0.698, Expected=  1
# >Predicted=0.601, Expected=  1
# >Predicted=0.521, Expected=  0
# >Predicted=0.472, Expected=  0
# >Predicted=0.447, Expected=  0
# >Predicted=0.493, Expected=  0
# >Predicted=0.497, Expected=  0
# >Predicted=0.465, Expected=  0
# >Predicted=0.460, Expected=  0
# >Predicted=0.382, Expected=  0
# >Predicted=0.302, Expected=  0
# >Predicted=0.241, Expected=  0
# >Predicted=0.205, Expected=  0
# >Predicted=0.247, Expected=  0
# >Predicted=0.329, Expected=  0
# >Predicted=0.422, Expected=  0
# >Predicted=0.422, Expected=  0
# >Predicted=0.377, Expected=  0
# >Predicted=0.358, Expected=  0
# >Predicted=0.336, Expected=  0
# >Predicted=0.290, Expected=  0
# >Predicted=0.294, Expected=  0
# >Predicted=0.309, Expected=  0
# >Predicted=0.307, Expected=  0
# >Predicted=0.350, Expected=  0
# >Predicted=0.387, Expected=  0
# >Predicted=0.324, Expected=  0
# >Predicted=0.328, Expected=  0
# >Predicted=0.413, Expected=  0
# >Predicted=0.324, Expected=  0
# >Predicted=0.255, Expected=  0
# >Predicted=0.334, Expected=  0
# >Predicted=0.311, Expected=  0
# >Predicted=0.291, Expected=  0
# >Predicted=0.259, Expected=  0
# >Predicted=0.235, Expected=  0
# >Predicted=0.245, Expected=  0
# >Predicted=0.344, Expected=  0
# >Predicted=0.449, Expected=  0
# >Predicted=0.459, Expected=  0
# >Predicted=0.453, Expected=  0
# >Predicted=0.417, Expected=  0
# >Predicted=0.332, Expected=  0
# >Predicted=0.307, Expected=  0
# >Predicted=0.293, Expected=  0
# >Predicted=0.264, Expected=  0
# >Predicted=0.228, Expected=  0
# >Predicted=0.212, Expected=  0
# >Predicted=0.228, Expected=  0
# >Predicted=0.246, Expected=  0
# >Predicted=0.245, Expected=  0
# >Predicted=0.205, Expected=  0
# >Predicted=0.177, Expected=  0
# >Predicted=0.165, Expected=  0
# >Predicted=0.166, Expected=  0
# >Predicted=0.147, Expected=  0
# >Predicted=0.143, Expected=  0
# >Predicted=0.169, Expected=  0
# >Predicted=0.166, Expected=  0
# >Predicted=0.159, Expected=  0
# >Predicted=0.158, Expected=  0
# >Predicted=0.165, Expected=  0
# >Predicted=0.183, Expected=  0
# >Predicted=0.182, Expected=  0
# >Predicted=0.161, Expected=  0
# >Predicted=0.145, Expected=  0
# >Predicted=0.126, Expected=  0
# >Predicted=0.113, Expected=  0
# >Predicted=0.096, Expected=  0
# >Predicted=0.086, Expected=  0
# >Predicted=0.088, Expected=  0
# >Predicted=0.088, Expected=  0
# >Predicted=0.089, Expected=  0
# >Predicted=0.088, Expected=  0
# >Predicted=0.082, Expected=  0
# >Predicted=0.097, Expected=  0
# >Predicted=0.085, Expected=  0
# >Predicted=0.095, Expected=  0
# >Predicted=0.100, Expected=  0
# >Predicted=0.100, Expected=  0
# >Predicted=0.093, Expected=  0
# >Predicted=0.095, Expected=  0
# >Predicted=0.089, Expected=  0
# >Predicted=0.097, Expected=  0
# >Predicted=0.101, Expected=  0
# >Predicted=0.099, Expected=  0
# >Predicted=0.104, Expected=  0
# >Predicted=0.141, Expected=  0
# >Predicted=0.138, Expected=  0
# >Predicted=0.117, Expected=  0
# >Predicted=0.120, Expected=  0
# >Predicted=0.122, Expected=  0
# >Predicted=0.129, Expected=  0
# >Predicted=0.135, Expected=  0
# >Predicted=0.113, Expected=  0
# >Predicted=0.085, Expected=  0
# >Predicted=0.075, Expected=  0
# >Predicted=0.063, Expected=  0
# >Predicted=0.065, Expected=  0
# >Predicted=0.078, Expected=  0
# >Predicted=0.075, Expected=  0
# >Predicted=0.074, Expected=  0
# >Predicted=0.073, Expected=  0
# >Predicted=0.076, Expected=  0
# >Predicted=0.076, Expected=  0
# >Predicted=0.075, Expected=  0
# >Predicted=0.068, Expected=  0
# >Predicted=0.064, Expected=  0
# >Predicted=0.063, Expected=  0
# >Predicted=0.064, Expected=  0
# >Predicted=0.065, Expected=  0
# >Predicted=0.081, Expected=  0
# >Predicted=0.246, Expected=  0
# >Predicted=0.328, Expected=  0
# >Predicted=0.469, Expected=  1
# >Predicted=0.586, Expected=  0
# >Predicted=0.426, Expected=  0
# >Predicted=0.406, Expected=  0
# >Predicted=0.420, Expected=  0
# >Predicted=0.310, Expected=  0
# >Predicted=0.241, Expected=  0
# >Predicted=0.191, Expected=  0
# >Predicted=0.165, Expected=  0
# >Predicted=0.171, Expected=  0
# >Predicted=0.179, Expected=  0
# >Predicted=0.181, Expected=  0
# >Predicted=0.192, Expected=  0
# >Predicted=0.200, Expected=  0
# >Predicted=0.238, Expected=  0
# >Predicted=0.275, Expected=  0
# >Predicted=0.267, Expected=  0
# >Predicted=0.293, Expected=  0
# >Predicted=0.288, Expected=  0
# >Predicted=0.272, Expected=  0
# >Predicted=0.242, Expected=  0
# >Predicted=0.216, Expected=  0
# >Predicted=0.208, Expected=  0
# >Predicted=0.191, Expected=  0
# >Predicted=0.185, Expected=  0
# >Predicted=0.188, Expected=  0
# >Predicted=0.199, Expected=  0
# >Predicted=0.182, Expected=  0
# >Predicted=0.191, Expected=  0
# >Predicted=0.202, Expected=  0
# >Predicted=0.202, Expected=  0
# >Predicted=0.191, Expected=  0
# >Predicted=0.184, Expected=  0
# >Predicted=0.196, Expected=  0
# >Predicted=0.202, Expected=  0
# >Predicted=0.231, Expected=  0
# >Predicted=0.287, Expected=  0
# >Predicted=0.283, Expected=  0
# >Predicted=0.268, Expected=  0
# >Predicted=0.266, Expected=  0
# >Predicted=0.271, Expected=  0
# >Predicted=0.290, Expected=  0
# >Predicted=0.419, Expected=  0
# >Predicted=0.488, Expected=  0
# >Predicted=0.369, Expected=  0
# >Predicted=0.323, Expected=  0
# >Predicted=0.306, Expected=  0
# >Predicted=0.290, Expected=  0
# >Predicted=0.290, Expected=  0
# >Predicted=0.274, Expected=  0
# >Predicted=0.274, Expected=  0
# >Predicted=0.248, Expected=  0
# >Predicted=0.219, Expected=  0
# >Predicted=0.219, Expected=  0
# >Predicted=0.205, Expected=  0
# >Predicted=0.205, Expected=  0
# >Predicted=0.202, Expected=  0
# >Predicted=0.205, Expected=  0
# >Predicted=0.210, Expected=  0
# >Predicted=0.213, Expected=  0
# >Predicted=0.213, Expected=  0
# >Predicted=0.213, Expected=  0
# >Predicted=0.216, Expected=  0
# >Predicted=0.216, Expected=  0
# >Predicted=0.210, Expected=  0
# >Predicted=0.208, Expected=  0
# >Predicted=0.213, Expected=  0
# >Predicted=0.213, Expected=  0
# >Predicted=0.216, Expected=  0
# >Predicted=0.219, Expected=  0
# >Predicted=0.216, Expected=  0
# >Predicted=0.205, Expected=  0
# >Predicted=0.215, Expected=  0
# >Predicted=0.208, Expected=  0
# >Predicted=0.198, Expected=  0
# >Predicted=0.202, Expected=  0
# >Predicted=0.190, Expected=  0
# >Predicted=0.188, Expected=  0
# >Predicted=0.174, Expected=  0
# >Predicted=0.165, Expected=  0
# >Predicted=0.160, Expected=  0
# >Predicted=0.164, Expected=  0
# >Predicted=0.161, Expected=  0
# >Predicted=0.164, Expected=  0
# >Predicted=0.166, Expected=  0
# >Predicted=0.172, Expected=  0
# >Predicted=0.176, Expected=  0
# >Predicted=0.180, Expected=  0
# >Predicted=0.182, Expected=  0
# >Predicted=0.184, Expected=  0
# >Predicted=0.185, Expected=  0
# >Predicted=0.185, Expected=  0
# >Predicted=0.178, Expected=  0
# >Predicted=0.172, Expected=  0
# >Predicted=0.172, Expected=  0
# >Predicted=0.175, Expected=  0
# >Predicted=0.177, Expected=  0
# >Predicted=0.181, Expected=  0
# >Predicted=0.180, Expected=  0
# >Predicted=0.180, Expected=  0
# >Predicted=0.182, Expected=  0
# >Predicted=0.181, Expected=  0
# >Predicted=0.182, Expected=  0
# >Predicted=0.183, Expected=  0
# >Predicted=0.184, Expected=  0
# RMSE for the persistent model is: 0.693

# %% [markdown]
# ### 4.b) Grid Search of ARIMA Hyperparameters
#
# We want to find a model that can do better than the persistence model on this dataset. To confirm this analysis, we can grid search a suite of ARIMA hyperparameters.
#
# In this section, we will search values of p, d, and q for combinations (skipping those that fail to converge), and find the combination that results in the best performance. We will use a grid search to explore all combinations in a subset of integer values.

# %%
if (notifyStatus): email_notify("ARIMA Hyperparameters Search has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Set the initial P, D, and Q order parameters for non-seasonal ARIMA modeling
start_p = 0
start_d = None
start_q = 0
max_p = 2
max_d = 1
max_q = 2

# %%
# Set the initial P, D, and Q order parameters for seasonal ARIMA modeling
start_P = 0
start_D = None
start_Q = 0
max_P = 2
max_D = 1
max_Q = 2

# %%
# Testing the time series data for suggestions on the differencing term
start_d = pm.arima.ndiffs(train_ts)
print('The suggested non-seasonal differencing term is:', start_d)
if (seasonal_freq != 0):
    start_D = pm.arima.nsdiffs(train_ts, m = seasonal_freq)
    print('The suggested seasonal differencing term is:', start_D)
# Out:
# The suggested non-seasonal differencing term is: 0
# The suggested seasonal differencing term is: 0

# %%
print('The initial non-seasonal parameters are: p =', start_p, '| d =', start_d, '| q =', start_q)
print('The maximum non-seasonal parameters are: max_p =', max_p, '| max_d =', max_d, '| max_q =', max_q)
if (seasonal_freq != 0):
    print('The initial seasonal parameters are: P =', start_P, '| D =', start_D, '| Q =', start_Q, '| m =', seasonal_freq)
    print('The maximum seasonal parameters are: max_P =', max_P, '| max_D =', max_D, '| max_Q =', max_Q)
# Out:
# The initial non-seasonal parameters are: p = 0 | d = 0 | q = 0
# The maximum non-seasonal parameters are: max_p = 2 | max_d = 1 | max_q = 2
# The initial seasonal parameters are: P = 0 | D = 0 | Q = 0 | m = 365
# The maximum seasonal parameters are: max_P = 2 | max_D = 1 | max_Q = 2

# %%
# Do an automated stepwise search of ARIMA parameters
# if (seasonal_freq == 0):
#     stepwise_results = pm.auto_arima(train_ts, seasonal = False, stepwise = True, trace = True, suppress_warnings = True, random_state = seedNum)
# else:
#     stepwise_results = pm.auto_arima(train_ts, seasonal = True, m = seasonal_freq, stepwise = True, trace = True, suppress_warnings = True, random_state = seedNum)

# %%
# Summarize residual errors for the automated grid search ARIMA model
# print(stepwise_results.summary())
# stepwise_results.plot_diagnostics(figsize=(12,12))
# plt.show()

# %%
if (notifyStatus): email_notify("ARIMA automated stepwise search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Do an automated random search of ARIMA parameters
# n_fits = int(max_p * max_d * max_q * max_P * max_D * max_Q * 0.25)
# if (seasonal_freq == 0):
#     randgrid_results = pm.auto_arima(train_ts, start_p = start_p, d = start_d, start_q = start_q, max_p = max_p, max_d = max_d, max_q = max_q,
#                                      seasonal = False, stepwise = False, random = True, n_fits = n_fits, max_order = None,
#                                      trace = True, suppress_warnings = True, random_state = seedNum)
# else:
#     randgrid_results = pm.auto_arima(train_ts, start_p = start_p, d = start_d, start_q = start_q, max_p = max_p, max_d = max_d, max_q = max_q,
#                                      seasonal = True, m = seasonal_freq, start_P = start_P, D = start_D, start_Q = start_Q, max_P = max_P, max_D = max_D, max_Q = max_Q,
#                                      stepwise = False, random = True, n_fits = n_fits, max_order = None,
#                                      trace = True, suppress_warnings = True, random_state = seedNum)

# %%
# Summarize residual errors for the automated grid search ARIMA model
# print(randgrid_results.summary())
# randgrid_results.plot_diagnostics(figsize=(12,12))
# plt.show()

# %%
if (notifyStatus): email_notify("ARIMA automated random search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Do an automated grid search of ARIMA parameters
# if (seasonal_freq == 0):
#     autogrid_results = pm.auto_arima(train_ts, start_p = start_p, d = start_d, start_q = start_q, max_p = max_p, max_d = max_d, max_q = max_q,
#                                      seasonal = False, stepwise = False, max_order = None, trace = True, suppress_warnings = True, random_state = seedNum)
# else:
#     autogrid_results = pm.auto_arima(train_ts, start_p = start_p, d = start_d, start_q = start_q, max_p = max_p, max_d = max_d, max_q = max_q,
#                                      seasonal = True, m = seasonal_freq, start_P = start_P, D = start_D, start_Q = start_Q, max_P = max_P, max_D = max_D, max_Q = max_Q,
#                                      stepwise = False, max_order = None, trace = True, suppress_warnings = True, random_state = seedNum)

# %%
# Summarize residual errors for the automated grid search ARIMA model
# print(autogrid_results.summary())
# autogrid_results.plot_diagnostics(figsize=(12,12))
# plt.show()

# %%
if (notifyStatus): email_notify("ARIMA automated grid search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Set up the function to handle the ARIMA calculation
def Calculate_ARIMA(ns_order, ss_order):
    startTimeModel = datetime.now()
    aic_score, bic_score = float("inf"), float("inf")
    if (verbose): print('Trying to fit the model with parameters:', ns_order, ss_order)
    try:
        if (ss_order[3] == 0): grid_model = SARIMAX(train_ts, order=ns_order)
        else: grid_model = SARIMAX(train_ts, order=ns_order, seasonal_order=ss_order)
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            grid_results = grid_model.fit(disp = False)
        aic_score = grid_results.aic
        bic_score = grid_results.bic
        if (verbose): print('Fitted ARIMA: order=%s seasonal_order=%s; AIC=%.3f, BIC=%.3f, Fit time=%s' % 
              (ns_order, ss_order, aic_score, bic_score, (datetime.now() - startTimeModel)))
        return(aic_score, bic_score)
    except:
        return(float("inf"), float("inf"))

# %%
# Do a manual grid search of ARIMA parameters
# The randomized_threshold variable controls the % of grid search that gets executed
randomized_threshold = 25
best_score, best_ns_cfg, best_ss_cfg = float("inf"), None, None
for p in range(start_p, max_p+1):
    for d in range(start_d, max_d+1):
        for q in range(start_q, max_q+1):
            for P in range(start_P, max_P+1):
                for D in range(start_D, max_D+1):
                    for Q in range(start_Q, max_Q+1):
                        if (randint(1,100) <= randomized_threshold):
                            ns_order = (p, d, q)
                            ss_order = (P, D, Q, seasonal_freq)
                            aic_score, bic_score = Calculate_ARIMA(ns_order, ss_order)
                            if (aic_score < best_score):
                                best_ns_cfg, best_ss_cfg, best_score = ns_order, ss_order, aic_score
                                print('A better model found: order=%s seasonal_order=%s; AIC=%.3f, BIC=%.3f' %
                                      (ns_order, ss_order, aic_score, bic_score))
print('Best ARIMA model via manual search: order=%s seasonal_order=%s; AIC=%f' % (best_ns_cfg, best_ss_cfg, best_score))
# Out:
# Trying to fit the model with parameters: (0, 0, 0) (0, 1, 2, 365)
# Trying to fit the model with parameters: (0, 0, 0) (1, 0, 2, 365)
# Trying to fit the model with parameters: (0, 0, 0) (1, 1, 2, 365)
# Trying to fit the model with parameters: (0, 0, 0) (2, 1, 1, 365)
# Trying to fit the model with parameters: (0, 0, 1) (0, 0, 2, 365)
# Trying to fit the model with parameters: (0, 0, 1) (0, 1, 1, 365)
# Trying to fit the model with parameters: (0, 0, 1) (1, 1, 2, 365)
# Trying to fit the model with parameters: (0, 0, 1) (2, 0, 0, 365)
# Fitted ARIMA: order=(0, 0, 1) seasonal_order=(2, 0, 0, 365); AIC=3265.933, BIC=3285.927, Fit time=1:30:59.044426
# A better model found: order=(0, 0, 1) seasonal_order=(2, 0, 0, 365); AIC=3265.933, BIC=3285.927
# Trying to fit the model with parameters: (0, 0, 1) (2, 0, 2, 365)
# Trying to fit the model with parameters: (0, 0, 2) (0, 0, 1, 365)
# Trying to fit the model with parameters: (0, 0, 2) (1, 0, 1, 365)
# Trying to fit the model with parameters: (0, 0, 2) (1, 1, 0, 365)
# Fitted ARIMA: order=(0, 0, 2) seasonal_order=(1, 1, 0, 365); AIC=1876.943, BIC=1895.315, Fit time=1:13:52.895279
# A better model found: order=(0, 0, 2) seasonal_order=(1, 1, 0, 365); AIC=1876.943, BIC=1895.315
# Trying to fit the model with parameters: (0, 1, 0) (0, 1, 0, 365)
# Fitted ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 365); AIC=2049.068, BIC=2053.660, Fit time=0:02:45.012544
# Trying to fit the model with parameters: (0, 1, 0) (0, 1, 1, 365)
# Trying to fit the model with parameters: (0, 1, 1) (0, 0, 2, 365)
# Trying to fit the model with parameters: (0, 1, 1) (0, 1, 1, 365)
# Trying to fit the model with parameters: (0, 1, 1) (1, 0, 1, 365)
# Trying to fit the model with parameters: (0, 1, 1) (2, 0, 0, 365)
# Fitted ARIMA: order=(0, 1, 1) seasonal_order=(2, 0, 0, 365); AIC=1910.871, BIC=1930.861, Fit time=1:08:10.043205
# Trying to fit the model with parameters: (0, 1, 2) (1, 1, 0, 365)
# Fitted ARIMA: order=(0, 1, 2) seasonal_order=(1, 1, 0, 365); AIC=1585.748, BIC=1604.115, Fit time=0:55:26.100895
# A better model found: order=(0, 1, 2) seasonal_order=(1, 1, 0, 365); AIC=1585.748, BIC=1604.115
# Trying to fit the model with parameters: (1, 0, 0) (0, 1, 0, 365)
# Fitted ARIMA: order=(1, 0, 0) seasonal_order=(0, 1, 0, 365); AIC=2024.197, BIC=2033.383, Fit time=0:04:52.551894
# Trying to fit the model with parameters: (1, 0, 0) (1, 0, 0, 365)
# Fitted ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 0, 365); AIC=2530.733, BIC=2545.728, Fit time=0:06:17.590578
# Trying to fit the model with parameters: (1, 0, 0) (1, 0, 1, 365)
# Trying to fit the model with parameters: (1, 0, 0) (2, 0, 0, 365)
# Fitted ARIMA: order=(1, 0, 0) seasonal_order=(2, 0, 0, 365); AIC=2523.906, BIC=2543.900, Fit time=1:02:39.807773
# Trying to fit the model with parameters: (1, 0, 0) (2, 0, 2, 365)
# Trying to fit the model with parameters: (1, 0, 1) (0, 0, 2, 365)
# Trying to fit the model with parameters: (1, 0, 1) (0, 1, 0, 365)
# Fitted ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 0, 365); AIC=1586.969, BIC=1600.748, Fit time=0:07:02.166940
# Trying to fit the model with parameters: (1, 0, 1) (2, 0, 1, 365)
# Trying to fit the model with parameters: (1, 0, 1) (2, 0, 2, 365)
# Trying to fit the model with parameters: (1, 0, 1) (2, 1, 2, 365)
# Trying to fit the model with parameters: (1, 0, 2) (0, 0, 0, 365)
# Fitted ARIMA: order=(1, 0, 2) seasonal_order=(0, 0, 0, 365); AIC=1754.979, BIC=1774.973, Fit time=0:00:00.455490
# Trying to fit the model with parameters: (1, 0, 2) (0, 0, 2, 365)
# Trying to fit the model with parameters: (1, 0, 2) (0, 1, 0, 365)
# Fitted ARIMA: order=(1, 0, 2) seasonal_order=(0, 1, 0, 365); AIC=1516.963, BIC=1535.335, Fit time=0:06:48.939712
# A better model found: order=(1, 0, 2) seasonal_order=(0, 1, 0, 365); AIC=1516.963, BIC=1535.335
# Trying to fit the model with parameters: (1, 0, 2) (0, 1, 1, 365)
# Trying to fit the model with parameters: (1, 0, 2) (1, 0, 2, 365)
# Trying to fit the model with parameters: (1, 0, 2) (1, 1, 2, 365)
# Trying to fit the model with parameters: (1, 1, 1) (0, 0, 0, 365)
# Fitted ARIMA: order=(1, 1, 1) seasonal_order=(0, 0, 0, 365); AIC=1868.317, BIC=1883.310, Fit time=0:00:00.307941
# Trying to fit the model with parameters: (1, 1, 1) (0, 1, 2, 365)
# Trying to fit the model with parameters: (1, 1, 1) (1, 1, 2, 365)
# Trying to fit the model with parameters: (1, 1, 1) (2, 1, 0, 365)
# Trying to fit the model with parameters: (1, 1, 2) (0, 0, 0, 365)
# Fitted ARIMA: order=(1, 1, 2) seasonal_order=(0, 0, 0, 365); AIC=1847.363, BIC=1867.353, Fit time=0:00:00.577308
# Trying to fit the model with parameters: (1, 1, 2) (1, 0, 1, 365)
# Trying to fit the model with parameters: (1, 1, 2) (2, 0, 0, 365)
# Fitted ARIMA: order=(1, 1, 2) seasonal_order=(2, 0, 0, 365); AIC=1846.425, BIC=1876.411, Fit time=2:10:53.507452
# Trying to fit the model with parameters: (1, 1, 2) (2, 0, 1, 365)
# Trying to fit the model with parameters: (1, 1, 2) (2, 0, 2, 365)
# Trying to fit the model with parameters: (1, 1, 2) (2, 1, 0, 365)
# Trying to fit the model with parameters: (1, 1, 2) (2, 1, 2, 365)
# Trying to fit the model with parameters: (2, 0, 0) (0, 0, 1, 365)
# Trying to fit the model with parameters: (2, 0, 0) (0, 0, 2, 365)
# Trying to fit the model with parameters: (2, 0, 0) (1, 0, 1, 365)
# Trying to fit the model with parameters: (2, 0, 0) (1, 1, 0, 365)
# Fitted ARIMA: order=(2, 0, 0) seasonal_order=(1, 1, 0, 365); AIC=1675.854, BIC=1694.226, Fit time=1:04:00.629428
# Trying to fit the model with parameters: (2, 0, 1) (0, 1, 1, 365)
# Trying to fit the model with parameters: (2, 0, 1) (1, 0, 2, 365)
# Trying to fit the model with parameters: (2, 0, 1) (1, 1, 2, 365)
# Trying to fit the model with parameters: (2, 0, 1) (2, 0, 1, 365)
# Trying to fit the model with parameters: (2, 0, 1) (2, 1, 1, 365)
# Trying to fit the model with parameters: (2, 0, 2) (1, 0, 1, 365)
# Trying to fit the model with parameters: (2, 1, 0) (0, 0, 0, 365)
# Fitted ARIMA: order=(2, 1, 0) seasonal_order=(0, 0, 0, 365); AIC=1831.782, BIC=1846.774, Fit time=0:00:00.268959
# Trying to fit the model with parameters: (2, 1, 0) (1, 0, 1, 365)
# Trying to fit the model with parameters: (2, 1, 0) (1, 1, 1, 365)
# Trying to fit the model with parameters: (2, 1, 0) (2, 0, 2, 365)
# Trying to fit the model with parameters: (2, 1, 0) (2, 1, 2, 365)
# Trying to fit the model with parameters: (2, 1, 1) (0, 0, 2, 365)
# Trying to fit the model with parameters: (2, 1, 1) (0, 1, 1, 365)
# Trying to fit the model with parameters: (2, 1, 1) (1, 0, 0, 365)
# Fitted ARIMA: order=(2, 1, 1) seasonal_order=(1, 0, 0, 365); AIC=1815.044, BIC=1840.032, Fit time=0:11:34.662560
# Trying to fit the model with parameters: (2, 1, 1) (2, 1, 1, 365)
# Trying to fit the model with parameters: (2, 1, 2) (0, 1, 1, 365)
# Trying to fit the model with parameters: (2, 1, 2) (1, 1, 2, 365)
# Trying to fit the model with parameters: (2, 1, 2) (2, 1, 2, 365)
# Best ARIMA model via manual search: order=(1, 0, 2) seasonal_order=(0, 1, 0, 365); AIC=1516.963198

# %%
# Summarize residual errors for the manual ARIMA model
manual_model = SARIMAX(train_ts, order=best_ns_cfg, seasonal_order=best_ss_cfg)
manual_results = manual_model.fit(disp = False)
print(manual_results.summary())
manual_results.plot_diagnostics(figsize=(12,12))
plt.show()
# Out:
#                                   Statespace Model Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                 1095
# Model:             SARIMAX(1, 0, 2)x(0, 1, 0, 365)   Log Likelihood                -754.482
# Date:                             Tue, 07 Jan 2020   AIC                           1516.963
# Time:                                     03:41:57   BIC                           1535.335
# Sample:                                          0   HQIC                          1524.051
#                                             - 1095
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7925      0.014     58.607      0.000       0.766       0.819
# ma.L1          1.0172      0.017     60.655      0.000       0.984       1.050
# ma.L2          0.3435      0.027     12.746      0.000       0.291       0.396
# sigma2         0.4604      0.004    117.880      0.000       0.453       0.468
# ===================================================================================
# Ljung-Box (Q):                       65.62   Jarque-Bera (JB):            294820.46
# Prob(Q):                              0.01   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.15   Skew:                             1.62
# Prob(H) (two-sided):                  0.00   Kurtosis:                       101.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
if (notifyStatus): email_notify("ARIMA manual grid search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
if (notifyStatus): email_notify("ARIMA Hyperparameters Search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 4.c) Evaluate the Residual Errors
#
# A good final check of a model is to review residual forecast errors. Ideally, the distribution of residual errors should be a Gaussian with a zero mean.

# %%
# Set the ARIMA order parameters for validation and forecasting
# final_ns_order = stepwise_results.order
# final_ns_order = randgrid_results.order
# final_ns_order = autogrid_results.order
final_ns_order = best_ns_cfg
if (seasonal_freq != 0):
#     final_ss_order = stepwise_results.seasonal_order
#     final_ss_order = randgrid_results.seasonal_order
#     final_ss_order = autogrid_results.seasonal_order
    final_ss_order = best_ss_cfg
    print("Final Non-season order:", final_ns_order, 'Final Seasonal Order:', final_ss_order)
else:
    print("Final Non-season order:", final_ns_order)
# Out:
# Final Non-season order: (1, 0, 2) Final Seasonal Order: (0, 1, 0, 365)

# %%
# Summarize residual errors for the final ARIMA model
if (seasonal_freq != 0):
    final_model = SARIMAX(time_series, order=final_ns_order, seasonal_order=final_ss_order)
else:
    final_model = SARIMAX(time_series, order=final_ns_order)
final_results = final_model.fit(disp = False)
print(final_results.summary())
final_results.plot_diagnostics(figsize=(12,12))
plt.show()
# Out:
# /usr/local/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
#                                   Statespace Model Results
# ===========================================================================================
# Dep. Variable:                              values   No. Observations:                 1461
# Model:             SARIMAX(1, 0, 2)x(0, 1, 0, 365)   Log Likelihood               -1341.769
# Date:                             Tue, 07 Jan 2020   AIC                           2691.539
# Time:                                     03:50:18   BIC                           2711.536
# Sample:                                 01-01-1988   HQIC                          2699.105
#                                       - 12-31-1991
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7493      0.010     77.824      0.000       0.730       0.768
# ma.L1          0.7959      0.010     76.246      0.000       0.775       0.816
# ma.L2          0.2895      0.017     16.981      0.000       0.256       0.323
# sigma2         0.6759      0.004    160.067      0.000       0.668       0.684
# ===================================================================================
# Ljung-Box (Q):                       65.21   Jarque-Bera (JB):            384857.75
# Prob(Q):                              0.01   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.99   Skew:                            -1.99
# Prob(H) (two-sided):                  0.00   Kurtosis:                        94.72
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
if (notifyStatus): email_notify("Model Fitting and Evaluation completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 5. Finalize Model
#
# After models have been developed and a final model selected, it must be validated and finalized. Validation is an optional part of the process, but one that provides a ‘last check’ to ensure we have not fooled or lied to ourselves.

# %%
if (notifyStatus): email_notify("Model Finalization has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 5.a) Validation via In-sample Data

# %%
validate_forecast = final_results.get_prediction(start = -test_size)
mean_validate_forecast = validate_forecast.predicted_mean
validate_confidence_intervals = validate_forecast.conf_int()

# %%
# Because some predicted values turned out to be negative, we will need to set those values to 0
print(mean_validate_forecast[mean_validate_forecast<0])
mean_validate_forecast[mean_validate_forecast<0] = 0
# Out:
# 1991-04-21   -1.154292
# 1991-05-14   -2.513274
# 1991-05-19   -0.285594
# 1991-06-17   -0.086112
# dtype: float64

# %%
plt.figure(figsize=(12,9))
plt.plot(time_series.index, time_series[target_col], label='observed')
plt.plot(mean_validate_forecast.index, mean_validate_forecast.values, color='red', label='forecast')
plt.fill_between(validate_confidence_intervals.index, validate_confidence_intervals[lower_bound], 
                 validate_confidence_intervals[upper_bound], color='pink')
plt.show()

# %%
# Evaluate RMSE for the validation data
y_test = time_series[-test_size:]
predictions = mean_validate_forecast.values
for i in range(y_test.shape[0]):
    print(y_test.index[i], ' | ', y_test.iloc[i,0], ' | ', predictions[i])
print('RMSE from the validation data is: %.3f' % math.sqrt(mean_squared_error(y_test, predictions)))
# Out:
# 1990-12-31 00:00:00  |  0.084  |  0.079997176399532
# 1991-01-01 00:00:00  |  0.078  |  0.07752052759793457
# 1991-01-02 00:00:00  |  0.075  |  0.06877634872928895
# 1991-01-03 00:00:00  |  0.071  |  0.07457563570470219
# 1991-01-04 00:00:00  |  0.067  |  0.06744274002488174
# 1991-01-05 00:00:00  |  0.064  |  0.06160346776959568
# 1991-01-06 00:00:00  |  0.062  |  0.06127169084224396
# 1991-01-07 00:00:00  |  0.059000000000000004  |  0.0607660381484457
# 1991-01-08 00:00:00  |  0.053  |  0.05905011169425411
# 1991-01-09 00:00:00  |  0.053  |  0.04917508682096421
# 1991-01-10 00:00:00  |  0.052000000000000005  |  0.06204471921174082
# 1991-01-11 00:00:00  |  0.054000000000000006  |  0.05087131706448093
# 1991-01-12 00:00:00  |  0.054000000000000006  |  0.05959078736467768
# 1991-01-13 00:00:00  |  0.053  |  0.060217468353816465
# 1991-01-14 00:00:00  |  0.055  |  0.04915357417170929
# 1991-01-15 00:00:00  |  0.057999999999999996  |  0.06207677829462646
# 1991-01-16 00:00:00  |  0.057999999999999996  |  0.055209269408684834
# 1991-01-17 00:00:00  |  0.06  |  0.06054818627215069
# 1991-01-18 00:00:00  |  0.06  |  0.06412691147073374
# 1991-01-19 00:00:00  |  0.061  |  0.060813513471134256
# 1991-01-20 00:00:00  |  0.061  |  0.06746103498626582
# 1991-01-21 00:00:00  |  0.059000000000000004  |  0.0636730325432588
# 1991-01-22 00:00:00  |  0.061  |  0.0606759096231128
# 1991-01-23 00:00:00  |  0.061  |  0.0701706312684297
# 1991-01-24 00:00:00  |  0.061  |  0.06431458502237958
# 1991-01-25 00:00:00  |  0.06  |  0.061229271721955365
# 1991-01-26 00:00:00  |  0.057  |  0.05933362119271994
# 1991-01-27 00:00:00  |  0.055999999999999994  |  0.06130621429408169
# 1991-01-28 00:00:00  |  0.054000000000000006  |  0.06087143097523807
# 1991-01-29 00:00:00  |  0.049  |  0.0590188159688672
# 1991-01-30 00:00:00  |  0.043  |  0.054317450527780066
# 1991-01-31 00:00:00  |  0.040999999999999995  |  0.04013086431486244
# 1991-02-01 00:00:00  |  0.038  |  0.049952313525753675
# 1991-02-02 00:00:00  |  0.038  |  0.03477790669501541
# 1991-02-03 00:00:00  |  0.039  |  0.053387426247058715
# 1991-02-04 00:00:00  |  0.040999999999999995  |  0.057768875976320334
# 1991-02-05 00:00:00  |  0.044000000000000004  |  0.0275363739784803
# 1991-02-06 00:00:00  |  0.045  |  0.05953442483504612
# 1991-02-07 00:00:00  |  0.045  |  0.047981139114582155
# 1991-02-08 00:00:00  |  0.05  |  0.048950651761186084
# 1991-02-09 00:00:00  |  0.062  |  0.05924960475289458
# 1991-02-10 00:00:00  |  0.078  |  0.07276139162216902
# 1991-02-11 00:00:00  |  0.083  |  0.08572374319033875
# 1991-02-12 00:00:00  |  0.08199999999999999  |  0.08985342487905884
# 1991-02-13 00:00:00  |  0.081  |  0.07422080486392711
# 1991-02-14 00:00:00  |  0.08  |  0.08062905553375367
# 1991-02-15 00:00:00  |  0.078  |  0.08471581127977118
# 1991-02-16 00:00:00  |  0.077  |  0.07572967540083791
# 1991-02-17 00:00:00  |  0.076  |  0.07782482752369042
# 1991-02-18 00:00:00  |  0.076  |  0.07867366078741256
# 1991-02-19 00:00:00  |  0.075  |  0.07335272893777131
# 1991-02-20 00:00:00  |  0.073  |  0.08704437699345502
# 1991-02-21 00:00:00  |  0.073  |  0.06556508829593646
# 1991-02-22 00:00:00  |  0.07200000000000001  |  0.08161520417593031
# 1991-02-23 00:00:00  |  0.071  |  0.06901652765216659
# 1991-02-24 00:00:00  |  0.07  |  0.0738096652257419
# 1991-02-25 00:00:00  |  0.069  |  0.07855716886429297
# 1991-02-26 00:00:00  |  0.068  |  0.07206088050311127
# 1991-02-27 00:00:00  |  0.066  |  0.07227564231363551
# 1991-02-28 00:00:00  |  0.063  |  0.07110726360463043
# 1991-03-01 00:00:00  |  0.06  |  0.06226203490392805
# 1991-03-02 00:00:00  |  0.059000000000000004  |  0.06738377395084877
# 1991-03-03 00:00:00  |  0.055  |  0.06370548993380991
# 1991-03-04 00:00:00  |  0.054000000000000006  |  0.05793078884373719
# 1991-03-05 00:00:00  |  0.057999999999999996  |  0.05988842545697415
# 1991-03-06 00:00:00  |  0.06  |  0.06664253795262023
# 1991-03-07 00:00:00  |  0.054000000000000006  |  0.06494870867306132
# 1991-03-08 00:00:00  |  0.051  |  0.054649608530799684
# 1991-03-09 00:00:00  |  0.051  |  0.05771349027485172
# 1991-03-10 00:00:00  |  0.052000000000000005  |  0.05938829816093816
# 1991-03-11 00:00:00  |  0.054000000000000006  |  0.06121492116626305
# 1991-03-12 00:00:00  |  0.055  |  0.08565902446304309
# 1991-03-13 00:00:00  |  0.057  |  0.1633194184083547
# 1991-03-14 00:00:00  |  0.062  |  0.09565026669050156
# 1991-03-15 00:00:00  |  0.065  |  0.24738883283080343
# 1991-03-16 00:00:00  |  0.065  |  0.088179982138134
# 1991-03-17 00:00:00  |  0.065  |  0.14762605756739922
# 1991-03-18 00:00:00  |  0.068  |  0.23492874281732923
# 1991-03-19 00:00:00  |  0.077  |  0.12495210921283684
# 1991-03-20 00:00:00  |  0.107  |  0.11226713635160812
# 1991-03-21 00:00:00  |  0.217  |  0.23562561159880607
# 1991-03-22 00:00:00  |  0.384  |  0.3455166028050367
# 1991-03-23 00:00:00  |  0.653  |  0.3417422577017214
# 1991-03-24 00:00:00  |  0.879  |  0.7633040268367753
# 1991-03-25 00:00:00  |  0.861  |  0.8796223909897243
# 1991-03-26 00:00:00  |  0.74  |  0.7003120282104947
# 1991-03-27 00:00:00  |  0.607  |  0.6288788870826327
# 1991-03-28 00:00:00  |  0.5479999999999999  |  0.49033792429683387
# 1991-03-29 00:00:00  |  0.465  |  0.5120886946071981
# 1991-03-30 00:00:00  |  0.397  |  0.5970600992813521
# 1991-03-31 00:00:00  |  0.43  |  2.8006913562305065
# 1991-04-01 00:00:00  |  0.595  |  10.914748590021837
# 1991-04-02 00:00:00  |  1.0  |  4.757299179802999
# 1991-04-03 00:00:00  |  3.42  |  0.7642414874608257
# 1991-04-04 00:00:00  |  9.67  |  5.656294928601744
# 1991-04-05 00:00:00  |  7.52  |  10.673631179046543
# 1991-04-06 00:00:00  |  6.67  |  4.447457746469834
# 1991-04-07 00:00:00  |  6.15  |  6.896604782877949
# 1991-04-08 00:00:00  |  4.24  |  5.104168951052603
# 1991-04-09 00:00:00  |  2.89  |  2.7834750449810413
# 1991-04-10 00:00:00  |  1.86  |  2.579475080522215
# 1991-04-11 00:00:00  |  1.3  |  1.2631850324411023
# 1991-04-12 00:00:00  |  0.9540000000000001  |  1.3557084228892808
# 1991-04-13 00:00:00  |  0.721  |  1.318542339427931
# 1991-04-14 00:00:00  |  0.613  |  1.053622981254461
# 1991-04-15 00:00:00  |  0.6759999999999999  |  1.2635189615896847
# 1991-04-16 00:00:00  |  0.718  |  0.3170046086003495
# 1991-04-17 00:00:00  |  0.648  |  1.177179540754136
# 1991-04-18 00:00:00  |  0.5870000000000001  |  0.8878264238943072
# 1991-04-19 00:00:00  |  0.535  |  1.501987104072775
# 1991-04-20 00:00:00  |  0.442  |  2.3294694515315766
# 1991-04-21 00:00:00  |  0.381  |  0.0
# 1991-04-22 00:00:00  |  0.37799999999999995  |  1.099244788650081
# 1991-04-23 00:00:00  |  0.424  |  0.37381949448329044
# 1991-04-24 00:00:00  |  0.424  |  0.5434279291117208
# 1991-04-25 00:00:00  |  0.39  |  0.7715486300748478
# 1991-04-26 00:00:00  |  0.32799999999999996  |  1.0232802606209457
# 1991-04-27 00:00:00  |  0.307  |  0.47659007642949236
# 1991-04-28 00:00:00  |  0.355  |  0.15103035236231044
# 1991-04-29 00:00:00  |  0.358  |  0.41861839505836707
# 1991-04-30 00:00:00  |  0.373  |  0.4179957787489019
# 1991-05-01 00:00:00  |  0.39399999999999996  |  0.4973031023072807
# 1991-05-02 00:00:00  |  0.397  |  0.4985587151656543
# 1991-05-03 00:00:00  |  0.397  |  0.547761327328026
# 1991-05-04 00:00:00  |  0.47100000000000003  |  0.36161499444447176
# 1991-05-05 00:00:00  |  0.607  |  0.6447526137664154
# 1991-05-06 00:00:00  |  0.9640000000000001  |  0.877315171349858
# 1991-05-07 00:00:00  |  1.6  |  0.9413247662979385
# 1991-05-08 00:00:00  |  1.85  |  2.106481000875104
# 1991-05-09 00:00:00  |  1.74  |  1.7786068424075059
# 1991-05-10 00:00:00  |  1.78  |  1.6197039819449568
# 1991-05-11 00:00:00  |  3.13  |  1.7536213495716557
# 1991-05-12 00:00:00  |  11.2  |  3.578007332308913
# 1991-05-13 00:00:00  |  4.61  |  15.017580991215299
# 1991-05-14 00:00:00  |  2.39  |  0.0
# 1991-05-15 00:00:00  |  1.44  |  2.741735378756438
# 1991-05-16 00:00:00  |  0.948  |  1.6012981730833133
# 1991-05-17 00:00:00  |  0.705  |  0.6459667131734497
# 1991-05-18 00:00:00  |  0.581  |  2.5195537389289075
# 1991-05-19 00:00:00  |  0.5  |  0.0
# 1991-05-20 00:00:00  |  0.51  |  0.35844855705825474
# 1991-05-21 00:00:00  |  0.507  |  0.7018811669802563
# 1991-05-22 00:00:00  |  0.503  |  0.37990176427173983
# 1991-05-23 00:00:00  |  0.598  |  0.5719435143393032
# 1991-05-24 00:00:00  |  0.826  |  0.7203109389130593
# 1991-05-25 00:00:00  |  0.792  |  0.9563627310798295
# 1991-05-26 00:00:00  |  0.698  |  0.6284953611240333
# 1991-05-27 00:00:00  |  0.601  |  0.6306578988120214
# 1991-05-28 00:00:00  |  0.521  |  0.572919146287631
# 1991-05-29 00:00:00  |  0.47200000000000003  |  0.5057460259891968
# 1991-05-30 00:00:00  |  0.447  |  0.4707881505138533
# 1991-05-31 00:00:00  |  0.493  |  0.5574793158341943
# 1991-06-01 00:00:00  |  0.49700000000000005  |  0.5560013622143756
# 1991-06-02 00:00:00  |  0.465  |  0.3736158403504301
# 1991-06-03 00:00:00  |  0.46  |  0.5100592507748496
# 1991-06-04 00:00:00  |  0.382  |  0.49198418186250037
# 1991-06-05 00:00:00  |  0.302  |  0.39440329854160383
# 1991-06-06 00:00:00  |  0.24100000000000002  |  0.4056455865492009
# 1991-06-07 00:00:00  |  0.205  |  0.16837140853284727
# 1991-06-08 00:00:00  |  0.247  |  0.2563807916284569
# 1991-06-09 00:00:00  |  0.32899999999999996  |  0.3944578375777259
# 1991-06-10 00:00:00  |  0.42200000000000004  |  0.3442235722125218
# 1991-06-11 00:00:00  |  0.42200000000000004  |  0.500145004865103
# 1991-06-12 00:00:00  |  0.377  |  0.7407484862253051
# 1991-06-13 00:00:00  |  0.358  |  0.7048098419459459
# 1991-06-14 00:00:00  |  0.336  |  0.6504850509130389
# 1991-06-15 00:00:00  |  0.29  |  0.0349299015147122
# 1991-06-16 00:00:00  |  0.294  |  0.7103682264577115
# 1991-06-17 00:00:00  |  0.309  |  0.0
# 1991-06-18 00:00:00  |  0.307  |  0.39574145250808
# 1991-06-19 00:00:00  |  0.35  |  0.33112513116926695
# 1991-06-20 00:00:00  |  0.387  |  0.35080054356126933
# 1991-06-21 00:00:00  |  0.324  |  0.6716715081977038
# 1991-06-22 00:00:00  |  0.32799999999999996  |  0.43837315603352633
# 1991-06-23 00:00:00  |  0.413  |  0.9405365939336754
# 1991-06-24 00:00:00  |  0.324  |  0.28638114063072395
# 1991-06-25 00:00:00  |  0.255  |  0.06121617868261109
# 1991-06-26 00:00:00  |  0.33399999999999996  |  0.33307213853507356
# 1991-06-27 00:00:00  |  0.311  |  0.3837471340087901
# 1991-06-28 00:00:00  |  0.29100000000000004  |  0.36918589765895765
# 1991-06-29 00:00:00  |  0.259  |  0.27604911904880847
# 1991-06-30 00:00:00  |  0.235  |  0.32687164115329564
# 1991-07-01 00:00:00  |  0.245  |  0.2935366324937372
# 1991-07-02 00:00:00  |  0.344  |  0.2603717303770655
# 1991-07-03 00:00:00  |  0.449  |  0.42200278982646466
# 1991-07-04 00:00:00  |  0.45899999999999996  |  0.5493251942818546
# 1991-07-05 00:00:00  |  0.45299999999999996  |  0.482057461822639
# 1991-07-06 00:00:00  |  0.41700000000000004  |  0.42038828496214753
# 1991-07-07 00:00:00  |  0.332  |  0.6108037507774713
# 1991-07-08 00:00:00  |  0.307  |  0.35396608660877804
# 1991-07-09 00:00:00  |  0.293  |  0.3528556347272471
# 1991-07-10 00:00:00  |  0.264  |  0.33698815824102424
# 1991-07-11 00:00:00  |  0.228  |  0.21253594709962043
# 1991-07-12 00:00:00  |  0.212  |  0.226810842424165
# 1991-07-13 00:00:00  |  0.228  |  0.23274594674144383
# 1991-07-14 00:00:00  |  0.24600000000000002  |  0.24217320667326567
# 1991-07-15 00:00:00  |  0.245  |  0.2578533715331449
# 1991-07-16 00:00:00  |  0.205  |  0.2285228970345803
# 1991-07-17 00:00:00  |  0.177  |  0.21919014521448144
# 1991-07-18 00:00:00  |  0.165  |  0.1862592962931845
# 1991-07-19 00:00:00  |  0.166  |  0.3015218535300305
# 1991-07-20 00:00:00  |  0.147  |  0.14072725896725685
# 1991-07-21 00:00:00  |  0.14300000000000002  |  0.18426565702296926
# 1991-07-22 00:00:00  |  0.16899999999999998  |  0.17147515327335877
# 1991-07-23 00:00:00  |  0.166  |  0.18679585527522938
# 1991-07-24 00:00:00  |  0.159  |  0.19016814577530594
# 1991-07-25 00:00:00  |  0.158  |  0.15509847135594365
# 1991-07-26 00:00:00  |  0.165  |  0.17343734949313674
# 1991-07-27 00:00:00  |  0.183  |  0.19125021322859395
# 1991-07-28 00:00:00  |  0.182  |  0.17309542265913874
# 1991-07-29 00:00:00  |  0.161  |  0.21602648670145563
# 1991-07-30 00:00:00  |  0.145  |  0.16513033285902146
# 1991-07-31 00:00:00  |  0.126  |  0.16866520152506384
# 1991-08-01 00:00:00  |  0.113  |  0.14860971288073177
# 1991-08-02 00:00:00  |  0.096  |  0.13047071617717598
# 1991-08-03 00:00:00  |  0.086  |  0.09243483491650531
# 1991-08-04 00:00:00  |  0.08800000000000001  |  0.09406556180993078
# 1991-08-05 00:00:00  |  0.08800000000000001  |  0.12270040232916213
# 1991-08-06 00:00:00  |  0.08900000000000001  |  0.09051326859090875
# 1991-08-07 00:00:00  |  0.08800000000000001  |  0.10487425758101807
# 1991-08-08 00:00:00  |  0.08199999999999999  |  0.08974692548722693
# 1991-08-09 00:00:00  |  0.09699999999999999  |  0.09930106126726454
# 1991-08-10 00:00:00  |  0.085  |  0.12501217801176828
# 1991-08-11 00:00:00  |  0.095  |  0.08233695522626663
# 1991-08-12 00:00:00  |  0.1  |  0.13808160769191846
# 1991-08-13 00:00:00  |  0.1  |  0.11145365016719747
# 1991-08-14 00:00:00  |  0.09300000000000001  |  0.1014587484782653
# 1991-08-15 00:00:00  |  0.095  |  0.13529797204028837
# 1991-08-16 00:00:00  |  0.08900000000000001  |  0.10033863165072704
# 1991-08-17 00:00:00  |  0.09699999999999999  |  0.0934249924876426
# 1991-08-18 00:00:00  |  0.10099999999999999  |  0.10416228895514278
# 1991-08-19 00:00:00  |  0.099  |  0.10859577001396867
# 1991-08-20 00:00:00  |  0.10400000000000001  |  0.09276378579227454
# 1991-08-21 00:00:00  |  0.141  |  0.10721204504941245
# 1991-08-22 00:00:00  |  0.138  |  0.16614987988356222
# 1991-08-23 00:00:00  |  0.11699999999999999  |  0.12438175202721549
# 1991-08-24 00:00:00  |  0.12  |  0.09774219984910486
# 1991-08-25 00:00:00  |  0.122  |  0.14783380921733752
# 1991-08-26 00:00:00  |  0.129  |  0.11514648430761165
# 1991-08-27 00:00:00  |  0.135  |  0.14880579098488264
# 1991-08-28 00:00:00  |  0.113  |  0.14703821222765437
# 1991-08-29 00:00:00  |  0.085  |  0.1279546839204646
# 1991-08-30 00:00:00  |  0.075  |  0.11504530182726855
# 1991-08-31 00:00:00  |  0.063  |  0.07857024740369703
# 1991-09-01 00:00:00  |  0.065  |  0.052154178717899874
# 1991-09-02 00:00:00  |  0.078  |  0.08182890310706001
# 1991-09-03 00:00:00  |  0.075  |  0.10475530523236805
# 1991-09-04 00:00:00  |  0.07400000000000001  |  0.07954432330543859
# 1991-09-05 00:00:00  |  0.073  |  0.08480829456316945
# 1991-09-06 00:00:00  |  0.076  |  0.07382964566223685
# 1991-09-07 00:00:00  |  0.076  |  0.07537709676531633
# 1991-09-08 00:00:00  |  0.075  |  0.06867627367835098
# 1991-09-09 00:00:00  |  0.068  |  0.08249673089990478
# 1991-09-10 00:00:00  |  0.064  |  0.06807540659201741
# 1991-09-11 00:00:00  |  0.063  |  0.06209365209645567
# 1991-09-12 00:00:00  |  0.064  |  0.06382196030938292
# 1991-09-13 00:00:00  |  0.065  |  0.06817720288013068
# 1991-09-14 00:00:00  |  0.081  |  0.07104228266365965
# 1991-09-15 00:00:00  |  0.24600000000000002  |  0.11601410517829235
# 1991-09-16 00:00:00  |  0.32799999999999996  |  0.3492393302107403
# 1991-09-17 00:00:00  |  0.469  |  0.3093452932776297
# 1991-09-18 00:00:00  |  0.586  |  0.4986794760199944
# 1991-09-19 00:00:00  |  0.426  |  0.5681377828038686
# 1991-09-20 00:00:00  |  0.406  |  0.25217950713028575
# 1991-09-21 00:00:00  |  0.42  |  0.42904825329102847
# 1991-09-22 00:00:00  |  0.31  |  0.3996142531266381
# 1991-09-23 00:00:00  |  0.24100000000000002  |  0.22893395893207275
# 1991-09-24 00:00:00  |  0.191  |  0.23060993112961384
# 1991-09-25 00:00:00  |  0.165  |  0.16297504635768054
# 1991-09-26 00:00:00  |  0.171  |  0.1411674634327217
# 1991-09-27 00:00:00  |  0.179  |  0.19133203562377443
# 1991-09-28 00:00:00  |  0.18100000000000002  |  0.15956581060908756
# 1991-09-29 00:00:00  |  0.192  |  0.17971827943384433
# 1991-09-30 00:00:00  |  0.2  |  0.19644604940288712
# 1991-10-01 00:00:00  |  0.23800000000000002  |  0.19284408055198224
# 1991-10-02 00:00:00  |  0.275  |  0.2538985872128257
# 1991-10-03 00:00:00  |  0.267  |  0.27602299489958737
# 1991-10-04 00:00:00  |  0.293  |  0.27584178731598297
# 1991-10-05 00:00:00  |  0.28800000000000003  |  0.33321657762105267
# 1991-10-06 00:00:00  |  0.272  |  0.2541991906429697
# 1991-10-07 00:00:00  |  0.242  |  0.242311722467566
# 1991-10-08 00:00:00  |  0.21600000000000003  |  0.20914447303724507
# 1991-10-09 00:00:00  |  0.20800000000000002  |  0.2175987118076853
# 1991-10-10 00:00:00  |  0.191  |  0.19608582962802246
# 1991-10-11 00:00:00  |  0.185  |  0.16942404627109348
# 1991-10-12 00:00:00  |  0.188  |  0.18291799117919483
# 1991-10-13 00:00:00  |  0.19899999999999998  |  0.18103781334236901
# 1991-10-14 00:00:00  |  0.182  |  0.19198486165899678
# 1991-10-15 00:00:00  |  0.191  |  0.16772550835497713
# 1991-10-16 00:00:00  |  0.20199999999999999  |  0.19434608657790478
# 1991-10-17 00:00:00  |  0.20199999999999999  |  0.20178530004061887
# 1991-10-18 00:00:00  |  0.191  |  0.19984363915094472
# 1991-10-19 00:00:00  |  0.184  |  0.1847462151597772
# 1991-10-20 00:00:00  |  0.196  |  0.17883077352982651
# 1991-10-21 00:00:00  |  0.20199999999999999  |  0.20017679726128104
# 1991-10-22 00:00:00  |  0.231  |  0.1981443434314144
# 1991-10-23 00:00:00  |  0.287  |  0.24187672850550848
# 1991-10-24 00:00:00  |  0.28300000000000003  |  0.30183376191981287
# 1991-10-25 00:00:00  |  0.268  |  0.25648708906933804
# 1991-10-26 00:00:00  |  0.266  |  0.25313694309347196
# 1991-10-27 00:00:00  |  0.271  |  0.24400349607944052
# 1991-10-28 00:00:00  |  0.29  |  0.2731293516646629
# 1991-10-29 00:00:00  |  0.419  |  0.28640127744226873
# 1991-10-30 00:00:00  |  0.488  |  0.4667323267890756
# 1991-10-31 00:00:00  |  0.369  |  0.4650811748207041
# 1991-11-01 00:00:00  |  0.32299999999999995  |  0.24854342609601554
# 1991-11-02 00:00:00  |  0.306  |  0.3285774640943704
# 1991-11-03 00:00:00  |  0.29  |  0.28799727215787013
# 1991-11-04 00:00:00  |  0.29  |  0.26673494316348356
# 1991-11-05 00:00:00  |  0.27399999999999997  |  0.28627796349995455
# 1991-11-06 00:00:00  |  0.27399999999999997  |  0.24915823295084102
# 1991-11-07 00:00:00  |  0.248  |  0.27065791887945484
# 1991-11-08 00:00:00  |  0.21899999999999997  |  0.2241207813071487
# 1991-11-09 00:00:00  |  0.21899999999999997  |  0.19959740884488048
# 1991-11-10 00:00:00  |  0.205  |  0.22643996129212673
# 1991-11-11 00:00:00  |  0.205  |  0.1905451546553781
# 1991-11-12 00:00:00  |  0.20199999999999999  |  0.21028786191175367
# 1991-11-13 00:00:00  |  0.205  |  0.2040844856823274
# 1991-11-14 00:00:00  |  0.21  |  0.21957686914079963
# 1991-11-15 00:00:00  |  0.213  |  0.20789983687970054
# 1991-11-16 00:00:00  |  0.213  |  0.2135430448634785
# 1991-11-17 00:00:00  |  0.213  |  0.21554889157749463
# 1991-11-18 00:00:00  |  0.21600000000000003  |  0.21231866350279352
# 1991-11-19 00:00:00  |  0.21600000000000003  |  0.21894413399205373
# 1991-11-20 00:00:00  |  0.21  |  0.21247492171528226
# 1991-11-21 00:00:00  |  0.20800000000000002  |  0.21168236380867453
# 1991-11-22 00:00:00  |  0.213  |  0.2271109714941829
# 1991-11-23 00:00:00  |  0.213  |  0.22522276263608643
# 1991-11-24 00:00:00  |  0.21600000000000003  |  0.21321962156585578
# 1991-11-25 00:00:00  |  0.21899999999999997  |  0.21970683288003917
# 1991-11-26 00:00:00  |  0.21600000000000003  |  0.2130185153639964
# 1991-11-27 00:00:00  |  0.205  |  0.221935363804851
# 1991-11-28 00:00:00  |  0.215  |  0.19140872348704882
# 1991-11-29 00:00:00  |  0.20800000000000002  |  0.21413207362865805
# 1991-11-30 00:00:00  |  0.198  |  0.19945137610731403
# 1991-12-01 00:00:00  |  0.20199999999999999  |  0.18932026514541023
# 1991-12-02 00:00:00  |  0.19  |  0.20941449292853914
# 1991-12-03 00:00:00  |  0.188  |  0.16297191826788215
# 1991-12-04 00:00:00  |  0.174  |  0.19053993517420653
# 1991-12-05 00:00:00  |  0.165  |  0.16457811085308166
# 1991-12-06 00:00:00  |  0.16  |  0.15379782550210866
# 1991-12-07 00:00:00  |  0.16399999999999998  |  0.16480751856992298
# 1991-12-08 00:00:00  |  0.161  |  0.16389926644018038
# 1991-12-09 00:00:00  |  0.16399999999999998  |  0.15495727907284434
# 1991-12-10 00:00:00  |  0.166  |  0.16835145490065473
# 1991-12-11 00:00:00  |  0.172  |  0.16423917305935157
# 1991-12-12 00:00:00  |  0.17600000000000002  |  0.18548387854865644
# 1991-12-13 00:00:00  |  0.18  |  0.17769305233123972
# 1991-12-14 00:00:00  |  0.182  |  0.1793379934666268
# 1991-12-15 00:00:00  |  0.184  |  0.18578354141648382
# 1991-12-16 00:00:00  |  0.185  |  0.18334826614664523
# 1991-12-17 00:00:00  |  0.185  |  0.18579520714262115
# 1991-12-18 00:00:00  |  0.17800000000000002  |  0.1800930987073592
# 1991-12-19 00:00:00  |  0.172  |  0.15910393746697746
# 1991-12-20 00:00:00  |  0.172  |  0.16389937785495887
# 1991-12-21 00:00:00  |  0.175  |  0.1506613635253519
# 1991-12-22 00:00:00  |  0.177  |  0.16817544026164588
# 1991-12-23 00:00:00  |  0.18100000000000002  |  0.17026687892125303
# 1991-12-24 00:00:00  |  0.18  |  0.1705389489737152
# 1991-12-25 00:00:00  |  0.18  |  0.17082837499032627
# 1991-12-26 00:00:00  |  0.182  |  0.16722973659676982
# 1991-12-27 00:00:00  |  0.18100000000000002  |  0.1663479972463979
# 1991-12-28 00:00:00  |  0.182  |  0.1708688497902597
# 1991-12-29 00:00:00  |  0.183  |  0.1730294935359581
# 1991-12-30 00:00:00  |  0.184  |  0.17033715148378833
# 1991-12-31 00:00:00  |  0.18899999999999997  |  0.16968899340176738
# RMSE from the validation data is: 0.987

# %% [markdown]
# ### 5.b) Forecasting Out-of-Sample Data

# %%
final_forecast = final_results.get_forecast(steps = test_size)
mean_final_forecast = final_forecast.predicted_mean
final_confidence_intervals = final_forecast.conf_int()
print("The forecasted values are:\n\n", mean_final_forecast)
# Out:
# The forecasted values are:
#
#  1992-01-01    0.175996
# 1992-01-02    0.154015
# 1992-01-03    0.130203
# 1992-01-04    0.111358
# 1992-01-05    0.097235
#                 ...
# 1992-12-27    0.182000
# 1992-12-28    0.183000
# 1992-12-29    0.184000
# 1992-12-30    0.189000
# 1992-12-31    0.175996
# Freq: D, Length: 366, dtype: float64

# %%
plt.figure(figsize=(12,9))
plt.plot(time_series.index, time_series[target_col], label='observed')
plt.plot(mean_final_forecast.index, mean_final_forecast.values, color='red', label='forecast')
plt.fill_between(final_confidence_intervals.index, final_confidence_intervals[lower_bound], 
                 final_confidence_intervals[upper_bound], color='pink')
plt.show()

# %%
if (notifyStatus): email_notify("Model Finalization completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
print ('Total time for the script:',(datetime.now() - startTimeScript))
# Out:
# Total time for the script: 10:03:11.416011
