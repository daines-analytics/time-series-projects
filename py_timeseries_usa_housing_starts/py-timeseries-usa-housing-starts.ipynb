# %% [markdown]
# # Time Series Model for USA Housing Starts Using Python
# ### David Lowe
# ### October 30, 2019
#
# Template Credit: Adapted from a template made available by Dr. Jason Brownlee of Machine Learning Mastery. https://machinelearningmastery.com/
#
# SUMMARY: The purpose of this project is to construct a time series prediction model and document the end-to-end steps using a template. The USA Housing Sales dataset is a time series situation where we are trying to forecast future outcomes based on past data points.
#
# INTRODUCTION: The problem is to forecast the monthly housing starts in the US. The dataset describes a time-series of housing sales over 11 years (1965-1975) in the US, and there are 132 monthly observations. We used the first 80% of the observations for training and testing various models, while holding back the remaining observations for validating the final model.
#
# ANALYSIS: The baseline prediction (or persistence) for the dataset resulted in an RMSE of 13059. After performing a grid search for the most optimal ARIMA parameters, the final ARIMA non-seasonal order was (4, 0, 4) with the seasonal order being (1, 0, 1, 12). Furthermore, the chosen model processed the validation data with an RMSE of 6276, which was better than the baseline model as expected.
#
# CONCLUSION: For this dataset, the chosen ARIMA model achieved a satisfactory result and should be considered for further modeling.
#
# Dataset Used: U.S. Housing Starts 1965 - 1975
#
# Dataset ML Model: Time series forecast with numerical attributes
#
# Dataset Reference: Rob Hyndman and Yangzhuoran Yang (2018). tsdl: Time Series Data Library. v0.1.0. https://pkg.yangzhuoranyang./tsdl/.
#
# The project aims to touch on the following areas:
#
# * Document a predictive modeling problem end-to-end
# * Explore data cleaning and transformation options
# * Explore various algorithms for baselining the model performance
# * Explore tuning techniques for improving the model performance
#
# A time series predictive modeling project genrally can be broken down into about five major tasks:
#
# 1. Define Problem and Acquire Data
# 2. Inspect and Explore Data
# 3. Clean and Pre-Process Data
# 4. Fit and Evaluate Models
# 5. Finalize Model

# %% [markdown]
# ## Section 1. Define Problem and Acquire Data

# %% [markdown]
# ### 1.a) Load Libraries

# %%
# Set the warning message filter
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import math
import smtplib
import pmdarima as pm
from datetime import datetime
from email.message import EmailMessage
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %% [markdown]
# ### 1.b) Set up the controlling parameters and functions

# %%
# Create the random seed number for reproducible results
seedNum = 888

# Set up the number of CPU cores available for multi-thread processing
n_jobs = 1

# Set up the verbose flag to print detailed messages for debugging (setting True will activate!)
verbose = False

# Set up the flag to stop sending progress emails (setting to True will send status emails!)
notifyStatus = False

# %%
# Set up the email notification function
def email_notify(msg_text):
    sender = os.environ.get('MAIL_SENDER')
    receiver = os.environ.get('MAIL_RECEIVER')
    gateway = os.environ.get('SMTP_GATEWAY')
    smtpuser = os.environ.get('SMTP_USERNAME')
    password = os.environ.get('SMTP_PASSWORD')
    if sender==None or receiver==None or gateway==None or smtpuser==None or password==None:
        sys.exit("Incomplete email setup info. Script Processing Aborted!!!")
    msg = EmailMessage()
    msg.set_content(msg_text)
    msg['Subject'] = 'Notification from Python Time Series Script'
    msg['From'] = sender
    msg['To'] = receiver
    server = smtplib.SMTP(gateway, 587)
    server.starttls()
    server.login(smtpuser, password)
    server.send_message(msg)
    server.quit()

# %%
if (notifyStatus): email_notify("Library and Data Loading has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 1.c) Acquire and Load the Data
#
# Since the dataset is not current, this means that we cannot easily collect updated data to validate the model. Therefore, we will withhold a portion of the data towards the end from analysis and model selection. This very segment of data will be used to validate the final model.

# %%
startTimeScript = datetime.now()

# %%
# load the dataset and the necessary data structure
time_series = pd.read_csv('tsdl011.csv', index_col='idx', parse_dates=True)

# Sample code for subsetting the time-series data
# original_series = pd.read_csv('minimum-daily-temperatures.csv', index_col='Date', parse_dates=True)
# time_series = original_series['1986':'1990']

# %%
target_col = time_series.columns[0]
lower_bound = 'lower ' + target_col
upper_bound = 'upper ' + target_col
print('The target column of the time series is:', target_col)
print('The forecast boundary columns are:', lower_bound, '&', upper_bound)
# Out:
# The target column of the time series is: values
# The forecast boundary columns are: lower values & upper values

# %%
time_series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 132 entries, 1965-01-01 to 1975-12-01
# Data columns (total 1 columns):
# values    132 non-null int64
# dtypes: int64(1)
# memory usage: 2.1 KB

# %%
time_series.head(10)
# Out:
#             values
# idx
# 1965-01-01   52149
# 1965-02-01   47205
# 1965-03-01   82150
# 1965-04-01  100931
# 1965-05-01   98408
# 1965-06-01   97351
# 1965-07-01   96489
# 1965-08-01   88830
# 1965-09-01   80876
# 1965-10-01   85750

# %%
time_series.tail(10)
# Out:
#             values
# idx
# 1975-03-01   62498
# 1975-04-01   77777
# 1975-05-01   92782
# 1975-06-01   90284
# 1975-07-01   92782
# 1975-08-01   90655
# 1975-09-01   84517
# 1975-10-01   93826
# 1975-11-01   71646
# 1975-12-01   55650

# %%
if (notifyStatus): email_notify("Library and Data Loading completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 2. Inspect and Explore Data

# %%
if (notifyStatus): email_notify("Data Inspection and Exploration has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 2.a) Summary Statistics of the Time Series Data
#
# Summary statistics provide a quick look at the limits of observed values. It can help to get a quick idea of what we are working with.

# %%
# Summary statistics of time series
print(time_series.describe())
# Out:
#               values
# count     132.000000
# mean    79406.159091
# std     23150.150284
# min     33363.000000
# 25%     64238.750000
# 50%     79805.000000
# 75%     92812.500000
# max    135167.000000

# %% [markdown]
# ### 2.b) Line Plot of the Time Series Data
#
# A line plot of a time series can provide a lot of insight into the problem. Some observations from the plot can include:
#
# * Whether the trend appears to be level around the mean
# * Whether there appear to be any obvious outliers
#
# The ARIMA(p,d,q) model requires three parameters and assumes that we are working with a stationary time series.
#
# The ADF results should show that the test statistic value is smaller than the critical value at 5% if the time series is stationary. This suggests that we can reject the null hypothesis (i.e. a low probability that the result is a statistical fluke).

# %%
# Line plots of time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Time Series Data')
time_series.plot(ax=ax)
plt.show()

# %% [markdown]
# ### 2.c) Histogram and Density Plots of the Time Series Data
#
# Reviewing plots of the density of observations can provide further insight into the structure of the data. Some observations from the plots can include:
#
# * Whether the distribution is Gaussian
# * Whether the distribution has a long tail and may suggest the need for data transformation

# %%
# Line plots of time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Histogram of the Time Series Data')
time_series.hist(ax=ax)
plt.show()

# %%
# Line plots of time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Density Plot of the Time Series Data')
time_series.plot(kind='kde', ax=ax)
plt.show()

# %% [markdown]
# ### 2.d) Box and Whisker Plots of the Time Series Data
#
# We can group or aggregate the data and get a better idea of the spread of observations. Some observations from reviewing the plot can include:
#
# * Whether the median values for each grouping shows any significant trend
# * Whether the spread, or middle 50% of the data, shows any significant variability
# * Whether there are outliers in some grouping

# %%
# boxplots of time series
fig, ax = plt.subplots(figsize=(12,9))
squeezed = time_series.squeeze()
sns.boxplot(squeezed.index.year, squeezed, ax=ax)
plt.show()

# %%
if (notifyStatus): email_notify("Data Inspection and Exploration completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 3. Data Transformation and Stationarity Tests

# %%
if (notifyStatus): email_notify("Data Cleaning and Pre-Processing has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### Section 3.a) Data Transformation

# %%
# Resampling the time series into monthly average for the ease of modeling
# original_series = time_series
# resample = original_series.resample('M')
# time_series = resample.mean()
# time_series.head(10)

# %%
# Line plots of the transformed time series
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Time Series Data')
time_series.plot(ax=ax)
plt.show()

# %% [markdown]
# ### Section 3.b) Test for Stationarity

# %%
# Check if stationary
result = adfuller(time_series[target_col])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Test Statistics Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -2.663920
# p-value: 0.080493
# Critical Test Statistics Values:
# 	1%: -3.487
# 	5%: -2.886
# 	10%: -2.580

# %%
# ACF and PACF plots of the time series data
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))
plot_acf(time_series, ax=ax1)
plot_pacf(time_series, ax=ax2)
plt.show()

# %% [markdown]
# ### 3.c) Test for Stationarity of Non-Seasonal Time Series Data
#
# Occasionally a time series may look non-stationary on the first look. We can make it stationary by differencing the series and using a statistical test to confirm that the differenced result is stationary. Rejecting the null hypothesis means that the process has no unit root, and in turn that the time series is stationary or does not have time-dependent structure.

# %%
# Create a differenced series
stationary_ns = time_series.diff().dropna()

# Plot differenced data
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Stationary Time Series Data')
stationary_ns.plot(ax=ax)
plt.show()

# %%
# Check for stationarity
result = adfuller(stationary_ns[target_col])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Test Statistics Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -1.999455
# p-value: 0.286812
# Critical Test Statistics Values:
# 	1%: -3.487
# 	5%: -2.886
# 	10%: -2.580

# %%
# ACF and PACF plots of the stationary time series
lags = 25
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))
plot_acf(stationary_ns, lags=lags, ax=ax1)
plot_pacf(stationary_ns, lags=lags, ax=ax2)
plt.show()

# %% [markdown]
# ### 3.d) Seasonal Decomposition for Seasonal Time Series Data

# %%
# Set the initial seasonal frequency parameter
seasonal_freq = 12

# %%
# Perform seasonal decomposition to observe the seasonal frequency
decomp_results = seasonal_decompose(time_series, freq=seasonal_freq)
decomp_results.plot()
plt.show()

# %%
# Detrending the time series
N = seasonal_freq
detrend = time_series - time_series.rolling(N).mean()
detrend = detrend.dropna()

# %%
# ACF and PACF plots of the time series data
lag = seasonal_freq * 2
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))
plot_acf(detrend, lags=lag, ax=ax1)
plot_pacf(detrend, lags=lag, ax=ax2)
plt.show()

# %% [markdown]
# ### 3.e) Test for Stationarity of Seasonal Time Series Data
#
# Occasionally a time series may look non-stationary on the first look. We can make it stationary by differencing the series and using a statistical test to confirm that the differenced result is stationary. Rejecting the null hypothesis means that the process has no unit root, and in turn that the time series is stationary or does not have time-dependent structure.

# %%
# Create a differenced series
# stationary_ss = time_series.diff(seasonal_freq).diff(seasonal_freq).dropna()
stationary_ss = time_series.diff(seasonal_freq).dropna()

# Plot differenced data
fig, ax = plt.subplots(figsize=(12,9))
fig.suptitle('Line Plot of the Stationary Time Series Data')
stationary_ss.plot(ax=ax)
plt.show()

# %%
# Check for stationarity
result = adfuller(stationary_ss[target_col])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Test Statistics Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -2.028274
# p-value: 0.274315
# Critical Test Statistics Values:
# 	1%: -3.494
# 	5%: -2.889
# 	10%: -2.582

# %%
# ACF and PACF plots of the stationary time series
lags = seasonal_freq
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))
plot_acf(stationary_ss, lags=lags, ax=ax1)
plot_pacf(stationary_ss, lags=lags, ax=ax2)
plt.show()

# %%
if (notifyStatus): email_notify("Data Cleaning and Pre-Processing completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 4. Fit and Evaluate Models
#
# In this section, we will develop Autoregressive Integrated Moving Average or ARIMA models for the problem. We will first establish a persistent model. Next we will use a grid search approach to look for an optimal ARIMA model. This will be followed by a third step of investigating the residual errors of the chosen model.
#
# * Establish the Persistent Model
# * Automatically Configure the ARIMA
# * Review Residual Errors

# %%
if (notifyStatus): email_notify("Model Fitting and Evaluation has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 4.a) Establish the Persistent Model
#
# The first step before getting bogged down in data analysis and modeling is to establish a baseline of performance. This will provide both a template for evaluating models using the proposed test harness and a performance measure by which all more elaborate predictive models can be compared.
#
# The baseline prediction for time series forecasting is called the naive forecast, or persistence. This is where the observation from the previous time step is used as the prediction for the observation at the next time step.

# %% [markdown]
# #### 4.a.iii) Establish the Persistent Model as Baseline

# %%
# Prepare and evaluate a persistence model
X = time_series.values
X = X.astype('float32')
train_pct = 0.80
train_size = int(len(X) * train_pct)
test_size = len(X) - train_size
train_ts, test_ts = X[0:train_size], X[train_size:]

# walk-forward validation
history = [x for x in train_ts]
predictions = list()
for i in range(len(test_ts)):
    yhat = history[-1]
    predictions.append(yhat)
    obs = test_ts[i]
    history.append(obs)
    print('>Predicted=%.3f, Expected=%3.f' % (yhat, obs))

# Calculate performance
rmse = math.sqrt(mean_squared_error(test_ts, predictions))
print('RMSE for the persistent model is: %.3f' % rmse)
# Out:
# >Predicted=84504.000, Expected=86004
# >Predicted=86004.000, Expected=70488
# >Predicted=70488.000, Expected=46767
# >Predicted=46767.000, Expected=43292
# >Predicted=43292.000, Expected=57593
# >Predicted=57593.000, Expected=76946
# >Predicted=76946.000, Expected=102237
# >Predicted=102237.000, Expected=96340
# >Predicted=96340.000, Expected=99318
# >Predicted=99318.000, Expected=90715
# >Predicted=90715.000, Expected=79782
# >Predicted=79782.000, Expected=73443
# >Predicted=73443.000, Expected=69460
# >Predicted=69460.000, Expected=57898
# >Predicted=57898.000, Expected=41041
# >Predicted=41041.000, Expected=39791
# >Predicted=39791.000, Expected=39959
# >Predicted=39959.000, Expected=62498
# >Predicted=62498.000, Expected=77777
# >Predicted=77777.000, Expected=92782
# >Predicted=92782.000, Expected=90284
# >Predicted=90284.000, Expected=92782
# >Predicted=92782.000, Expected=90655
# >Predicted=90655.000, Expected=84517
# >Predicted=84517.000, Expected=93826
# >Predicted=93826.000, Expected=71646
# >Predicted=71646.000, Expected=55650
# RMSE for the persistent model is: 13059.517

# %% [markdown]
# ### 4.b) Grid Search of ARIMA Hyperparameters
#
# We want to find a model that can do better than the persistence model on this dataset. To confirm this analysis, we can grid search a suite of ARIMA hyperparameters.
#
# In this section, we will search values of p, d, and q for combinations (skipping those that fail to converge), and find the combination that results in the best performance. We will use a grid search to explore all combinations in a subset of integer values.

# %%
if (notifyStatus): email_notify("ARIMA Hyperparameters Search has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Testing the time series data for suggestions on the differencing term
print('The suggested non-seasonal differencing term is:', pm.arima.ndiffs(time_series))
if (seasonal_freq != 0): print('The suggested seasonal differencing term is:', pm.arima.nsdiffs(time_series, m = seasonal_freq))
# Out:
# The suggested non-seasonal differencing term is: 0
# The suggested seasonal differencing term is: 0

# %%
# Set the P, D, and Q order parameters for non-seasonal ARIMA modeling
start_p = 0
start_d = 0
start_q = 0
max_p = 5
max_d = 2
max_q = 5

# %%
# Set the P, D, and Q order parameters for seasonal ARIMA modeling
start_P = 0
start_D = 0
start_Q = 0
max_P = 2
max_D = 1
max_Q = 2

# %%
print('The initial non-seasonal parameters are: p =', start_p, '| d =', start_d, '| q =', start_q)
print('The maximum non-seasonal parameters are: max_p =', max_p, '| max_d =', max_d, '| max_q =', max_q)
print('The initial seasonal parameters are: P =', start_P, '| D =', start_D, '| Q =', start_Q, '| m =', seasonal_freq)
print('The maximum seasonal parameters are: max_P =', max_P, '| max_D =', max_D, '| max_Q =', max_Q)
# Out:
# The initial non-seasonal parameters are: p = 0 | d = 0 | q = 0
# The maximum non-seasonal parameters are: max_p = 5 | max_d = 2 | max_q = 5
# The initial seasonal parameters are: P = 0 | D = 0 | Q = 0 | m = 12
# The maximum seasonal parameters are: max_P = 2 | max_D = 1 | max_Q = 2

# %%
# Do an automated stepwise search of ARIMA parameters
if (seasonal_freq == 0):
    stepwise_results = pm.auto_arima(time_series, seasonal = False, stepwise = True, trace = True, suppress_warnings = True, random_state = seedNum)
else:
    stepwise_results = pm.auto_arima(time_series, seasonal = True, m = seasonal_freq, stepwise = True, trace = True, suppress_warnings = True, random_state = seedNum)
# Out:
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=2800.053, BIC=2823.115, Fit time=1.761 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=3030.732, BIC=3036.497, Fit time=0.024 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=2818.662, BIC=2830.193, Fit time=0.461 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=2933.245, BIC=2944.776, Fit time=0.330 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(0, 0, 1, 12); AIC=2815.863, BIC=2836.043, Fit time=0.873 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=2795.980, BIC=2821.925, Fit time=4.526 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(2, 0, 0, 12); AIC=2798.423, BIC=2821.486, Fit time=3.878 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(2, 0, 2, 12); AIC=2796.508, BIC=2825.336, Fit time=6.143 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=2801.829, BIC=2822.009, Fit time=0.751 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=2799.403, BIC=2822.465, Fit time=4.459 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=2793.410, BIC=2822.238, Fit time=4.933 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=2795.510, BIC=2821.455, Fit time=5.197 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(2, 0, 1, 12); AIC=2794.456, BIC=2826.167, Fit time=5.624 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=2793.736, BIC=2816.799, Fit time=4.387 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(2, 0, 1, 12); AIC=2800.822, BIC=2835.415, Fit time=6.594 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=2790.276, BIC=2816.222, Fit time=2.314 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=2795.137, BIC=2818.200, Fit time=2.007 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 0, 2, 12); AIC=2795.303, BIC=2824.131, Fit time=6.375 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=2833.100, BIC=2853.280, Fit time=0.622 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(2, 0, 2, 12); AIC=2792.430, BIC=2824.141, Fit time=6.427 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=2795.854, BIC=2824.682, Fit time=1.675 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=2801.074, BIC=2824.136, Fit time=1.648 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(1, 0, 1, 12); AIC=2794.430, BIC=2823.258, Fit time=2.174 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=2799.372, BIC=2819.552, Fit time=1.619 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(1, 0, 1, 12); AIC=2791.847, BIC=2823.558, Fit time=2.679 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(0, 0, 1, 12); AIC=2817.154, BIC=2840.216, Fit time=1.456 seconds
# Total fit time: 78.968 seconds

# %%
print(stepwise_results.summary())
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  132
# Model:             SARIMAX(3, 0, 2)x(1, 0, 1, 12)   Log Likelihood               -1386.138
# Date:                            Mon, 14 Oct 2019   AIC                           2790.276
# Time:                                    17:57:37   BIC                           2816.222
# Sample:                                         0   HQIC                          2800.819
#                                             - 132
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   1.616e+04   1.28e+04      1.264      0.206   -8900.200    4.12e+04
# ar.L1         -1.1030      0.160     -6.882      0.000      -1.417      -0.789
# ar.L2          0.5979      0.149      4.024      0.000       0.307       0.889
# ar.L3          0.7271      0.120      6.081      0.000       0.493       0.961
# ma.L1          1.9314      0.179     10.784      0.000       1.580       2.282
# ma.L2          0.9333      0.179      5.213      0.000       0.582       1.284
# ar.S.L12       0.7552      0.156      4.847      0.000       0.450       1.060
# ma.S.L12      -0.1697      0.272     -0.624      0.533      -0.703       0.363
# sigma2      1.131e+08      0.986   1.15e+08      0.000    1.13e+08    1.13e+08
# ===================================================================================
# Ljung-Box (Q):                       55.99   Jarque-Bera (JB):                 2.10
# Prob(Q):                              0.05   Prob(JB):                         0.35
# Heteroskedasticity (H):               1.23   Skew:                             0.28
# Prob(H) (two-sided):                  0.49   Kurtosis:                         2.73
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 7.38e+23. Standard errors may be unstable.

# %%
if (notifyStatus): email_notify("ARIMA automated stepwise search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Do an automated random search of ARIMA parameters
n_fits = int(max_p * max_d * max_q * max_P * max_D * max_Q * 0.30)
if (seasonal_freq == 0):
    randgrid_results = pm.auto_arima(time_series, start_p = start_p, start_q = start_q, max_p = max_p, max_d = max_d, max_q = max_q,
                                     seasonal = False, stepwise = False, random = True, n_fits = n_fits, max_order = None,
                                     trace = True, suppress_warnings = True, random_state = seedNum)
else:
    randgrid_results = pm.auto_arima(time_series, start_p = start_p, start_q = start_q, max_p = max_p, max_d = max_d, max_q = max_q,
                                     seasonal = True, m = seasonal_freq, start_P = start_P, start_Q = start_Q, max_P = max_P, max_D = max_D, max_Q = max_Q,
                                     stepwise = False, random = True, n_fits = n_fits, max_order = None,
                                     trace = True, suppress_warnings = True, random_state = seedNum)
# Out:
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(1, 0, 1, 12); AIC=2768.557, BIC=2800.268, Fit time=2.989 seconds
# Fit ARIMA: order=(5, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=2802.144, BIC=2830.972, Fit time=6.507 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(2, 0, 0, 12); AIC=2825.902, BIC=2866.262, Fit time=8.363 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 0, 2, 12); AIC=2820.941, BIC=2835.356, Fit time=0.553 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(1, 0, 1, 12); AIC=2795.855, BIC=2821.800, Fit time=2.060 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=2870.906, BIC=2879.555, Fit time=0.078 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 0, 1, 12); AIC=2830.055, BIC=2841.587, Fit time=0.486 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(2, 0, 2, 12); AIC=2834.873, BIC=2875.233, Fit time=7.993 seconds
# Fit ARIMA: order=(1, 0, 4) seasonal_order=(0, 0, 1, 12); AIC=2819.875, BIC=2842.937, Fit time=1.143 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=2818.739, BIC=2833.153, Fit time=0.748 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 0, 0, 12); AIC=2798.974, BIC=2819.153, Fit time=3.584 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(2, 0, 2, 12); AIC=2838.907, BIC=2873.500, Fit time=8.015 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=2819.317, BIC=2845.262, Fit time=1.367 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 0, 2, 12); AIC=2801.048, BIC=2826.993, Fit time=4.914 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(0, 0, 2, 12); AIC=2808.866, BIC=2831.928, Fit time=0.866 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(1, 0, 1, 12); AIC=2838.648, BIC=2867.476, Fit time=2.924 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(0, 0, 1, 12); AIC=2828.022, BIC=2865.498, Fit time=3.428 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=2833.239, BIC=2859.184, Fit time=1.357 seconds
# Fit ARIMA: order=(1, 0, 4) seasonal_order=(1, 0, 2, 12); AIC=2838.685, BIC=2867.513, Fit time=6.248 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(2, 0, 0, 12); AIC=2779.830, BIC=2814.424, Fit time=7.567 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(0, 0, 1, 12); AIC=2815.884, BIC=2833.181, Fit time=0.571 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(1, 0, 0, 12); AIC=2784.474, BIC=2816.185, Fit time=2.382 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(2, 0, 2, 12); AIC=2806.876, BIC=2832.821, Fit time=6.134 seconds
# Fit ARIMA: order=(2, 0, 5) seasonal_order=(1, 0, 1, 12); AIC=2813.862, BIC=2845.573, Fit time=3.350 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=2801.074, BIC=2824.136, Fit time=1.593 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(1, 0, 2, 12); AIC=2770.683, BIC=2805.277, Fit time=6.773 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(1, 0, 2, 12); AIC=2830.754, BIC=2868.231, Fit time=6.087 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(1, 0, 1, 12); AIC=2767.714, BIC=2802.308, Fit time=3.009 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(0, 0, 2, 12); AIC=2806.821, BIC=2827.001, Fit time=0.824 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(0, 0, 2, 12); AIC=2803.336, BIC=2837.929, Fit time=6.627 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 0, 0, 12); AIC=2799.229, BIC=2819.408, Fit time=1.108 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=2847.023, BIC=2875.851, Fit time=1.282 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(0, 0, 2, 12); AIC=2824.451, BIC=2853.279, Fit time=1.270 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(2, 0, 1, 12); AIC=2823.548, BIC=2861.024, Fit time=8.689 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 0, 2, 12); AIC=2806.967, BIC=2827.147, Fit time=2.817 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=2843.372, BIC=2860.669, Fit time=0.294 seconds
# Fit ARIMA: order=(0, 0, 4) seasonal_order=(2, 0, 0, 12); AIC=2890.618, BIC=2913.680, Fit time=4.288 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=2846.884, BIC=2869.947, Fit time=0.272 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(0, 0, 2, 12); AIC=2807.019, BIC=2841.613, Fit time=6.384 seconds
# Fit ARIMA: order=(4, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=2811.460, BIC=2831.639, Fit time=0.912 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(0, 0, 2, 12); AIC=2809.976, BIC=2830.156, Fit time=1.065 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(2, 0, 0, 12); AIC=2814.695, BIC=2837.757, Fit time=4.977 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(2, 0, 0, 12); AIC=2793.998, BIC=2822.826, Fit time=5.447 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=2850.450, BIC=2882.160, Fit time=1.835 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(0, 0, 2, 12); AIC=2808.461, BIC=2843.054, Fit time=6.237 seconds
# Fit ARIMA: order=(5, 0, 2) seasonal_order=(1, 0, 2, 12); AIC=2798.924, BIC=2833.517, Fit time=6.560 seconds
# Fit ARIMA: order=(2, 0, 4) seasonal_order=(2, 0, 1, 12); AIC=2770.351, BIC=2802.062, Fit time=4.863 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=2844.971, BIC=2862.268, Fit time=0.184 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 0, 0, 12); AIC=2820.538, BIC=2834.952, Fit time=2.143 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(1, 0, 0, 12); AIC=2793.053, BIC=2818.998, Fit time=2.038 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=2817.682, BIC=2840.745, Fit time=1.043 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=2828.657, BIC=2851.720, Fit time=1.164 seconds
# Fit ARIMA: order=(0, 0, 5) seasonal_order=(1, 0, 2, 12); AIC=2950.600, BIC=2979.428, Fit time=7.405 seconds
# Fit ARIMA: order=(5, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=2796.514, BIC=2831.108, Fit time=7.069 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(0, 0, 2, 12); AIC=2809.390, BIC=2835.335, Fit time=1.951 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=2793.410, BIC=2822.238, Fit time=4.887 seconds
# Fit ARIMA: order=(4, 0, 0) seasonal_order=(0, 0, 1, 12); AIC=2815.844, BIC=2836.023, Fit time=0.715 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(1, 0, 1, 12); AIC=2773.771, BIC=2811.247, Fit time=3.306 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 2, 12); AIC=2972.740, BIC=2984.271, Fit time=0.395 seconds
# Fit ARIMA: order=(1, 0, 4) seasonal_order=(2, 0, 1, 12); AIC=2796.391, BIC=2825.219, Fit time=4.795 seconds
# Total fit time: 203.999 seconds

# %%
print(randgrid_results.summary())
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  132
# Model:             SARIMAX(4, 0, 4)x(1, 0, 1, 12)   Log Likelihood               -1371.857
# Date:                            Mon, 14 Oct 2019   AIC                           2767.714
# Time:                                    18:01:02   BIC                           2802.308
# Sample:                                         0   HQIC                          2781.771
#                                             - 132
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    963.5801   2419.122      0.398      0.690   -3777.811    5704.972
# ar.L1         -1.0708      0.170     -6.286      0.000      -1.405      -0.737
# ar.L2         -0.1342      0.163     -0.822      0.411      -0.454       0.186
# ar.L3          0.8731      0.149      5.842      0.000       0.580       1.166
# ar.L4          0.8140      0.135      6.036      0.000       0.550       1.078
# ma.L1          1.8924      0.249      7.608      0.000       1.405       2.380
# ma.L2          1.7656      0.481      3.667      0.000       0.822       2.709
# ma.L3          0.7505      0.461      1.628      0.103      -0.153       1.654
# ma.L4         -0.1152      0.239     -0.482      0.630      -0.584       0.353
# ar.S.L12       0.9770      0.038     25.865      0.000       0.903       1.051
# ma.S.L12      -0.6875      0.241     -2.852      0.004      -1.160      -0.215
# sigma2      9.087e+07      0.067   1.36e+09      0.000    9.09e+07    9.09e+07
# ===================================================================================
# Ljung-Box (Q):                       25.79   Jarque-Bera (JB):                 3.78
# Prob(Q):                              0.96   Prob(JB):                         0.15
# Heteroskedasticity (H):               1.16   Skew:                             0.41
# Prob(H) (two-sided):                  0.63   Kurtosis:                         2.96
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.32e+24. Standard errors may be unstable.

# %%
if (notifyStatus): email_notify("ARIMA automated random search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Do an automated grid search of ARIMA parameters
if (seasonal_freq == 0):
    autogrid_results = pm.auto_arima(time_series, start_p = start_p, start_q = start_q, max_p = max_p, max_d = max_d, max_q = max_q,
                                     seasonal = False, stepwise = False, max_order = None, trace = True, suppress_warnings = True, random_state = seedNum)
else:
    autogrid_results = pm.auto_arima(time_series, start_p = start_p, start_q = start_q, max_p = max_p, max_d = max_d, max_q = max_q,
                                     seasonal = True, m = seasonal_freq, start_P = start_P, start_Q = start_Q, max_P = max_P, max_D = max_D, max_Q = max_Q,
                                     stepwise = False, max_order = None, trace = True, suppress_warnings = True, random_state = seedNum)
# Out:
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=3030.732, BIC=3036.497, Fit time=0.024 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 1, 12); AIC=2977.828, BIC=2986.476, Fit time=0.209 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 2, 12); AIC=2972.740, BIC=2984.271, Fit time=0.390 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=3028.158, BIC=3036.807, Fit time=0.122 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=2979.164, BIC=2990.696, Fit time=0.479 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(1, 0, 2, 12); AIC=2974.674, BIC=2989.088, Fit time=1.920 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(2, 0, 0, 12); AIC=3011.926, BIC=3023.457, Fit time=1.775 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=2980.113, BIC=2994.527, Fit time=3.149 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(2, 0, 2, 12); AIC=2975.551, BIC=2992.848, Fit time=3.943 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 0, 12); AIC=2915.213, BIC=2923.862, Fit time=0.289 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=2933.245, BIC=2944.776, Fit time=0.322 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 2, 12); AIC=2933.365, BIC=2947.779, Fit time=0.568 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(1, 0, 0, 12); AIC=2946.737, BIC=2958.268, Fit time=0.272 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=2935.029, BIC=2949.443, Fit time=0.742 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(1, 0, 2, 12); AIC=2935.328, BIC=2952.625, Fit time=2.776 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(2, 0, 0, 12); AIC=2946.205, BIC=2960.619, Fit time=1.707 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=2934.250, BIC=2951.547, Fit time=3.316 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(2, 0, 2, 12); AIC=2936.203, BIC=2956.382, Fit time=4.553 seconds
# Fit ARIMA: order=(0, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=2907.648, BIC=2919.180, Fit time=0.286 seconds
# Fit ARIMA: order=(0, 0, 2) seasonal_order=(0, 0, 1, 12); AIC=2895.129, BIC=2909.543, Fit time=0.632 seconds
# Fit ARIMA: order=(0, 0, 2) seasonal_order=(0, 0, 2, 12); AIC=2895.182, BIC=2912.479, Fit time=1.640 seconds
# Fit ARIMA: order=(0, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=2905.914, BIC=2920.328, Fit time=0.602 seconds
# Fit ARIMA: order=(0, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=2896.645, BIC=2913.942, Fit time=1.132 seconds
# Fit ARIMA: order=(0, 0, 2) seasonal_order=(1, 0, 2, 12); AIC=2897.016, BIC=2917.195, Fit time=5.072 seconds
# Fit ARIMA: order=(0, 0, 2) seasonal_order=(2, 0, 0, 12); AIC=2906.122, BIC=2923.419, Fit time=2.509 seconds
# Fit ARIMA: order=(0, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=2895.608, BIC=2915.787, Fit time=3.822 seconds
# Fit ARIMA: order=(0, 0, 2) seasonal_order=(2, 0, 2, 12); AIC=2914.647, BIC=2937.709, Fit time=5.944 seconds
# Fit ARIMA: order=(0, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=2876.966, BIC=2891.380, Fit time=0.291 seconds
# Fit ARIMA: order=(0, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=2869.787, BIC=2887.084, Fit time=0.756 seconds
# Fit ARIMA: order=(0, 0, 3) seasonal_order=(0, 0, 2, 12); AIC=2869.095, BIC=2889.275, Fit time=1.057 seconds
# Fit ARIMA: order=(0, 0, 3) seasonal_order=(1, 0, 0, 12); AIC=2875.577, BIC=2892.874, Fit time=0.537 seconds
# Fit ARIMA: order=(0, 0, 3) seasonal_order=(1, 0, 1, 12); AIC=2871.557, BIC=2891.737, Fit time=2.128 seconds
# Fit ARIMA: order=(0, 0, 3) seasonal_order=(1, 0, 2, 12); AIC=2870.872, BIC=2893.934, Fit time=4.893 seconds
# Fit ARIMA: order=(0, 0, 3) seasonal_order=(2, 0, 0, 12); AIC=2877.488, BIC=2897.668, Fit time=3.849 seconds
# Fit ARIMA: order=(0, 0, 3) seasonal_order=(2, 0, 1, 12); AIC=2868.968, BIC=2892.030, Fit time=3.766 seconds
# Fit ARIMA: order=(0, 0, 3) seasonal_order=(2, 0, 2, 12); AIC=2874.305, BIC=2900.250, Fit time=5.625 seconds
# Fit ARIMA: order=(0, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=2840.511, BIC=2857.808, Fit time=0.717 seconds
# Fit ARIMA: order=(0, 0, 4) seasonal_order=(0, 0, 1, 12); AIC=2883.235, BIC=2903.414, Fit time=0.712 seconds
# Fit ARIMA: order=(0, 0, 4) seasonal_order=(0, 0, 2, 12); AIC=2882.898, BIC=2905.960, Fit time=0.826 seconds
# Fit ARIMA: order=(0, 0, 4) seasonal_order=(1, 0, 0, 12); AIC=2888.707, BIC=2908.886, Fit time=0.749 seconds
# Fit ARIMA: order=(0, 0, 4) seasonal_order=(1, 0, 1, 12); AIC=2886.304, BIC=2909.366, Fit time=2.830 seconds
# Fit ARIMA: order=(0, 0, 4) seasonal_order=(1, 0, 2, 12); AIC=2884.782, BIC=2910.728, Fit time=6.154 seconds
# Fit ARIMA: order=(0, 0, 4) seasonal_order=(2, 0, 0, 12); AIC=2890.618, BIC=2913.680, Fit time=4.245 seconds
# Fit ARIMA: order=(0, 0, 4) seasonal_order=(2, 0, 1, 12); AIC=2896.049, BIC=2921.994, Fit time=4.859 seconds
# Fit ARIMA: order=(0, 0, 4) seasonal_order=(2, 0, 2, 12); AIC=2893.621, BIC=2922.449, Fit time=7.202 seconds
# Fit ARIMA: order=(0, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=2911.293, BIC=2931.472, Fit time=0.351 seconds
# Fit ARIMA: order=(0, 0, 5) seasonal_order=(0, 0, 1, 12); AIC=2907.427, BIC=2930.489, Fit time=1.136 seconds
# Fit ARIMA: order=(0, 0, 5) seasonal_order=(0, 0, 2, 12); AIC=2907.642, BIC=2933.587, Fit time=1.604 seconds
# Fit ARIMA: order=(0, 0, 5) seasonal_order=(1, 0, 0, 12); AIC=2913.280, BIC=2936.343, Fit time=1.666 seconds
# Fit ARIMA: order=(0, 0, 5) seasonal_order=(1, 0, 1, 12); AIC=2925.148, BIC=2951.093, Fit time=3.068 seconds
# Fit ARIMA: order=(0, 0, 5) seasonal_order=(1, 0, 2, 12); AIC=2950.600, BIC=2979.428, Fit time=6.922 seconds
# Fit ARIMA: order=(0, 0, 5) seasonal_order=(2, 0, 0, 12); AIC=2934.034, BIC=2959.979, Fit time=5.287 seconds
# Fit ARIMA: order=(0, 0, 5) seasonal_order=(2, 0, 1, 12); AIC=2923.924, BIC=2952.752, Fit time=5.422 seconds
# Fit ARIMA: order=(0, 0, 5) seasonal_order=(2, 0, 2, 12); AIC=2914.206, BIC=2945.917, Fit time=7.231 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=2870.906, BIC=2879.555, Fit time=0.064 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 0, 1, 12); AIC=2830.055, BIC=2841.587, Fit time=0.460 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 0, 2, 12); AIC=2820.941, BIC=2835.356, Fit time=0.534 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=2818.662, BIC=2830.193, Fit time=0.459 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=2818.739, BIC=2833.153, Fit time=0.762 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 2, 12); AIC=2818.361, BIC=2835.658, Fit time=2.470 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 0, 0, 12); AIC=2820.538, BIC=2834.952, Fit time=2.144 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=2810.041, BIC=2827.338, Fit time=3.173 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 0, 2, 12); AIC=2814.181, BIC=2834.361, Fit time=4.438 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 0, 0, 12); AIC=2853.249, BIC=2864.780, Fit time=0.087 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=2819.732, BIC=2834.146, Fit time=0.480 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 0, 2, 12); AIC=2810.876, BIC=2828.172, Fit time=0.619 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 0, 0, 12); AIC=2805.082, BIC=2819.496, Fit time=0.469 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=2806.700, BIC=2823.996, Fit time=0.589 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 0, 2, 12); AIC=2806.967, BIC=2827.147, Fit time=2.414 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(2, 0, 0, 12); AIC=2806.290, BIC=2823.586, Fit time=2.174 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=2799.584, BIC=2819.763, Fit time=4.115 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(2, 0, 2, 12); AIC=2802.235, BIC=2825.297, Fit time=4.861 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=2846.076, BIC=2860.490, Fit time=0.147 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(0, 0, 1, 12); AIC=2815.884, BIC=2833.181, Fit time=0.554 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(0, 0, 2, 12); AIC=2807.346, BIC=2827.526, Fit time=0.820 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=2803.023, BIC=2820.320, Fit time=0.616 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=2804.763, BIC=2824.942, Fit time=1.425 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(1, 0, 2, 12); AIC=2804.603, BIC=2827.665, Fit time=3.405 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(2, 0, 0, 12); AIC=2804.317, BIC=2824.497, Fit time=2.610 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=2799.403, BIC=2822.465, Fit time=4.475 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(2, 0, 2, 12); AIC=2800.898, BIC=2826.844, Fit time=5.393 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=2844.971, BIC=2862.268, Fit time=0.188 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=2817.218, BIC=2837.398, Fit time=0.714 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(0, 0, 2, 12); AIC=2808.866, BIC=2831.928, Fit time=0.873 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(1, 0, 0, 12); AIC=2801.379, BIC=2821.558, Fit time=0.897 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(1, 0, 1, 12); AIC=2802.893, BIC=2825.955, Fit time=1.820 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(1, 0, 2, 12); AIC=2840.836, BIC=2866.781, Fit time=5.397 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(2, 0, 0, 12); AIC=2814.695, BIC=2837.757, Fit time=5.303 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(2, 0, 1, 12); AIC=2800.676, BIC=2826.622, Fit time=4.318 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(2, 0, 2, 12); AIC=2841.560, BIC=2870.388, Fit time=5.779 seconds
# Fit ARIMA: order=(1, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=2840.855, BIC=2861.035, Fit time=0.233 seconds
# Fit ARIMA: order=(1, 0, 4) seasonal_order=(0, 0, 1, 12); AIC=2819.875, BIC=2842.937, Fit time=1.185 seconds
# Fit ARIMA: order=(1, 0, 4) seasonal_order=(0, 0, 2, 12); AIC=2812.853, BIC=2838.798, Fit time=1.389 seconds
# Fit ARIMA: order=(1, 0, 4) seasonal_order=(1, 0, 0, 12); AIC=2798.524, BIC=2821.586, Fit time=1.067 seconds
# Fit ARIMA: order=(1, 0, 4) seasonal_order=(1, 0, 1, 12); AIC=2795.023, BIC=2820.968, Fit time=1.487 seconds
# Fit ARIMA: order=(1, 0, 4) seasonal_order=(1, 0, 2, 12); AIC=2838.685, BIC=2867.513, Fit time=6.239 seconds
# Fit ARIMA: order=(1, 0, 4) seasonal_order=(2, 0, 0, 12); AIC=2794.681, BIC=2820.626, Fit time=4.823 seconds
# Fit ARIMA: order=(1, 0, 4) seasonal_order=(2, 0, 1, 12); AIC=2796.391, BIC=2825.219, Fit time=4.808 seconds
# Fit ARIMA: order=(1, 0, 4) seasonal_order=(2, 0, 2, 12); AIC=2795.527, BIC=2827.238, Fit time=6.340 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=2846.884, BIC=2869.947, Fit time=0.269 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(0, 0, 1, 12); AIC=2829.367, BIC=2855.312, Fit time=1.234 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(0, 0, 2, 12); AIC=2824.451, BIC=2853.279, Fit time=1.226 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(1, 0, 0, 12); AIC=2815.739, BIC=2841.684, Fit time=2.096 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(1, 0, 1, 12); AIC=2838.648, BIC=2867.476, Fit time=2.909 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(1, 0, 2, 12); AIC=2839.168, BIC=2870.879, Fit time=6.978 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(2, 0, 0, 12); AIC=2847.820, BIC=2876.648, Fit time=5.724 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(2, 0, 1, 12); AIC=2842.155, BIC=2873.866, Fit time=5.704 seconds
# Fit ARIMA: order=(1, 0, 5) seasonal_order=(2, 0, 2, 12); AIC=2838.907, BIC=2873.500, Fit time=7.921 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=2842.353, BIC=2853.884, Fit time=0.096 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 0, 1, 12); AIC=2815.795, BIC=2830.209, Fit time=0.466 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 0, 2, 12); AIC=2809.906, BIC=2827.202, Fit time=0.769 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=2817.510, BIC=2831.924, Fit time=0.570 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=2813.268, BIC=2830.565, Fit time=0.915 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 0, 2, 12); AIC=2811.224, BIC=2831.403, Fit time=2.730 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 0, 0, 12); AIC=2819.367, BIC=2836.663, Fit time=2.906 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=2804.106, BIC=2824.286, Fit time=4.094 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 0, 2, 12); AIC=2809.443, BIC=2832.506, Fit time=5.745 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(0, 0, 0, 12); AIC=2844.041, BIC=2858.455, Fit time=0.181 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=2815.788, BIC=2833.084, Fit time=0.712 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(0, 0, 2, 12); AIC=2809.976, BIC=2830.156, Fit time=1.080 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(1, 0, 0, 12); AIC=2786.671, BIC=2803.967, Fit time=1.404 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=2799.372, BIC=2819.552, Fit time=1.582 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(1, 0, 2, 12); AIC=2799.716, BIC=2822.778, Fit time=4.199 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 0, 0, 12); AIC=2798.974, BIC=2819.153, Fit time=3.550 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=2793.736, BIC=2816.799, Fit time=4.371 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 0, 2, 12); AIC=2794.401, BIC=2820.346, Fit time=4.795 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=2843.372, BIC=2860.669, Fit time=0.200 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(0, 0, 1, 12); AIC=2815.863, BIC=2836.043, Fit time=0.878 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(0, 0, 2, 12); AIC=2808.294, BIC=2831.356, Fit time=1.189 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=2801.829, BIC=2822.009, Fit time=0.774 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=2800.053, BIC=2823.115, Fit time=1.788 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 0, 2, 12); AIC=2801.048, BIC=2826.993, Fit time=4.901 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(2, 0, 0, 12); AIC=2798.423, BIC=2821.486, Fit time=3.905 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=2795.980, BIC=2821.925, Fit time=4.526 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(2, 0, 2, 12); AIC=2796.508, BIC=2825.336, Fit time=6.134 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=2844.717, BIC=2864.896, Fit time=0.315 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=2817.705, BIC=2840.767, Fit time=0.818 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(0, 0, 2, 12); AIC=2810.407, BIC=2836.353, Fit time=1.260 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(1, 0, 0, 12); AIC=2794.800, BIC=2817.862, Fit time=1.266 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(1, 0, 1, 12); AIC=2795.855, BIC=2821.800, Fit time=2.099 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(1, 0, 2, 12); AIC=2797.290, BIC=2826.118, Fit time=6.269 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(2, 0, 0, 12); AIC=2793.911, BIC=2819.857, Fit time=4.815 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(2, 0, 1, 12); AIC=2795.185, BIC=2824.013, Fit time=5.115 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(2, 0, 2, 12); AIC=2794.778, BIC=2826.488, Fit time=5.865 seconds
# Fit ARIMA: order=(2, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=2845.409, BIC=2868.471, Fit time=1.318 seconds
# Fit ARIMA: order=(2, 0, 4) seasonal_order=(0, 0, 1, 12); AIC=2824.537, BIC=2850.482, Fit time=2.207 seconds
# Fit ARIMA: order=(2, 0, 4) seasonal_order=(0, 0, 2, 12); AIC=2812.223, BIC=2841.051, Fit time=3.795 seconds
# Fit ARIMA: order=(2, 0, 4) seasonal_order=(1, 0, 0, 12); AIC=2787.176, BIC=2813.121, Fit time=2.202 seconds
# Fit ARIMA: order=(2, 0, 4) seasonal_order=(1, 0, 1, 12); AIC=2768.383, BIC=2797.211, Fit time=2.499 seconds
# Fit ARIMA: order=(2, 0, 4) seasonal_order=(1, 0, 2, 12); AIC=2770.343, BIC=2802.053, Fit time=4.250 seconds
# Fit ARIMA: order=(2, 0, 4) seasonal_order=(2, 0, 0, 12); AIC=2777.440, BIC=2806.268, Fit time=4.692 seconds
# Fit ARIMA: order=(2, 0, 4) seasonal_order=(2, 0, 1, 12); AIC=2770.351, BIC=2802.062, Fit time=4.860 seconds
# Fit ARIMA: order=(2, 0, 4) seasonal_order=(2, 0, 2, 12); AIC=2772.345, BIC=2806.939, Fit time=6.233 seconds
# Fit ARIMA: order=(2, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=2859.005, BIC=2884.950, Fit time=1.198 seconds
# Fit ARIMA: order=(2, 0, 5) seasonal_order=(0, 0, 1, 12); AIC=2799.577, BIC=2828.405, Fit time=2.868 seconds
# Fit ARIMA: order=(2, 0, 5) seasonal_order=(0, 0, 2, 12); AIC=2800.360, BIC=2832.071, Fit time=5.707 seconds
# Fit ARIMA: order=(2, 0, 5) seasonal_order=(1, 0, 0, 12); AIC=2781.688, BIC=2810.516, Fit time=1.944 seconds
# Fit ARIMA: order=(2, 0, 5) seasonal_order=(1, 0, 1, 12); AIC=2813.862, BIC=2845.573, Fit time=3.449 seconds
# Fit ARIMA: order=(2, 0, 5) seasonal_order=(1, 0, 2, 12); AIC=2836.892, BIC=2871.485, Fit time=7.188 seconds
# Fit ARIMA: order=(2, 0, 5) seasonal_order=(2, 0, 0, 12); AIC=2837.998, BIC=2869.708, Fit time=5.434 seconds
# Fit ARIMA: order=(2, 0, 5) seasonal_order=(2, 0, 1, 12); AIC=2818.078, BIC=2852.671, Fit time=5.930 seconds
# Fit ARIMA: order=(2, 0, 5) seasonal_order=(2, 0, 2, 12); AIC=2836.957, BIC=2874.434, Fit time=7.408 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=2843.245, BIC=2857.659, Fit time=0.143 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(0, 0, 1, 12); AIC=2814.075, BIC=2831.372, Fit time=0.586 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(0, 0, 2, 12); AIC=2806.821, BIC=2827.001, Fit time=0.838 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=2813.279, BIC=2830.576, Fit time=0.828 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=2809.939, BIC=2830.119, Fit time=1.420 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(1, 0, 2, 12); AIC=2807.694, BIC=2830.756, Fit time=3.778 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(2, 0, 0, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=2801.050, BIC=2824.112, Fit time=5.319 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(2, 0, 2, 12); AIC=2806.876, BIC=2832.821, Fit time=6.170 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(0, 0, 0, 12); AIC=2845.204, BIC=2862.501, Fit time=0.305 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=2816.244, BIC=2836.424, Fit time=0.899 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(0, 0, 2, 12); AIC=2808.821, BIC=2831.884, Fit time=1.203 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 0, 0, 12); AIC=2799.229, BIC=2819.408, Fit time=1.110 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=2801.074, BIC=2824.136, Fit time=1.619 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 0, 2, 12); AIC=2801.634, BIC=2827.579, Fit time=5.148 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(2, 0, 0, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=2795.510, BIC=2821.455, Fit time=5.181 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(2, 0, 2, 12); AIC=2796.395, BIC=2825.223, Fit time=6.073 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=2833.100, BIC=2853.280, Fit time=0.626 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(0, 0, 1, 12); AIC=2817.154, BIC=2840.216, Fit time=1.482 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(0, 0, 2, 12); AIC=2809.390, BIC=2835.335, Fit time=1.983 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=2795.137, BIC=2818.200, Fit time=1.980 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=2790.276, BIC=2816.222, Fit time=2.343 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 0, 2, 12); AIC=2795.303, BIC=2824.131, Fit time=6.510 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(2, 0, 0, 12); AIC=2791.627, BIC=2817.572, Fit time=5.728 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=2793.410, BIC=2822.238, Fit time=4.892 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(2, 0, 2, 12); AIC=2792.430, BIC=2824.141, Fit time=6.063 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=2831.889, BIC=2854.951, Fit time=0.937 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=2819.317, BIC=2845.262, Fit time=1.468 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(0, 0, 2, 12); AIC=2811.908, BIC=2840.736, Fit time=1.922 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(1, 0, 0, 12); AIC=2793.053, BIC=2818.998, Fit time=2.064 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(1, 0, 1, 12); AIC=2794.430, BIC=2823.258, Fit time=2.169 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(1, 0, 2, 12); AIC=2798.802, BIC=2830.513, Fit time=5.804 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(2, 0, 0, 12); AIC=2840.430, BIC=2869.258, Fit time=5.712 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(2, 0, 1, 12); AIC=2794.456, BIC=2826.167, Fit time=5.737 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(2, 0, 2, 12); AIC=2798.330, BIC=2832.924, Fit time=6.766 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=2845.788, BIC=2871.733, Fit time=1.416 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(0, 0, 1, 12); AIC=2811.038, BIC=2839.866, Fit time=2.578 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(0, 0, 2, 12); AIC=2818.839, BIC=2850.550, Fit time=6.316 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(1, 0, 0, 12); AIC=2780.822, BIC=2809.650, Fit time=2.522 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(1, 0, 1, 12); AIC=2768.557, BIC=2800.268, Fit time=2.950 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(1, 0, 2, 12); AIC=2770.683, BIC=2805.277, Fit time=6.790 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(2, 0, 0, 12); AIC=2774.476, BIC=2806.187, Fit time=5.897 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(2, 0, 1, 12); AIC=2770.554, BIC=2805.148, Fit time=6.273 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(2, 0, 2, 12); AIC=2772.407, BIC=2809.884, Fit time=6.964 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=2860.935, BIC=2889.763, Fit time=1.579 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(0, 0, 1, 12); AIC=2824.238, BIC=2855.949, Fit time=3.065 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(0, 0, 2, 12); AIC=2803.336, BIC=2837.929, Fit time=6.621 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(1, 0, 0, 12); AIC=2775.886, BIC=2807.597, Fit time=2.441 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(1, 0, 1, 12); AIC=2773.966, BIC=2808.560, Fit time=3.104 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(1, 0, 2, 12); AIC=2830.754, BIC=2868.231, Fit time=6.026 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(2, 0, 0, 12); AIC=2848.244, BIC=2882.838, Fit time=4.734 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(2, 0, 1, 12); AIC=2823.548, BIC=2861.024, Fit time=8.541 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(2, 0, 2, 12); AIC=2834.873, BIC=2875.233, Fit time=7.978 seconds
# Fit ARIMA: order=(4, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=2844.114, BIC=2861.411, Fit time=0.169 seconds
# Fit ARIMA: order=(4, 0, 0) seasonal_order=(0, 0, 1, 12); AIC=2815.844, BIC=2836.023, Fit time=0.714 seconds
# Fit ARIMA: order=(4, 0, 0) seasonal_order=(0, 0, 2, 12); AIC=2808.466, BIC=2831.529, Fit time=1.038 seconds
# Fit ARIMA: order=(4, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=2811.460, BIC=2831.639, Fit time=0.946 seconds
# Fit ARIMA: order=(4, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=2809.979, BIC=2833.041, Fit time=1.578 seconds
# Fit ARIMA: order=(4, 0, 0) seasonal_order=(1, 0, 2, 12); AIC=2808.329, BIC=2834.274, Fit time=4.049 seconds
# Fit ARIMA: order=(4, 0, 0) seasonal_order=(2, 0, 0, 12); AIC=2813.453, BIC=2836.516, Fit time=4.028 seconds
# Fit ARIMA: order=(4, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=2801.537, BIC=2827.482, Fit time=5.147 seconds
# Fit ARIMA: order=(4, 0, 0) seasonal_order=(2, 0, 2, 12); AIC=2824.110, BIC=2852.938, Fit time=7.045 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(0, 0, 0, 12); AIC=2845.952, BIC=2866.132, Fit time=0.363 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=2817.682, BIC=2840.745, Fit time=1.037 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(0, 0, 2, 12); AIC=2810.491, BIC=2836.436, Fit time=1.366 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(1, 0, 0, 12); AIC=2795.465, BIC=2818.527, Fit time=1.161 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=2797.444, BIC=2823.389, Fit time=1.539 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(1, 0, 2, 12); AIC=2798.266, BIC=2827.094, Fit time=5.590 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(2, 0, 0, 12); AIC=2795.963, BIC=2821.909, Fit time=4.794 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=2794.180, BIC=2823.008, Fit time=6.144 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(2, 0, 2, 12); AIC=2794.458, BIC=2826.168, Fit time=6.246 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=2828.657, BIC=2851.720, Fit time=1.095 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(0, 0, 1, 12); AIC=2810.110, BIC=2836.055, Fit time=2.406 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(0, 0, 2, 12); AIC=2805.665, BIC=2834.493, Fit time=4.966 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=2791.024, BIC=2816.969, Fit time=2.074 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=2795.854, BIC=2824.682, Fit time=1.674 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(1, 0, 2, 12); AIC=2797.690, BIC=2829.401, Fit time=6.987 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(2, 0, 0, 12); AIC=2793.998, BIC=2822.826, Fit time=5.505 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=2795.443, BIC=2827.154, Fit time=5.899 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(2, 0, 2, 12); AIC=2796.862, BIC=2831.456, Fit time=6.610 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=2833.239, BIC=2859.184, Fit time=1.342 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=2818.743, BIC=2847.571, Fit time=2.201 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(0, 0, 2, 12); AIC=2813.621, BIC=2845.332, Fit time=2.791 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(1, 0, 0, 12); AIC=2795.279, BIC=2824.107, Fit time=2.318 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(1, 0, 1, 12); AIC=2791.847, BIC=2823.558, Fit time=2.714 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(1, 0, 2, 12); AIC=2807.756, BIC=2842.350, Fit time=7.502 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(2, 0, 0, 12); AIC=2791.035, BIC=2822.746, Fit time=6.933 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(2, 0, 1, 12); AIC=2800.822, BIC=2835.415, Fit time=6.644 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(2, 0, 2, 12); AIC=2799.436, BIC=2836.912, Fit time=6.723 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=2847.023, BIC=2875.851, Fit time=1.286 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(0, 0, 1, 12); AIC=2823.478, BIC=2855.188, Fit time=2.901 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(0, 0, 2, 12); AIC=2807.019, BIC=2841.613, Fit time=6.482 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(1, 0, 0, 12); AIC=2784.474, BIC=2816.185, Fit time=2.453 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(1, 0, 1, 12); AIC=2767.714, BIC=2802.308, Fit time=3.108 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(1, 0, 2, 12); AIC=2769.126, BIC=2806.602, Fit time=6.860 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(2, 0, 0, 12); AIC=2779.830, BIC=2814.424, Fit time=8.124 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(2, 0, 1, 12); AIC=2769.232, BIC=2806.708, Fit time=6.145 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(2, 0, 2, 12); AIC=2770.933, BIC=2811.292, Fit time=7.584 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=2868.809, BIC=2900.520, Fit time=1.526 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(0, 0, 1, 12); AIC=2822.691, BIC=2857.285, Fit time=3.205 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(0, 0, 2, 12); AIC=2791.593, BIC=2829.069, Fit time=7.609 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(1, 0, 0, 12); AIC=2773.331, BIC=2807.925, Fit time=2.586 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(1, 0, 1, 12); AIC=2805.081, BIC=2842.557, Fit time=3.810 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(1, 0, 2, 12); AIC=2826.939, BIC=2867.299, Fit time=7.264 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(2, 0, 0, 12); AIC=2828.976, BIC=2866.453, Fit time=6.900 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(2, 0, 1, 12); AIC=2825.751, BIC=2866.111, Fit time=7.367 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(2, 0, 2, 12); AIC=2762.867, BIC=2806.109, Fit time=9.761 seconds
# Fit ARIMA: order=(5, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=2845.092, BIC=2865.271, Fit time=0.207 seconds
# Fit ARIMA: order=(5, 0, 0) seasonal_order=(0, 0, 1, 12); AIC=2817.568, BIC=2840.630, Fit time=0.833 seconds
# Fit ARIMA: order=(5, 0, 0) seasonal_order=(0, 0, 2, 12); AIC=2809.765, BIC=2835.710, Fit time=1.734 seconds
# Fit ARIMA: order=(5, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=2810.479, BIC=2833.542, Fit time=1.286 seconds
# Fit ARIMA: order=(5, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=2810.131, BIC=2836.077, Fit time=2.199 seconds
# Fit ARIMA: order=(5, 0, 0) seasonal_order=(1, 0, 2, 12); AIC=2808.884, BIC=2837.712, Fit time=4.683 seconds
# Fit ARIMA: order=(5, 0, 0) seasonal_order=(2, 0, 0, 12); AIC=2812.453, BIC=2838.398, Fit time=4.655 seconds
# Fit ARIMA: order=(5, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=2802.144, BIC=2830.972, Fit time=6.481 seconds
# Fit ARIMA: order=(5, 0, 0) seasonal_order=(2, 0, 2, 12); AIC=2808.917, BIC=2840.628, Fit time=7.684 seconds
# Fit ARIMA: order=(5, 0, 1) seasonal_order=(0, 0, 0, 12); AIC=2845.443, BIC=2868.506, Fit time=0.529 seconds
# Fit ARIMA: order=(5, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=2819.573, BIC=2845.518, Fit time=1.319 seconds
# Fit ARIMA: order=(5, 0, 1) seasonal_order=(0, 0, 2, 12); AIC=2811.957, BIC=2840.785, Fit time=1.837 seconds
# Fit ARIMA: order=(5, 0, 1) seasonal_order=(1, 0, 0, 12); AIC=2796.319, BIC=2822.265, Fit time=1.998 seconds
# Fit ARIMA: order=(5, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=2798.211, BIC=2827.039, Fit time=2.532 seconds
# Fit ARIMA: order=(5, 0, 1) seasonal_order=(1, 0, 2, 12); AIC=2799.251, BIC=2830.962, Fit time=6.547 seconds
# Fit ARIMA: order=(5, 0, 1) seasonal_order=(2, 0, 0, 12); AIC=2796.527, BIC=2825.355, Fit time=5.809 seconds
# Fit ARIMA: order=(5, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=2795.865, BIC=2827.576, Fit time=6.940 seconds
# Fit ARIMA: order=(5, 0, 1) seasonal_order=(2, 0, 2, 12); AIC=2795.576, BIC=2830.170, Fit time=8.146 seconds
# Fit ARIMA: order=(5, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=2816.582, BIC=2842.527, Fit time=1.628 seconds
# Fit ARIMA: order=(5, 0, 2) seasonal_order=(0, 0, 1, 12); AIC=2823.105, BIC=2851.933, Fit time=2.636 seconds
# Fit ARIMA: order=(5, 0, 2) seasonal_order=(0, 0, 2, 12); AIC=2807.930, BIC=2839.641, Fit time=4.635 seconds
# Fit ARIMA: order=(5, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=2797.206, BIC=2826.034, Fit time=2.518 seconds
# Fit ARIMA: order=(5, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=2797.614, BIC=2829.325, Fit time=2.968 seconds
# Fit ARIMA: order=(5, 0, 2) seasonal_order=(1, 0, 2, 12); AIC=2798.924, BIC=2833.517, Fit time=6.582 seconds
# Fit ARIMA: order=(5, 0, 2) seasonal_order=(2, 0, 0, 12); AIC=2795.298, BIC=2827.009, Fit time=6.124 seconds
# Fit ARIMA: order=(5, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=2796.514, BIC=2831.108, Fit time=7.120 seconds
# Fit ARIMA: order=(5, 0, 2) seasonal_order=(2, 0, 2, 12); AIC=2796.234, BIC=2833.711, Fit time=7.853 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=2838.906, BIC=2867.734, Fit time=1.526 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=2815.298, BIC=2847.009, Fit time=2.159 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(0, 0, 2, 12); AIC=2808.461, BIC=2843.054, Fit time=6.166 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(1, 0, 0, 12); AIC=2791.559, BIC=2823.270, Fit time=2.730 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(1, 0, 1, 12); AIC=2788.260, BIC=2822.854, Fit time=2.932 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(1, 0, 2, 12); AIC=2790.073, BIC=2827.549, Fit time=6.431 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(2, 0, 0, 12); AIC=2787.741, BIC=2822.334, Fit time=6.843 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(2, 0, 1, 12); AIC=2791.151, BIC=2828.628, Fit time=7.080 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(2, 0, 2, 12); AIC=2787.875, BIC=2828.234, Fit time=7.982 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=2850.450, BIC=2882.160, Fit time=1.850 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(0, 0, 1, 12); AIC=2828.495, BIC=2863.088, Fit time=3.361 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(0, 0, 2, 12); AIC=2801.786, BIC=2839.263, Fit time=7.379 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(1, 0, 0, 12); AIC=2785.686, BIC=2820.280, Fit time=3.179 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(1, 0, 1, 12); AIC=2773.771, BIC=2811.247, Fit time=3.270 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(1, 0, 2, 12); AIC=2775.584, BIC=2815.943, Fit time=7.400 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(2, 0, 0, 12); AIC=2781.978, BIC=2819.454, Fit time=8.310 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(2, 0, 1, 12); AIC=2775.797, BIC=2816.156, Fit time=7.525 seconds
# Fit ARIMA: order=(5, 0, 4) seasonal_order=(2, 0, 2, 12); AIC=2775.709, BIC=2818.951, Fit time=8.310 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=2837.445, BIC=2872.039, Fit time=1.813 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(0, 0, 1, 12); AIC=2828.022, BIC=2865.498, Fit time=3.415 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(0, 0, 2, 12); AIC=2795.635, BIC=2835.994, Fit time=8.096 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(1, 0, 0, 12); AIC=2774.351, BIC=2811.827, Fit time=3.285 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(1, 0, 1, 12); AIC=2775.645, BIC=2816.005, Fit time=4.265 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(1, 0, 2, 12); AIC=2829.374, BIC=2872.616, Fit time=8.861 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(2, 0, 0, 12); AIC=2825.902, BIC=2866.262, Fit time=8.319 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(2, 0, 1, 12); AIC=2793.351, BIC=2836.593, Fit time=9.391 seconds
# Fit ARIMA: order=(5, 0, 5) seasonal_order=(2, 0, 2, 12); AIC=2763.094, BIC=2809.219, Fit time=10.905 seconds
# Total fit time: 1114.838 seconds

# %%
print(autogrid_results.summary())
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  132
# Model:             SARIMAX(4, 0, 5)x(2, 0, 2, 12)   Log Likelihood               -1366.434
# Date:                            Mon, 14 Oct 2019   AIC                           2762.867
# Time:                                    18:19:37   BIC                           2806.109
# Sample:                                         0   HQIC                          2780.439
#                                             - 132
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   1.646e+04   1.72e+04      0.956      0.339   -1.73e+04    5.02e+04
# ar.L1         -1.1820      0.146     -8.110      0.000      -1.468      -0.896
# ar.L2         -0.2960      0.204     -1.454      0.146      -0.695       0.103
# ar.L3          0.7249      0.171      4.236      0.000       0.390       1.060
# ar.L4          0.7058      0.107      6.586      0.000       0.496       0.916
# ma.L1          2.0507      0.195     10.533      0.000       1.669       2.432
# ma.L2          2.1807      0.442      4.932      0.000       1.314       3.047
# ma.L3          1.3202      0.541      2.439      0.015       0.259       2.381
# ma.L4          0.3380      0.432      0.782      0.434      -0.509       1.185
# ma.L5          0.1419      0.188      0.754      0.451      -0.227       0.511
# ar.S.L12      -0.0677      0.425     -0.159      0.873      -0.900       0.765
# ar.S.L24       0.8950      0.343      2.607      0.009       0.222       1.568
# ma.S.L12       0.4822      0.646      0.747      0.455      -0.783       1.747
# ma.S.L24      -0.4449      0.345     -1.289      0.197      -1.121       0.231
# sigma2      6.479e+07      1.219   5.32e+07      0.000    6.48e+07    6.48e+07
# ===================================================================================
# Ljung-Box (Q):                       35.03   Jarque-Bera (JB):                 5.07
# Prob(Q):                              0.69   Prob(JB):                         0.08
# Heteroskedasticity (H):               1.18   Skew:                             0.48
# Prob(H) (two-sided):                  0.59   Kurtosis:                         3.02
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.24e+23. Standard errors may be unstable.

# %%
if (notifyStatus): email_notify("ARIMA automated grid search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Not applicable for this iteration of the project

# Set up the function to handle the ARIMA calculation
# def Calculate_ARIMA(ns_order, ss_order):
#     startTimeModel = datetime.now()
#     aic_score, bic_score = float("inf"), float("inf")
#     if (verbose): print('Trying to fit the model with parameters:', ns_order, ss_order)
#     try:
#         if (ss_order[3] == 0): grid_model = SARIMAX(time_series, order=ns_order)
#         else: grid_model = SARIMAX(time_series, order=ns_order, seasonal_order=ss_order)
#         with warnings.catch_warnings():
#             warnings.simplefilter("ignore")
#             grid_results = grid_model.fit(disp = False)
#         aic_score = grid_results.aic
#         bic_score = grid_results.bic
#         if (verbose): print('Fit ARIMA: order=%s seasonal_order=%s; AIC=%.3f, BIC=%.3f, Fit time=%s' % 
#               (ns_order, ss_order, aic_score, bic_score, (datetime.now() - startTimeModel)))
#         return(aic_score, bic_score)
#     except:
#         return(float("inf"), float("inf"))

# %%
# Not applicable for this iteration of the project

# Do a manual grid search of ARIMA parameters
# best_score, best_ns_cfg, best_ss_cfg = float("inf"), None, None
# for p in range(start_p, max_p+1):
#     for d in range(start_d, max_d+1):
#         for q in range(start_q, max_q+1):
#             for P in range(start_P, max_P+1):
#                 for D in range(start_D, max_D+1):
#                     for Q in range(start_Q, max_Q+1):
#                         ns_order = (p, d, q)
#                         ss_order = (P, D, Q, seasonal_freq)
#                         aic_score, bic_score = Calculate_ARIMA(ns_order, ss_order)
#                         if (aic_score < best_score):
#                             best_ns_cfg, best_ss_cfg, best_score = ns_order, ss_order, aic_score
#                             print('A better model found: order=%s seasonal_order=%s; AIC=%.3f, BIC=%.3f' % (ns_order, ss_order, aic_score, bic_score))
# print('Best ARIMA model via manual search: order=%s seasonal_order=%s; AIC=%f' % (best_ns_cfg, best_ss_cfg, best_score))

# %%
# manual_model = SARIMAX(time_series, order=best_ns_cfg, seasonal_order=best_ss_cfg)
# results = manual_model.fit(disp = False)
# print(results.summary())

# %%
if (notifyStatus): email_notify("ARIMA Hyperparameters Search completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 4.c) Evaluate the Residual Errors
#
# A good final check of a model is to review residual forecast errors. Ideally, the distribution of residual errors should be a Gaussian with a zero mean.

# %%
# Set the ARIMA order parameters for validation and forecasting
# final_ns_order = stepwise_results.order
# final_ss_order = stepwise_results.seasonal_order
final_ns_order = randgrid_results.order
final_ss_order = randgrid_results.seasonal_order
# final_ns_order = autogrid_results.order
# final_ss_order = autogrid_results.seasonal_order
# final_ns_order = best_ns_cfg
# final_ss_order = best_ss_cfg
print("Final Non-season order:", final_ns_order, 'Final Seasonal Order:', final_ss_order)
# Out:
# Final Non-season order: (4, 0, 4) Final Seasonal Order: (1, 0, 1, 12)

# %%
# Summarize residual errors for the chosen ARIMA model
final_model = SARIMAX(time_series, order=final_ns_order, seasonal_order=final_ss_order)
final_results = final_model.fit(disp = False)
print(final_results.summary())
final_results.plot_diagnostics(figsize=(12,12))
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /opt/conda/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                             values   No. Observations:                  132
# Model:             SARIMAX(4, 0, 4)x(1, 0, 1, 12)   Log Likelihood               -1374.226
# Date:                            Mon, 14 Oct 2019   AIC                           2770.451
# Time:                                    18:19:41   BIC                           2802.162
# Sample:                                01-01-1965   HQIC                          2783.337
#                                      - 12-01-1975
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1974      5.090      0.039      0.969      -9.778      10.173
# ar.L2          0.0756      0.541      0.140      0.889      -0.985       1.136
# ar.L3          0.8877      0.286      3.099      0.002       0.326       1.449
# ar.L4         -0.2799      4.557     -0.061      0.951      -9.210       8.651
# ma.L1          0.5823      5.116      0.114      0.909      -9.446      10.610
# ma.L2          0.6259      4.565      0.137      0.891      -8.321       9.573
# ma.L3         -0.3259      4.420     -0.074      0.941      -8.988       8.336
# ma.L4          0.0723      0.515      0.140      0.888      -0.938       1.082
# ar.S.L12       0.9833      0.028     34.829      0.000       0.928       1.039
# ma.S.L12      -0.7231      0.247     -2.923      0.003      -1.208      -0.238
# sigma2       9.09e+07    2.5e-07   3.64e+14      0.000    9.09e+07    9.09e+07
# ===================================================================================
# Ljung-Box (Q):                       24.51   Jarque-Bera (JB):                 4.23
# Prob(Q):                              0.97   Prob(JB):                         0.12
# Heteroskedasticity (H):               1.11   Skew:                             0.44
# Prob(H) (two-sided):                  0.74   Kurtosis:                         3.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.52e+31. Standard errors may be unstable.

# %%
if (notifyStatus): email_notify("Model Fitting and Evaluation completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 5. Finalize Model
#
# After models have been developed and a final model selected, it must be validated and finalized. Validation is an optional part of the process, but one that provides a ‘last check’ to ensure we have not fooled or lied to ourselves.

# %%
if (notifyStatus): email_notify("Model Finalization has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 5.a) Validation via In-sample Data

# %%
forecast = final_results.get_prediction(start = -test_size)
mean_forecast = forecast.predicted_mean
confidence_intervals = forecast.conf_int()

# %%
plt.figure(figsize=(12,9))
plt.plot(time_series.index, time_series[target_col], label='observed')
plt.plot(mean_forecast.index, mean_forecast.values, color='red', label='forecast')
plt.fill_between(confidence_intervals.index, confidence_intervals[lower_bound], confidence_intervals[upper_bound], color='pink')
plt.show()

# %%
# Evaluate RMSE for the validation data
y = time_series[-test_size:]
predictions = mean_forecast.values
rmse = math.sqrt(mean_squared_error(y, predictions))
print('RMSE from the validation data is: %.3f' % rmse)
# Out:
# RMSE from the validation data is: 6276.241

# %% [markdown]
# ### 5.b) Forecasting Out-of-Sample Data

# %%
forecast = final_results.get_forecast(steps = test_size)
mean_forecast = forecast.predicted_mean
confidence_intervals = forecast.conf_int()

# %%
plt.figure(figsize=(12,9))
plt.plot(time_series.index, time_series[target_col], label='observed')
plt.plot(mean_forecast.index, mean_forecast.values, color='red', label='forecast')
plt.fill_between(confidence_intervals.index, confidence_intervals[lower_bound], confidence_intervals[upper_bound], color='pink')
plt.show()

# %%
if (notifyStatus): email_notify("Model Finalization completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
print ('Total time for the script:',(datetime.now() - startTimeScript))
# Out:
# Total time for the script: 0:23:46.812282
